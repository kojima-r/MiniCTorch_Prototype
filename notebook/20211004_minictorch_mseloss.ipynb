# %% [markdown]
# MSE Loss　回帰問題
# 　　参考：https://axa.biopapyrus.jp/deep-learning/pytorch/regression-multiple-features.html

# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks/"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# フォルダは自分の指定のものに変更して下さい。

# %%
# %cd "ctorch210929/MiniCTorch_Prototype/notebook"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch210929/MiniCTorch_Prototype/notebook

# %% [markdown]
# サンプルデータ

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(2020)

_x = np.random.uniform(0, 10, 100)

x1 = np.sin(_x)
x2 = np.exp(_x / 5)
x = np.stack([x1, x2], axis=1)
y = 3 * x1 + 2 * x2 + np.random.uniform(-1, 1, 100)

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %%
! pip install lark-parser
# Out:
# Collecting lark-parser
#   Downloading lark_parser-0.12.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 5.4 MB/s
# Installing collected packages: lark-parser
# Successfully installed lark-parser-0.12.0

# %%
import sys
sys.path.append("../")

import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import minictorch.generator as GN
import minictorch.converter as CV

# %% [markdown]
# ニューラルネットワークの定義

# %%
def mean_squared_error( x0, x1 ):
    diff = x0 - x1
    y = (diff**2).sum() / len(diff)
    return y;

class Net(torch.nn.Module):
  
  def __init__( self, t ):
    super(Net, self).__init__()
    self.fc1 = torch.nn.Linear(2, 64)
    self.fc2 = torch.nn.Linear(64, 32)
    self.fc3 = torch.nn.Linear(32, 1)
    self.target = t

  def forward(self, x):
    x = torch.nn.functional.relu(self.fc1(x))
    x = torch.nn.functional.relu(self.fc2(x))
    x = self.fc3(x)

    self.out=x

    #y = mean_squared_error( x, self.target )
    loss = nn.MSELoss()
    y = loss( x, self.target )
    #print('loss', y )
    return y

# %%
def generate_json( json_path, input, target ):

    model = Net( target )

    model.eval()
    with torch.no_grad():
        print("[SAVE]", json_path )
        GN.generate_minictorch_file( model, input, json_path )

    return model

# %%
torch.manual_seed( 1 )

x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y.reshape(-1, 1)).float()

project = 'mse1'
json_path = '../network/' + project +'.json'

x_tensor.requires_grad = True

model = generate_json( json_path, x_tensor, y_tensor )

with torch.set_grad_enabled(True):
  #model.train()
  loss = model( x_tensor )
  print("loss ",loss)
  loss.backward()
  #print("out",model.out)
  #print("target",model.target)
  print("input",x_tensor.grad)
# Out:
# [SAVE] ../network/mse1.json
# skip: Net/Linear[fc1]/weight/50
# skip: Net/Linear[fc1]/weight/50
# skip: Net/Linear[fc2]/weight/53
# skip: Net/Linear[fc2]/weight/53
# skip: Net/Linear[fc3]/weight/56
# skip: Net/Linear[fc3]/weight/56
# loss  tensor(67.4897, grad_fn=<MseLossBackward>)
# input tensor([[ 6.7952e-03,  4.8823e-04],
#         [-8.7210e-03,  1.5778e-03],
#         [-1.4692e-03, -5.7917e-04],
#         [ 5.0851e-03, -3.3004e-03],
#         [-3.1918e-03, -6.0882e-04],
#         [ 7.3107e-03, -3.7030e-03],
#         [ 8.1786e-03, -5.5729e-03],
#         [-4.1216e-03, -7.8619e-04],
#         [-5.0728e-03,  8.8635e-04],
#         [ 3.6004e-04, -8.5637e-05],
#         [ 3.5354e-04, -8.4093e-05],
#         [-4.3465e-03,  7.3654e-04],
#         [-4.0067e-03,  6.7897e-04],
#         [-3.4841e-03, -5.3126e-04],
#         [-3.7277e-03, -7.1106e-04],
#         [ 6.2141e-05,  9.6287e-04],
#         [ 7.2834e-03, -3.6891e-03],
#         [-4.4959e-03, -3.9537e-04],
#         [ 3.9924e-04, -9.4963e-05],
#         [-3.5350e-03, -7.2280e-04],
#         [-5.3305e-04,  2.0967e-03],
#         [ 4.2013e-04, -9.9933e-05],
#         [-4.3099e-03, -3.7900e-04],
#         [-5.4636e-05,  1.1250e-03],
#         [-2.3520e-03, -7.7544e-04],
#         [ 6.5594e-05,  1.0163e-03],
#         [-2.8175e-04, -2.5140e-03],
#         [-7.3042e-05,  7.3730e-04],
#         [ 3.8610e-04, -9.1838e-05],
#         [-1.3349e-03, -3.4530e-04],
#         [ 3.9049e-04, -9.2883e-05],
#         [-7.6121e-03,  1.3772e-03],
#         [-2.6267e-03, -4.2821e-04],
#         [-1.7136e-03, -2.7936e-04],
#         [-4.4977e-03,  7.8585e-04],
#         [-2.1708e-03,  1.3491e-03],
#         [-5.9388e-03, -5.2225e-04],
#         [ 6.3841e-05,  9.8919e-04],
#         [ 3.9380e-04, -9.3669e-05],
#         [-4.4856e-03,  7.8374e-04],
#         [-8.4061e-05,  8.4853e-04],
#         [-4.9228e-03,  8.6014e-04],
#         [-4.0186e-03,  6.8098e-04],
#         [-3.4811e-03,  2.1633e-03],
#         [ 3.0112e-03, -1.4009e-03],
#         [ 3.6493e-04, -8.6801e-05],
#         [-1.8208e-03,  6.9478e-04],
#         [-3.8754e-03, -3.4080e-04],
#         [ 1.4418e-03, -9.3774e-04],
#         [ 4.3009e-05,  7.0248e-04],
#         [-9.6583e-04, -4.9340e-04],
#         [ 4.0602e-03, -2.6449e-03],
#         [-5.1178e-03, -4.5006e-04],
#         [ 6.8097e-03, -3.4492e-03],
#         [-7.0340e-03, -1.0018e-03],
#         [ 3.7568e-03, -2.7978e-03],
#         [-3.8822e-03, -3.4139e-04],
#         [-5.5184e-04,  2.1706e-03],
#         [-4.1151e-03,  6.9734e-04],
#         [-3.6962e-03,  6.3108e-04],
#         [-7.3168e-05,  7.3858e-04],
#         [ 5.7143e-05,  8.8541e-04],
#         [-3.6987e-03,  6.2677e-04],
#         [-4.1779e-03, -6.8109e-04],
#         [-1.2692e-03, -4.1847e-04],
#         [-4.0164e-04, -3.5837e-03],
#         [-8.2358e-03,  1.4901e-03],
#         [-4.9725e-03,  8.6881e-04],
#         [-3.7774e-03,  6.4012e-04],
#         [-7.7986e-03,  1.4110e-03],
#         [ 5.3231e-03, -3.4821e-03],
#         [ 1.6586e-03, -1.0787e-03],
#         [-7.1008e-03, -6.2444e-04],
#         [ 1.5773e-03, -4.1490e-04],
#         [-6.4321e-03, -9.1612e-04],
#         [ 6.1014e-05,  9.4538e-04],
#         [-4.9271e-04,  1.9380e-03],
#         [-4.6086e-03,  8.0524e-04],
#         [ 3.0026e-03, -1.3970e-03],
#         [ 4.1085e-04, -9.7724e-05],
#         [-4.3112e-03, -3.7912e-04],
#         [ 3.7647e-04, -8.9547e-05],
#         [ 7.5713e-03,  5.4400e-04],
#         [ 3.2488e-04, -7.7276e-05],
#         [-4.4317e-03,  7.7433e-04],
#         [ 2.7303e-03, -7.1365e-04],
#         [-4.9614e-03,  8.6688e-04],
#         [-8.7595e-03,  1.5848e-03],
#         [-6.4906e-05,  6.5517e-04],
#         [-7.3791e-03, -5.9744e-04],
#         [-5.4198e-05,  1.1160e-03],
#         [-9.5431e-04,  1.3051e-03],
#         [-6.8366e-05,  6.9010e-04],
#         [ 4.8607e-03, -3.1796e-03],
#         [-3.0570e-03,  1.8998e-03],
#         [ 5.4695e-03, -3.5499e-03],
#         [-5.6283e-04,  2.2138e-03],
#         [-1.6223e-03,  1.0441e-03],
#         [ 3.9325e-04, -9.3538e-05],
#         [-5.8559e-05,  5.9112e-04]])

# %%
"""
def convert_json( project, folder, model, input_x, json_path, rand_flag=0 ):

    #folder = "src"
    cpp_fname   = project + ".cpp"
    param_fname = project + "_param.cpp"
    cpp_path    = folder + "/" + cpp_fname
    param_path  = folder + "/" + param_fname
    make_path   = folder + "/" + "Makefile"

    # load json file
    print( "[JSON]", json_path )
    fp = open( json_path )
    obj = json.load( fp )

    # save parameter file
    code1 = CV.c_param_generator( obj, model, input_x )
    if len( code1 ) > 0:
       print( "[PARAM]", param_path )
       ofparam = open( param_path, "w" )
       ofparam.write( code1 )

    # save cpp file
    print( "[CPP]  ", cpp_path )
    code2 = CV.c_code_generator( obj, model, rand_flag )

    #print("[SAVE]",args.path+"/"+args.output)
    #ofp=open(args.path+"/"+args.output,"w")
    ofp = open( cpp_path, "w" )
    ofp.write( code2 )

    # save make file
    print( "[MAKE] ", make_path )
    make_code = CV.makefile_generator( cpp_fname )

    #makefp=open(args.path+"/"+"Makefile","w")
    makefp = open( make_path, "w" )
    makefp.write( make_code )

"""

# %%
CV.convert_json( project, "../src", model, x_tensor, json_path )
# Out:
# [JSON] ../network/mse1.json
# {'name': 'Net/Linear[fc1]/weight/64', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# {'name': 'Net/Linear[fc1]/bias/63', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# {'name': 'Net/Linear[fc2]/weight/67', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# {'name': 'Net/Linear[fc2]/bias/66', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# {'name': 'Net/Linear[fc3]/weight/70', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 9}
# {'name': 'Net/Linear[fc3]/bias/69', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 10}
# [PARAM] ../src/mse1_param.cpp
# {'name': 'input/x', 'op': 'IO Node', 'in': [], 'output_id': 0, 'shape': [100, 2], 'out': [3], 'sorted_id': 0}
# {'name': 'Net/Linear[fc1]/weight/64', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# Net/Linear[fc1]/weight/64  ->  fc1_weight
# {'name': 'Net/Linear[fc1]/bias/63', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# Net/Linear[fc1]/bias/63  ->  fc1_bias
# {'name': 'Net/Linear[fc1]/input.1', 'op': 'aten::linear', 'in': [0, 1, 2], 'output_id': 0, 'shape': [100, 64], 'out': [4], 'sorted_id': 3}
# {'name': 'Net/input.3', 'op': 'aten::relu', 'in': [3], 'output_id': 0, 'shape': [100, 64], 'out': [7], 'sorted_id': 4}
# {'name': 'Net/Linear[fc2]/weight/67', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# Net/Linear[fc2]/weight/67  ->  fc2_weight
# {'name': 'Net/Linear[fc2]/bias/66', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# Net/Linear[fc2]/bias/66  ->  fc2_bias
# {'name': 'Net/Linear[fc2]/input.5', 'op': 'aten::linear', 'in': [4, 5, 6], 'output_id': 0, 'shape': [100, 32], 'out': [8], 'sorted_id': 7}
# {'name': 'Net/input.7', 'op': 'aten::relu', 'in': [7], 'output_id': 0, 'shape': [100, 32], 'out': [11], 'sorted_id': 8}
# {'name': 'Net/Linear[fc3]/weight/70', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 9}
# Net/Linear[fc3]/weight/70  ->  fc3_weight
# {'name': 'Net/Linear[fc3]/bias/69', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 10}
# Net/Linear[fc3]/bias/69  ->  fc3_bias
# {'name': 'Net/Linear[fc3]/input.9', 'op': 'aten::linear', 'in': [8, 9, 10], 'output_id': 0, 'shape': [100, 1], 'out': [13], 'sorted_id': 11}
# {'name': 'Net/target.1', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [100, 1], 'constant_value': [12.6442, 14.2724, 2.3541, 3.9799, 2.7917, 6.2946, 5.4144, 3.6112, 14.1766, 4.7809, 4.6936, 12.7688, 11.7691, 3.2024, 3.2638, 9.1611, 6.271, 4.5049, 5.3078, 3.2171, 13.3978, 5.5882, 4.32, 12.3751, 3.1452, 9.6706, 2.7055, 2.4756, 5.1311, 2.4733, 5.1901, 12.4477, 2.2895, 1.4738, 12.5678, 8.8092, 5.9747, 9.4119, 5.2347, 12.5353, 2.8599, 13.761, 11.8049, 14.1149, 4.6603, 4.8467, 7.3956, 3.8746, 5.8784, 2.454, 3.005, 3.8026, 5.1516, 5.8612, 4.4625, 3.2352, 3.885, 13.8736, 12.0878, 10.4887, 2.4796, 8.4232, 10.8639, 3.6631, 1.6655, 3.8742, 13.4705, 13.8999, 11.0951, 12.7526, 5.4187, 6.7698, 7.1659, 1.756, 4.0808, 8.9944, 12.381, 12.8833, 4.6455, 5.4636, 4.3245, 5.0018, 14.0947, 4.3089, 12.3858, 2.9765, 13.8632, 14.326, 2.1931, 5.8966, 12.2755, 2.9158, 2.3136, 4.9452, 12.3885, 4.2832, 14.1509, 2.685, 5.2271, 1.9709], 'out': [13], 'sorted_id': 12}
# {'name': 'Net/39', 'op': 'prim::ListConstruct', 'in': [11, 12], 'output_id': 0, 'shape': [], 'out': [14], 'sorted_id': 13}
# {'name': 'Net/40', 'op': 'aten::broadcast_tensors', 'in': [13], 'output_id': 0, 'shape': [], 'out': [16, 15], 'sorted_id': 14}
# {'name': 'Net/input', 'op': 'prim::ListUnpack', 'in': [14], 'output_id': 0, 'shape': [100, 1], 'out': [18], 'sorted_id': 15}
# {'name': 'Net/target', 'op': 'prim::ListUnpack', 'in': [14], 'output_id': 1, 'shape': [100, 1], 'out': [18], 'sorted_id': 16}
# {'name': 'Net/43', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [18], 'sorted_id': 17}
# {'name': 'Net/44', 'op': 'aten::mse_loss', 'in': [15, 16, 17], 'output_id': 0, 'shape': [], 'out': [19], 'sorted_id': 18}
# {'name': 'output/output.1', 'op': 'IO Node', 'in': [18], 'output_id': 0, 'shape': [], 'out': [], 'sorted_id': 19}
# [CPP]  ../src/mse1.cpp
# [MAKE] ../src/Makefile

# %%
# !g++ -std=c++14 ../src/mse1.cpp ../src/mse1_param.cpp  -I ../../../xtensor  -lcblas -o ../bin/mse1

# %% [markdown]
# (注意) xtensorフォルダにxtensor関連のincludeを置いています。各自の環境に合わせて変更して下さい。

# %%
# !../bin/mse1
# Out:
# ### forward computation ...
#  67.489609
# ### backward computation ...
# input_grad{{ 0.006795,  0.000488},
#  {-0.008721,  0.001578},
#  {-0.001469, -0.000579},
#  { 0.005085, -0.0033  },
#  {-0.003192, -0.000609},
#  { 0.007311, -0.003703},
#  { 0.008179, -0.005573},
#  {-0.004122, -0.000786},
#  {-0.005073,  0.000886},
#  { 0.00036 , -0.000086},
#  { 0.000354, -0.000084},
#  {-0.004346,  0.000737},
#  {-0.004007,  0.000679},
#  {-0.003484, -0.000531},
#  {-0.003728, -0.000711},
#  { 0.000062,  0.000963},
#  { 0.007283, -0.003689},
#  {-0.004496, -0.000395},
#  { 0.000399, -0.000095},
#  {-0.003535, -0.000723},
#  {-0.000533,  0.002097},
#  { 0.00042 , -0.0001  },
#  {-0.00431 , -0.000379},
#  {-0.000055,  0.001125},
#  {-0.002352, -0.000775},
#  { 0.000066,  0.001016},
#  {-0.000282, -0.002514},
#  {-0.000073,  0.000737},
#  { 0.000386, -0.000092},
#  {-0.001335, -0.000345},
#  { 0.00039 , -0.000093},
#  {-0.007612,  0.001377},
#  {-0.002627, -0.000428},
#  {-0.001714, -0.000279},
#  {-0.004498,  0.000786},
#  {-0.002171,  0.001349},
#  {-0.005939, -0.000522},
#  { 0.000064,  0.000989},
#  { 0.000394, -0.000094},
#  {-0.004486,  0.000784},
#  {-0.000084,  0.000849},
#  {-0.004923,  0.00086 },
#  {-0.004019,  0.000681},
#  {-0.003481,  0.002163},
#  { 0.003011, -0.001401},
#  { 0.000365, -0.000087},
#  {-0.001821,  0.000695},
#  {-0.003875, -0.000341},
#  { 0.001442, -0.000938},
#  { 0.000043,  0.000702},
#  {-0.000966, -0.000493},
#  { 0.00406 , -0.002645},
#  {-0.005118, -0.00045 },
#  { 0.00681 , -0.003449},
#  {-0.007034, -0.001002},
#  { 0.003757, -0.002798},
#  {-0.003882, -0.000341},
#  {-0.000552,  0.002171},
#  {-0.004115,  0.000697},
#  {-0.003696,  0.000631},
#  {-0.000073,  0.000739},
#  { 0.000057,  0.000885},
#  {-0.003699,  0.000627},
#  {-0.004178, -0.000681},
#  {-0.001269, -0.000418},
#  {-0.000402, -0.003584},
#  {-0.008236,  0.00149 },
#  {-0.004972,  0.000869},
#  {-0.003777,  0.00064 },
#  {-0.007799,  0.001411},
#  { 0.005323, -0.003482},
#  { 0.001659, -0.001079},
#  {-0.007101, -0.000624},
#  { 0.001577, -0.000415},
#  {-0.006432, -0.000916},
#  { 0.000061,  0.000945},
#  {-0.000493,  0.001938},
#  {-0.004609,  0.000805},
#  { 0.003003, -0.001397},
#  { 0.000411, -0.000098},
#  {-0.004311, -0.000379},
#  { 0.000376, -0.00009 },
#  { 0.007571,  0.000544},
#  { 0.000325, -0.000077},
#  {-0.004432,  0.000774},
#  { 0.00273 , -0.000714},
#  {-0.004961,  0.000867},
#  {-0.008759,  0.001585},
#  {-0.000065,  0.000655},
#  {-0.007379, -0.000597},
#  {-0.000054,  0.001116},
#  {-0.000954,  0.001305},
#  {-0.000068,  0.00069 },
#  { 0.004861, -0.00318 },
#  {-0.003057,  0.0019  },
#  { 0.00547 , -0.00355 },
#  {-0.000563,  0.002214},
#  {-0.001622,  0.001044},
#  { 0.000393, -0.000094},
#  {-0.000059,  0.000591}}

# %% [markdown]
# 学習の実行(torch版)

# %%
class Net(torch.nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = torch.nn.Linear(2, 64)
    self.fc2 = torch.nn.Linear(64, 32)
    self.fc3 = torch.nn.Linear(32, 1)

  def forward(self, x):
    x = torch.nn.functional.relu(self.fc1(x))
    x = torch.nn.functional.relu(self.fc2(x))
    x = self.fc3(x)
    return x

# %%
torch.manual_seed( 1 )
 
x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y.reshape(-1, 1)).float()

project = 'test4'
json_path = '../network/' + project +'.json'

x_tensor.requires_grad = True

net = Net()
net.train()
lr=0.01
opt=torch.optim.SGD(net.parameters(), lr)
mse=torch.nn.MSELoss()

for epoch in range(3):
  out=net(x_tensor)
  loss=mse(out,y_tensor)
  print("loss",loss)

  opt.zero_grad()
  loss.backward()
  opt.step();
# Out:
# loss tensor(67.4897, grad_fn=<MseLossBackward>)
# loss tensor(36.1833, grad_fn=<MseLossBackward>)
# loss tensor(3.8057, grad_fn=<MseLossBackward>)

# %% [markdown]
# C++のコードは手作業で修正しています。

# %%
# !g++ -std=c++14 ../src/mse1.cpp ../src/mse1_param.cpp ../src/mse1_train.cpp  -D_TRAIN_LOOP -I ../../../xtensor -lcblas -o ../bin/mse1_train

# %% [markdown]
# (注意) xtensorにxtensor関連のincludeを置いています。

# %%
# !../bin/mse1_train
# Out:
# epoch 0 - loss 67.4896
# epoch 1 - loss 36.1833
# epoch 2 - loss 3.80568
# epoch 3 - loss 5.00023
# epoch 4 - loss 8.29694
# epoch 5 - loss 23.9232
# epoch 6 - loss 8.93713
# epoch 7 - loss 25.941
# epoch 8 - loss 5.53438
# epoch 9 - loss 14.032
# epoch 10 - loss 10.9611
# epoch 11 - loss 31.0119
# epoch 12 - loss 1.59739
# epoch 13 - loss 1.55513
# epoch 14 - loss 1.66704
# epoch 15 - loss 2.34869
# epoch 16 - loss 3.64226
# epoch 17 - loss 9.31862
# epoch 18 - loss 9.30901
# epoch 19 - loss 26.372
# epoch 20 - loss 1.44155
# epoch 21 - loss 2.284
# epoch 22 - loss 3.39256
# epoch 23 - loss 8.37133
# epoch 24 - loss 7.2635
# epoch 25 - loss 19.5551
# epoch 26 - loss 2.92081
# epoch 27 - loss 6.62633
# epoch 28 - loss 5.92831
# epoch 29 - loss 15.0172
# epoch 30 - loss 3.91594
# epoch 31 - loss 9.14582
# epoch 32 - loss 5.23805
# epoch 33 - loss 12.5484
# epoch 34 - loss 4.02986
# epoch 35 - loss 9.12672
# epoch 36 - loss 4.5776
# epoch 37 - loss 10.4065
# epoch 38 - loss 4.05323
# epoch 39 - loss 8.92107
# epoch 40 - loss 4.11703
# epoch 41 - loss 8.97
# epoch 42 - loss 3.90764
# epoch 43 - loss 8.34061
# epoch 44 - loss 3.82469
# epoch 45 - loss 8.0497
# epoch 46 - loss 3.70604
# epoch 47 - loss 7.68513
# epoch 48 - loss 3.61044
# epoch 49 - loss 7.3887
# epoch 50 - loss 3.51833
# epoch 51 - loss 7.11025
# epoch 52 - loss 3.43334
# epoch 53 - loss 6.85663
# epoch 54 - loss 3.35463
# epoch 55 - loss 6.62464
# epoch 56 - loss 3.27981
# epoch 57 - loss 6.40786
# epoch 58 - loss 3.2093
# epoch 59 - loss 6.2059
# epoch 60 - loss 3.1429
# epoch 61 - loss 6.01765
# epoch 62 - loss 3.07968
# epoch 63 - loss 5.84108
# epoch 64 - loss 3.02022
# epoch 65 - loss 5.67528
# epoch 66 - loss 2.96111
# epoch 67 - loss 5.51284
# epoch 68 - loss 2.9056
# epoch 69 - loss 5.36331
# epoch 70 - loss 2.85267
# epoch 71 - loss 5.22294
# epoch 72 - loss 2.8034
# epoch 73 - loss 5.09347
# epoch 74 - loss 2.75746
# epoch 75 - loss 4.97001
# epoch 76 - loss 2.71284
# epoch 77 - loss 4.85772
# epoch 78 - loss 2.67018
# epoch 79 - loss 4.74421
# epoch 80 - loss 2.62857
# epoch 81 - loss 4.63748
# epoch 82 - loss 2.58819
# epoch 83 - loss 4.53794
# epoch 84 - loss 2.5491
# epoch 85 - loss 4.43666
# epoch 86 - loss 2.5115
# epoch 87 - loss 4.34301
# epoch 88 - loss 2.47651
# epoch 89 - loss 4.25915
# epoch 90 - loss 2.44236
# epoch 91 - loss 4.17156
# epoch 92 - loss 2.40812
# epoch 93 - loss 4.09119
# epoch 94 - loss 2.37554
# epoch 95 - loss 4.009
# epoch 96 - loss 2.34326
# epoch 97 - loss 3.93198
# epoch 98 - loss 2.31196
# epoch 99 - loss 3.85888
# epoch 100 - loss 2.28128
# epoch 101 - loss 3.78278
# epoch 102 - loss 2.25089
# epoch 103 - loss 3.71079
# epoch 104 - loss 2.22143
# epoch 105 - loss 3.64411
# epoch 106 - loss 2.19223
# epoch 107 - loss 3.57406
# epoch 108 - loss 2.16324
# epoch 109 - loss 3.50741
# epoch 110 - loss 2.13645
# epoch 111 - loss 3.44898
# epoch 112 - loss 2.11106
# epoch 113 - loss 3.38839
# epoch 114 - loss 2.08484
# epoch 115 - loss 3.3307
# epoch 116 - loss 2.05966
# epoch 117 - loss 3.27158
# epoch 118 - loss 2.03412
# epoch 119 - loss 3.21735
# epoch 120 - loss 2.01061
# epoch 121 - loss 3.16267
# epoch 122 - loss 1.98644
# epoch 123 - loss 3.11265
# epoch 124 - loss 1.9634
# epoch 125 - loss 3.05963
# epoch 126 - loss 1.93974
# epoch 127 - loss 3.00851
# epoch 128 - loss 1.91683
# epoch 129 - loss 2.96151
# epoch 130 - loss 1.89502
# epoch 131 - loss 2.91217
# epoch 132 - loss 1.87245
# epoch 133 - loss 2.86465
# epoch 134 - loss 1.85041
# epoch 135 - loss 2.8175
# epoch 136 - loss 1.82862
# epoch 137 - loss 2.77373
# epoch 138 - loss 1.80789
# epoch 139 - loss 2.72837
# epoch 140 - loss 1.78675
# epoch 141 - loss 2.68435
# epoch 142 - loss 1.76599
# epoch 143 - loss 2.6382
# epoch 144 - loss 1.74461
# epoch 145 - loss 2.59523
# epoch 146 - loss 1.72466
# epoch 147 - loss 2.5574
# epoch 148 - loss 1.70566
# epoch 149 - loss 2.51575
# epoch 150 - loss 1.68583
# epoch 151 - loss 2.47587
# epoch 152 - loss 1.66648
# epoch 153 - loss 2.43738
# epoch 154 - loss 1.64759
# epoch 155 - loss 2.39969
# epoch 156 - loss 1.62893
# epoch 157 - loss 2.36567
# epoch 158 - loss 1.61165
# epoch 159 - loss 2.32862
# epoch 160 - loss 1.59422
# epoch 161 - loss 2.29407
# epoch 162 - loss 1.57704
# epoch 163 - loss 2.26248
# epoch 164 - loss 1.56095
# epoch 165 - loss 2.2291
# epoch 166 - loss 1.54384
# epoch 167 - loss 2.19589
# epoch 168 - loss 1.52811
# epoch 169 - loss 2.1683
# epoch 170 - loss 1.51335
# epoch 171 - loss 2.13908
# epoch 172 - loss 1.49868
# epoch 173 - loss 2.11138
# epoch 174 - loss 1.48318
# epoch 175 - loss 2.07874
# epoch 176 - loss 1.46758
# epoch 177 - loss 2.04927
# epoch 178 - loss 1.45171
# epoch 179 - loss 2.02289
# epoch 180 - loss 1.43724
# epoch 181 - loss 1.99246
# epoch 182 - loss 1.42186
# epoch 183 - loss 1.9657
# epoch 184 - loss 1.40629
# epoch 185 - loss 1.93731
# epoch 186 - loss 1.39191
# epoch 187 - loss 1.90929
# epoch 188 - loss 1.37638
# epoch 189 - loss 1.88029
# epoch 190 - loss 1.3617
# epoch 191 - loss 1.85355
# epoch 192 - loss 1.34666
# epoch 193 - loss 1.82865
# epoch 194 - loss 1.33363
# epoch 195 - loss 1.80281
# epoch 196 - loss 1.31901
# epoch 197 - loss 1.77678
# epoch 198 - loss 1.30558
# epoch 199 - loss 1.75256
# epoch 200 - loss 1.29166
# epoch 201 - loss 1.72808
# epoch 202 - loss 1.27829
# epoch 203 - loss 1.7044
# epoch 204 - loss 1.26476
# epoch 205 - loss 1.68263
# epoch 206 - loss 1.25296
# epoch 207 - loss 1.65975
# epoch 208 - loss 1.2397
# epoch 209 - loss 1.63653
# epoch 210 - loss 1.22688
# epoch 211 - loss 1.61417
# epoch 212 - loss 1.21399
# epoch 213 - loss 1.59204
# epoch 214 - loss 1.20217
# epoch 215 - loss 1.57154
# epoch 216 - loss 1.18999
# epoch 217 - loss 1.55054
# epoch 218 - loss 1.17839
# epoch 219 - loss 1.53073
# epoch 220 - loss 1.16644
# epoch 221 - loss 1.51029
# epoch 222 - loss 1.15465
# epoch 223 - loss 1.49007
# epoch 224 - loss 1.14266
# epoch 225 - loss 1.46985
# epoch 226 - loss 1.13114
# epoch 227 - loss 1.45069
# epoch 228 - loss 1.11962
# epoch 229 - loss 1.43156
# epoch 230 - loss 1.10862
# epoch 231 - loss 1.41315
# epoch 232 - loss 1.09755
# epoch 233 - loss 1.39499
# epoch 234 - loss 1.08693
# epoch 235 - loss 1.37745
# epoch 236 - loss 1.07626
# epoch 237 - loss 1.35981
# epoch 238 - loss 1.06586
# epoch 239 - loss 1.34291
# epoch 240 - loss 1.05537
# epoch 241 - loss 1.32558
# epoch 242 - loss 1.04549
# epoch 243 - loss 1.3095
# epoch 244 - loss 1.03541
# epoch 245 - loss 1.29325
# epoch 246 - loss 1.02584
# epoch 247 - loss 1.27769
# epoch 248 - loss 1.0161
# epoch 249 - loss 1.26197
# epoch 250 - loss 1.00679
# epoch 251 - loss 1.24717
# epoch 252 - loss 0.99743
# epoch 253 - loss 1.23224
# epoch 254 - loss 0.988424
# epoch 255 - loss 1.21676
# epoch 256 - loss 0.97881
# epoch 257 - loss 1.20287
# epoch 258 - loss 0.970362
# epoch 259 - loss 1.18842
# epoch 260 - loss 0.961246
# epoch 261 - loss 1.17536
# epoch 262 - loss 0.953209
# epoch 263 - loss 1.16158
# epoch 264 - loss 0.944356
# epoch 265 - loss 1.14899
# epoch 266 - loss 0.936367
# epoch 267 - loss 1.13544
# epoch 268 - loss 0.928109
# epoch 269 - loss 1.12379
# epoch 270 - loss 0.92042
# epoch 271 - loss 1.11076
# epoch 272 - loss 0.912799
# epoch 273 - loss 1.10014
# epoch 274 - loss 0.905777
# epoch 275 - loss 1.08927
# epoch 276 - loss 0.898904
# epoch 277 - loss 1.0787
# epoch 278 - loss 0.89173
# epoch 279 - loss 1.0677
# epoch 280 - loss 0.884643
# epoch 281 - loss 1.0569
# epoch 282 - loss 0.87798
# epoch 283 - loss 1.04647
# epoch 284 - loss 0.870943
# epoch 285 - loss 1.0348
# epoch 286 - loss 0.863382
# epoch 287 - loss 1.02451
# epoch 288 - loss 0.856828
# epoch 289 - loss 1.01459
# epoch 290 - loss 0.850096
# epoch 291 - loss 1.00453
# epoch 292 - loss 0.843441
# epoch 293 - loss 0.994587
# epoch 294 - loss 0.837039
# epoch 295 - loss 0.983949
# epoch 296 - loss 0.830492
# epoch 297 - loss 0.97523
# epoch 298 - loss 0.824644
# epoch 299 - loss 0.966518
# epoch 300 - loss 0.818941
# epoch 301 - loss 0.958064
# epoch 302 - loss 0.813043
# epoch 303 - loss 0.949313
# epoch 304 - loss 0.807156
# epoch 305 - loss 0.94065
# epoch 306 - loss 0.801469
# epoch 307 - loss 0.932269
# epoch 308 - loss 0.795612
# epoch 309 - loss 0.923688
# epoch 310 - loss 0.78988
# epoch 311 - loss 0.915307
# epoch 312 - loss 0.784077
# epoch 313 - loss 0.906874
# epoch 314 - loss 0.778479
# epoch 315 - loss 0.898676
# epoch 316 - loss 0.772788
# epoch 317 - loss 0.890452
# epoch 318 - loss 0.767278
# epoch 319 - loss 0.882493
# epoch 320 - loss 0.761721
# epoch 321 - loss 0.874507
# epoch 322 - loss 0.75636
# epoch 323 - loss 0.866809
# epoch 324 - loss 0.751062
# epoch 325 - loss 0.859232
# epoch 326 - loss 0.745837
# epoch 327 - loss 0.851786
# epoch 328 - loss 0.74083
# epoch 329 - loss 0.844644
# epoch 330 - loss 0.735717
# epoch 331 - loss 0.837377
# epoch 332 - loss 0.730726
# epoch 333 - loss 0.830425
# epoch 334 - loss 0.725961
# epoch 335 - loss 0.82367
# epoch 336 - loss 0.72109
# epoch 337 - loss 0.816808
# epoch 338 - loss 0.716389
# epoch 339 - loss 0.810176
# epoch 340 - loss 0.711642
# epoch 341 - loss 0.803609
# epoch 342 - loss 0.707066
# epoch 343 - loss 0.797162
# epoch 344 - loss 0.702594
# epoch 345 - loss 0.790902
# epoch 346 - loss 0.698179
# epoch 347 - loss 0.784805
# epoch 348 - loss 0.693879
# epoch 349 - loss 0.778835
# epoch 350 - loss 0.689751
# epoch 351 - loss 0.773095
# epoch 352 - loss 0.685531
# epoch 353 - loss 0.767203
# epoch 354 - loss 0.681373
# epoch 355 - loss 0.761523
# epoch 356 - loss 0.677369
# epoch 357 - loss 0.756737
# epoch 358 - loss 0.673779
# epoch 359 - loss 0.750992
# epoch 360 - loss 0.669663
# epoch 361 - loss 0.745326
# epoch 362 - loss 0.665727
# epoch 363 - loss 0.739897
# epoch 364 - loss 0.661738
# epoch 365 - loss 0.735252
# epoch 366 - loss 0.658461
# epoch 367 - loss 0.729991
# epoch 368 - loss 0.654514
# epoch 369 - loss 0.724649
# epoch 370 - loss 0.65064
# epoch 371 - loss 0.7201
# epoch 372 - loss 0.647408
# epoch 373 - loss 0.714904
# epoch 374 - loss 0.643597
# epoch 375 - loss 0.709826
# epoch 376 - loss 0.639933
# epoch 377 - loss 0.705568
# epoch 378 - loss 0.636819
# epoch 379 - loss 0.700626
# epoch 380 - loss 0.633129
# epoch 381 - loss 0.695693
# epoch 382 - loss 0.629507
# epoch 383 - loss 0.690808
# epoch 384 - loss 0.626002
# epoch 385 - loss 0.686735
# epoch 386 - loss 0.623076
# epoch 387 - loss 0.682173
# epoch 388 - loss 0.61974
# epoch 389 - loss 0.67768
# epoch 390 - loss 0.616351
# epoch 391 - loss 0.673888
# epoch 392 - loss 0.6135
# epoch 393 - loss 0.669375
# epoch 394 - loss 0.610242
# epoch 395 - loss 0.665108
# epoch 396 - loss 0.607026
# epoch 397 - loss 0.660781
# epoch 398 - loss 0.603842
# epoch 399 - loss 0.657268
# epoch 400 - loss 0.601222
# epoch 401 - loss 0.653265
# epoch 402 - loss 0.598153
# epoch 403 - loss 0.649136
# epoch 404 - loss 0.595062
# epoch 405 - loss 0.645839
# epoch 406 - loss 0.592626
# epoch 407 - loss 0.642061
# epoch 408 - loss 0.589743
# epoch 409 - loss 0.638109
# epoch 410 - loss 0.586735
# epoch 411 - loss 0.634162
# epoch 412 - loss 0.58383
# epoch 413 - loss 0.631196
# epoch 414 - loss 0.581492
# epoch 415 - loss 0.62733
# epoch 416 - loss 0.578748
# epoch 417 - loss 0.623714
# epoch 418 - loss 0.575925
# epoch 419 - loss 0.620927
# epoch 420 - loss 0.573858
# epoch 421 - loss 0.617319
# epoch 422 - loss 0.571121
# epoch 423 - loss 0.61397
# epoch 424 - loss 0.568452
# epoch 425 - loss 0.610361
# epoch 426 - loss 0.565843
# epoch 427 - loss 0.607793
# epoch 428 - loss 0.563821
# epoch 429 - loss 0.604351
# epoch 430 - loss 0.561079
# epoch 431 - loss 0.600822
# epoch 432 - loss 0.558491
# epoch 433 - loss 0.597633
# epoch 434 - loss 0.556073
# epoch 435 - loss 0.595018
# epoch 436 - loss 0.553839
# epoch 437 - loss 0.591759
# epoch 438 - loss 0.55156
# epoch 439 - loss 0.588585
# epoch 440 - loss 0.549057
# epoch 441 - loss 0.585474
# epoch 442 - loss 0.546516
# epoch 443 - loss 0.582969
# epoch 444 - loss 0.544748
# epoch 445 - loss 0.579926
# epoch 446 - loss 0.54233
# epoch 447 - loss 0.577038
# epoch 448 - loss 0.539957
# epoch 449 - loss 0.573874
# epoch 450 - loss 0.537643
# epoch 451 - loss 0.571648
# epoch 452 - loss 0.535944
# epoch 453 - loss 0.568751
# epoch 454 - loss 0.533467
# epoch 455 - loss 0.565627
# epoch 456 - loss 0.531228
# epoch 457 - loss 0.562642
# epoch 458 - loss 0.528943
# epoch 459 - loss 0.560494
# epoch 460 - loss 0.527159
# epoch 461 - loss 0.557516
# epoch 462 - loss 0.52472
# epoch 463 - loss 0.554439
# epoch 464 - loss 0.522545
# epoch 465 - loss 0.551818
# epoch 466 - loss 0.520382
# epoch 467 - loss 0.549663
# epoch 468 - loss 0.518529
# epoch 469 - loss 0.546737
# epoch 470 - loss 0.516473
# epoch 471 - loss 0.544154
# epoch 472 - loss 0.514361
# epoch 473 - loss 0.541629
# epoch 474 - loss 0.512422
# epoch 475 - loss 0.539577
# epoch 476 - loss 0.510726
# epoch 477 - loss 0.537067
# epoch 478 - loss 0.508839
# epoch 479 - loss 0.534618
# epoch 480 - loss 0.506885
# epoch 481 - loss 0.532277
# epoch 482 - loss 0.505101
# epoch 483 - loss 0.530436
# epoch 484 - loss 0.503395
# epoch 485 - loss 0.527951
# epoch 486 - loss 0.501577
# epoch 487 - loss 0.525586
# epoch 488 - loss 0.499724
# epoch 489 - loss 0.523428
# epoch 490 - loss 0.498002
# epoch 491 - loss 0.521747
# epoch 492 - loss 0.49663
# epoch 493 - loss 0.519588
# epoch 494 - loss 0.494787
# epoch 495 - loss 0.517219
# epoch 496 - loss 0.493017
# epoch 497 - loss 0.515646
# epoch 498 - loss 0.491711
# epoch 499 - loss 0.513414

# %%
f = open('./mse1.out', 'r')

epoch_loss = []

datalist = f.readlines()
for data in datalist:
  #print(data)
  epoch_loss.append( float(data) )

f.close()

print("epoch =", len(epoch_loss))
print( epoch_loss)


f2 = open('./mse1.pred', 'r')

x_new = []
y_pred = []
datalist = f2.readlines()
for data in datalist:
  #print(data)
  ds = data.split(',')
  x_new.append( float(ds[0]))
  y_pred.append( float(ds[1]))
  #x_new.append( float(data) )

f2.close()

print("pred =", len(x_new))
print( x_new )
print( y_pred )
# Out:
# epoch = 500
# [67.489609, 36.1833, 3.805676, 5.000233, 8.296941, 23.923243, 8.937128, 25.940987, 5.534382, 14.032016, 10.961112, 31.011883, 1.597391, 1.555127, 1.66704, 2.348695, 3.64226, 9.31862, 9.309009, 26.371971, 1.441545, 2.283998, 3.392555, 8.371325, 7.2635, 19.555117, 2.920814, 6.626325, 5.928308, 15.017187, 3.915945, 9.145824, 5.238048, 12.548371, 4.029859, 9.126719, 4.577601, 10.406542, 4.053226, 8.92107, 4.117025, 8.970004, 3.907642, 8.340606, 3.824687, 8.049696, 3.706045, 7.685133, 3.610443, 7.388703, 3.51833, 7.110254, 3.433341, 6.856628, 3.354629, 6.624643, 3.279809, 6.40786, 3.209304, 6.205905, 3.142902, 6.017651, 3.079683, 5.841084, 3.020222, 5.675284, 2.961112, 5.512842, 2.905596, 5.363312, 2.852673, 5.222939, 2.803398, 5.09347, 2.757456, 4.970007, 2.712839, 4.857723, 2.670183, 4.744208, 2.628574, 4.637481, 2.588186, 4.537941, 2.549103, 4.436661, 2.511497, 4.343006, 2.476508, 4.259149, 2.442358, 4.171561, 2.408118, 4.09119, 2.375538, 4.009, 2.343258, 3.931981, 2.311956, 3.858881, 2.281279, 3.782778, 2.250894, 3.710785, 2.221428, 3.644115, 2.192225, 3.574063, 2.16324, 3.507415, 2.136453, 3.448983, 2.111065, 3.388387, 2.084836, 3.330698, 2.059658, 3.271584, 2.034117, 3.217355, 2.010613, 3.162668, 1.986441, 3.112654, 1.963399, 3.059626, 1.939745, 3.008514, 1.916832, 2.96151, 1.895016, 2.912172, 1.872449, 2.864652, 1.850412, 2.817496, 1.828621, 2.773731, 1.807888, 2.728373, 1.786752, 2.684349, 1.765994, 2.638204, 1.744607, 2.595233, 1.724663, 2.5574, 1.705657, 2.515753, 1.68583, 2.475873, 1.66648, 2.437377, 1.647586, 2.399688, 1.628929, 2.365668, 1.611648, 2.328618, 1.594216, 2.294068, 1.577038, 2.262481, 1.56095, 2.229097, 1.543836, 2.195889, 1.52811, 2.168299, 1.513354, 2.139076, 1.498681, 2.111383, 1.483185, 2.07874, 1.467579, 2.049271, 1.451711, 2.022889, 1.437236, 1.992462, 1.421857, 1.965703, 1.406292, 1.937305, 1.391909, 1.90929, 1.376378, 1.880287, 1.361698, 1.853548, 1.346661, 1.828655, 1.33363, 1.802806, 1.319009, 1.776779, 1.305578, 1.752564, 1.291663, 1.72808, 1.278291, 1.7044, 1.264756, 1.682628, 1.252962, 1.659752, 1.239701, 1.636528, 1.226881, 1.614173, 1.213993, 1.592038, 1.202173, 1.571537, 1.18999, 1.550538, 1.178391, 1.530729, 1.166436, 1.510292, 1.154653, 1.490069, 1.14266, 1.46985, 1.131136, 1.450691, 1.119623, 1.431564, 1.108619, 1.413152, 1.097553, 1.394992, 1.086926, 1.377446, 1.076256, 1.359814, 1.065857, 1.34291, 1.055369, 1.325576, 1.045486, 1.309499, 1.035414, 1.293248, 1.025835, 1.277694, 1.016099, 1.261969, 1.006785, 1.24717, 0.99743, 1.232242, 0.988424, 1.216763, 0.97881, 1.202875, 0.970362, 1.188419, 0.961246, 1.17536, 0.953209, 1.16158, 0.944356, 1.148995, 0.936367, 1.135436, 0.928109, 1.123789, 0.92042, 1.110762, 0.912799, 1.100136, 0.905777, 1.089274, 0.898904, 1.078695, 0.89173, 1.067699, 0.884643, 1.056901, 0.87798, 1.046467, 0.870943, 1.034799, 0.863382, 1.024507, 0.856828, 1.014595, 0.850096, 1.004527, 0.843441, 0.994587, 0.837039, 0.983949, 0.830492, 0.97523, 0.824644, 0.966518, 0.818941, 0.958064, 0.813043, 0.949313, 0.807156, 0.94065, 0.801469, 0.932269, 0.795612, 0.923688, 0.78988, 0.915307, 0.784077, 0.906874, 0.778479, 0.898676, 0.772788, 0.890452, 0.767278, 0.882493, 0.761721, 0.874507, 0.75636, 0.866809, 0.751062, 0.859232, 0.745837, 0.851786, 0.74083, 0.844644, 0.735717, 0.837377, 0.730726, 0.830425, 0.725961, 0.82367, 0.72109, 0.816808, 0.716389, 0.810176, 0.711642, 0.803609, 0.707066, 0.797162, 0.702594, 0.790902, 0.698179, 0.784805, 0.693879, 0.778835, 0.689751, 0.773095, 0.685531, 0.767203, 0.681373, 0.761523, 0.677369, 0.756737, 0.673779, 0.750992, 0.669663, 0.745326, 0.665727, 0.739897, 0.661738, 0.735252, 0.658461, 0.729991, 0.654514, 0.724649, 0.65064, 0.7201, 0.647408, 0.714904, 0.643597, 0.709826, 0.639933, 0.705568, 0.636819, 0.700626, 0.633129, 0.695693, 0.629507, 0.690808, 0.626002, 0.686735, 0.623076, 0.682173, 0.61974, 0.67768, 0.616351, 0.673888, 0.6135, 0.669375, 0.610242, 0.665108, 0.607026, 0.660781, 0.603842, 0.657268, 0.601222, 0.653265, 0.598153, 0.649136, 0. ...
# pred = 1000
# [0.0, 0.01001, 0.02002, 0.03003, 0.04004, 0.05005, 0.06006, 0.07007, 0.08008, 0.09009, 0.1001, 0.11011, 0.12012, 0.13013, 0.14014, 0.15015, 0.16016, 0.17017, 0.18018, 0.19019, 0.2002, 0.21021, 0.22022, 0.23023, 0.24024, 0.25025, 0.26026, 0.27027, 0.28028, 0.29029, 0.3003, 0.31031, 0.32032, 0.33033, 0.34034, 0.35035, 0.36036, 0.37037, 0.38038, 0.39039, 0.4004, 0.41041, 0.42042, 0.43043, 0.44044, 0.45045, 0.46046, 0.47047, 0.48048, 0.49049, 0.500501, 0.510511, 0.520521, 0.530531, 0.540541, 0.550551, 0.560561, 0.570571, 0.580581, 0.590591, 0.600601, 0.610611, 0.620621, 0.630631, 0.640641, 0.650651, 0.660661, 0.670671, 0.680681, 0.690691, 0.700701, 0.710711, 0.720721, 0.730731, 0.740741, 0.750751, 0.760761, 0.770771, 0.780781, 0.790791, 0.800801, 0.810811, 0.820821, 0.830831, 0.840841, 0.850851, 0.860861, 0.870871, 0.880881, 0.890891, 0.900901, 0.910911, 0.920921, 0.930931, 0.940941, 0.950951, 0.960961, 0.970971, 0.980981, 0.990991, 1.001001, 1.011011, 1.021021, 1.031031, 1.041041, 1.051051, 1.061061, 1.071071, 1.081081, 1.091091, 1.101101, 1.111111, 1.121121, 1.131131, 1.141141, 1.151151, 1.161161, 1.171171, 1.181181, 1.191191, 1.201201, 1.211211, 1.221221, 1.231231, 1.241241, 1.251251, 1.261261, 1.271271, 1.281281, 1.291291, 1.301301, 1.311311, 1.321321, 1.331331, 1.341341, 1.351351, 1.361361, 1.371371, 1.381381, 1.391391, 1.401401, 1.411411, 1.421421, 1.431431, 1.441441, 1.451451, 1.461461, 1.471471, 1.481481, 1.491491, 1.501502, 1.511512, 1.521522, 1.531532, 1.541542, 1.551552, 1.561562, 1.571572, 1.581582, 1.591592, 1.601602, 1.611612, 1.621622, 1.631632, 1.641642, 1.651652, 1.661662, 1.671672, 1.681682, 1.691692, 1.701702, 1.711712, 1.721722, 1.731732, 1.741742, 1.751752, 1.761762, 1.771772, 1.781782, 1.791792, 1.801802, 1.811812, 1.821822, 1.831832, 1.841842, 1.851852, 1.861862, 1.871872, 1.881882, 1.891892, 1.901902, 1.911912, 1.921922, 1.931932, 1.941942, 1.951952, 1.961962, 1.971972, 1.981982, 1.991992, 2.002002, 2.012012, 2.022022, 2.032032, 2.042042, 2.052052, 2.062062, 2.072072, 2.082082, 2.092092, 2.102102, 2.112112, 2.122122, 2.132132, 2.142142, 2.152152, 2.162162, 2.172172, 2.182182, 2.192192, 2.202202, 2.212212, 2.222222, 2.232232, 2.242242, 2.252252, 2.262262, 2.272272, 2.282282, 2.292292, 2.302302, 2.312312, 2.322322, 2.332332, 2.342342, 2.352352, 2.362362, 2.372372, 2.382382, 2.392392, 2.402402, 2.412412, 2.422422, 2.432432, 2.442442, 2.452452, 2.462462, 2.472472, 2.482482, 2.492492, 2.502502, 2.512512, 2.522522, 2.532532, 2.542542, 2.552552, 2.562562, 2.572572, 2.582582, 2.592592, 2.602603, 2.612613, 2.622623, 2.632633, 2.642643, 2.652653, 2.662663, 2.672673, 2.682683, 2.692693, 2.702703, 2.712713, 2.722723, 2.732733, 2.742743, 2.752753, 2.762763, 2.772773, 2.782783, 2.792793, 2.802803, 2.812813, 2.822823, 2.832833, 2.842843, 2.852853, 2.862863, 2.872873, 2.882883, 2.892893, 2.902903, 2.912913, 2.922923, 2.932933, 2.942943, 2.952953, 2.962963, 2.972973, 2.982983, 2.992993, 3.003003, 3.013013, 3.023023, 3.033033, 3.043043, 3.053053, 3.063063, 3.073073, 3.083083, 3.093093, 3.103103, 3.113113, 3.123123, 3.133133, 3.143143, 3.153153, 3.163163, 3.173173, 3.183183, 3.193193, 3.203203, 3.213213, 3.223223, 3.233233, 3.243243, 3.253253, 3.263263, 3.273273, 3.283283, 3.293293, 3.303303, 3.313313, 3.323323, 3.333333, 3.343343, 3.353353, 3.363363, 3.373373, 3.383383, 3.393393, 3.403404, 3.413414, 3.423424, 3.433434, 3.443444, 3.453454, 3.463464, 3.473474, 3.483484, 3.493494, 3.503504, 3.513514, 3.523524, 3.533534, 3.543544, 3.553554, 3.563564, 3.573574, 3.583584, 3.593594, 3.603604, 3.613614, 3.623624, 3.633634, 3.643644, 3.653654, 3.663664, 3.673674, 3.683684, 3.693694, 3.703704, 3.713714, 3.723724, 3.733734, 3.743744, 3.753754, 3.763764, 3.773774, 3.783784, 3.793794, 3.803804, 3.813814, 3.823824, 3.833834, 3.843844, 3.853854, 3.863864, 3.873874, 3.883884, 3.893894, 3.903904, 3.913914, 3.923924, 3.933934, 3.943944, 3.953954, 3.963964, 3.973974, 3.983984, 3.993994, 4.004004, 4.014014, 4.024024, 4.034034, 4.044044, 4.05405 ...
# [2.313747, 2.332242, 2.350263, 2.368175, 2.385906, 2.404664, 2.424037, 2.443405, 2.462767, 2.484096, 2.509948, 2.535784, 2.561603, 2.587402, 2.613179, 2.638932, 2.66466, 2.690358, 2.716025, 2.741661, 2.767261, 2.792823, 2.818346, 2.843828, 2.869778, 2.896501, 2.923173, 2.949791, 2.976355, 3.00457, 3.035323, 3.066003, 3.095955, 3.125626, 3.15522, 3.185066, 3.215465, 3.245775, 3.275997, 3.306124, 3.336157, 3.366145, 3.396038, 3.425827, 3.455511, 3.485087, 3.514552, 3.543905, 3.573142, 3.602261, 3.63126, 3.660136, 3.688887, 3.717511, 3.746005, 3.774367, 3.802599, 3.830697, 3.858778, 3.888013, 3.917096, 3.946314, 3.975563, 4.00465, 4.033572, 4.062327, 4.090913, 4.119328, 4.147568, 4.175631, 4.203516, 4.23122, 4.258742, 4.286077, 4.313226, 4.340185, 4.366951, 4.393524, 4.4199, 4.446087, 4.472154, 4.498017, 4.523674, 4.549123, 4.574361, 4.599388, 4.624201, 4.648798, 4.673177, 4.697336, 4.721273, 4.744988, 4.768477, 4.791739, 4.814772, 4.837574, 4.860145, 4.882481, 4.904581, 4.926444, 4.948068, 4.969451, 4.990592, 5.01149, 5.032142, 5.052547, 5.072705, 5.092612, 5.112269, 5.131673, 5.150824, 5.169719, 5.188356, 5.206737, 5.224859, 5.24272, 5.260319, 5.277657, 5.294729, 5.310778, 5.32657, 5.342111, 5.357398, 5.372432, 5.387211, 5.401734, 5.416001, 5.430009, 5.443761, 5.457253, 5.470485, 5.483457, 5.496167, 5.508616, 5.520802, 5.532724, 5.544384, 5.555778, 5.566908, 5.577772, 5.58837, 5.598702, 5.608767, 5.618565, 5.628094, 5.637356, 5.646349, 5.655074, 5.66353, 5.671717, 5.679634, 5.687282, 5.69466, 5.701768, 5.708608, 5.715176, 5.721504, 5.7276, 5.733426, 5.738982, 5.744267, 5.749284, 5.754029, 5.758505, 5.762712, 5.766649, 5.770316, 5.773716, 5.776846, 5.779709, 5.782303, 5.78463, 5.786721, 5.788607, 5.790227, 5.791583, 5.792677, 5.793509, 5.794076, 5.794383, 5.79443, 5.794216, 5.793742, 5.793011, 5.79202, 5.790772, 5.789268, 5.787508, 5.785493, 5.783225, 5.780704, 5.77793, 5.774904, 5.771628, 5.768114, 5.764371, 5.760379, 5.756143, 5.751661, 5.746938, 5.74197, 5.736763, 5.731315, 5.725628, 5.719704, 5.713545, 5.70715, 5.700522, 5.693662, 5.686571, 5.679251, 5.671702, 5.663928, 5.655929, 5.647706, 5.639261, 5.629894, 5.620241, 5.610355, 5.600241, 5.5899, 5.579333, 5.568543, 5.557531, 5.5463, 5.53485, 5.523184, 5.511304, 5.499211, 5.486908, 5.474397, 5.461679, 5.448756, 5.435632, 5.422307, 5.408784, 5.395064, 5.381152, 5.367046, 5.352752, 5.338341, 5.324224, 5.309927, 5.295456, 5.28081, 5.265993, 5.251005, 5.235851, 5.220532, 5.205051, 5.189409, 5.17361, 5.157655, 5.141547, 5.125288, 5.108881, 5.092328, 5.075632, 5.058794, 5.041819, 5.024706, 5.007462, 4.990086, 4.972581, 4.954951, 4.937197, 4.919323, 4.901331, 4.883224, 4.865004, 4.847223, 4.829401, 4.811478, 4.793454, 4.775335, 4.757133, 4.738837, 4.720454, 4.701983, 4.683446, 4.664833, 4.646141, 4.627374, 4.608533, 4.589623, 4.570646, 4.551604, 4.531946, 4.512146, 4.492288, 4.472374, 4.452409, 4.432394, 4.412332, 4.392227, 4.372082, 4.351898, 4.33168, 4.31143, 4.291088, 4.270362, 4.249372, 4.227015, 4.204638, 4.182574, 4.160664, 4.138742, 4.116813, 4.093798, 4.070318, 4.046839, 4.023363, 3.999895, 3.976436, 3.952989, 3.92956, 3.906149, 3.882711, 3.85916, 3.835665, 3.812202, 3.788773, 3.765383, 3.742035, 3.71878, 3.695784, 3.672838, 3.649947, 3.627112, 3.604414, 3.581797, 3.559245, 3.536763, 3.514354, 3.49202, 3.470347, 3.448758, 3.427252, 3.405832, 3.384141, 3.362806, 3.341605, 3.320501, 3.29942, 3.277796, 3.256248, 3.23481, 3.213486, 3.192277, 3.171188, 3.15022, 3.129377, 3.108662, 3.088077, 3.067626, 3.047311, 3.027135, 3.007102, 2.987213, 2.967472, 2.947881, 2.928444, 2.909163, 2.890041, 2.87108, 2.852284, 2.833656, 2.815196, 2.796909, 2.778798, 2.760864, 2.743111, 2.725541, 2.708155, 2.690935, 2.673906, 2.657072, 2.640433, 2.623993, 2.607838, 2.595149, 2.583182, 2.571392, 2.562629, 2.55417, 2.547651, 2.541646, 2.535744, 2.530876, 2.526227, 2.521669, 2.517204, 2.512832, 2.508554, 2.504372, 2.500286, 2.496297, 2.492405, 2.488613, 2.484919, 2.481326, 2.47783, 2.474033, 2.470344,  ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.plot( x_new, y_pred, c='orange')
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %% [markdown]
# 学習

# %%
num_epochs = 1000

x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y.reshape(-1, 1)).float()

net = Net()
net.train()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()

epoch_loss = []
for epoch in range(num_epochs):
  
  outputs = net(x_tensor)
  loss = criterion(outputs, y_tensor)
    
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
    
  epoch_loss.append(loss.data.numpy().tolist())
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=1, bias=True)
# )
# True
# True
# True
# True
# True
# True
# <generator object Module.named_parameters at 0x7f99790439d0>
# fc1.weight
# True
# None
# ---
# fc1.bias
# True
# None
# ---
# fc2.weight
# True
# None
# ---
# fc2.bias
# True
# None
# ---
# fc3.weight
# True
# None
# ---
# fc3.bias
# True
# None
# ---
# Parameter containing:
# tensor([[ 0.3874, -0.5647],
#         [-0.6766,  0.6111],
#         [ 0.4934, -0.6330],
#         [ 0.5197,  0.3673],
#         [-0.2603, -0.0761],
#         [-0.3394,  0.0356],
#         [ 0.4697, -0.0500],
#         [-0.3039,  0.2805],
#         [ 0.1860, -0.6480],
#         [ 0.3688, -0.1265],
#         [ 0.2277, -0.5620],
#         [ 0.6186, -0.1891],
#         [ 0.4563, -0.3899],
#         [-0.0606,  0.5275],
#         [-0.2258, -0.6937],
#         [-0.6117,  0.6076],
#         [-0.1122,  0.6290],
#         [-0.3709,  0.4826],
#         [ 0.2488, -0.6291],
#         [ 0.3292,  0.6114],
#         [ 0.3217,  0.3992],
#         [-0.0649, -0.2912],
#         [-0.4742,  0.2912],
#         [-0.6123, -0.5004],
#         [ 0.4389, -0.2268],
#         [-0.4978,  0.6258],
#         [ 0.3140,  0.0377],
#         [ 0.3305,  0.3085],
#         [ 0.6995, -0.3024],
#         [ 0.2129,  0.2592],
#         [ 0.2770, -0.0453],
#         [ 0.2095, -0.0995],
#         [-0.3780,  0.1701],
#         [-0.5502, -0.3046],
#         [ 0.5532, -0.0504],
#         [-0.6565, -0.4028],
#         [-0.5443,  0.5956],
#         [-0.5551,  0.6634],
#         [ 0.0022, -0.3858],
#         [ 0.6274, -0.0873],
#         [ 0.2521,  0.2400],
#         [-0.5472, -0.1241],
#         [-0.2464,  0.2157],
#         [ 0.1812,  0.6282],
#         [-0.0033,  0.4497],
#         [ 0.3939, -0.2850],
#         [-0.4224, -0.5739],
#         [ 0.0893, -0.0360],
#         [-0.7055, -0.3926],
#         [-0.0435,  0.1849],
#         [-0.1636, -0.5669],
#         [-0.5485, -0.2755],
#         [ 0.6801, -0.3804],
#         [ 0.4860, -0.5582],
#         [ 0.5098,  0.4628],
#         [ 0.3876,  0.3581],
#         [ 0.0072,  0.3753],
#         [ 0.5108, -0.4711],
#         [ 0.1961, -0.6495],
#         [-0.2921,  0.3380],
#         [-0.0751,  0.5578],
#         [ 0.6284, -0.6240],
#         [ 0.6936, -0.6959],
#         [ 0.6185,  0.4071]], requires_grad=True)
# Parameter containing:
# tensor([-0.0496, -0.0880, -0.1924, -0.6547, -0.4498, -0.4681, -0.0112,  0.2777,
#          0.5326, -0.0246, -0.3511, -0.2808,  0.3130, -0.3792,  0.0641, -0.2834,
#          0.1871,  0.6836, -0.3702, -0.2328, -0.5259,  0.3564, -0.1728,  0.6914,
#         -0.6369, -0.2857,  0.4633, -0.6449, -0.2866, -0.5386,  0.3787, -0.0430,
#         -0.5644, -0.6919, -0.1616, -0.1238, -0.4502,  0.6048, -0.3602,  0.2825,
#         -0.4983,  0.2452, -0.5587, -0.2200, -0.0042,  0.4363,  0.0134, -0.5673,
#         -0.1924, -0.5274, -0.1785,  0.4260, -0.3300, -0.3874,  0.5215, -0.2541,
#         -0.3085,  0.5492, -0.1846, -0.5105,  0.5818,  0.6412,  0.0354,  0.0159],
#        requires_grad=True)
# OrderedDict([('fc1.weight', tensor([[ 0.3874, -0.5647],
#         [-0.6766,  0.6111],
#         [ 0.4934, -0.6330],
#         [ 0.5197,  0.3673],
#         [-0.2603, -0.0761],
#         [-0.3394,  0.0356],
#         [ 0.4697, -0.0500],
#         [-0.3039,  0.2805],
#         [ 0.1860, -0.6480],
#         [ 0.3688, -0.1265],
#         [ 0.2277, -0.5620],
#         [ 0.6186, -0.1891],
#         [ 0.4563, -0.3899],
#         [-0.0606,  0.5275],
#         [-0.2258, -0.6937],
#         [-0.6117,  0.6076],
#         [-0.1122,  0.6290],
#         [-0.3709,  0.4826],
#         [ 0.2488, -0.6291],
#         [ 0.3292,  0.6114],
#         [ 0.3217,  0.3992],
#         [-0.0649, -0.2912],
#         [-0.4742,  0.2912],
#         [-0.6123, -0.5004],
#         [ 0.4389, -0.2268],
#         [-0.4978,  0.6258],
#         [ 0.3140,  0.0377],
#         [ 0.3305,  0.3085],
#         [ 0.6995, -0.3024],
#         [ 0.2129,  0.2592],
#         [ 0.2770, -0.0453],
#         [ 0.2095, -0.0995],
#         [-0.3780,  0.1701],
#         [-0.5502, -0.3046],
#         [ 0.5532, -0.0504],
#         [-0.6565, -0.4028],
#         [-0.5443,  0.5956],
#         [-0.5551,  0.6634],
#         [ 0.0022, -0.3858],
#         [ 0.6274, -0.0873],
#         [ 0.2521,  0.2400],
#         [-0.5472, -0.1241],
#         [-0.2464,  0.2157],
#         [ 0.1812,  0.6282],
#         [-0.0033,  0.4497],
#         [ 0.3939, -0.2850],
#         [-0.4224, -0.5739],
#         [ 0.0893, -0.0360],
#         [-0.7055, -0.3926],
#         [-0.0435,  0.1849],
#         [-0.1636, -0.5669],
#         [-0.5485, -0.2755],
#         [ 0.6801, -0.3804],
#         [ 0.4860, -0.5582],
#         [ 0.5098,  0.4628],
#         [ 0.3876,  0.3581],
#         [ 0.0072,  0.3753],
#         [ 0.5108, -0.4711],
#         [ 0.1961, -0.6495],
#         [-0.2921,  0.3380],
#         [-0.0751,  0.5578],
#         [ 0.6284, -0.6240],
#         [ 0.6936, -0.6959],
#         [ 0.6185,  0.4071]])), ('fc1.bias', tensor([-0.0496, -0.0880, -0.1924, -0.6547, -0.4498, -0.4681, -0.0112,  0.2777,
#          0.5326, -0.0246, -0.3511, -0.2808,  0.3130, -0.3792,  0.0641, -0.2834,
#          0.1871,  0.6836, -0.3702, -0.2328, -0.5259,  0.3564, -0.1728,  0.6914,
#         -0.6369, -0.2857,  0.4633, -0.6449, -0.2866, -0.5386,  0.3787, -0.0430,
#         -0.5644, -0.6919, -0.1616, -0.1238, -0.4502,  0.6048, -0.3602,  0.2825,
#         -0.4983,  0.2452, -0.5587, -0.2200, -0.0042,  0.4363,  0.0134, -0.5673,
#         -0.1924, -0.5274, -0.1785,  0.4260, -0.3300, -0.3874,  0.5215, -0.2541,
#         -0.3085,  0.5492, -0.1846, -0.5105,  0.5818,  0.6412,  0.0354,  0.0159])), ('fc2.weight', tensor([[-0.0172, -0.0436,  0.0498,  ...,  0.0113, -0.0273,  0.0175],
#         [-0.0068,  0.0477,  0.0754,  ..., -0.0360,  0.0404, -0.0660],
#         [ 0.0725, -0.0036,  0.0990,  ...,  0.0152,  0.0963, -0.0857],
#         ...,
#         [ 0.0385, -0.0177,  0.0519,  ..., -0.0950,  0.0802,  0.0731],
#         [ 0.1232, -0.0715, -0.1201,  ..., -0.0822,  0.1247,  0.0124],
#         [ 0.1235,  0.0842, -0.0918,  ...,  0.0094, -0.0529, -0.0078]])), ('fc2.bias', tensor([-0.0188, -0.0585, -0.0066,  0.1040,  0.1140, -0.0592,  0.0688, -0.0143,
#          0.0989, -0.0312, -0.0463, -0.0146, -0.0183, -0.1153, -0.1101,  0.1229,
#          0.0568, -0.0013, -0.0279,  0.0698, -0.0616,  0.0588,  0.0413, -0.0637,
#         -0.0379, -0.1206, -0.0460,  0.1248,  0.0963,  0.0185,  0.1117, -0.0684])), ('fc3.weight', tensor([[ 0.1085, -0.1530, -0.1083,  0.0474,  0.1055,  0.0016, -0.0237,  0.1219,
#          -0.0203, -0.0923,  0.0807,  0.0318, -0.1578, -0.0448, -0.1077,  0.0541,
#          -0.0703, -0.0038, -0.0702, -0.0299,  0.0227, -0.1663, -0.1658, -0.0224,
#           0.1121,  0.1170, -0.1423,  0.1700, -0.1271,  0.1588,  0.0396,  0.0104]])), ('fc3.bias', tensor([-0.1371]))])
# <class 'collections.OrderedDict'>
# odict_keys(['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias'])
# ['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias']
# <class 'str'>
# tensor([-0.0496, -0.0880, -0.1924, -0.6547, -0.4498, -0.4681, -0.0112,  0.2777,
#          0.5326, -0.0246, -0.3511, -0.2808,  0.3130, -0.3792,  0.0641, -0.2834,
#          0.1871,  0.6836, -0.3702, -0.2328, -0.5259,  0.3564, -0.1728,  0.6914,
#         -0.6369, -0.2857,  0.4633, -0.6449, -0.2866, -0.5386,  0.3787, -0.0430,
#         -0.5644, -0.6919, -0.1616, -0.1238, -0.4502,  0.6048, -0.3602,  0.2825,
#         -0.4983,  0.2452, -0.5587, -0.2200, -0.0042,  0.4363,  0.0134, -0.5673,
#         -0.1924, -0.5274, -0.1785,  0.4260, -0.3300, -0.3874,  0.5215, -0.2541,
#         -0.3085,  0.5492, -0.1846, -0.5105,  0.5818,  0.6412,  0.0354,  0.0159])
# None
# True
# dict_keys(['training', '_parameters', '_buffers', '_non_persistent_buffers_set', '_backward_hooks', '_is_full_backward_hook', '_forward_hooks', '_forward_pre_hooks', '_state_dict_hooks', '_load_state_dict_pre_hooks', '_modules'])
# '\nepoch_loss = []\nfor epoch in range(num_epochs):\n  \n  outputs = net(x_tensor)\n  loss = criterion(outputs, y_tensor)\n    \n  optimizer.zero_grad()\n  loss.backward()\n  optimizer.step()\n    \n  epoch_loss.append(loss.data.numpy().tolist())\n'

# %% [markdown]
# 学習の収束の図化

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %% [markdown]
# 予測

# %%
net.eval()

_x_new = np.linspace(0, 10, 1000)
x1_new = np.sin(_x_new)
x2_new = np.exp(_x_new / 5)
x_new = np.stack([x1_new, x2_new], axis=1)


x_new_tensor = torch.from_numpy(x_new).float()
with torch.no_grad():
    y_pred_tensor = net(x_new_tensor)

y_pred = y_pred_tensor.data.numpy()



fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.plot(_x_new, y_pred, c='orange')
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %% [markdown]
# [ ミニバッチ学習 ]

# %% [markdown]
# サンプルデータ

# %%
import numpy as np

np.random.seed(2020)
_x = np.random.uniform(0, 10, 100)
x1 = np.sin(_x)
x2 = np.exp(_x / 5)
x = np.stack([x1, x2], axis=1)
y = 3 * x1 + 2 * x2 + np.random.uniform(-1, 1, 100)

# %% [markdown]
# DataSetクラスの定義

# %%
import torch

class MakeDataset(torch.utils.data.Dataset):

    def __init__(self, x, y=None):
        self.x = x
        self.y = y

    def __len__(self):
        return self.x.shape[0]

    def __getitem__(self, i):
        x = torch.from_numpy(self.x[i]).float()
        if self.y is not None:
            y = torch.from_numpy(self.y[i]).float()
        
        if self.y is not None:
            return x, y
        else:
            return x

# %% [markdown]
# ニューラルネットワークの定義

# %%
import torch
import torch.nn.functional
import torch.utils.data


class Net(torch.nn.Module):

  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = torch.nn.Linear(2, 64)
    self.fc2 = torch.nn.Linear(64, 32)
    self.fc3 = torch.nn.Linear(32, 1)

  def forward(self, x):
    x = torch.nn.functional.relu(self.fc1(x))
    x = torch.nn.functional.relu(self.fc2(x))
    x = self.fc3(x)
    return x

# %% [markdown]
# ミニバッチ学習

# %%
num_epochs = 1000
batch_size = 64

# prepare dataset
dataset = MakeDataset(x, y.reshape(-1, 1))
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

# prepare model and training parameters
net = Net()
net.train()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()

# training
epoch_loss = []
for epoch in range(num_epochs):
    
    # use 'dataloader' to start batch learning
    running_loss = 0   # loss in this epoch
    for inputs, labels in dataloader:
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # add loss of this batch to loss of epoch
        running_loss += loss.data.numpy().tolist()
    
    epoch_loss.append(running_loss)

# %% [markdown]
# 予測

# %%
net.eval()

_x_new = np.linspace(0, 10, 1000)
x1_new = np.sin(_x_new)
x2_new = np.exp(_x_new / 5)
x_new = np.stack([x1_new, x2_new], axis=1)


test_dataset = MakeDataset(x_new)
dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=64)

y_pred = None
with torch.no_grad():
    for inputs in dataloader:
        outputs = net(inputs)
        if y_pred is None:
            y_pred = outputs.data.numpy()
        else:
            y_pred = np.concatenate([y_pred, outputs.data.numpy()])

y_pred = y_pred.reshape(-1)

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.plot(_x_new, y_pred, c='orange')
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %%
x_tensor
# Out:
# tensor([[-0.4241,  7.1890],
#         [ 0.6372,  5.7361],
#         [-0.9268,  2.7718],
#         [ 0.4107,  1.7223],
#         [-0.2256,  1.9618],
#         [ 0.8260,  1.5433],
#         [ 0.3680,  1.7384],
#         [-0.2874,  1.9870],
#         [ 0.7196,  5.6087],
#         [ 1.0000,  1.3681],
#         [ 0.9869,  1.3255],
#         [ 0.9602,  4.5456],
#         [ 0.8820,  4.3608],
#         [-0.4032,  2.0367],
#         [-0.2661,  1.9782],
#         [ 0.3754,  3.7947],
#         [ 0.8252,  1.5437],
#         [-0.6201,  3.0736],
#         [ 0.9464,  1.2819],
#         [-0.0557,  1.8955],
#         [-0.1072,  6.7290],
#         [ 0.9806,  1.3162],
#         [-0.5556,  3.1231],
#         [-0.3258,  7.0380],
#         [-0.9488,  2.7366],
#         [ 0.3834,  3.8012],
#         [ 0.3353,  1.0708],
#         [-0.9886,  2.4899],
#         [ 0.9999,  1.3657],
#         [-0.9988,  2.5911],
#         [ 0.9920,  1.4041],
#         [ 0.4459,  6.0045],
#         [-0.5583,  2.1102],
#         [-0.6094,  2.1370],
#         [ 0.7457,  5.5658],
#         [ 0.1765,  3.6405],
#         [-0.4337,  3.2121],
#         [ 0.3897,  3.8065],
#         [ 0.9786,  1.4270],
#         [ 0.8030,  5.4657],
#         [-0.9586,  2.4224],
#         [ 0.8957,  5.2748],
#         [ 0.9770,  4.6082],
#         [ 0.2259,  6.2926],
#         [ 0.6486,  1.1516],
#         [ 1.0000,  1.3666],
#         [ 0.0857,  3.5744],
#         [-0.6641,  3.0386],
#         [ 0.9399,  1.4679],
#         [-0.8979,  2.3427],
#         [-0.9123,  2.7922],
#         [ 0.4330,  1.7139],
#         [-0.2888,  3.3136],
#         [ 0.8075,  1.5532],
#         [ 0.1326,  1.8253],
#         [ 0.4653,  1.1016],
#         [-0.5972,  3.0914],
#         [ 0.0644,  6.5017],
#         [ 0.9845,  4.9831],
#         [ 0.6364,  4.0334],
#         [-0.9951,  2.5162],
#         [ 0.3346,  3.7617],
#         [ 0.9368,  4.4787],
#         [-0.8241,  2.8948],
#         [-0.9933,  2.6264],
#         [ 0.2886,  1.0603],
#         [ 0.4635,  5.9809],
#         [ 0.8955,  5.2755],
#         [ 0.8890,  4.3740],
#         [ 0.4258,  6.0315],
#         [ 0.7408,  1.5864],
#         [ 0.9739,  1.4332],
#         [-0.1411,  3.4155],
#         [ 0.1659,  1.0339],
#         [ 0.1478,  1.8197],
#         [ 0.3915,  3.8079],
#         [-0.1006,  6.7201],
#         [ 0.9529,  5.1162],
#         [ 0.7023,  1.1685],
#         [ 0.9749,  1.3090],
#         [-0.4949,  3.1680],
#         [ 0.9797,  1.4255],
#         [-0.4967,  7.3076],
#         [ 0.9222,  1.2646],
#         [ 0.8502,  5.3746],
#         [ 0.1398,  1.0285],
#         [ 0.6502,  5.7166],
#         [ 0.3901,  6.0788],
#         [-0.9758,  2.4557],
#         [-0.1012,  3.4431],
#         [-0.3570,  7.0848],
#         [-0.7387,  2.2135],
#         [-0.9713,  2.4460],
#         [ 0.7236,  1.5944],
#         [ 0.1073,  6.4460],
#         [ 0.4019,  1.7257],
#         [ 0.1013,  6.4537],
#         [-0.8364,  2.2852],
#         [ 0.9994,  1.3790],
#         [-0.9997,  2.5539]])
