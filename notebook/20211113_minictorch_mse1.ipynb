# %% [markdown]
# mse1　回帰問題
# 　　参考：https://axa.biopapyrus.jp/deep-learning/object-classification/regression-multiple-features.html

# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks/"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# フォルダは自分の指定のものに変更して下さい。

# %%
# %cd "ctorch210929/MiniCTorch_Prototype/notebook"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch210929/MiniCTorch_Prototype/notebook

# %% [markdown]
# ライブラリのimport

# %%
! pip install lark-parser
# Out:
# Collecting lark-parser
#   Downloading lark_parser-0.12.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 10.2 MB/s
# Installing collected packages: lark-parser
# Successfully installed lark-parser-0.12.0

# %%
import sys
sys.path.append("../")

import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import minictorch.generator as GN
import minictorch.converter as CV

# %% [markdown]
# サンプルデータ

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(2020)

_x = np.random.uniform(0, 10, 100)

x1 = np.sin(_x)
x2 = np.exp(_x / 5)
x = np.stack([x1, x2], axis=1)
y = 3 * x1 + 2 * x2 + np.random.uniform(-1, 1, 100)

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %% [markdown]
# ニューラルネットワークの定義

# %%
"""def mean_squared_error( x0, x1 ):
    diff = x0 - x1
    y = (diff**2).sum() / len(diff)
    return y;
"""

class Net(torch.nn.Module):
  
  def __init__( self, t ):
    super(Net, self).__init__()
    self.fc1 = torch.nn.Linear(2, 64)
    self.fc2 = torch.nn.Linear(64, 32)
    self.fc3 = torch.nn.Linear(32, 1)
    self.target = t
    self.kind = 0;

  def forward(self, x):
    x = torch.nn.functional.relu(self.fc1(x))
    x = torch.nn.functional.relu(self.fc2(x))
    x = self.fc3(x)
    self.out = x
    if self.kind == 1: return 0.0

    #y = mean_squared_error( x, self.target )
    loss = nn.MSELoss()
    y = loss( x, self.target )
    #print('loss', y )
    return y

# %%
def generate_json( json_path, input, target ):

    model = Net( target )

    model.eval()
    with torch.no_grad():
        print("[SAVE]", json_path )
        GN.generate_minictorch_file( model, input, json_path )

    return model

# %%
torch.manual_seed( 1 )

x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y.reshape(-1, 1)).float()

project = 'mse1'
json_path = './network/' + project +'.json'

x_tensor.requires_grad = True

model = generate_json( json_path, x_tensor, y_tensor )
# Out:
# [SAVE] ./network/mse1.json
# skip: Net/Linear[fc1]/weight/fc1
# skip: Net/Linear[fc1]/weight/fc1
# skip: Net/Linear[fc2]/weight/fc2
# skip: Net/Linear[fc2]/weight/fc2
# skip: Net/Linear[fc3]/weight/fc3
# skip: Net/Linear[fc3]/weight/fc3

# %% [markdown]
# 一回の順伝播、逆伝播のC++コードを生成する

# %%
folder = "./mse"
CV.convert_cpp_code( project, folder, model, x_tensor, json_path )
# Out:
# [JSON] ./network/mse1.json
# {'name': 'Net/Linear[fc1]/weight/weight.7', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# {'name': 'Net/Linear[fc1]/bias/bias.7', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# {'name': 'Net/Linear[fc2]/weight/weight.9', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# {'name': 'Net/Linear[fc2]/bias/bias.9', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# {'name': 'Net/Linear[fc3]/weight/weight', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 9}
# {'name': 'Net/Linear[fc3]/bias/bias', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 10}
# [PARAM] ./mse/mse1_param.cpp
# {'name': 'input/x', 'op': 'IO Node', 'in': [], 'output_id': 0, 'shape': [100, 2], 'out': [3], 'sorted_id': 0}
# {'name': 'Net/Linear[fc1]/weight/weight.7', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# Net/Linear[fc1]/weight/weight.7  ->  fc1_weight
# {'name': 'Net/Linear[fc1]/bias/bias.7', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# Net/Linear[fc1]/bias/bias.7  ->  fc1_bias
# {'name': 'Net/Linear[fc1]/input.1', 'op': 'aten::linear', 'in': [0, 1, 2], 'output_id': 0, 'shape': [100, 64], 'out': [4], 'sorted_id': 3}
# {'name': 'Net/input.3', 'op': 'aten::relu', 'in': [3], 'output_id': 0, 'shape': [100, 64], 'out': [7], 'sorted_id': 4}
# {'name': 'Net/Linear[fc2]/weight/weight.9', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# Net/Linear[fc2]/weight/weight.9  ->  fc2_weight
# {'name': 'Net/Linear[fc2]/bias/bias.9', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# Net/Linear[fc2]/bias/bias.9  ->  fc2_bias
# {'name': 'Net/Linear[fc2]/input.5', 'op': 'aten::linear', 'in': [4, 5, 6], 'output_id': 0, 'shape': [100, 32], 'out': [8], 'sorted_id': 7}
# {'name': 'Net/input.7', 'op': 'aten::relu', 'in': [7], 'output_id': 0, 'shape': [100, 32], 'out': [11], 'sorted_id': 8}
# {'name': 'Net/Linear[fc3]/weight/weight', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 9}
# Net/Linear[fc3]/weight/weight  ->  fc3_weight
# {'name': 'Net/Linear[fc3]/bias/bias', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 10}
# Net/Linear[fc3]/bias/bias  ->  fc3_bias
# {'name': 'Net/Linear[fc3]/input.9', 'op': 'aten::linear', 'in': [8, 9, 10], 'output_id': 0, 'shape': [100, 1], 'out': [13], 'sorted_id': 11}
# {'name': 'Net/target.1', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [100, 1], 'constant_value': [12.6442, 14.2724, 2.3541, 3.9799, 2.7917, 6.2946, 5.4144, 3.6112, 14.1766, 4.7809, 4.6936, 12.7688, 11.7691, 3.2024, 3.2638, 9.1611, 6.271, 4.5049, 5.3078, 3.2171, 13.3978, 5.5882, 4.32, 12.3751, 3.1452, 9.6706, 2.7055, 2.4756, 5.1311, 2.4733, 5.1901, 12.4477, 2.2895, 1.4738, 12.5678, 8.8092, 5.9747, 9.4119, 5.2347, 12.5353, 2.8599, 13.761, 11.8049, 14.1149, 4.6603, 4.8467, 7.3956, 3.8746, 5.8784, 2.454, 3.005, 3.8026, 5.1516, 5.8612, 4.4625, 3.2352, 3.885, 13.8736, 12.0878, 10.4887, 2.4796, 8.4232, 10.8639, 3.6631, 1.6655, 3.8742, 13.4705, 13.8999, 11.0951, 12.7526, 5.4187, 6.7698, 7.1659, 1.756, 4.0808, 8.9944, 12.381, 12.8833, 4.6455, 5.4636, 4.3245, 5.0018, 14.0947, 4.3089, 12.3858, 2.9765, 13.8632, 14.326, 2.1931, 5.8966, 12.2755, 2.9158, 2.3136, 4.9452, 12.3885, 4.2832, 14.1509, 2.685, 5.2271, 1.9709], 'out': [13], 'sorted_id': 12}
# {'name': 'Net/39', 'op': 'prim::ListConstruct', 'in': [11, 12], 'output_id': 0, 'shape': [], 'out': [14], 'sorted_id': 13}
# {'name': 'Net/40', 'op': 'aten::broadcast_tensors', 'in': [13], 'output_id': 0, 'shape': [], 'out': [15, 16], 'sorted_id': 14}
# {'name': 'Net/input', 'op': 'prim::ListUnpack', 'in': [14], 'output_id': 0, 'shape': [100, 1], 'out': [18], 'sorted_id': 15}
# {'name': 'Net/target', 'op': 'prim::ListUnpack', 'in': [14], 'output_id': 1, 'shape': [100, 1], 'out': [18], 'sorted_id': 16}
# {'name': 'Net/43', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [18], 'sorted_id': 17}
# {'name': 'Net/44', 'op': 'aten::mse_loss', 'in': [15, 16, 17], 'output_id': 0, 'shape': [], 'out': [19], 'sorted_id': 18}
# {'name': 'output/output.1', 'op': 'IO Node', 'in': [18], 'output_id': 0, 'shape': [], 'out': [], 'sorted_id': 19}
# [CPP]  ./mse/mse1.cpp
# [MAKE] ./mse/Makefile

# %%
# check code
with torch.set_grad_enabled(True):
  #model.train()
  loss = model( x_tensor )
  print("loss ",loss)
  loss.backward()
  print("input",x_tensor.grad)
# Out:
# loss  tensor(67.4897, grad_fn=<MseLossBackward0>)
# input tensor([[ 6.7952e-03,  4.8823e-04],
#         [-8.7210e-03,  1.5778e-03],
#         [-1.4692e-03, -5.7917e-04],
#         [ 5.0851e-03, -3.3004e-03],
#         [-3.1918e-03, -6.0882e-04],
#         [ 7.3107e-03, -3.7030e-03],
#         [ 8.1786e-03, -5.5729e-03],
#         [-4.1216e-03, -7.8619e-04],
#         [-5.0728e-03,  8.8635e-04],
#         [ 3.6004e-04, -8.5637e-05],
#         [ 3.5354e-04, -8.4093e-05],
#         [-4.3465e-03,  7.3654e-04],
#         [-4.0067e-03,  6.7897e-04],
#         [-3.4841e-03, -5.3126e-04],
#         [-3.7277e-03, -7.1106e-04],
#         [ 6.2141e-05,  9.6287e-04],
#         [ 7.2834e-03, -3.6891e-03],
#         [-4.4959e-03, -3.9537e-04],
#         [ 3.9924e-04, -9.4963e-05],
#         [-3.5350e-03, -7.2280e-04],
#         [-5.3305e-04,  2.0967e-03],
#         [ 4.2013e-04, -9.9933e-05],
#         [-4.3099e-03, -3.7900e-04],
#         [-5.4636e-05,  1.1250e-03],
#         [-2.3520e-03, -7.7544e-04],
#         [ 6.5594e-05,  1.0163e-03],
#         [-2.8175e-04, -2.5140e-03],
#         [-7.3042e-05,  7.3730e-04],
#         [ 3.8610e-04, -9.1838e-05],
#         [-1.3349e-03, -3.4530e-04],
#         [ 3.9049e-04, -9.2883e-05],
#         [-7.6121e-03,  1.3772e-03],
#         [-2.6267e-03, -4.2821e-04],
#         [-1.7136e-03, -2.7936e-04],
#         [-4.4977e-03,  7.8585e-04],
#         [-2.1708e-03,  1.3491e-03],
#         [-5.9388e-03, -5.2225e-04],
#         [ 6.3841e-05,  9.8919e-04],
#         [ 3.9380e-04, -9.3669e-05],
#         [-4.4856e-03,  7.8374e-04],
#         [-8.4061e-05,  8.4853e-04],
#         [-4.9228e-03,  8.6014e-04],
#         [-4.0186e-03,  6.8098e-04],
#         [-3.4811e-03,  2.1633e-03],
#         [ 3.0112e-03, -1.4009e-03],
#         [ 3.6493e-04, -8.6801e-05],
#         [-1.8208e-03,  6.9478e-04],
#         [-3.8754e-03, -3.4080e-04],
#         [ 1.4418e-03, -9.3774e-04],
#         [ 4.3009e-05,  7.0248e-04],
#         [-9.6583e-04, -4.9340e-04],
#         [ 4.0602e-03, -2.6449e-03],
#         [-5.1178e-03, -4.5006e-04],
#         [ 6.8097e-03, -3.4492e-03],
#         [-7.0340e-03, -1.0018e-03],
#         [ 3.7568e-03, -2.7978e-03],
#         [-3.8822e-03, -3.4139e-04],
#         [-5.5184e-04,  2.1706e-03],
#         [-4.1151e-03,  6.9734e-04],
#         [-3.6962e-03,  6.3108e-04],
#         [-7.3168e-05,  7.3858e-04],
#         [ 5.7143e-05,  8.8541e-04],
#         [-3.6987e-03,  6.2677e-04],
#         [-4.1779e-03, -6.8109e-04],
#         [-1.2692e-03, -4.1847e-04],
#         [-4.0164e-04, -3.5837e-03],
#         [-8.2358e-03,  1.4901e-03],
#         [-4.9725e-03,  8.6881e-04],
#         [-3.7774e-03,  6.4012e-04],
#         [-7.7986e-03,  1.4110e-03],
#         [ 5.3231e-03, -3.4821e-03],
#         [ 1.6586e-03, -1.0787e-03],
#         [-7.1008e-03, -6.2444e-04],
#         [ 1.5773e-03, -4.1490e-04],
#         [-6.4321e-03, -9.1612e-04],
#         [ 6.1014e-05,  9.4538e-04],
#         [-4.9271e-04,  1.9380e-03],
#         [-4.6086e-03,  8.0524e-04],
#         [ 3.0026e-03, -1.3970e-03],
#         [ 4.1085e-04, -9.7724e-05],
#         [-4.3112e-03, -3.7912e-04],
#         [ 3.7647e-04, -8.9547e-05],
#         [ 7.5713e-03,  5.4400e-04],
#         [ 3.2488e-04, -7.7276e-05],
#         [-4.4317e-03,  7.7433e-04],
#         [ 2.7303e-03, -7.1365e-04],
#         [-4.9614e-03,  8.6688e-04],
#         [-8.7595e-03,  1.5848e-03],
#         [-6.4906e-05,  6.5517e-04],
#         [-7.3791e-03, -5.9744e-04],
#         [-5.4198e-05,  1.1160e-03],
#         [-9.5431e-04,  1.3051e-03],
#         [-6.8366e-05,  6.9010e-04],
#         [ 4.8607e-03, -3.1796e-03],
#         [-3.0570e-03,  1.8998e-03],
#         [ 5.4695e-03, -3.5499e-03],
#         [-5.6283e-04,  2.2138e-03],
#         [-1.6223e-03,  1.0441e-03],
#         [ 3.9325e-04, -9.3538e-05],
#         [-5.8559e-05,  5.9112e-04]])

# %% [markdown]
# C++コードをコンパイル、リンクする

# %%
# !g++ -std=c++14 ./mse/mse1.cpp ./mse/mse1_param.cpp -D_NOTEBOOK -I ../../../xtensor  -lcblas -o ./mse/mse1

# %% [markdown]
# (注意) xtensorフォルダにxtensor関連のincludeファイルを置いています。各自の環境に合わせて変更して下さい。

# %%
# !./mse/mse1
# Out:
# ### forward computation ...
#  67.489609
# ### backward computation ...
# input_grad{{ 0.006795,  0.000488},
#  {-0.008721,  0.001578},
#  {-0.001469, -0.000579},
#  { 0.005085, -0.0033  },
#  {-0.003192, -0.000609},
#  { 0.007311, -0.003703},
#  { 0.008179, -0.005573},
#  {-0.004122, -0.000786},
#  {-0.005073,  0.000886},
#  { 0.00036 , -0.000086},
#  { 0.000354, -0.000084},
#  {-0.004346,  0.000737},
#  {-0.004007,  0.000679},
#  {-0.003484, -0.000531},
#  {-0.003728, -0.000711},
#  { 0.000062,  0.000963},
#  { 0.007283, -0.003689},
#  {-0.004496, -0.000395},
#  { 0.000399, -0.000095},
#  {-0.003535, -0.000723},
#  {-0.000533,  0.002097},
#  { 0.00042 , -0.0001  },
#  {-0.00431 , -0.000379},
#  {-0.000055,  0.001125},
#  {-0.002352, -0.000775},
#  { 0.000066,  0.001016},
#  {-0.000282, -0.002514},
#  {-0.000073,  0.000737},
#  { 0.000386, -0.000092},
#  {-0.001335, -0.000345},
#  { 0.00039 , -0.000093},
#  {-0.007612,  0.001377},
#  {-0.002627, -0.000428},
#  {-0.001714, -0.000279},
#  {-0.004498,  0.000786},
#  {-0.002171,  0.001349},
#  {-0.005939, -0.000522},
#  { 0.000064,  0.000989},
#  { 0.000394, -0.000094},
#  {-0.004486,  0.000784},
#  {-0.000084,  0.000849},
#  {-0.004923,  0.00086 },
#  {-0.004019,  0.000681},
#  {-0.003481,  0.002163},
#  { 0.003011, -0.001401},
#  { 0.000365, -0.000087},
#  {-0.001821,  0.000695},
#  {-0.003875, -0.000341},
#  { 0.001442, -0.000938},
#  { 0.000043,  0.000702},
#  {-0.000966, -0.000493},
#  { 0.00406 , -0.002645},
#  {-0.005118, -0.00045 },
#  { 0.00681 , -0.003449},
#  {-0.007034, -0.001002},
#  { 0.003757, -0.002798},
#  {-0.003882, -0.000341},
#  {-0.000552,  0.002171},
#  {-0.004115,  0.000697},
#  {-0.003696,  0.000631},
#  {-0.000073,  0.000739},
#  { 0.000057,  0.000885},
#  {-0.003699,  0.000627},
#  {-0.004178, -0.000681},
#  {-0.001269, -0.000418},
#  {-0.000402, -0.003584},
#  {-0.008236,  0.00149 },
#  {-0.004972,  0.000869},
#  {-0.003777,  0.00064 },
#  {-0.007799,  0.001411},
#  { 0.005323, -0.003482},
#  { 0.001659, -0.001079},
#  {-0.007101, -0.000624},
#  { 0.001577, -0.000415},
#  {-0.006432, -0.000916},
#  { 0.000061,  0.000945},
#  {-0.000493,  0.001938},
#  {-0.004609,  0.000805},
#  { 0.003003, -0.001397},
#  { 0.000411, -0.000098},
#  {-0.004311, -0.000379},
#  { 0.000376, -0.00009 },
#  { 0.007571,  0.000544},
#  { 0.000325, -0.000077},
#  {-0.004432,  0.000774},
#  { 0.00273 , -0.000714},
#  {-0.004961,  0.000867},
#  {-0.008759,  0.001585},
#  {-0.000065,  0.000655},
#  {-0.007379, -0.000597},
#  {-0.000054,  0.001116},
#  {-0.000954,  0.001305},
#  {-0.000068,  0.00069 },
#  { 0.004861, -0.00318 },
#  {-0.003057,  0.0019  },
#  { 0.00547 , -0.00355 },
#  {-0.000563,  0.002214},
#  {-0.001622,  0.001044},
#  { 0.000393, -0.000094},
#  {-0.000059,  0.000591}}

# %% [markdown]
# 学習ループの実行(python版)

# %%
torch.manual_seed( 1 )
 
x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y.reshape(-1, 1)).float()

project = 'mse1'
json_path = 'network/' + project +'.json'

x_tensor.requires_grad = True

net = Net( y_tensor )
net.train()

lr = 0.01
opt=torch.optim.SGD(net.parameters(), lr)
#mse=torch.nn.MSELoss()

epoch_loss = []
for epoch in range(300):
  loss = net(x_tensor)
  print("loss",loss)
  epoch_loss.append( loss )

  opt.zero_grad()
  loss.backward()
  opt.step();
# Out:
# loss tensor(67.4897, grad_fn=<MseLossBackward0>)
# loss tensor(36.1833, grad_fn=<MseLossBackward0>)
# loss tensor(3.8057, grad_fn=<MseLossBackward0>)
# loss tensor(5.0003, grad_fn=<MseLossBackward0>)
# loss tensor(8.2970, grad_fn=<MseLossBackward0>)
# loss tensor(23.9235, grad_fn=<MseLossBackward0>)
# loss tensor(8.9370, grad_fn=<MseLossBackward0>)
# loss tensor(25.9405, grad_fn=<MseLossBackward0>)
# loss tensor(5.5347, grad_fn=<MseLossBackward0>)
# loss tensor(14.0332, grad_fn=<MseLossBackward0>)
# loss tensor(10.9607, grad_fn=<MseLossBackward0>)
# loss tensor(31.0107, grad_fn=<MseLossBackward0>)
# loss tensor(1.5975, grad_fn=<MseLossBackward0>)
# loss tensor(1.5555, grad_fn=<MseLossBackward0>)
# loss tensor(1.6678, grad_fn=<MseLossBackward0>)
# loss tensor(2.3511, grad_fn=<MseLossBackward0>)
# loss tensor(3.6467, grad_fn=<MseLossBackward0>)
# loss tensor(9.3329, grad_fn=<MseLossBackward0>)
# loss tensor(9.3094, grad_fn=<MseLossBackward0>)
# loss tensor(26.3715, grad_fn=<MseLossBackward0>)
# loss tensor(1.4412, grad_fn=<MseLossBackward0>)
# loss tensor(2.2828, grad_fn=<MseLossBackward0>)
# loss tensor(3.3906, grad_fn=<MseLossBackward0>)
# loss tensor(8.3649, grad_fn=<MseLossBackward0>)
# loss tensor(7.2623, grad_fn=<MseLossBackward0>)
# loss tensor(19.5514, grad_fn=<MseLossBackward0>)
# loss tensor(2.9221, grad_fn=<MseLossBackward0>)
# loss tensor(6.6299, grad_fn=<MseLossBackward0>)
# loss tensor(5.9288, grad_fn=<MseLossBackward0>)
# loss tensor(15.0181, grad_fn=<MseLossBackward0>)
# loss tensor(3.9151, grad_fn=<MseLossBackward0>)
# loss tensor(9.1434, grad_fn=<MseLossBackward0>)
# loss tensor(5.2380, grad_fn=<MseLossBackward0>)
# loss tensor(12.5481, grad_fn=<MseLossBackward0>)
# loss tensor(4.0297, grad_fn=<MseLossBackward0>)
# loss tensor(9.1261, grad_fn=<MseLossBackward0>)
# loss tensor(4.5775, grad_fn=<MseLossBackward0>)
# loss tensor(10.4061, grad_fn=<MseLossBackward0>)
# loss tensor(4.0532, grad_fn=<MseLossBackward0>)
# loss tensor(8.9208, grad_fn=<MseLossBackward0>)
# loss tensor(4.1169, grad_fn=<MseLossBackward0>)
# loss tensor(8.9696, grad_fn=<MseLossBackward0>)
# loss tensor(3.9076, grad_fn=<MseLossBackward0>)
# loss tensor(8.3403, grad_fn=<MseLossBackward0>)
# loss tensor(3.8243, grad_fn=<MseLossBackward0>)
# loss tensor(8.0490, grad_fn=<MseLossBackward0>)
# loss tensor(3.7063, grad_fn=<MseLossBackward0>)
# loss tensor(7.6858, grad_fn=<MseLossBackward0>)
# loss tensor(3.6104, grad_fn=<MseLossBackward0>)
# loss tensor(7.3885, grad_fn=<MseLossBackward0>)
# loss tensor(3.5183, grad_fn=<MseLossBackward0>)
# loss tensor(7.1103, grad_fn=<MseLossBackward0>)
# loss tensor(3.4333, grad_fn=<MseLossBackward0>)
# loss tensor(6.8566, grad_fn=<MseLossBackward0>)
# loss tensor(3.3546, grad_fn=<MseLossBackward0>)
# loss tensor(6.6246, grad_fn=<MseLossBackward0>)
# loss tensor(3.2798, grad_fn=<MseLossBackward0>)
# loss tensor(6.4079, grad_fn=<MseLossBackward0>)
# loss tensor(3.2093, grad_fn=<MseLossBackward0>)
# loss tensor(6.2059, grad_fn=<MseLossBackward0>)
# loss tensor(3.1426, grad_fn=<MseLossBackward0>)
# loss tensor(6.0173, grad_fn=<MseLossBackward0>)
# loss tensor(3.0799, grad_fn=<MseLossBackward0>)
# loss tensor(5.8418, grad_fn=<MseLossBackward0>)
# loss tensor(3.0204, grad_fn=<MseLossBackward0>)
# loss tensor(5.6759, grad_fn=<MseLossBackward0>)
# loss tensor(2.9614, grad_fn=<MseLossBackward0>)
# loss tensor(5.5136, grad_fn=<MseLossBackward0>)
# loss tensor(2.9056, grad_fn=<MseLossBackward0>)
# loss tensor(5.3634, grad_fn=<MseLossBackward0>)
# loss tensor(2.8527, grad_fn=<MseLossBackward0>)
# loss tensor(5.2230, grad_fn=<MseLossBackward0>)
# loss tensor(2.8034, grad_fn=<MseLossBackward0>)
# loss tensor(5.0935, grad_fn=<MseLossBackward0>)
# loss tensor(2.7577, grad_fn=<MseLossBackward0>)
# loss tensor(4.9704, grad_fn=<MseLossBackward0>)
# loss tensor(2.7128, grad_fn=<MseLossBackward0>)
# loss tensor(4.8575, grad_fn=<MseLossBackward0>)
# loss tensor(2.6701, grad_fn=<MseLossBackward0>)
# loss tensor(4.7439, grad_fn=<MseLossBackward0>)
# loss tensor(2.6285, grad_fn=<MseLossBackward0>)
# loss tensor(4.6372, grad_fn=<MseLossBackward0>)
# loss tensor(2.5881, grad_fn=<MseLossBackward0>)
# loss tensor(4.5377, grad_fn=<MseLossBackward0>)
# loss tensor(2.5490, grad_fn=<MseLossBackward0>)
# loss tensor(4.4364, grad_fn=<MseLossBackward0>)
# loss tensor(2.5114, grad_fn=<MseLossBackward0>)
# loss tensor(4.3427, grad_fn=<MseLossBackward0>)
# loss tensor(2.4764, grad_fn=<MseLossBackward0>)
# loss tensor(4.2588, grad_fn=<MseLossBackward0>)
# loss tensor(2.4424, grad_fn=<MseLossBackward0>)
# loss tensor(4.1716, grad_fn=<MseLossBackward0>)
# loss tensor(2.4082, grad_fn=<MseLossBackward0>)
# loss tensor(4.0913, grad_fn=<MseLossBackward0>)
# loss tensor(2.3756, grad_fn=<MseLossBackward0>)
# loss tensor(4.0091, grad_fn=<MseLossBackward0>)
# loss tensor(2.3433, grad_fn=<MseLossBackward0>)
# loss tensor(3.9320, grad_fn=<MseLossBackward0>)
# loss tensor(2.3121, grad_fn=<MseLossBackward0>)
# loss tensor(3.8591, grad_fn=<MseLossBackward0>)
# loss tensor(2.2814, grad_fn=<MseLossBackward0>)
# loss tensor(3.7830, grad_fn=<MseLossBackward0>)
# loss tensor(2.2510, grad_fn=<MseLossBackward0>)
# loss tensor(3.7110, grad_fn=<MseLossBackward0>)
# loss tensor(2.2215, grad_fn=<MseLossBackward0>)
# loss tensor(3.6444, grad_fn=<MseLossBackward0>)
# loss tensor(2.1924, grad_fn=<MseLossBackward0>)
# loss tensor(3.5745, grad_fn=<MseLossBackward0>)
# loss tensor(2.1634, grad_fn=<MseLossBackward0>)
# loss tensor(3.5078, grad_fn=<MseLossBackward0>)
# loss tensor(2.1366, grad_fn=<MseLossBackward0>)
# loss tensor(3.4494, grad_fn=<MseLossBackward0>)
# loss tensor(2.1112, grad_fn=<MseLossBackward0>)
# loss tensor(3.3888, grad_fn=<MseLossBackward0>)
# loss tensor(2.0849, grad_fn=<MseLossBackward0>)
# loss tensor(3.3309, grad_fn=<MseLossBackward0>)
# loss tensor(2.0597, grad_fn=<MseLossBackward0>)
# loss tensor(3.2717, grad_fn=<MseLossBackward0>)
# loss tensor(2.0341, grad_fn=<MseLossBackward0>)
# loss tensor(3.2174, grad_fn=<MseLossBackward0>)
# loss tensor(2.0106, grad_fn=<MseLossBackward0>)
# loss tensor(3.1627, grad_fn=<MseLossBackward0>)
# loss tensor(1.9864, grad_fn=<MseLossBackward0>)
# loss tensor(3.1126, grad_fn=<MseLossBackward0>)
# loss tensor(1.9634, grad_fn=<MseLossBackward0>)
# loss tensor(3.0596, grad_fn=<MseLossBackward0>)
# loss tensor(1.9397, grad_fn=<MseLossBackward0>)
# loss tensor(3.0085, grad_fn=<MseLossBackward0>)
# loss tensor(1.9168, grad_fn=<MseLossBackward0>)
# loss tensor(2.9614, grad_fn=<MseLossBackward0>)
# loss tensor(1.8950, grad_fn=<MseLossBackward0>)
# loss tensor(2.9121, grad_fn=<MseLossBackward0>)
# loss tensor(1.8724, grad_fn=<MseLossBackward0>)
# loss tensor(2.8646, grad_fn=<MseLossBackward0>)
# loss tensor(1.8504, grad_fn=<MseLossBackward0>)
# loss tensor(2.8176, grad_fn=<MseLossBackward0>)
# loss tensor(1.8286, grad_fn=<MseLossBackward0>)
# loss tensor(2.7738, grad_fn=<MseLossBackward0>)
# loss tensor(1.8079, grad_fn=<MseLossBackward0>)
# loss tensor(2.7282, grad_fn=<MseLossBackward0>)
# loss tensor(1.7867, grad_fn=<MseLossBackward0>)
# loss tensor(2.6843, grad_fn=<MseLossBackward0>)
# loss tensor(1.7660, grad_fn=<MseLossBackward0>)
# loss tensor(2.6383, grad_fn=<MseLossBackward0>)
# loss tensor(1.7446, grad_fn=<MseLossBackward0>)
# loss tensor(2.5952, grad_fn=<MseLossBackward0>)
# loss tensor(1.7245, grad_fn=<MseLossBackward0>)
# loss tensor(2.5573, grad_fn=<MseLossBackward0>)
# loss tensor(1.7058, grad_fn=<MseLossBackward0>)
# loss tensor(2.5159, grad_fn=<MseLossBackward0>)
# loss tensor(1.6859, grad_fn=<MseLossBackward0>)
# loss tensor(2.4760, grad_fn=<MseLossBackward0>)
# loss tensor(1.6665, grad_fn=<MseLossBackward0>)
# loss tensor(2.4373, grad_fn=<MseLossBackward0>)
# loss tensor(1.6476, grad_fn=<MseLossBackward0>)
# loss tensor(2.3997, grad_fn=<MseLossBackward0>)
# loss tensor(1.6289, grad_fn=<MseLossBackward0>)
# loss tensor(2.3656, grad_fn=<MseLossBackward0>)
# loss tensor(1.6116, grad_fn=<MseLossBackward0>)
# loss tensor(2.3286, grad_fn=<MseLossBackward0>)
# loss tensor(1.5942, grad_fn=<MseLossBackward0>)
# loss tensor(2.2940, grad_fn=<MseLossBackward0>)
# loss tensor(1.5770, grad_fn=<MseLossBackward0>)
# loss tensor(2.2625, grad_fn=<MseLossBackward0>)
# loss tensor(1.5608, grad_fn=<MseLossBackward0>)
# loss tensor(2.2287, grad_fn=<MseLossBackward0>)
# loss tensor(1.5439, grad_fn=<MseLossBackward0>)
# loss tensor(2.1962, grad_fn=<MseLossBackward0>)
# loss tensor(1.5282, grad_fn=<MseLossBackward0>)
# loss tensor(2.1684, grad_fn=<MseLossBackward0>)
# loss tensor(1.5139, grad_fn=<MseLossBackward0>)
# loss tensor(2.1400, grad_fn=<MseLossBackward0>)
# loss tensor(1.4985, grad_fn=<MseLossBackward0>)
# loss tensor(2.1110, grad_fn=<MseLossBackward0>)
# loss tensor(1.4836, grad_fn=<MseLossBackward0>)
# loss tensor(2.0793, grad_fn=<MseLossBackward0>)
# loss tensor(1.4671, grad_fn=<MseLossBackward0>)
# loss tensor(2.0486, grad_fn=<MseLossBackward0>)
# loss tensor(1.4519, grad_fn=<MseLossBackward0>)
# loss tensor(2.0231, grad_fn=<MseLossBackward0>)
# loss tensor(1.4373, grad_fn=<MseLossBackward0>)
# loss tensor(1.9926, grad_fn=<MseLossBackward0>)
# loss tensor(1.4219, grad_fn=<MseLossBackward0>)
# loss tensor(1.9658, grad_fn=<MseLossBackward0>)
# loss tensor(1.4063, grad_fn=<MseLossBackward0>)
# loss tensor(1.9373, grad_fn=<MseLossBackward0>)
# loss tensor(1.3919, grad_fn=<MseLossBackward0>)
# loss tensor(1.9092, grad_fn=<MseLossBackward0>)
# loss tensor(1.3764, grad_fn=<MseLossBackward0>)
# loss tensor(1.8802, grad_fn=<MseLossBackward0>)
# loss tensor(1.3615, grad_fn=<MseLossBackward0>)
# loss tensor(1.8532, grad_fn=<MseLossBackward0>)
# loss tensor(1.3467, grad_fn=<MseLossBackward0>)
# loss tensor(1.8288, grad_fn=<MseLossBackward0>)
# loss tensor(1.3334, grad_fn=<MseLossBackward0>)
# loss tensor(1.8026, grad_fn=<MseLossBackward0>)
# loss tensor(1.3191, grad_fn=<MseLossBackward0>)
# loss tensor(1.7767, grad_fn=<MseLossBackward0>)
# loss tensor(1.3056, grad_fn=<MseLossBackward0>)
# loss tensor(1.7527, grad_fn=<MseLossBackward0>)
# loss tensor(1.2917, grad_fn=<MseLossBackward0>)
# loss tensor(1.7282, grad_fn=<MseLossBackward0>)
# loss tensor(1.2784, grad_fn=<MseLossBackward0>)
# loss tensor(1.7046, grad_fn=<MseLossBackward0>)
# loss tensor(1.2649, grad_fn=<MseLossBackward0>)
# loss tensor(1.6828, grad_fn=<MseLossBackward0>)
# loss tensor(1.2530, grad_fn=<MseLossBackward0>)
# loss tensor(1.6599, grad_fn=<MseLossBackward0>)
# loss tensor(1.2396, grad_fn=<MseLossBackward0>)
# loss tensor(1.6363, grad_fn=<MseLossBackward0>)
# loss tensor(1.2268, grad_fn=<MseLossBackward0>)
# loss tensor(1.6142, grad_fn=<MseLossBackward0>)
# loss tensor(1.2140, grad_fn=<MseLossBackward0>)
# loss tensor(1.5921, grad_fn=<MseLossBackward0>)
# loss tensor(1.2023, grad_fn=<MseLossBackward0>)
# loss tensor(1.5717, grad_fn=<MseLossBackward0>)
# loss tensor(1.1902, grad_fn=<MseLossBackward0>)
# loss tensor(1.5509, grad_fn=<MseLossBackward0>)
# loss tensor(1.1784, grad_fn=<MseLossBackward0>)
# loss tensor(1.5308, grad_fn=<MseLossBackward0>)
# loss tensor(1.1664, grad_fn=<MseLossBackward0>)
# loss tensor(1.5102, grad_fn=<MseLossBackward0>)
# loss tensor(1.1548, grad_fn=<MseLossBackward0>)
# loss tensor(1.4901, grad_fn=<MseLossBackward0>)
# loss tensor(1.1427, grad_fn=<MseLossBackward0>)
# loss tensor(1.4700, grad_fn=<MseLossBackward0>)
# loss tensor(1.1313, grad_fn=<MseLossBackward0>)
# loss tensor(1.4509, grad_fn=<MseLossBackward0>)
# loss tensor(1.1196, grad_fn=<MseLossBackward0>)
# loss tensor(1.4314, grad_fn=<MseLossBackward0>)
# loss tensor(1.1087, grad_fn=<MseLossBackward0>)
# loss tensor(1.4133, grad_fn=<MseLossBackward0>)
# loss tensor(1.0976, grad_fn=<MseLossBackward0>)
# loss tensor(1.3951, grad_fn=<MseLossBackward0>)
# loss tensor(1.0869, grad_fn=<MseLossBackward0>)
# loss tensor(1.3775, grad_fn=<MseLossBackward0>)
# loss tensor(1.0763, grad_fn=<MseLossBackward0>)
# loss tensor(1.3598, grad_fn=<MseLossBackward0>)
# loss tensor(1.0658, grad_fn=<MseLossBackward0>)
# loss tensor(1.3429, grad_fn=<MseLossBackward0>)
# loss tensor(1.0555, grad_fn=<MseLossBackward0>)
# loss tensor(1.3257, grad_fn=<MseLossBackward0>)
# loss tensor(1.0455, grad_fn=<MseLossBackward0>)
# loss tensor(1.3095, grad_fn=<MseLossBackward0>)
# loss tensor(1.0354, grad_fn=<MseLossBackward0>)
# loss tensor(1.2932, grad_fn=<MseLossBackward0>)
# loss tensor(1.0258, grad_fn=<MseLossBackward0>)
# loss tensor(1.2777, grad_fn=<MseLossBackward0>)
# loss tensor(1.0161, grad_fn=<MseLossBackward0>)
# loss tensor(1.2619, grad_fn=<MseLossBackward0>)
# loss tensor(1.0067, grad_fn=<MseLossBackward0>)
# loss tensor(1.2470, grad_fn=<MseLossBackward0>)
# loss tensor(0.9974, grad_fn=<MseLossBackward0>)
# loss tensor(1.2322, grad_fn=<MseLossBackward0>)
# loss tensor(0.9885, grad_fn=<MseLossBackward0>)
# loss tensor(1.2168, grad_fn=<MseLossBackward0>)
# loss tensor(0.9787, grad_fn=<MseLossBackward0>)
# loss tensor(1.2028, grad_fn=<MseLossBackward0>)
# loss tensor(0.9704, grad_fn=<MseLossBackward0>)
# loss tensor(1.1885, grad_fn=<MseLossBackward0>)
# loss tensor(0.9613, grad_fn=<MseLossBackward0>)
# loss tensor(1.1755, grad_fn=<MseLossBackward0>)
# loss tensor(0.9532, grad_fn=<MseLossBackward0>)
# loss tensor(1.1616, grad_fn=<MseLossBackward0>)
# loss tensor(0.9444, grad_fn=<MseLossBackward0>)
# loss tensor(1.1491, grad_fn=<MseLossBackward0>)
# loss tensor(0.9365, grad_fn=<MseLossBackward0>)
# loss tensor(1.1357, grad_fn=<MseLossBackward0>)
# loss tensor(0.9280, grad_fn=<MseLossBackward0>)
# loss tensor(1.1237, grad_fn=<MseLossBackward0>)
# loss tensor(0.9206, grad_fn=<MseLossBackward0>)
# loss tensor(1.1110, grad_fn=<MseLossBackward0>)
# loss tensor(0.9128, grad_fn=<MseLossBackward0>)
# loss tensor(1.1001, grad_fn=<MseLossBackward0>)
# loss tensor(0.9058, grad_fn=<MseLossBackward0>)
# loss tensor(1.0893, grad_fn=<MseLossBackward0>)
# loss tensor(0.8989, grad_fn=<MseLossBackward0>)
# loss tensor(1.0787, grad_fn=<MseLossBackward0>)
# loss tensor(0.8917, grad_fn=<MseLossBackward0>)
# loss tensor(1.0677, grad_fn=<MseLossBackward0>)
# loss tensor(0.8847, grad_fn=<MseLossBackward0>)
# loss tensor(1.0569, grad_fn=<MseLossBackward0>)
# loss tensor(0.8780, grad_fn=<MseLossBackward0>)
# loss tensor(1.0465, grad_fn=<MseLossBackward0>)
# loss tensor(0.8710, grad_fn=<MseLossBackward0>)
# loss tensor(1.0348, grad_fn=<MseLossBackward0>)
# loss tensor(0.8636, grad_fn=<MseLossBackward0>)
# loss tensor(1.0247, grad_fn=<MseLossBackward0>)
# loss tensor(0.8568, grad_fn=<MseLossBackward0>)
# loss tensor(1.0145, grad_fn=<MseLossBackward0>)
# loss tensor(0.8502, grad_fn=<MseLossBackward0>)
# loss tensor(1.0046, grad_fn=<MseLossBackward0>)
# loss tensor(0.8435, grad_fn=<MseLossBackward0>)
# loss tensor(0.9946, grad_fn=<MseLossBackward0>)
# loss tensor(0.8370, grad_fn=<MseLossBackward0>)
# loss tensor(0.9849, grad_fn=<MseLossBackward0>)
# loss tensor(0.8311, grad_fn=<MseLossBackward0>)
# loss tensor(0.9761, grad_fn=<MseLossBackward0>)
# loss tensor(0.8253, grad_fn=<MseLossBackward0>)
# loss tensor(0.9674, grad_fn=<MseLossBackward0>)

# %% [markdown]
# 評価データを生成する。

# %%
nd = 1000
d1 = np.linspace(0.,10.,nd)
x1 = np.sin(d1)
x2 = np.exp(d1 / 5)
d2 = np.stack([x1, x2], axis=1)

dd = torch.from_numpy(d2).float()

net.kind = 1
net.eval()
loss = net( dd )

y_pred = net.out.data.numpy()

# %% [markdown]
# 収束状況グラフを描画する

# %%
import matplotlib.pyplot as plt

# convergence graph
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %% [markdown]
# 評価データを描画する

# %%
# prediction result
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y )
ax.plot( d1, y_pred, c='orange')
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %% [markdown]
# 学習用データファイル、学習ループのC++コードを生成する

# %%
project = "mse1"
folder = "./mse"
nd = 1000
d1 = np.linspace(0.,10.,nd)
x1 = np.sin(d1)
x2 = np.exp(d1 / 5)
d2 = np.stack([x1, x2], axis=1)
#print(x1)
#print(x2)
#print(d2)

CV.convert_data_file( project, folder, inp_data=d1, pred_data=d2 )
CV.convert_train_code( project, folder, json_path, sol="mse1", epochs=300, inp_data=d1, pred_data=d2 )
# Out:
# datafile key :  inp_data
# datafile key :  pred_data
# [DATA] ./mse/mse1_data.cpp
# [JSON] network/mse1.json
# epoch_num :  300
# batch_size :  32
# lr :  0.01
# inp shape (1000,) 1
# inp  shape :  1 {1000}
# pred shape :  1 {1000,2}
# target shape :  0
# div :  False
# unpack0 prim::ListUnpack
# unpack1 aten::broadcast_tensors 0
# unpack2 prim::ListConstruct 0
# unpack original no:  11 15
# unpack0 prim::ListUnpack
# unpack1 aten::broadcast_tensors 1
# unpack2 prim::ListConstruct 1
# unpack original no:  12 16
# mse_no :  11 12
# batch_size: 32
# inp_shape: {1000}
# file 1 inp_data
# [TRAIN]  ./mse/mse1_train.cpp

# %% [markdown]
# 学習用C++コードをコンパイル、リンクする

# %%
# !g++ -std=c++14 ./mse/mse1.cpp ./mse/mse1_param.cpp ./mse/mse1_train.cpp ./mse/mse1_data.cpp -D_NOTEBOOK -D_TRAIN -I ../../../xtensor -lcblas -o ./mse/mse1_train

# %% [markdown]
# (注意) xtensorフォルダにxtensor関連のincludeファイルを置いています。

# %%
# !./mse/mse1_train
# Out:
# epoch_num : 300
# epoch 0 - loss 67.4896
# epoch 1 - loss 36.1833
# epoch 2 - loss 3.80568
# epoch 3 - loss 5.00023
# epoch 4 - loss 8.29694
# epoch 5 - loss 23.9232
# epoch 6 - loss 8.93713
# epoch 7 - loss 25.941
# epoch 8 - loss 5.53438
# epoch 9 - loss 14.032
# epoch 10 - loss 10.9611
# epoch 11 - loss 31.0119
# epoch 12 - loss 1.59739
# epoch 13 - loss 1.55513
# epoch 14 - loss 1.66704
# epoch 15 - loss 2.34869
# epoch 16 - loss 3.64226
# epoch 17 - loss 9.31862
# epoch 18 - loss 9.30901
# epoch 19 - loss 26.372
# epoch 20 - loss 1.44155
# epoch 21 - loss 2.284
# epoch 22 - loss 3.39256
# epoch 23 - loss 8.37133
# epoch 24 - loss 7.2635
# epoch 25 - loss 19.5551
# epoch 26 - loss 2.92081
# epoch 27 - loss 6.62633
# epoch 28 - loss 5.92831
# epoch 29 - loss 15.0172
# epoch 30 - loss 3.91594
# epoch 31 - loss 9.14582
# epoch 32 - loss 5.23805
# epoch 33 - loss 12.5484
# epoch 34 - loss 4.02986
# epoch 35 - loss 9.12672
# epoch 36 - loss 4.5776
# epoch 37 - loss 10.4065
# epoch 38 - loss 4.05323
# epoch 39 - loss 8.92107
# epoch 40 - loss 4.11703
# epoch 41 - loss 8.97
# epoch 42 - loss 3.90764
# epoch 43 - loss 8.34061
# epoch 44 - loss 3.82469
# epoch 45 - loss 8.0497
# epoch 46 - loss 3.70604
# epoch 47 - loss 7.68513
# epoch 48 - loss 3.61044
# epoch 49 - loss 7.3887
# epoch 50 - loss 3.51833
# epoch 51 - loss 7.11025
# epoch 52 - loss 3.43334
# epoch 53 - loss 6.85663
# epoch 54 - loss 3.35463
# epoch 55 - loss 6.62464
# epoch 56 - loss 3.27981
# epoch 57 - loss 6.40786
# epoch 58 - loss 3.2093
# epoch 59 - loss 6.2059
# epoch 60 - loss 3.1429
# epoch 61 - loss 6.01765
# epoch 62 - loss 3.07968
# epoch 63 - loss 5.84108
# epoch 64 - loss 3.02022
# epoch 65 - loss 5.67528
# epoch 66 - loss 2.96111
# epoch 67 - loss 5.51284
# epoch 68 - loss 2.9056
# epoch 69 - loss 5.36331
# epoch 70 - loss 2.85267
# epoch 71 - loss 5.22294
# epoch 72 - loss 2.8034
# epoch 73 - loss 5.09347
# epoch 74 - loss 2.75746
# epoch 75 - loss 4.97001
# epoch 76 - loss 2.71284
# epoch 77 - loss 4.85772
# epoch 78 - loss 2.67018
# epoch 79 - loss 4.74421
# epoch 80 - loss 2.62857
# epoch 81 - loss 4.63748
# epoch 82 - loss 2.58819
# epoch 83 - loss 4.53794
# epoch 84 - loss 2.5491
# epoch 85 - loss 4.43666
# epoch 86 - loss 2.5115
# epoch 87 - loss 4.34301
# epoch 88 - loss 2.47651
# epoch 89 - loss 4.25915
# epoch 90 - loss 2.44236
# epoch 91 - loss 4.17156
# epoch 92 - loss 2.40812
# epoch 93 - loss 4.09119
# epoch 94 - loss 2.37554
# epoch 95 - loss 4.009
# epoch 96 - loss 2.34326
# epoch 97 - loss 3.93198
# epoch 98 - loss 2.31196
# epoch 99 - loss 3.85888
# epoch 100 - loss 2.28128
# epoch 101 - loss 3.78278
# epoch 102 - loss 2.25089
# epoch 103 - loss 3.71079
# epoch 104 - loss 2.22143
# epoch 105 - loss 3.64411
# epoch 106 - loss 2.19223
# epoch 107 - loss 3.57406
# epoch 108 - loss 2.16324
# epoch 109 - loss 3.50741
# epoch 110 - loss 2.13645
# epoch 111 - loss 3.44898
# epoch 112 - loss 2.11106
# epoch 113 - loss 3.38839
# epoch 114 - loss 2.08484
# epoch 115 - loss 3.3307
# epoch 116 - loss 2.05966
# epoch 117 - loss 3.27158
# epoch 118 - loss 2.03412
# epoch 119 - loss 3.21735
# epoch 120 - loss 2.01061
# epoch 121 - loss 3.16267
# epoch 122 - loss 1.98644
# epoch 123 - loss 3.11265
# epoch 124 - loss 1.9634
# epoch 125 - loss 3.05963
# epoch 126 - loss 1.93974
# epoch 127 - loss 3.00851
# epoch 128 - loss 1.91683
# epoch 129 - loss 2.96151
# epoch 130 - loss 1.89502
# epoch 131 - loss 2.91217
# epoch 132 - loss 1.87245
# epoch 133 - loss 2.86465
# epoch 134 - loss 1.85041
# epoch 135 - loss 2.8175
# epoch 136 - loss 1.82862
# epoch 137 - loss 2.77373
# epoch 138 - loss 1.80789
# epoch 139 - loss 2.72837
# epoch 140 - loss 1.78675
# epoch 141 - loss 2.68435
# epoch 142 - loss 1.76599
# epoch 143 - loss 2.6382
# epoch 144 - loss 1.74461
# epoch 145 - loss 2.59523
# epoch 146 - loss 1.72466
# epoch 147 - loss 2.5574
# epoch 148 - loss 1.70566
# epoch 149 - loss 2.51575
# epoch 150 - loss 1.68583
# epoch 151 - loss 2.47587
# epoch 152 - loss 1.66648
# epoch 153 - loss 2.43738
# epoch 154 - loss 1.64759
# epoch 155 - loss 2.39969
# epoch 156 - loss 1.62893
# epoch 157 - loss 2.36567
# epoch 158 - loss 1.61165
# epoch 159 - loss 2.32862
# epoch 160 - loss 1.59422
# epoch 161 - loss 2.29407
# epoch 162 - loss 1.57704
# epoch 163 - loss 2.26248
# epoch 164 - loss 1.56095
# epoch 165 - loss 2.2291
# epoch 166 - loss 1.54384
# epoch 167 - loss 2.19589
# epoch 168 - loss 1.52811
# epoch 169 - loss 2.1683
# epoch 170 - loss 1.51335
# epoch 171 - loss 2.13908
# epoch 172 - loss 1.49868
# epoch 173 - loss 2.11138
# epoch 174 - loss 1.48318
# epoch 175 - loss 2.07874
# epoch 176 - loss 1.46758
# epoch 177 - loss 2.04927
# epoch 178 - loss 1.45171
# epoch 179 - loss 2.02289
# epoch 180 - loss 1.43724
# epoch 181 - loss 1.99246
# epoch 182 - loss 1.42186
# epoch 183 - loss 1.9657
# epoch 184 - loss 1.40629
# epoch 185 - loss 1.93731
# epoch 186 - loss 1.39191
# epoch 187 - loss 1.90929
# epoch 188 - loss 1.37638
# epoch 189 - loss 1.88029
# epoch 190 - loss 1.3617
# epoch 191 - loss 1.85355
# epoch 192 - loss 1.34666
# epoch 193 - loss 1.82865
# epoch 194 - loss 1.33363
# epoch 195 - loss 1.80281
# epoch 196 - loss 1.31901
# epoch 197 - loss 1.77678
# epoch 198 - loss 1.30558
# epoch 199 - loss 1.75256
# epoch 200 - loss 1.29166
# epoch 201 - loss 1.72808
# epoch 202 - loss 1.27829
# epoch 203 - loss 1.7044
# epoch 204 - loss 1.26476
# epoch 205 - loss 1.68263
# epoch 206 - loss 1.25296
# epoch 207 - loss 1.65975
# epoch 208 - loss 1.2397
# epoch 209 - loss 1.63653
# epoch 210 - loss 1.22688
# epoch 211 - loss 1.61417
# epoch 212 - loss 1.21399
# epoch 213 - loss 1.59204
# epoch 214 - loss 1.20217
# epoch 215 - loss 1.57154
# epoch 216 - loss 1.18999
# epoch 217 - loss 1.55054
# epoch 218 - loss 1.17839
# epoch 219 - loss 1.53073
# epoch 220 - loss 1.16644
# epoch 221 - loss 1.51029
# epoch 222 - loss 1.15465
# epoch 223 - loss 1.49007
# epoch 224 - loss 1.14266
# epoch 225 - loss 1.46985
# epoch 226 - loss 1.13114
# epoch 227 - loss 1.45069
# epoch 228 - loss 1.11962
# epoch 229 - loss 1.43156
# epoch 230 - loss 1.10862
# epoch 231 - loss 1.41315
# epoch 232 - loss 1.09755
# epoch 233 - loss 1.39499
# epoch 234 - loss 1.08693
# epoch 235 - loss 1.37745
# epoch 236 - loss 1.07626
# epoch 237 - loss 1.35981
# epoch 238 - loss 1.06586
# epoch 239 - loss 1.34291
# epoch 240 - loss 1.05537
# epoch 241 - loss 1.32558
# epoch 242 - loss 1.04549
# epoch 243 - loss 1.3095
# epoch 244 - loss 1.03541
# epoch 245 - loss 1.29325
# epoch 246 - loss 1.02584
# epoch 247 - loss 1.27769
# epoch 248 - loss 1.0161
# epoch 249 - loss 1.26197
# epoch 250 - loss 1.00679
# epoch 251 - loss 1.24717
# epoch 252 - loss 0.99743
# epoch 253 - loss 1.23224
# epoch 254 - loss 0.988424
# epoch 255 - loss 1.21676
# epoch 256 - loss 0.97881
# epoch 257 - loss 1.20287
# epoch 258 - loss 0.970362
# epoch 259 - loss 1.18842
# epoch 260 - loss 0.961246
# epoch 261 - loss 1.17536
# epoch 262 - loss 0.953209
# epoch 263 - loss 1.16158
# epoch 264 - loss 0.944356
# epoch 265 - loss 1.14899
# epoch 266 - loss 0.936367
# epoch 267 - loss 1.13544
# epoch 268 - loss 0.928109
# epoch 269 - loss 1.12379
# epoch 270 - loss 0.92042
# epoch 271 - loss 1.11076
# epoch 272 - loss 0.912799
# epoch 273 - loss 1.10014
# epoch 274 - loss 0.905777
# epoch 275 - loss 1.08927
# epoch 276 - loss 0.898904
# epoch 277 - loss 1.0787
# epoch 278 - loss 0.89173
# epoch 279 - loss 1.0677
# epoch 280 - loss 0.884643
# epoch 281 - loss 1.0569
# epoch 282 - loss 0.87798
# epoch 283 - loss 1.04647
# epoch 284 - loss 0.870943
# epoch 285 - loss 1.0348
# epoch 286 - loss 0.863382
# epoch 287 - loss 1.02451
# epoch 288 - loss 0.856828
# epoch 289 - loss 1.01459
# epoch 290 - loss 0.850096
# epoch 291 - loss 1.00453
# epoch 292 - loss 0.843441
# epoch 293 - loss 0.994587
# epoch 294 - loss 0.837039
# epoch 295 - loss 0.983949
# epoch 296 - loss 0.830492
# epoch 297 - loss 0.97523
# epoch 298 - loss 0.824644
# epoch 299 - loss 0.966518

# %%
# read output file from c++ code
f = open('./mse/mse1.out', 'r')

epoch_loss = []

datalist = f.readlines()
for data in datalist:
  #print(data)
  epoch_loss.append( float(data) )

f.close()

print("epoch =", len(epoch_loss))
print( epoch_loss)


f2 = open('./mse/mse1.pred', 'r')

x_new = []
y_pred = []
datalist = f2.readlines()
for data in datalist:
  #print(data)
  ds = data.split(',')
  x_new.append( float(ds[0]))
  y_pred.append( float(ds[1]))
  #x_new.append( float(data) )

f2.close()

print("pred =", len(x_new))
print( x_new )
print( y_pred )
# Out:
# epoch = 300
# [67.489609, 36.1833, 3.805676, 5.000233, 8.296941, 23.923243, 8.937128, 25.940987, 5.534382, 14.032016, 10.961112, 31.011883, 1.597391, 1.555127, 1.66704, 2.348695, 3.64226, 9.31862, 9.309009, 26.371971, 1.441545, 2.283998, 3.392555, 8.371325, 7.2635, 19.555117, 2.920814, 6.626325, 5.928308, 15.017187, 3.915945, 9.145824, 5.238048, 12.548371, 4.029859, 9.126719, 4.577601, 10.406542, 4.053226, 8.92107, 4.117025, 8.970004, 3.907642, 8.340606, 3.824687, 8.049696, 3.706045, 7.685133, 3.610443, 7.388703, 3.51833, 7.110254, 3.433341, 6.856628, 3.354629, 6.624643, 3.279809, 6.40786, 3.209304, 6.205905, 3.142902, 6.017651, 3.079683, 5.841084, 3.020222, 5.675284, 2.961112, 5.512842, 2.905596, 5.363312, 2.852673, 5.222939, 2.803398, 5.09347, 2.757456, 4.970007, 2.712839, 4.857723, 2.670183, 4.744208, 2.628574, 4.637481, 2.588186, 4.537941, 2.549103, 4.436661, 2.511497, 4.343006, 2.476508, 4.259149, 2.442358, 4.171561, 2.408118, 4.09119, 2.375538, 4.009, 2.343258, 3.931981, 2.311956, 3.858881, 2.281279, 3.782778, 2.250894, 3.710785, 2.221428, 3.644115, 2.192225, 3.574063, 2.16324, 3.507415, 2.136453, 3.448983, 2.111065, 3.388387, 2.084836, 3.330698, 2.059658, 3.271584, 2.034117, 3.217355, 2.010613, 3.162668, 1.986441, 3.112654, 1.963399, 3.059626, 1.939745, 3.008514, 1.916832, 2.96151, 1.895016, 2.912172, 1.872449, 2.864652, 1.850412, 2.817496, 1.828621, 2.773731, 1.807888, 2.728373, 1.786752, 2.684349, 1.765994, 2.638204, 1.744607, 2.595233, 1.724663, 2.5574, 1.705657, 2.515753, 1.68583, 2.475873, 1.66648, 2.437377, 1.647586, 2.399688, 1.628929, 2.365668, 1.611648, 2.328618, 1.594216, 2.294068, 1.577038, 2.262481, 1.56095, 2.229097, 1.543836, 2.195889, 1.52811, 2.168299, 1.513354, 2.139076, 1.498681, 2.111383, 1.483185, 2.07874, 1.467579, 2.049271, 1.451711, 2.022889, 1.437236, 1.992462, 1.421857, 1.965703, 1.406292, 1.937305, 1.391909, 1.90929, 1.376378, 1.880287, 1.361698, 1.853548, 1.346661, 1.828655, 1.33363, 1.802806, 1.319009, 1.776779, 1.305578, 1.752564, 1.291663, 1.72808, 1.278291, 1.7044, 1.264756, 1.682628, 1.252962, 1.659752, 1.239701, 1.636528, 1.226881, 1.614173, 1.213993, 1.592038, 1.202173, 1.571537, 1.18999, 1.550538, 1.178391, 1.530729, 1.166436, 1.510292, 1.154653, 1.490069, 1.14266, 1.46985, 1.131136, 1.450691, 1.119623, 1.431564, 1.108619, 1.413152, 1.097553, 1.394992, 1.086926, 1.377446, 1.076256, 1.359814, 1.065857, 1.34291, 1.055369, 1.325576, 1.045486, 1.309499, 1.035414, 1.293248, 1.025835, 1.277694, 1.016099, 1.261969, 1.006785, 1.24717, 0.99743, 1.232242, 0.988424, 1.216763, 0.97881, 1.202875, 0.970362, 1.188419, 0.961246, 1.17536, 0.953209, 1.16158, 0.944356, 1.148995, 0.936367, 1.135436, 0.928109, 1.123789, 0.92042, 1.110762, 0.912799, 1.100136, 0.905777, 1.089274, 0.898904, 1.078695, 0.89173, 1.067699, 0.884643, 1.056901, 0.87798, 1.046467, 0.870943, 1.034799, 0.863382, 1.024507, 0.856828, 1.014595, 0.850096, 1.004527, 0.843441, 0.994587, 0.837039, 0.983949, 0.830492, 0.97523, 0.824644, 0.966518]
# pred = 1000
# [0.0, 0.01001, 0.02002, 0.03003, 0.04004, 0.05005, 0.06006, 0.07007, 0.08008, 0.09009, 0.1001, 0.11011, 0.12012, 0.13013, 0.14014, 0.15015, 0.16016, 0.17017, 0.18018, 0.19019, 0.2002, 0.21021, 0.22022, 0.23023, 0.24024, 0.25025, 0.26026, 0.27027, 0.28028, 0.29029, 0.3003, 0.31031, 0.32032, 0.33033, 0.34034, 0.35035, 0.36036, 0.37037, 0.38038, 0.39039, 0.4004, 0.41041, 0.42042, 0.43043, 0.44044, 0.45045, 0.46046, 0.47047, 0.48048, 0.49049, 0.500501, 0.510511, 0.520521, 0.530531, 0.540541, 0.550551, 0.560561, 0.570571, 0.580581, 0.590591, 0.600601, 0.610611, 0.620621, 0.630631, 0.640641, 0.650651, 0.660661, 0.670671, 0.680681, 0.690691, 0.700701, 0.710711, 0.720721, 0.730731, 0.740741, 0.750751, 0.760761, 0.770771, 0.780781, 0.790791, 0.800801, 0.810811, 0.820821, 0.830831, 0.840841, 0.850851, 0.860861, 0.870871, 0.880881, 0.890891, 0.900901, 0.910911, 0.920921, 0.930931, 0.940941, 0.950951, 0.960961, 0.970971, 0.980981, 0.990991, 1.001001, 1.011011, 1.021021, 1.031031, 1.041041, 1.051051, 1.061061, 1.071071, 1.081081, 1.091091, 1.101101, 1.111111, 1.121121, 1.131131, 1.141141, 1.151151, 1.161161, 1.171171, 1.181181, 1.191191, 1.201201, 1.211211, 1.221221, 1.231231, 1.241241, 1.251251, 1.261261, 1.271271, 1.281281, 1.291291, 1.301301, 1.311311, 1.321321, 1.331331, 1.341341, 1.351351, 1.361361, 1.371371, 1.381381, 1.391391, 1.401401, 1.411411, 1.421421, 1.431431, 1.441441, 1.451451, 1.461461, 1.471471, 1.481481, 1.491491, 1.501502, 1.511512, 1.521522, 1.531532, 1.541542, 1.551552, 1.561562, 1.571572, 1.581582, 1.591592, 1.601602, 1.611612, 1.621622, 1.631632, 1.641642, 1.651652, 1.661662, 1.671672, 1.681682, 1.691692, 1.701702, 1.711712, 1.721722, 1.731732, 1.741742, 1.751752, 1.761762, 1.771772, 1.781782, 1.791792, 1.801802, 1.811812, 1.821822, 1.831832, 1.841842, 1.851852, 1.861862, 1.871872, 1.881882, 1.891892, 1.901902, 1.911912, 1.921922, 1.931932, 1.941942, 1.951952, 1.961962, 1.971972, 1.981982, 1.991992, 2.002002, 2.012012, 2.022022, 2.032032, 2.042042, 2.052052, 2.062062, 2.072072, 2.082082, 2.092092, 2.102102, 2.112112, 2.122122, 2.132132, 2.142142, 2.152152, 2.162162, 2.172172, 2.182182, 2.192192, 2.202202, 2.212212, 2.222222, 2.232232, 2.242242, 2.252252, 2.262262, 2.272272, 2.282282, 2.292292, 2.302302, 2.312312, 2.322322, 2.332332, 2.342342, 2.352352, 2.362362, 2.372372, 2.382382, 2.392392, 2.402402, 2.412412, 2.422422, 2.432432, 2.442442, 2.452452, 2.462462, 2.472472, 2.482482, 2.492492, 2.502502, 2.512512, 2.522522, 2.532532, 2.542542, 2.552552, 2.562562, 2.572572, 2.582582, 2.592592, 2.602603, 2.612613, 2.622623, 2.632633, 2.642643, 2.652653, 2.662663, 2.672673, 2.682683, 2.692693, 2.702703, 2.712713, 2.722723, 2.732733, 2.742743, 2.752753, 2.762763, 2.772773, 2.782783, 2.792793, 2.802803, 2.812813, 2.822823, 2.832833, 2.842843, 2.852853, 2.862863, 2.872873, 2.882883, 2.892893, 2.902903, 2.912913, 2.922923, 2.932933, 2.942943, 2.952953, 2.962963, 2.972973, 2.982983, 2.992993, 3.003003, 3.013013, 3.023023, 3.033033, 3.043043, 3.053053, 3.063063, 3.073073, 3.083083, 3.093093, 3.103103, 3.113113, 3.123123, 3.133133, 3.143143, 3.153153, 3.163163, 3.173173, 3.183183, 3.193193, 3.203203, 3.213213, 3.223223, 3.233233, 3.243243, 3.253253, 3.263263, 3.273273, 3.283283, 3.293293, 3.303303, 3.313313, 3.323323, 3.333333, 3.343343, 3.353353, 3.363363, 3.373373, 3.383383, 3.393393, 3.403404, 3.413414, 3.423424, 3.433434, 3.443444, 3.453454, 3.463464, 3.473474, 3.483484, 3.493494, 3.503504, 3.513514, 3.523524, 3.533534, 3.543544, 3.553554, 3.563564, 3.573574, 3.583584, 3.593594, 3.603604, 3.613614, 3.623624, 3.633634, 3.643644, 3.653654, 3.663664, 3.673674, 3.683684, 3.693694, 3.703704, 3.713714, 3.723724, 3.733734, 3.743744, 3.753754, 3.763764, 3.773774, 3.783784, 3.793794, 3.803804, 3.813814, 3.823824, 3.833834, 3.843844, 3.853854, 3.863864, 3.873874, 3.883884, 3.893894, 3.903904, 3.913914, 3.923924, 3.933934, 3.943944, 3.953954, 3.963964, 3.973974, 3.983984, 3.993994, 4.004004, 4.014014, 4.024024, 4.034034, 4.044044, 4.05405 ...
# [2.349627, 2.368962, 2.388106, 2.407253, 2.427031, 2.447915, 2.468794, 2.493846, 2.521394, 2.548931, 2.576453, 2.603959, 2.631446, 2.658911, 2.686353, 2.713768, 2.741155, 2.768511, 2.795835, 2.823122, 2.850372, 2.877582, 2.904748, 2.932149, 2.960577, 2.988955, 3.017276, 3.045541, 3.073746, 3.104713, 3.136739, 3.168284, 3.199795, 3.231232, 3.263264, 3.295532, 3.327709, 3.359792, 3.39178, 3.423666, 3.455452, 3.487133, 3.518707, 3.550171, 3.581522, 3.612758, 3.643876, 3.674873, 3.705748, 3.736497, 3.767118, 3.797607, 3.827964, 3.858185, 3.888292, 3.918261, 3.948087, 3.977767, 4.008387, 4.039198, 4.069848, 4.100335, 4.130655, 4.160807, 4.191182, 4.221519, 4.251728, 4.281832, 4.311749, 4.341475, 4.371011, 4.400352, 4.429496, 4.45844, 4.487183, 4.515722, 4.544055, 4.572178, 4.600093, 4.627792, 4.655277, 4.682545, 4.709593, 4.736419, 4.76302, 4.789396, 4.815543, 4.84146, 4.867146, 4.892596, 4.91781, 4.942787, 4.967523, 4.992017, 5.016266, 5.04027, 5.064026, 5.087533, 5.110788, 5.133791, 5.156537, 5.179029, 5.201262, 5.223235, 5.244946, 5.266395, 5.287579, 5.308496, 5.329146, 5.349526, 5.369637, 5.389474, 5.409039, 5.428329, 5.447342, 5.466078, 5.484535, 5.502711, 5.520608, 5.537959, 5.554584, 5.570936, 5.587017, 5.602824, 5.618356, 5.633612, 5.648591, 5.663293, 5.677716, 5.69186, 5.705724, 5.719306, 5.732607, 5.745625, 5.758363, 5.770823, 5.783, 5.794893, 5.806501, 5.817825, 5.828862, 5.839613, 5.850078, 5.860255, 5.870144, 5.879745, 5.889058, 5.898083, 5.906818, 5.915265, 5.923421, 5.931288, 5.938866, 5.946153, 5.953149, 5.959856, 5.966273, 5.9724, 5.978236, 5.983782, 5.989038, 5.994003, 5.998679, 6.003065, 6.007163, 6.01097, 6.014488, 6.017718, 6.020659, 6.023313, 6.025677, 6.027756, 6.029546, 6.031052, 6.03227, 6.033204, 6.033886, 6.034316, 6.03446, 6.034322, 6.0339, 6.033198, 6.032216, 6.030951, 6.029409, 6.027588, 6.025489, 6.023243, 6.020733, 6.017951, 6.014895, 6.01157, 6.007976, 6.004112, 5.99998, 5.995583, 5.990919, 5.986039, 5.980904, 5.975506, 5.969849, 5.963933, 5.957761, 5.951332, 5.944649, 5.937712, 5.930524, 5.923085, 5.915398, 5.907463, 5.899282, 5.890856, 5.882188, 5.873279, 5.864129, 5.854741, 5.845118, 5.835201, 5.824403, 5.813361, 5.802077, 5.790554, 5.778792, 5.766794, 5.754563, 5.7421, 5.729405, 5.716483, 5.703336, 5.689963, 5.67637, 5.662556, 5.648525, 5.634278, 5.619819, 5.605147, 5.590268, 5.575676, 5.560997, 5.546123, 5.531052, 5.51579, 5.500339, 5.4847, 5.468877, 5.45287, 5.436684, 5.42032, 5.40378, 5.387068, 5.370185, 5.353134, 5.335918, 5.318539, 5.301, 5.283302, 5.26545, 5.247445, 5.229289, 5.210987, 5.19254, 5.173951, 5.155223, 5.136357, 5.117358, 5.098228, 5.078969, 5.059585, 5.040077, 5.02045, 5.000705, 4.980844, 4.960873, 4.941144, 4.921607, 4.901983, 4.882262, 4.862445, 4.842537, 4.822538, 4.802454, 4.782286, 4.762037, 4.741693, 4.720786, 4.699805, 4.678753, 4.657635, 4.636451, 4.615205, 4.593902, 4.572542, 4.55113, 4.529669, 4.508161, 4.486609, 4.465017, 4.443388, 4.421735, 4.399689, 4.377276, 4.354001, 4.330271, 4.30638, 4.282789, 4.260036, 4.23727, 4.214496, 4.191717, 4.168936, 4.146155, 4.12338, 4.100411, 4.076467, 4.052377, 4.028304, 4.004255, 3.980253, 3.956277, 3.932332, 3.908419, 3.884543, 3.860706, 3.837397, 3.814261, 3.791174, 3.768139, 3.745159, 3.722251, 3.69952, 3.676854, 3.654255, 3.631727, 3.609318, 3.587032, 3.564826, 3.543205, 3.521768, 3.500417, 3.479157, 3.45799, 3.436939, 3.416239, 3.395455, 3.374612, 3.353736, 3.332845, 3.312068, 3.291407, 3.270866, 3.250447, 3.230153, 3.209987, 3.189952, 3.17005, 3.150285, 3.13066, 3.111177, 3.091839, 3.072649, 3.05361, 3.034724, 3.015994, 2.997423, 2.979015, 2.960771, 2.942694, 2.924787, 2.907052, 2.889493, 2.872113, 2.854912, 2.837895, 2.821064, 2.804396, 2.787918, 2.771635, 2.755794, 2.741709, 2.727799, 2.7147, 2.701825, 2.689124, 2.6766, 2.664254, 2.652089, 2.640589, 2.629489, 2.620021, 2.612346, 2.604819, 2.597934, 2.593231, 2.588635, 2.584147, 2.579767, 2.575497, 2.571337, 2.56729, 2.563354, 2.560076, 2.557238, 2.554177, 2.551134, 2.54819 ...

# %% [markdown]
# 収束状況グラフを描画する

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %% [markdown]
# 評価データを描画する

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.plot( x_new, y_pred, c='orange')
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()
