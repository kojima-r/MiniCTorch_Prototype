# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# %cd "ctorch220301/MiniCTorch_Prototype/notebook"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch220301/MiniCTorch_Prototype/notebook

# %%
# !mkdir -p gtest

# %%
# !g++ -std=c++14 ../test/sum_test.cpp -o ./gtest/sum_test  -I ./gtest/include -L ./gtest -lgtest -lgtest_main -lpthread

# %%
! ./gtest/sum_test
# Out:
# Running main() from /content/drive/My Drive/Colab Notebooks/googletest-release-1.11.0/googletest/src/gtest_main.cc
# [==========] Running 1 test from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 1 test from MyTestCase
# [ RUN      ] MyTestCase.TestSum
# [       OK ] MyTestCase.TestSum (0 ms)
# [----------] 1 test from MyTestCase (0 ms total)
#
# [----------] Global test environment tear-down
# [==========] 1 test from 1 test suite ran. (0 ms total)
# [  PASSED  ] 1 test.

# %% [markdown]
# 環境構築
#
# (注意) インストール済みの場合は各自の環境に合わせて変更して下さい。

# %%
! git clone https://github.com/xtensor-stack/xtensor.git
! git clone https://github.com/xtensor-stack/xtensor-blas.git
! git clone https://github.com/xtensor-stack/xtl.git
# Out:
# fatal: destination path 'xtensor' already exists and is not an empty directory.
# fatal: destination path 'xtensor-blas' already exists and is not an empty directory.
# fatal: destination path 'xtl' already exists and is not an empty directory.

# %% [markdown]
# ## 以下、テストコードを実行する

# %%
G_LIB = '-I ../src -I ./xtensor/include -I ./xtensor-blas/include -I ./xtl/include -I ./gtest/include -L ./gtest -lgtest -lgtest_main -lpthread -lcblas'
# !echo "G_LIB =" $G_LIB
# Out:
# G_LIB = -I ../src -I ./xtensor/include -I ./xtensor-blas/include -I ./xtl/include -I ./gtest/include -L ./gtest -lgtest -lgtest_main -lpthread -lcblas

# %%
! g++ -std=c++14 ../test/test_arithmetic.cpp -o ./gtest/test_arithmetic $G_LIB

# %%
! ./gtest/test_arithmetic
# Out:
# Running main() from /content/drive/My Drive/Colab Notebooks/googletest-release-1.11.0/googletest/src/gtest_main.cc
# [==========] Running 30 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 30 tests from MyTestCase
# [ RUN      ] MyTestCase.TestAdd
# [       OK ] MyTestCase.TestAdd (1 ms)
# [ RUN      ] MyTestCase.TestAddGrad
# [       OK ] MyTestCase.TestAddGrad (0 ms)
# [ RUN      ] MyTestCase.TestSub
# [       OK ] MyTestCase.TestSub (0 ms)
# [ RUN      ] MyTestCase.TestSubGrad
# [       OK ] MyTestCase.TestSubGrad (0 ms)
# [ RUN      ] MyTestCase.TestMul
# [       OK ] MyTestCase.TestMul (0 ms)
# [ RUN      ] MyTestCase.TestMulGrad
# [       OK ] MyTestCase.TestMulGrad (0 ms)
# [ RUN      ] MyTestCase.TestDiv
# [       OK ] MyTestCase.TestDiv (0 ms)
# [ RUN      ] MyTestCase.TestDivGrad
# [       OK ] MyTestCase.TestDivGrad (0 ms)
# [ RUN      ] MyTestCase.TestRsub
# [       OK ] MyTestCase.TestRsub (0 ms)
# ...

# %%
# !g++ -std=c++14 ../test/test_activation.cpp -o ./gtest/test_activation $G_LIB

# %%
! ./gtest/test_activation
# Out:
# Running main() from /content/drive/My Drive/Colab Notebooks/googletest-release-1.11.0/googletest/src/gtest_main.cc
# [==========] Running 21 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 21 tests from MyTestCase
# [ RUN      ] MyTestCase.TestRelu
# [       OK ] MyTestCase.TestRelu (0 ms)
# [ RUN      ] MyTestCase.TestReluGrad
# [       OK ] MyTestCase.TestReluGrad (0 ms)
# [ RUN      ] MyTestCase.TestReluGrad2
# [       OK ] MyTestCase.TestReluGrad2 (0 ms)
# [ RUN      ] MyTestCase.TestElu
# [       OK ] MyTestCase.TestElu (0 ms)
# [ RUN      ] MyTestCase.TestEluGrad
# [       OK ] MyTestCase.TestEluGrad (0 ms)
# [ RUN      ] MyTestCase.TestEluGrad2
# [       OK ] MyTestCase.TestEluGrad2 (0 ms)
# [ RUN      ] MyTestCase.TestLeakyRelu
# [       OK ] MyTestCase.TestLeakyRelu (0 ms)
# [ RUN      ] MyTestCase.TestLeakyReluGrad
# [       OK ] MyTestCase.TestLeakyReluGrad (0 ms)
# [ RUN      ] MyTestCase.TestLeakyReluGrad2
# ...

# %%
# !g++ -std=c++14 ../test/test_matrix.cpp -o ./gtest/test_matrix $G_LIB

# %%
! ./gtest/test_matrix
# Out:
# Running main() from /content/drive/My Drive/Colab Notebooks/googletest-release-1.11.0/googletest/src/gtest_main.cc
# [==========] Running 10 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 10 tests from MyTestCase
# [ RUN      ] MyTestCase.TestLinear1
# [       OK ] MyTestCase.TestLinear1 (16 ms)
# [ RUN      ] MyTestCase.TestLinear2
# [       OK ] MyTestCase.TestLinear2 (0 ms)
# [ RUN      ] MyTestCase.TestLinear3
# [       OK ] MyTestCase.TestLinear3 (0 ms)
# [ RUN      ] MyTestCase.TestAddmm1
# addmm dim 2,2
# [       OK ] MyTestCase.TestAddmm1 (0 ms)
# [ RUN      ] MyTestCase.TestAddmm2
# addmm dim 1,1
# [       OK ] MyTestCase.TestAddmm2 (0 ms)
# [ RUN      ] MyTestCase.TestAddmm3
# addmm dim 0,1
# [       OK ] MyTestCase.TestAddmm3 (0 ms)
# [ RUN      ] MyTestCase.TestBatchNorm
# [       OK ] MyTestCase.TestBatchNorm (0 ms)
# [ RUN      ] MyTestCase.TestBatchNormGrad
# [       OK ] MyTestCase.TestBatchNormGrad (0 ms)
# ...

# %%
# !g++ -std=c++14 ../test/test_loss.cpp -o ./gtest/test_loss $G_LIB

# %%
! ./gtest/test_loss
# Out:
# Running main() from /content/drive/My Drive/Colab Notebooks/googletest-release-1.11.0/googletest/src/gtest_main.cc
# [==========] Running 11 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 11 tests from MyTestCase
# [ RUN      ] MyTestCase.TestMseLoss
# [       OK ] MyTestCase.TestMseLoss (1 ms)
# [ RUN      ] MyTestCase.TestMseLossGrad
# [       OK ] MyTestCase.TestMseLossGrad (0 ms)
# [ RUN      ] MyTestCase.TestCrossEntropyLoss
# [       OK ] MyTestCase.TestCrossEntropyLoss (0 ms)
# [ RUN      ] MyTestCase.TestCrossEntropyLossGrad
# [       OK ] MyTestCase.TestCrossEntropyLossGrad (0 ms)
# [ RUN      ] MyTestCase.TestBinaryCrossEntropyLoss
# [       OK ] MyTestCase.TestBinaryCrossEntropyLoss (0 ms)
# [ RUN      ] MyTestCase.TestBinaryCrossEntropyLossGrad
# [       OK ] MyTestCase.TestBinaryCrossEntropyLossGrad (0 ms)
# [ RUN      ] MyTestCase.TestNLLLoss
# [       OK ] MyTestCase.TestNLLLoss (0 ms)
# [ RUN      ] MyTestCase.TestNLLLossGrad
# ...

# %%
! g++ -std=c++14 ../test/test_broadcast.cpp -o ./gtest/test_broadcast $G_LIB

# %%
! ./gtest/test_broadcast
# Out:
# Running main() from /content/drive/My Drive/Colab Notebooks/googletest-release-1.11.0/googletest/src/gtest_main.cc
# [==========] Running 22 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 22 tests from MyTestCase
# [ RUN      ] MyTestCase.TestBroadcastAdd1
# [       OK ] MyTestCase.TestBroadcastAdd1 (0 ms)
# [ RUN      ] MyTestCase.TestBroadcastAdd2
# [       OK ] MyTestCase.TestBroadcastAdd2 (0 ms)
# [ RUN      ] MyTestCase.TestBroadcastAdd3
# [       OK ] MyTestCase.TestBroadcastAdd3 (0 ms)
# [ RUN      ] MyTestCase.TestDot
# [       OK ] MyTestCase.TestDot (0 ms)
# [ RUN      ] MyTestCase.TestMatMul1
# [       OK ] MyTestCase.TestMatMul1 (0 ms)
# [ RUN      ] MyTestCase.TestMatMul2
# [       OK ] MyTestCase.TestMatMul2 (0 ms)
# [ RUN      ] MyTestCase.TestMatMul3
# [       OK ] MyTestCase.TestMatMul3 (0 ms)
# [ RUN      ] MyTestCase.TestMatMul4
# [       OK ] MyTestCase.TestMatMul4 (0 ms)
# [ RUN      ] MyTestCase.TestBroadcastMatMul1
# ...
