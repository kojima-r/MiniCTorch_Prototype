# %% [markdown]
# vae2_class　オートエンコーダー ( net/lossクラス分離 )
#
# 参考文献　我妻幸長　「はじめてのディープラーニング２」

# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# フォルダは自分の指定のものに変更して下さい。

# %%
# %cd "ctorch210929/MiniCTorch_Prototype/notebook"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch210929/MiniCTorch_Prototype/notebook

# %% [markdown]
# ライブラリのimport

# %%
! pip install lark-parser
# Out:
# Requirement already satisfied: lark-parser in /usr/local/lib/python3.7/dist-packages (0.12.0)

# %%
import sys
sys.path.append("../")

import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import minictorch
import minictorch.generator as GN
import minictorch.converter as CV

# %% [markdown]
# サンプルデータの生成

# %%
import torch.utils as utils
from torchvision import datasets, transforms
from sklearn import datasets

img_size = 8
n_in = img_size * img_size
n_mid = 16
n_out = n_in
n_z = 2
n_batch = 32

digits_data = datasets.load_digits()
dd = np.asarray( digits_data.data, dtype=np.float32 )
dd /= 15
x_train = torch.from_numpy( dd ).clone()
t_train = digits_data.target
print(x_train.shape)
# Out:
# torch.Size([1797, 64])

# %% [markdown]
# サンプルデータの図化

# %%
import matplotlib.pyplot as plt
n_img = 16

plt.figure( figsize=(16,3))
for i in range(n_img):
  ax = plt.subplot(3,n_img,i+1)
  plt.imshow(dd[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %% [markdown]
# ニューラルネットワークの定義

# %%
import torch.distributions as td

"""
def kl_divergence( mean, log_var ):
  g = 1 + log_var - mean**2 - torch.exp( log_var )
  y = 0.5 * torch.sum( g )
  return -y
"""

class VAE(torch.nn.Module):
  
  class Net(torch.nn.Module):
    def __init__( self, n_in, n_mid, n_out, n_z ):
      super().__init__()
      print("create net class")
      self.fc1 = nn.Linear(n_in, n_mid)
      self.bn1 = nn.BatchNorm1d(n_mid)
      self.fc2_mean = nn.Linear(n_mid, n_z)
      self.fc2_var  = nn.Linear(n_mid, n_z)
      self.fc3 = nn.Linear(n_z  ,n_mid)
      self.fc4 = nn.Linear(n_mid,n_out)
      #self.drop1 = nn.Dropout(p=0.2)
    
      nn.init.constant_(self.fc1.bias,0)
      nn.init.constant_(self.fc2_mean.bias,0)
      nn.init.constant_(self.fc2_var.bias,0)
      nn.init.constant_(self.fc3.bias,0)
      nn.init.constant_(self.fc4.bias,0)
    
    def forward( self, x ):
      # encoder
      self.x1 = F.relu( self.fc1(x) )
      self.x2 = self.bn1( self.x1 )
      m1 = self.fc2_mean( self.x2 )
      v1 = self.fc2_var( self.x2 )
      self.mean = m1;
      self.log_var = v1;

      # reparametrization
      self.std = torch.exp( 0.5 * self.log_var )
      q_z = td.normal.Normal( self.mean, self.std )
      self.z = q_z.rsample()

      # decoder
      y = F.relu( self.fc3( self.z ) )
      #y = self.drop1( y )
      y = torch.sigmoid( self.fc4( y ) )
      self.out = y 

      return y, q_z
  
  class Loss(torch.nn.Module):
    def __init__(self):
      super().__init__()
      print("create loss class")

    def forward( self, y, x, q_z ):
      e1 = F.binary_cross_entropy( y , x, reduction="sum" )
      p_z = td.normal.Normal( torch.zeros_like(q_z.loc), torch.ones_like(q_z.scale) )
      e2  = td.kl_divergence( q_z, p_z ).sum()
      #e2 = kl_divergence( mean, log_var )

      self.loss1 = e1
      self.loss2 = e2
      #print("e1,e2",e1,e2)
      return (e1+e2)

  def __init__( self, n_in, n_mid, n_out, n_z ):
    super( VAE, self ).__init__()
    print("create vae class")
    self.net  = self.Net( n_in, n_mid, n_out, n_z )
    self.loss = self.Loss()

  def forward( self, x ):
    y, q_z = self.net(x)
    output = self.loss( y, x, q_z )
    return output

# %% [markdown]
# 計算グラフをJSONファイルに変換する

# %%
def generate_json( json_path, input ):

    model = VAE( n_in, n_mid, n_out, n_z )

    model.eval()
    with torch.no_grad():
        print("[SAVE]", json_path )
        GN.generate_minictorch_file( model, input, json_path )

    return model

# %%
torch.manual_seed( 1 )

project = 'vae2_class'
json_path = './network/' + project +'.json'

x = x_train.clone().detach()
torch.reshape( x, (-1,n_in) )

x = x[0:n_batch,:]
#x.requires_grad = True

model = generate_json( json_path, x )
# Out:
# create vae class
# create net class
# create loss class
# [SAVE] ./network/vae2_class.json
# skip: VAE/Net[net]/Linear[fc1]/weight/fc1
# skip: VAE/Net[net]/Linear[fc1]/weight/fc1
# skip: VAE/Net[net]/BatchNorm1d[bn1]/weight/bn1
# skip: VAE/Net[net]/BatchNorm1d[bn1]/weight/bn1
# skip: VAE/Net[net]/BatchNorm1d[bn1]/weight/bn1
# skip: VAE/Net[net]/BatchNorm1d[bn1]/weight/bn1
# skip: VAE/Net[net]/Linear[fc2_mean]/weight/fc2_mean
# skip: VAE/Net[net]/Linear[fc2_mean]/weight/fc2_mean
# skip: VAE/Net[net]/Linear[fc2_var]/weight/fc2_var
# skip: VAE/Net[net]/Linear[fc2_var]/weight/fc2_var
# skip: VAE/Net[net]/Linear[fc3]/weight/fc3
# skip: VAE/Net[net]/Linear[fc3]/weight/fc3
# skip: VAE/Net[net]/Linear[fc4]/weight/fc4
# skip: VAE/Net[net]/Linear[fc4]/weight/fc4
# /usr/local/lib/python3.7/dist-packages/torch/jit/_trace.py:991: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Scalars are not close!
#
# Absolute difference: 0.4703369140625 (up to 1e-05 allowed)
# Relative difference: 0.0003294008981624594 (up to 1e-05 allowed)
#   _module_class,

# %% [markdown]
# 一回の順伝播、逆伝播のC++コードを生成する

# %%
folder = "./vae"
CV.convert_cpp_code( project, folder, model, x, json_path )
# Out:
# [JSON] ./network/vae2_class.json
# {'name': 'VAE/Net[net]/Linear[fc1]/weight/weight.13', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# {'name': 'VAE/Net[net]/Linear[fc1]/bias/bias.13', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/weight/weight.15', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [13], 'sorted_id': 5}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/bias/bias.15', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [13], 'sorted_id': 6}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/running_mean/running_mean', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [13], 'sorted_id': 7}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/running_var/running_var', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [13], 'sorted_id': 8}
# {'name': 'VAE/Net[net]/Linear[fc2_mean]/weight/weight.17', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [16], 'sorted_id': 14}
# {'name': 'VAE/Net[net]/Linear[fc2_mean]/bias/bias.17', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [16], 'sorted_id': 15}
# {'name': 'VAE/Net[net]/Linear[fc2_var]/weight/weight.19', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [19], 'sorted_id': 17}
# {'name': 'VAE/Net[net]/Linear[fc2_var]/bias/bias.19', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [19], 'sorted_id': 18}
# {'name': 'VAE/Net[net]/Linear[fc3]/weight/weight.21', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [43], 'sorted_id': 41}
# {'name': 'VAE/Net[net]/Linear[fc3]/bias/bias.21', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [43], 'sorted_id': 42}
# {'name': 'VAE/Net[net]/Linear[fc4]/weight/weight', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [47], 'sorted_id': 45}
# {'name': 'VAE/Net[net]/Linear[fc4]/bias/bias', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [47], 'sorted_id': 46}
# [PARAM] ./vae/vae2_class_param.cpp
# {'name': 'input/x', 'op': 'IO Node', 'in': [], 'output_id': 0, 'shape': [32, 64], 'out': [3, 53], 'sorted_id': 0}
# {'name': 'VAE/Net[net]/Linear[fc1]/weight/weight.13', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# VAE/Net[net]/Linear[fc1]/weight/weight.13  ->  fc1_weight
# {'name': 'VAE/Net[net]/Linear[fc1]/bias/bias.13', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# VAE/Net[net]/Linear[fc1]/bias/bias.13  ->  fc1_bias
# {'name': 'VAE/Net[net]/Linear[fc1]/input.1', 'op': 'aten::linear', 'in': [0, 1, 2], 'output_id': 0, 'shape': [32, 16], 'out': [4], 'sorted_id': 3}
# {'name': 'VAE/Net[net]/input.3', 'op': 'aten::relu', 'in': [3], 'output_id': 0, 'shape': [32, 16], 'out': [13], 'sorted_id': 4}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/weight/weight.15', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [13], 'sorted_id': 5}
# VAE/Net[net]/BatchNorm1d[bn1]/weight/weight.15  ->  bn1_weight
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/bias/bias.15', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [13], 'sorted_id': 6}
# VAE/Net[net]/BatchNorm1d[bn1]/bias/bias.15  ->  bn1_bias
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/running_mean/running_mean', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [13], 'sorted_id': 7}
# VAE/Net[net]/BatchNorm1d[bn1]/running_mean/running_mean  ->  bn1_running_mean
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/running_var/running_var', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [13], 'sorted_id': 8}
# VAE/Net[net]/BatchNorm1d[bn1]/running_var/running_var  ->  bn1_running_var
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/224', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [13, 34, 36], 'sorted_id': 9}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/225', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.1, 'out': [13], 'sorted_id': 10}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/226', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1e-05, 'out': [13], 'sorted_id': 11}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/227', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [13], 'sorted_id': 12}
# {'name': 'VAE/Net[net]/BatchNorm1d[bn1]/input.5', 'op': 'aten::batch_norm', 'in': [4, 5, 6, 7, 8, 9, 10, 11, 12], 'output_id': 0, 'shape': [32, 16], 'out': [19, 16], 'sorted_id': 13}
# {'name': 'VAE/Net[net]/Linear[fc2_mean]/weight/weight.17', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [16], 'sorted_id': 14}
# VAE/Net[net]/Linear[fc2_mean]/weight/weight.17  ->  fc2_mean_weight
# {'name': 'VAE/Net[net]/Linear[fc2_mean]/bias/bias.17', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [16], 'sorted_id': 15}
# VAE/Net[net]/Linear[fc2_mean]/bias/bias.17  ->  fc2_mean_bias
# {'name': 'VAE/Net[net]/Linear[fc2_mean]/245', 'op': 'aten::linear', 'in': [13, 14, 15], 'output_id': 0, 'shape': [32, 2], 'out': [23], 'sorted_id': 16}
# {'name': 'VAE/Net[net]/Linear[fc2_var]/weight/weight.19', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [19], 'sorted_id': 17}
# VAE/Net[net]/Linear[fc2_var]/weight/weight.19  ->  fc2_var_weight
# {'name': 'VAE/Net[net]/Linear[fc2_var]/bias/bias.19', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [19], 'sorted_id': 18}
# VAE/Net[net]/Linear[fc2_var]/bias/bias.19  ->  fc2_var_bias
# {'name': 'VAE/Net[net]/Linear[fc2_var]/v1', 'op': 'aten::linear', 'in': [13, 17, 18], 'output_id': 0, 'shape': [32, 2], 'out': [21], 'sorted_id': 19}
# {'name': 'VAE/Net[net]/223', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.5, 'out': [21], 'sorted_id': 20}
# {'name': 'VAE/Net[net]/249', 'op': 'aten::mul', 'in': [19, 20], 'output_id': 0, 'shape': [32, 2], 'out': [22], 'sorted_id': 21}
# {'name': 'VAE/Net[net]/250', 'op': 'aten::exp', 'in': [21], 'output_id': 0, 'shape': [32, 2], 'out': [23], 'sorted_id': 22}
# {'name': 'VAE/Net[net]/251', 'op': 'prim::ListConstruct', 'in': [16, 22], 'output_id': 0, 'shape': [], 'out': [24], 'sorted_id': 23}
# {'name': 'VAE/Net[net]/252', 'op': 'aten::broadcast_tensors', 'in': [23], 'output_id': 0, 'shape': [], 'out': [38, 25], 'sorted_id': 24}
# {'name': 'VAE/Net[net]/loc.1', 'op': 'prim::ListUnpack', 'in': [24], 'output_id': 0, 'shape': [32, 2], 'out': [29, 49, 40, 27], 'sorted_id': 25}
# {'name': 'VAE/Net[net]/222', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [27], 'sorted_id': 26}
# {'name': 'VAE/Net[net]/255', 'op': 'aten::size', 'in': [25, 26], 'output_id': 0, 'shape': [], 'out': [30, 35], 'sorted_id': 27}
# {'name': 'VAE/Net[net]/221', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [29, 40], 'sorted_id': 28}
# {'name': 'VAE/Net[net]/256', 'op': 'aten::size', 'in': [25, 28], 'output_id': 0, 'shape': [], 'out': [30, 35], 'sorted_id': 29}
# {'name': 'VAE/Net[net]/257', 'op': 'prim::ListConstruct', 'in': [27, 29], 'output_id': 0, 'shape': [], 'out': [34], 'sorted_id': 30}
# {'name': 'VAE/Net[net]/220', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [34, 36], 'sorted_id': 31}
# {'name': 'VAE/Net[net]/219', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [37, 34, 36], 'sorted_id': 32}
# {'name': 'VAE/Net[net]/218', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [34, 36], 'sorted_id': 33}
# {'name': 'VAE/Net[net]/258', 'op': 'aten::zeros', 'in': [30, 31, 32, 33, 9], 'output_id': 0, 'shape': [32, 2], 'out': [37], 'sorted_id': 34}
# {'name': 'VAE/Net[net]/259', 'op': 'prim::ListConstruct', 'in': [27, 29], 'output_id': 0, 'shape': [], 'out': [36], 'sorted_id': 35}
# {'name': 'VAE/Net[net]/260', 'op': 'aten::ones', 'in': [35, 31, 32, 33, 9], 'output_id': 0, 'shape': [32, 2], 'out': [37], 'sorted_id': 36}
# {'name': 'VAE/Net[net]/eps', 'op': 'aten::normal', 'in': [34, 36, 32], 'output_id': 0, 'shape': [32, 2], 'out': [39], 'sorted_id': 37}
# {'name': 'VAE/Net[net]/value.1', 'op': 'prim::ListUnpack', 'in': [24], 'output_id': 1, 'shape': [32, 2], 'out': [49, 39], 'sorted_id': 38}
# {'name': 'VAE/Net[net]/262', 'op': 'aten::mul', 'in': [37, 38], 'output_id': 0, 'shape': [32, 2], 'out': [40], 'sorted_id': 39}
# {'name': 'VAE/Net[net]/input.7', 'op': 'aten::add', 'in': [25, 39, 28], 'output_id': 0, 'shape': [32, 2], 'out': [43], 'sorted_id': 40}
# {'name': 'VAE/Net[net]/Linear[fc3]/weight/weight.21', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [43], 'sorted_id': 41}
# VAE/Net[net]/Linear[fc3]/weight/weight.21  ->  fc3_weight
# {'name': 'VAE/Net[net]/Linear[fc3]/bias/bias.21', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [43], 'sorted_id': 42}
# VAE/Net[net]/Linear[fc3]/bias/bias.21  ->  fc3_bias
# {'name': 'VAE/Net[net]/Linear[fc3]/input.9', 'op': 'aten::linear', 'in': [40, 41, 42], 'output_id': 0, 'shape': [32, 16], 'out': [44], 'sorted_id': 43}
# {'name': 'VAE/Net[net]/input.11', 'op': 'aten::relu', 'in': [43], 'output_id': 0, 'shape': [32, 16], 'out': [47], 'sorted_id': 44}
# {'name': 'VAE/Net[net]/Linear[fc4]/weight/weight', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [47], 'sorted_id': 45}
# VAE/Net[net]/Linear[fc4]/weight/weight  ->  fc4_weight
# {'name': 'VAE/Net[net]/Linear[fc4]/bias/bias', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [47], 'sorted_id': 46}
# VAE/Net[net]/Linear[fc4]/bias/bias  ->  fc4_bias
# {'name': 'VAE/Net[net]/Linear[fc4]/270', 'op': 'aten::linear', 'in': [44, 45, 46], 'output_id': 0, 'shape': [32, 64], 'out': [48], 'sorted_id': 47}
# {'name': 'VAE/Net[net]/input', 'op': 'aten::sigmoid', 'in': [47], 'output_id': 0, 'shape': [32, 64], 'out': [49], 'sorted_id': 48}
# {'name': 'VAE/272', 'op': 'prim::TupleConstruct', 'in': [48, 25, 38], 'output_id': 0, 'shape': [], 'out': [55, 50, 54], 'sorted_id': 49}
# {'name': 'VAE/213', 'op': 'prim::TupleUnpack', 'in': [49], 'output_id': 0, 'shape': [32, 64], 'out': [53], 'sorted_id': 50}
# {'name': 'VAE/Loss[loss]/281', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [61, 79, 60, 53], 'sorted_id': 51}
# {'name': 'VAE/Loss[loss]/280', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 2.0, 'out': [71, 66, 53], 'sorted_id': 52}
# {'name': 'VAE/Loss[loss]/e1', 'op': 'aten::binary_cross_entropy', 'in': [50, 0, 51, 52], 'output_id': 0, 'shape': [], 'out': [80], 'sorted_id': 53}
# {'name': 'VAE/215', 'op': 'prim::TupleUnpack', 'in': [49], 'output_id': 2, 'shape': [32, 2], 'out': [65, 61], 'sorted_id': 54}
# {'name': 'VAE/214', 'op': 'prim::TupleUnpack', 'in': [49], 'output_id': 1, 'shape': [32, 2], 'out': [69, 60], 'sorted_id': 55}
# {'name': 'VAE/Loss[loss]/279', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [61, 60], 'sorted_id': 56}
# {'name': 'VAE/Loss[loss]/278', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [61, 60], 'sorted_id': 57}
# {'name': 'VAE/Loss[loss]/277', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [61, 60], 'sorted_id': 58}
# {'name': 'VAE/Loss[loss]/276', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [61, 60], 'sorted_id': 59}
# {'name': 'VAE/Loss[loss]/283', 'op': 'aten::zeros_like', 'in': [55, 56, 57, 58, 59, 51], 'output_id': 0, 'shape': [32, 2], 'out': [62], 'sorted_id': 60}
# {'name': 'VAE/Loss[loss]/284', 'op': 'aten::ones_like', 'in': [54, 56, 57, 58, 59, 51], 'output_id': 0, 'shape': [32, 2], 'out': [62], 'sorted_id': 61}
# {'name': 'VAE/Loss[loss]/285', 'op': 'prim::ListConstruct', 'in': [60, 61], 'output_id': 0, 'shape': [], 'out': [63], 'sorted_id': 62}
# {'name': 'VAE/Loss[loss]/286', 'op': 'aten::broadcast_tensors', 'in': [62], 'output_id': 0, 'shape': [], 'out': [67, 64], 'sorted_id': 63}
# {'name': 'VAE/Loss[loss]/value', 'op': 'prim::ListUnpack', 'in': [63], 'output_id': 1, 'shape': [32, 2], 'out': [70, 65], 'sorted_id': 64}
# {'name': 'VAE/Loss[loss]/289', 'op': 'aten::div', 'in': [54, 64], 'output_id': 0, 'shape': [32, 2], 'out': [66], 'sorted_id': 65}
# {'name': 'VAE/Loss[loss]/var_ratio', 'op': 'aten::pow', 'in': [65, 52], 'output_id': 0, 'shape': [32, 2], 'out': [72, 75], 'sorted_id': 66}
# {'name': 'VAE/Loss[loss]/loc', 'op': 'prim::ListUnpack', 'in': [63], 'output_id': 0, 'shape': [32, 2], 'out': [69], 'sorted_id': 67}
# {'name': 'VAE/Loss[loss]/275', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [74, 80, 72, 76, 69], 'sorted_id': 68}
# {'name': 'VAE/Loss[loss]/291', 'op': 'aten::sub', 'in': [55, 67, 68], 'output_id': 0, 'shape': [32, 2], 'out': [70], 'sorted_id': 69}
# {'name': 'VAE/Loss[loss]/292', 'op': 'aten::div', 'in': [69, 64], 'output_id': 0, 'shape': [32, 2], 'out': [71], 'sorted_id': 70}
# {'name': 'VAE/Loss[loss]/t1', 'op': 'aten::pow', 'in': [70, 52], 'output_id': 0, 'shape': [32, 2], 'out': [72], 'sorted_id': 71}
# {'name': 'VAE/Loss[loss]/294', 'op': 'aten::add', 'in': [66, 71, 68], 'output_id': 0, 'shape': [32, 2], 'out': [74], 'sorted_id': 72}
# {'name': 'VAE/Loss[loss]/274', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [74], 'sorted_id': 73}
# {'name': 'VAE/Loss[loss]/295', 'op': 'aten::sub', 'in': [72, 73, 68], 'output_id': 0, 'shape': [32, 2], 'out': [76], 'sorted_id': 74}
# {'name': 'VAE/Loss[loss]/296', 'op': 'aten::log', 'in': [66], 'output_id': 0, 'shape': [32, 2], 'out': [76], 'sorted_id': 75}
# {'name': 'VAE/Loss[loss]/297', 'op': 'aten::sub', 'in': [74, 75, 68], 'output_id': 0, 'shape': [32, 2], 'out': [78], 'sorted_id': 76}
# {'name': 'VAE/Loss[loss]/273', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.5, 'out': [78], 'sorted_id': 77}
# {'name': 'VAE/Loss[loss]/298', 'op': 'aten::mul', 'in': [76, 77], 'output_id': 0, 'shape': [32, 2], 'out': [79], 'sorted_id': 78}
# {'name': 'VAE/Loss[loss]/e2', 'op': 'aten::sum', 'in': [78, 51], 'output_id': 0, 'shape': [], 'out': [80], 'sorted_id': 79}
# {'name': 'VAE/Loss[loss]/300', 'op': 'aten::add', 'in': [53, 79, 68], 'output_id': 0, 'shape': [], 'out': [81], 'sorted_id': 80}
# {'name': 'output/output.1', 'op': 'IO Node', 'in': [80], 'output_id': 0, 'shape': [], 'out': [], 'sorted_id': 81}
# [CPP]  ./vae/vae2_class.cpp
# [MAKE] ./vae/Makefile

# %%
# check code
print(x.shape)
with torch.set_grad_enabled(True):
  model.train()
  output = model( x )
  print("output",output)
  output.backward()
  print("input_grad",x.grad)
# Out:
# torch.Size([32, 64])
# output tensor(1448.0217, grad_fn=<AddBackward0>)
# input_grad None

# %% [markdown]
# C++コードをコンパイル、リンクする

# %%
# !g++ -std=c++14 ./vae/vae2_class.cpp ./vae/vae2_class_param.cpp -D_NOTEBOOK -I ../../../xtensor -lcblas -o ./vae/vae2_class

# %% [markdown]
# (注) xtensorフォルダにxtensor関連のincludeファイルを置いています。各自の環境に合わせて変更して下さい。

# %%
# !./vae/vae2_class
# Out:
# ### forward computation ...
# { 1452.403442}
# ### backward computation ...
# input_grad{{-0.125258,  0.182919, -0.01408 , ..., -0.088459, -0.858717,  0.31935 },
#  { 0.159821,  0.692014,  0.556623, ..., -0.145081,  0.285678,  0.64644 },
#  { 1.913896, -1.648967,  0.047376, ...,  0.648749, -0.584697, -1.671622},
#  ...,
#  {-0.253909, -0.497299,  0.239077, ..., -0.459145, -0.707026, -0.537639},
#  { 0.39497 , -0.093664, -0.296295, ..., -0.112299, -0.966484,  0.441378},
#  { 0.594774, -0.168871, -0.430799, ..., -0.309275,  0.039534, -0.03901 }}

# %% [markdown]
# ミニバッチによる学習の実行(python)

# %%
torch.manual_seed( 1 )

epoch_num = 200
batch_size = 32

vae = VAE( n_in, n_mid, n_out, n_z )
vae.train()

lr = 0.001
opt = torch.optim.SGD( vae.parameters(), lr)
#opt = torch.optim.Adam( vae.parameters(), lr )

epoch_loss = []

l_batch = len(x_train) // batch_size  # 1エポックあたりのバッチ数
print("batch",l_batch,len(x_train),batch_size)

for i in range(epoch_num):
        
    # -- 学習 -- 
    index_random = np.arange(len(x_train))
    np.random.shuffle(index_random)  # インデックスをシャッフルする

    total_loss = 0.0
    for j in range(l_batch):
        
        # ミニバッチを取り出す
        mb_index = index_random[ j*batch_size : (j+1)*batch_size ]
        x_mb = x_train[mb_index, :]
        #x_mb.requires_grad = True
        
        # 順伝播と逆伝播
        loss = vae( x_mb )
        total_loss += loss;

        opt.zero_grad()
        loss.backward()
        opt.step()

    # -- 誤差を求める --
    print("EPOCH: {} loss: {}".format(i, total_loss))
  
    x2 = x_train.clone().detach()
    torch.reshape( x2, (-1,n_in) )
    #print(x2.shape)

    vae.eval()
    loss = vae( x2 )
    print("loss", loss, vae.loss.loss1, vae.loss.loss2 )
    epoch_loss.append( loss )
# Out:
# create vae class
# create net class
# create loss class
# batch 56 1797 32
# EPOCH: 0 loss: 60943.3984375
# loss tensor(51241.7656, grad_fn=<AddBackward0>) tensor(48998.5625, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2243.2048, grad_fn=<SumBackward0>)
# EPOCH: 1 loss: 50143.6484375
# loss tensor(49036.5234, grad_fn=<AddBackward0>) tensor(46808.0234, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2228.4990, grad_fn=<SumBackward0>)
# EPOCH: 2 loss: 48506.578125
# loss tensor(48265.2422, grad_fn=<AddBackward0>) tensor(46618.0898, grad_fn=<BinaryCrossEntropyBackward0>) tensor(1647.1537, grad_fn=<SumBackward0>)
# EPOCH: 3 loss: 47798.62109375
# loss tensor(47501.6523, grad_fn=<AddBackward0>) tensor(45983.6484, grad_fn=<BinaryCrossEntropyBackward0>) tensor(1518.0034, grad_fn=<SumBackward0>)
# EPOCH: 4 loss: 47374.25
# loss tensor(46927.0352, grad_fn=<AddBackward0>) tensor(44923.9805, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2003.0530, grad_fn=<SumBackward0>)
# EPOCH: 5 loss: 46801.1640625
# loss tensor(46415.0898, grad_fn=<AddBackward0>) tensor(44148.7617, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2266.3286, grad_fn=<SumBackward0>)
# EPOCH: 6 loss: 46344.9453125
# loss tensor(46107.4219, grad_fn=<AddBackward0>) tensor(43678.3516, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2429.0691, grad_fn=<SumBackward0>)
# EPOCH: 7 loss: 46087.58984375
# loss tensor(46245.9258, grad_fn=<AddBackward0>) tensor(43659.8711, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2586.0564, grad_fn=<SumBackward0>)
# EPOCH: 8 loss: 45843.09375
# loss tensor(46200.1250, grad_fn=<AddBackward0>) tensor(43989.1523, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2210.9724, grad_fn=<SumBackward0>)
# EPOCH: 9 loss: 45705.57421875
# loss tensor(45708.9297, grad_fn=<AddBackward0>) tensor(42783.9102, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2925.0205, grad_fn=<SumBackward0>)
# EPOCH: 10 loss: 45536.0390625
# loss tensor(45570.1602, grad_fn=<AddBackward0>) tensor(42838.3477, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2731.8130, grad_fn=<SumBackward0>)
# EPOCH: 11 loss: 45415.05859375
# loss tensor(45677.0781, grad_fn=<AddBackward0>) tensor(42482.6680, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3194.4111, grad_fn=<SumBackward0>)
# EPOCH: 12 loss: 45353.19921875
# loss tensor(45311.5156, grad_fn=<AddBackward0>) tensor(42786.5039, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2525.0137, grad_fn=<SumBackward0>)
# EPOCH: 13 loss: 45282.2890625
# loss tensor(45716.4844, grad_fn=<AddBackward0>) tensor(42957.0547, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2759.4294, grad_fn=<SumBackward0>)
# EPOCH: 14 loss: 45291.69921875
# loss tensor(45176.1289, grad_fn=<AddBackward0>) tensor(42476.0742, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2700.0552, grad_fn=<SumBackward0>)
# EPOCH: 15 loss: 45109.23046875
# loss tensor(45130.6016, grad_fn=<AddBackward0>) tensor(42438.1445, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2692.4561, grad_fn=<SumBackward0>)
# EPOCH: 16 loss: 44907.30859375
# loss tensor(45003.5195, grad_fn=<AddBackward0>) tensor(42063.9258, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2939.5947, grad_fn=<SumBackward0>)
# EPOCH: 17 loss: 44838.0078125
# loss tensor(45029.5703, grad_fn=<AddBackward0>) tensor(42027.4102, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3002.1614, grad_fn=<SumBackward0>)
# EPOCH: 18 loss: 44827.47265625
# loss tensor(44788.7773, grad_fn=<AddBackward0>) tensor(41910.6992, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2878.0774, grad_fn=<SumBackward0>)
# EPOCH: 19 loss: 44703.375
# loss tensor(44641.6406, grad_fn=<AddBackward0>) tensor(41748.0820, grad_fn=<BinaryCrossEntropyBackward0>) tensor(2893.5579, grad_fn=<SumBackward0>)
# EPOCH: 20 loss: 44594.0234375
# loss tensor(44460.1562, grad_fn=<AddBackward0>) tensor(41063.6172, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3396.5405, grad_fn=<SumBackward0>)
# EPOCH: 21 loss: 44579.79296875
# loss tensor(44494.5781, grad_fn=<AddBackward0>) tensor(41106.3906, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3388.1855, grad_fn=<SumBackward0>)
# EPOCH: 22 loss: 44421.33203125
# loss tensor(44373.1719, grad_fn=<AddBackward0>) tensor(40923.2266, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3449.9443, grad_fn=<SumBackward0>)
# EPOCH: 23 loss: 44337.52734375
# loss tensor(44226.9727, grad_fn=<AddBackward0>) tensor(40746.8086, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3480.1628, grad_fn=<SumBackward0>)
# EPOCH: 24 loss: 44447.66015625
# loss tensor(44166.5117, grad_fn=<AddBackward0>) tensor(40872.8828, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3293.6292, grad_fn=<SumBackward0>)
# EPOCH: 25 loss: 44266.078125
# loss tensor(44299.3867, grad_fn=<AddBackward0>) tensor(40623.8398, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3675.5481, grad_fn=<SumBackward0>)
# EPOCH: 26 loss: 44336.78515625
# loss tensor(44070.8320, grad_fn=<AddBackward0>) tensor(40516.4648, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3554.3672, grad_fn=<SumBackward0>)
# EPOCH: 27 loss: 44102.59375
# loss tensor(44300.9648, grad_fn=<AddBackward0>) tensor(41043.0703, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3257.8936, grad_fn=<SumBackward0>)
# EPOCH: 28 loss: 44017.1953125
# loss tensor(44381.6133, grad_fn=<AddBackward0>) tensor(40882.9805, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3498.6343, grad_fn=<SumBackward0>)
# EPOCH: 29 loss: 44009.18359375
# loss tensor(44206.9414, grad_fn=<AddBackward0>) tensor(40825.8672, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3381.0745, grad_fn=<SumBackward0>)
# EPOCH: 30 loss: 44025.56640625
# loss tensor(44602.9062, grad_fn=<AddBackward0>) tensor(40806.0508, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3796.8574, grad_fn=<SumBackward0>)
# EPOCH: 31 loss: 43895.96484375
# loss tensor(43864.2930, grad_fn=<AddBackward0>) tensor(40212.2383, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3652.0544, grad_fn=<SumBackward0>)
# EPOCH: 32 loss: 43884.21875
# loss tensor(43817.3555, grad_fn=<AddBackward0>) tensor(39952.1445, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3865.2122, grad_fn=<SumBackward0>)
# EPOCH: 33 loss: 43882.04296875
# loss tensor(44094.0938, grad_fn=<AddBackward0>) tensor(40718.8203, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3375.2751, grad_fn=<SumBackward0>)
# EPOCH: 34 loss: 43737.859375
# loss tensor(43978.6406, grad_fn=<AddBackward0>) tensor(40064.0352, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3914.6057, grad_fn=<SumBackward0>)
# EPOCH: 35 loss: 44001.36328125
# loss tensor(44104.5273, grad_fn=<AddBackward0>) tensor(40679.2148, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3425.3115, grad_fn=<SumBackward0>)
# EPOCH: 36 loss: 44022.1796875
# loss tensor(43750.1953, grad_fn=<AddBackward0>) tensor(39801.8242, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3948.3701, grad_fn=<SumBackward0>)
# EPOCH: 37 loss: 43885.60546875
# loss tensor(44126.3477, grad_fn=<AddBackward0>) tensor(40032.4648, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4093.8826, grad_fn=<SumBackward0>)
# EPOCH: 38 loss: 43969.984375
# loss tensor(44184.6914, grad_fn=<AddBackward0>) tensor(40359.7500, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3824.9424, grad_fn=<SumBackward0>)
# EPOCH: 39 loss: 43936.2890625
# loss tensor(43737.4492, grad_fn=<AddBackward0>) tensor(40022.2266, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3715.2241, grad_fn=<SumBackward0>)
# EPOCH: 40 loss: 43838.453125
# loss tensor(43728.3398, grad_fn=<AddBackward0>) tensor(39763.2422, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3965.0972, grad_fn=<SumBackward0>)
# EPOCH: 41 loss: 43808.61328125
# loss tensor(43844.1055, grad_fn=<AddBackward0>) tensor(40161.9961, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3682.1108, grad_fn=<SumBackward0>)
# EPOCH: 42 loss: 43860.03515625
# loss tensor(43842.2461, grad_fn=<AddBackward0>) tensor(39798.9219, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4043.3259, grad_fn=<SumBackward0>)
# EPOCH: 43 loss: 44001.1328125
# loss tensor(43734.4258, grad_fn=<AddBackward0>) tensor(40022.2656, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3712.1602, grad_fn=<SumBackward0>)
# EPOCH: 44 loss: 43835.03515625
# loss tensor(43747.3047, grad_fn=<AddBackward0>) tensor(39879.9531, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3867.3496, grad_fn=<SumBackward0>)
# EPOCH: 45 loss: 43763.60546875
# loss tensor(43499.7383, grad_fn=<AddBackward0>) tensor(39553.8672, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3945.8723, grad_fn=<SumBackward0>)
# EPOCH: 46 loss: 43663.73046875
# loss tensor(43675.7734, grad_fn=<AddBackward0>) tensor(39918.5977, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3757.1748, grad_fn=<SumBackward0>)
# EPOCH: 47 loss: 43786.33203125
# loss tensor(43581.1055, grad_fn=<AddBackward0>) tensor(39917.2930, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3663.8110, grad_fn=<SumBackward0>)
# EPOCH: 48 loss: 43741.875
# loss tensor(43599.0898, grad_fn=<AddBackward0>) tensor(39800.2070, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3798.8845, grad_fn=<SumBackward0>)
# EPOCH: 49 loss: 43682.453125
# loss tensor(44123.6406, grad_fn=<AddBackward0>) tensor(39773.2891, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4350.3511, grad_fn=<SumBackward0>)
# EPOCH: 50 loss: 43640.03125
# loss tensor(43828.2500, grad_fn=<AddBackward0>) tensor(39997.2969, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3830.9543, grad_fn=<SumBackward0>)
# EPOCH: 51 loss: 43685.98828125
# loss tensor(43590.8203, grad_fn=<AddBackward0>) tensor(39689.6992, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3901.1216, grad_fn=<SumBackward0>)
# EPOCH: 52 loss: 43707.92578125
# loss tensor(44198.9258, grad_fn=<AddBackward0>) tensor(40091.3984, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4107.5259, grad_fn=<SumBackward0>)
# EPOCH: 53 loss: 43585.40625
# loss tensor(43487.9531, grad_fn=<AddBackward0>) tensor(39951.1992, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3536.7542, grad_fn=<SumBackward0>)
# EPOCH: 54 loss: 43671.515625
# loss tensor(43817.5430, grad_fn=<AddBackward0>) tensor(39733.1602, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4084.3823, grad_fn=<SumBackward0>)
# EPOCH: 55 loss: 43633.4765625
# loss tensor(43646.4258, grad_fn=<AddBackward0>) tensor(39837.5938, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3808.8325, grad_fn=<SumBackward0>)
# EPOCH: 56 loss: 43589.36328125
# loss tensor(43673.3047, grad_fn=<AddBackward0>) tensor(39469.3945, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4203.9121, grad_fn=<SumBackward0>)
# EPOCH: 57 loss: 43543.9296875
# loss tensor(43537.6836, grad_fn=<AddBackward0>) tensor(39740.7773, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3796.9080, grad_fn=<SumBackward0>)
# EPOCH: 58 loss: 43522.1875
# loss tensor(43855.9766, grad_fn=<AddBackward0>) tensor(40123.2109, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3732.7676, grad_fn=<SumBackward0>)
# EPOCH: 59 loss: 43529.4609375
# loss tensor(43748.5078, grad_fn=<AddBackward0>) tensor(39706.7500, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4041.7578, grad_fn=<SumBackward0>)
# EPOCH: 60 loss: 43647.86328125
# loss tensor(43530.8984, grad_fn=<AddBackward0>) tensor(39974.6289, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3556.2693, grad_fn=<SumBackward0>)
# EPOCH: 61 loss: 43567.68359375
# loss tensor(43512.4805, grad_fn=<AddBackward0>) tensor(39729.5039, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3782.9775, grad_fn=<SumBackward0>)
# EPOCH: 62 loss: 43655.078125
# loss tensor(43462.7812, grad_fn=<AddBackward0>) tensor(39635.0117, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3827.7708, grad_fn=<SumBackward0>)
# EPOCH: 63 loss: 43726.21484375
# loss tensor(43716.6172, grad_fn=<AddBackward0>) tensor(40147.3438, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3569.2749, grad_fn=<SumBackward0>)
# EPOCH: 64 loss: 43571.69921875
# loss tensor(43651.9922, grad_fn=<AddBackward0>) tensor(39494.0156, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4157.9761, grad_fn=<SumBackward0>)
# EPOCH: 65 loss: 43511.08203125
# loss tensor(43408.8789, grad_fn=<AddBackward0>) tensor(39678.8125, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3730.0681, grad_fn=<SumBackward0>)
# EPOCH: 66 loss: 43477.59375
# loss tensor(44060.3516, grad_fn=<AddBackward0>) tensor(39819.8281, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4240.5239, grad_fn=<SumBackward0>)
# EPOCH: 67 loss: 43426.3828125
# loss tensor(43451.5781, grad_fn=<AddBackward0>) tensor(39355.5117, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4096.0684, grad_fn=<SumBackward0>)
# EPOCH: 68 loss: 43596.17578125
# loss tensor(43460.4844, grad_fn=<AddBackward0>) tensor(39391.9727, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4068.5117, grad_fn=<SumBackward0>)
# EPOCH: 69 loss: 43473.6484375
# loss tensor(43433.3594, grad_fn=<AddBackward0>) tensor(39631.9883, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3801.3711, grad_fn=<SumBackward0>)
# EPOCH: 70 loss: 43588.76953125
# loss tensor(43494.2891, grad_fn=<AddBackward0>) tensor(39213.5352, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4280.7539, grad_fn=<SumBackward0>)
# EPOCH: 71 loss: 43464.7578125
# loss tensor(43436.4180, grad_fn=<AddBackward0>) tensor(39549.2500, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3887.1670, grad_fn=<SumBackward0>)
# EPOCH: 72 loss: 43460.76953125
# loss tensor(43435.2891, grad_fn=<AddBackward0>) tensor(39311.0352, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4124.2544, grad_fn=<SumBackward0>)
# EPOCH: 73 loss: 43438.484375
# loss tensor(43313.5508, grad_fn=<AddBackward0>) tensor(39164.9453, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4148.6055, grad_fn=<SumBackward0>)
# EPOCH: 74 loss: 43332.4375
# loss tensor(43588.3906, grad_fn=<AddBackward0>) tensor(39654.6992, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3933.6897, grad_fn=<SumBackward0>)
# EPOCH: 75 loss: 43546.00390625
# loss tensor(43329.0352, grad_fn=<AddBackward0>) tensor(38980.9414, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4348.0952, grad_fn=<SumBackward0>)
# EPOCH: 76 loss: 43477.625
# loss tensor(43403.8320, grad_fn=<AddBackward0>) tensor(39507.6016, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3896.2322, grad_fn=<SumBackward0>)
# EPOCH: 77 loss: 43430.0859375
# loss tensor(43197.5234, grad_fn=<AddBackward0>) tensor(39220.1836, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3977.3384, grad_fn=<SumBackward0>)
# EPOCH: 78 loss: 43365.94921875
# loss tensor(43446.1562, grad_fn=<AddBackward0>) tensor(39172.0430, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4274.1123, grad_fn=<SumBackward0>)
# EPOCH: 79 loss: 43337.8984375
# loss tensor(43282., grad_fn=<AddBackward0>) tensor(39037.8320, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4244.1699, grad_fn=<SumBackward0>)
# EPOCH: 80 loss: 43530.40234375
# loss tensor(43456.0156, grad_fn=<AddBackward0>) tensor(39685.3516, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3770.6646, grad_fn=<SumBackward0>)
# EPOCH: 81 loss: 43227.28515625
# loss tensor(43367.2344, grad_fn=<AddBackward0>) tensor(39182.9766, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4184.2563, grad_fn=<SumBackward0>)
# EPOCH: 82 loss: 43352.390625
# loss tensor(43276.8086, grad_fn=<AddBackward0>) tensor(39267.9648, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4008.8440, grad_fn=<SumBackward0>)
# EPOCH: 83 loss: 43254.4296875
# loss tensor(43319.4531, grad_fn=<AddBackward0>) tensor(39117.9570, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4201.4971, grad_fn=<SumBackward0>)
# EPOCH: 84 loss: 43389.7890625
# loss tensor(43324.2109, grad_fn=<AddBackward0>) tensor(39080.6836, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4243.5293, grad_fn=<SumBackward0>)
# EPOCH: 85 loss: 43406.19921875
# loss tensor(43757.8516, grad_fn=<AddBackward0>) tensor(40211.8281, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3546.0234, grad_fn=<SumBackward0>)
# EPOCH: 86 loss: 43405.36328125
# loss tensor(43365., grad_fn=<AddBackward0>) tensor(39145.4805, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4219.5195, grad_fn=<SumBackward0>)
# EPOCH: 87 loss: 43301.859375
# loss tensor(43494.5273, grad_fn=<AddBackward0>) tensor(39372.3125, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4122.2158, grad_fn=<SumBackward0>)
# EPOCH: 88 loss: 43336.0078125
# loss tensor(43096.5703, grad_fn=<AddBackward0>) tensor(39256.8359, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3839.7351, grad_fn=<SumBackward0>)
# EPOCH: 89 loss: 43210.375
# loss tensor(43380.4023, grad_fn=<AddBackward0>) tensor(39508.5547, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3871.8472, grad_fn=<SumBackward0>)
# EPOCH: 90 loss: 43271.89453125
# loss tensor(43283.5703, grad_fn=<AddBackward0>) tensor(38913.4258, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4370.1455, grad_fn=<SumBackward0>)
# EPOCH: 91 loss: 43405.87890625
# loss tensor(43626.0703, grad_fn=<AddBackward0>) tensor(39577.2109, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4048.8589, grad_fn=<SumBackward0>)
# EPOCH: 92 loss: 43143.84375
# loss tensor(43307.1875, grad_fn=<AddBackward0>) tensor(39163.7812, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4143.4062, grad_fn=<SumBackward0>)
# EPOCH: 93 loss: 43380.62109375
# loss tensor(43356.4883, grad_fn=<AddBackward0>) tensor(39168.7148, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4187.7749, grad_fn=<SumBackward0>)
# EPOCH: 94 loss: 43116.0625
# loss tensor(43254.7656, grad_fn=<AddBackward0>) tensor(39471.1875, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3783.5776, grad_fn=<SumBackward0>)
# EPOCH: 95 loss: 43297.94140625
# loss tensor(43148.1758, grad_fn=<AddBackward0>) tensor(39146.0547, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4002.1208, grad_fn=<SumBackward0>)
# EPOCH: 96 loss: 43277.80859375
# loss tensor(43407.9453, grad_fn=<AddBackward0>) tensor(39339.2344, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4068.7126, grad_fn=<SumBackward0>)
# EPOCH: 97 loss: 43280.36328125
# loss tensor(43629.7188, grad_fn=<AddBackward0>) tensor(39684.2266, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3945.4929, grad_fn=<SumBackward0>)
# EPOCH: 98 loss: 43251.140625
# loss tensor(43379.9453, grad_fn=<AddBackward0>) tensor(39276.8320, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4103.1133, grad_fn=<SumBackward0>)
# EPOCH: 99 loss: 43345.3671875
# loss tensor(43273.3320, grad_fn=<AddBackward0>) tensor(38622.2656, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4651.0674, grad_fn=<SumBackward0>)
# EPOCH: 100 loss: 43188.6875
# loss tensor(43174.1133, grad_fn=<AddBackward0>) tensor(39053.4062, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4120.7080, grad_fn=<SumBackward0>)
# EPOCH: 101 loss: 43171.74609375
# loss tensor(43369.4844, grad_fn=<AddBackward0>) tensor(39272.1641, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4097.3203, grad_fn=<SumBackward0>)
# EPOCH: 102 loss: 43242.86328125
# loss tensor(43278.0234, grad_fn=<AddBackward0>) tensor(39148.7617, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4129.2607, grad_fn=<SumBackward0>)
# EPOCH: 103 loss: 43244.55859375
# loss tensor(43302.4805, grad_fn=<AddBackward0>) tensor(38865.0195, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4437.4600, grad_fn=<SumBackward0>)
# EPOCH: 104 loss: 43214.4296875
# loss tensor(43050.7227, grad_fn=<AddBackward0>) tensor(39134.5938, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3916.1279, grad_fn=<SumBackward0>)
# EPOCH: 105 loss: 43218.76171875
# loss tensor(43176.5898, grad_fn=<AddBackward0>) tensor(39114.8320, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4061.7595, grad_fn=<SumBackward0>)
# EPOCH: 106 loss: 43230.5234375
# loss tensor(43660.9102, grad_fn=<AddBackward0>) tensor(38912.0273, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4748.8838, grad_fn=<SumBackward0>)
# EPOCH: 107 loss: 43332.27734375
# loss tensor(43290.9141, grad_fn=<AddBackward0>) tensor(38804.9805, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4485.9341, grad_fn=<SumBackward0>)
# EPOCH: 108 loss: 43142.8671875
# loss tensor(43059.0039, grad_fn=<AddBackward0>) tensor(39206.6016, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3852.4028, grad_fn=<SumBackward0>)
# EPOCH: 109 loss: 43192.17578125
# loss tensor(43244.7617, grad_fn=<AddBackward0>) tensor(38643.3828, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4601.3799, grad_fn=<SumBackward0>)
# EPOCH: 110 loss: 43267.421875
# loss tensor(43151.8594, grad_fn=<AddBackward0>) tensor(38987.3086, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4164.5508, grad_fn=<SumBackward0>)
# EPOCH: 111 loss: 43277.3828125
# loss tensor(43341.8125, grad_fn=<AddBackward0>) tensor(38758.5312, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4583.2793, grad_fn=<SumBackward0>)
# EPOCH: 112 loss: 43097.33984375
# loss tensor(43282.0117, grad_fn=<AddBackward0>) tensor(39160.6016, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4121.4116, grad_fn=<SumBackward0>)
# EPOCH: 113 loss: 43266.58203125
# loss tensor(43242.5938, grad_fn=<AddBackward0>) tensor(38901.8320, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4340.7617, grad_fn=<SumBackward0>)
# EPOCH: 114 loss: 43254.6640625
# loss tensor(43107.5781, grad_fn=<AddBackward0>) tensor(38908.0156, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4199.5645, grad_fn=<SumBackward0>)
# EPOCH: 115 loss: 43200.51171875
# loss tensor(43161.8984, grad_fn=<AddBackward0>) tensor(38840.5469, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4321.3525, grad_fn=<SumBackward0>)
# EPOCH: 116 loss: 43094.91796875
# loss tensor(43168.1914, grad_fn=<AddBackward0>) tensor(38511.3828, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4656.8101, grad_fn=<SumBackward0>)
# EPOCH: 117 loss: 43231.47265625
# loss tensor(43246.6914, grad_fn=<AddBackward0>) tensor(39030.7539, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4215.9385, grad_fn=<SumBackward0>)
# EPOCH: 118 loss: 43195.5
# loss tensor(43254.8359, grad_fn=<AddBackward0>) tensor(39004.3242, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4250.5107, grad_fn=<SumBackward0>)
# EPOCH: 119 loss: 43076.91015625
# loss tensor(44009.8516, grad_fn=<AddBackward0>) tensor(39320.0039, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4689.8462, grad_fn=<SumBackward0>)
# EPOCH: 120 loss: 43087.1640625
# loss tensor(43094.4766, grad_fn=<AddBackward0>) tensor(39056.9219, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4037.5566, grad_fn=<SumBackward0>)
# EPOCH: 121 loss: 43072.01953125
# loss tensor(42981.2734, grad_fn=<AddBackward0>) tensor(38904.2656, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4077.0078, grad_fn=<SumBackward0>)
# EPOCH: 122 loss: 43248.640625
# loss tensor(43398.8359, grad_fn=<AddBackward0>) tensor(38825.9023, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4572.9331, grad_fn=<SumBackward0>)
# EPOCH: 123 loss: 43169.9921875
# loss tensor(43514.1094, grad_fn=<AddBackward0>) tensor(39623.3203, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3890.7896, grad_fn=<SumBackward0>)
# EPOCH: 124 loss: 43314.26953125
# loss tensor(43150.0117, grad_fn=<AddBackward0>) tensor(38916.5703, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4233.4409, grad_fn=<SumBackward0>)
# EPOCH: 125 loss: 43162.01171875
# loss tensor(42997.5195, grad_fn=<AddBackward0>) tensor(38325.1680, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4672.3525, grad_fn=<SumBackward0>)
# EPOCH: 126 loss: 43087.9921875
# loss tensor(42912.3047, grad_fn=<AddBackward0>) tensor(38708.3633, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4203.9419, grad_fn=<SumBackward0>)
# EPOCH: 127 loss: 43290.58984375
# loss tensor(43292.3945, grad_fn=<AddBackward0>) tensor(39245.5742, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4046.8193, grad_fn=<SumBackward0>)
# EPOCH: 128 loss: 43183.71484375
# loss tensor(43215.8047, grad_fn=<AddBackward0>) tensor(38988.2734, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4227.5293, grad_fn=<SumBackward0>)
# EPOCH: 129 loss: 43142.703125
# loss tensor(43343.5977, grad_fn=<AddBackward0>) tensor(39199.2070, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4144.3921, grad_fn=<SumBackward0>)
# EPOCH: 130 loss: 43104.5390625
# loss tensor(42953.5547, grad_fn=<AddBackward0>) tensor(38874.1758, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4079.3784, grad_fn=<SumBackward0>)
# EPOCH: 131 loss: 43104.5703125
# loss tensor(43048.6055, grad_fn=<AddBackward0>) tensor(38715.4805, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4333.1245, grad_fn=<SumBackward0>)
# EPOCH: 132 loss: 43192.22265625
# loss tensor(42958.7109, grad_fn=<AddBackward0>) tensor(38426.2891, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4532.4214, grad_fn=<SumBackward0>)
# EPOCH: 133 loss: 43163.84765625
# loss tensor(43235.5781, grad_fn=<AddBackward0>) tensor(39070.3125, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4165.2676, grad_fn=<SumBackward0>)
# EPOCH: 134 loss: 43066.37890625
# loss tensor(43098.1953, grad_fn=<AddBackward0>) tensor(39123., grad_fn=<BinaryCrossEntropyBackward0>) tensor(3975.1958, grad_fn=<SumBackward0>)
# EPOCH: 135 loss: 43292.6015625
# loss tensor(43501.5938, grad_fn=<AddBackward0>) tensor(39666.8320, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3834.7622, grad_fn=<SumBackward0>)
# EPOCH: 136 loss: 43077.63671875
# loss tensor(43240.0078, grad_fn=<AddBackward0>) tensor(38486.6055, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4753.4043, grad_fn=<SumBackward0>)
# EPOCH: 137 loss: 43230.8984375
# loss tensor(42949.6016, grad_fn=<AddBackward0>) tensor(38870.2539, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4079.3481, grad_fn=<SumBackward0>)
# EPOCH: 138 loss: 43091.4453125
# loss tensor(42879.7656, grad_fn=<AddBackward0>) tensor(38620.6406, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4259.1265, grad_fn=<SumBackward0>)
# EPOCH: 139 loss: 43289.3046875
# loss tensor(43117.3047, grad_fn=<AddBackward0>) tensor(38921.0352, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4196.2710, grad_fn=<SumBackward0>)
# EPOCH: 140 loss: 43300.59765625
# loss tensor(42950.9727, grad_fn=<AddBackward0>) tensor(38311.5742, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4639.3984, grad_fn=<SumBackward0>)
# EPOCH: 141 loss: 43104.9453125
# loss tensor(43731.2148, grad_fn=<AddBackward0>) tensor(39355.4062, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4375.8091, grad_fn=<SumBackward0>)
# EPOCH: 142 loss: 43115.296875
# loss tensor(43003.2812, grad_fn=<AddBackward0>) tensor(38869.1562, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4134.1230, grad_fn=<SumBackward0>)
# EPOCH: 143 loss: 43085.46875
# loss tensor(42733.6250, grad_fn=<AddBackward0>) tensor(38286.9180, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4446.7070, grad_fn=<SumBackward0>)
# EPOCH: 144 loss: 43054.13671875
# loss tensor(43355.1094, grad_fn=<AddBackward0>) tensor(39516.1289, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3838.9790, grad_fn=<SumBackward0>)
# EPOCH: 145 loss: 43192.8359375
# loss tensor(43454.5859, grad_fn=<AddBackward0>) tensor(38823.0703, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4631.5176, grad_fn=<SumBackward0>)
# EPOCH: 146 loss: 43110.25
# loss tensor(42744.2891, grad_fn=<AddBackward0>) tensor(38533.9805, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4210.3071, grad_fn=<SumBackward0>)
# EPOCH: 147 loss: 43088.53125
# loss tensor(43181.6055, grad_fn=<AddBackward0>) tensor(39083.3086, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4098.2954, grad_fn=<SumBackward0>)
# EPOCH: 148 loss: 43067.56640625
# loss tensor(42816.1484, grad_fn=<AddBackward0>) tensor(38485.6523, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4330.4956, grad_fn=<SumBackward0>)
# EPOCH: 149 loss: 43059.59375
# loss tensor(43143.3594, grad_fn=<AddBackward0>) tensor(38716.9688, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4426.3887, grad_fn=<SumBackward0>)
# EPOCH: 150 loss: 43101.953125
# loss tensor(43059.6719, grad_fn=<AddBackward0>) tensor(38776.4258, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4283.2466, grad_fn=<SumBackward0>)
# EPOCH: 151 loss: 43108.109375
# loss tensor(43209.6289, grad_fn=<AddBackward0>) tensor(39382.8086, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3826.8215, grad_fn=<SumBackward0>)
# EPOCH: 152 loss: 42960.421875
# loss tensor(42855.2422, grad_fn=<AddBackward0>) tensor(38453.0078, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4402.2344, grad_fn=<SumBackward0>)
# EPOCH: 153 loss: 43043.421875
# loss tensor(42929.1172, grad_fn=<AddBackward0>) tensor(38936.8867, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3992.2319, grad_fn=<SumBackward0>)
# EPOCH: 154 loss: 43248.16796875
# loss tensor(43587.4023, grad_fn=<AddBackward0>) tensor(39811.9492, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3775.4543, grad_fn=<SumBackward0>)
# EPOCH: 155 loss: 43039.0703125
# loss tensor(43128.9805, grad_fn=<AddBackward0>) tensor(38741.0664, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4387.9150, grad_fn=<SumBackward0>)
# EPOCH: 156 loss: 43025.23046875
# loss tensor(43292.5039, grad_fn=<AddBackward0>) tensor(38908.8359, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4383.6675, grad_fn=<SumBackward0>)
# EPOCH: 157 loss: 43064.44921875
# loss tensor(42853.4180, grad_fn=<AddBackward0>) tensor(38702.0977, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4151.3203, grad_fn=<SumBackward0>)
# EPOCH: 158 loss: 43160.80859375
# loss tensor(42949.3711, grad_fn=<AddBackward0>) tensor(38673.7773, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4275.5952, grad_fn=<SumBackward0>)
# EPOCH: 159 loss: 43104.0390625
# loss tensor(43008.6797, grad_fn=<AddBackward0>) tensor(38810.3203, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4198.3608, grad_fn=<SumBackward0>)
# EPOCH: 160 loss: 43097.71484375
# loss tensor(43211.6250, grad_fn=<AddBackward0>) tensor(38388.6875, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4822.9370, grad_fn=<SumBackward0>)
# EPOCH: 161 loss: 43134.25390625
# loss tensor(42928.1953, grad_fn=<AddBackward0>) tensor(38710.0273, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4218.1689, grad_fn=<SumBackward0>)
# EPOCH: 162 loss: 43194.44140625
# loss tensor(42929.5391, grad_fn=<AddBackward0>) tensor(38669.1758, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4260.3638, grad_fn=<SumBackward0>)
# EPOCH: 163 loss: 43083.66015625
# loss tensor(43153.7734, grad_fn=<AddBackward0>) tensor(39029.5547, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4124.2168, grad_fn=<SumBackward0>)
# EPOCH: 164 loss: 43098.07421875
# loss tensor(43047.7383, grad_fn=<AddBackward0>) tensor(38650.0508, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4397.6875, grad_fn=<SumBackward0>)
# EPOCH: 165 loss: 43013.41796875
# loss tensor(43422.3281, grad_fn=<AddBackward0>) tensor(38866.3242, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4556.0039, grad_fn=<SumBackward0>)
# EPOCH: 166 loss: 43067.375
# loss tensor(43094.5938, grad_fn=<AddBackward0>) tensor(38649.1094, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4445.4839, grad_fn=<SumBackward0>)
# EPOCH: 167 loss: 43465.671875
# loss tensor(42893.7109, grad_fn=<AddBackward0>) tensor(38856.8164, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4036.8943, grad_fn=<SumBackward0>)
# EPOCH: 168 loss: 43067.83203125
# loss tensor(43640.6758, grad_fn=<AddBackward0>) tensor(38698.7461, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4941.9282, grad_fn=<SumBackward0>)
# EPOCH: 169 loss: 43094.24609375
# loss tensor(42696.8984, grad_fn=<AddBackward0>) tensor(38507.4531, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4189.4448, grad_fn=<SumBackward0>)
# EPOCH: 170 loss: 43065.12890625
# loss tensor(44353.2578, grad_fn=<AddBackward0>) tensor(39551.9141, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4801.3438, grad_fn=<SumBackward0>)
# EPOCH: 171 loss: 43073.08984375
# loss tensor(43060.0820, grad_fn=<AddBackward0>) tensor(38355.1953, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4704.8882, grad_fn=<SumBackward0>)
# EPOCH: 172 loss: 43068.7421875
# loss tensor(42871.4141, grad_fn=<AddBackward0>) tensor(38610.9102, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4260.5054, grad_fn=<SumBackward0>)
# EPOCH: 173 loss: 43144.30078125
# loss tensor(43207.7734, grad_fn=<AddBackward0>) tensor(39179.2578, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4028.5159, grad_fn=<SumBackward0>)
# EPOCH: 174 loss: 43079.921875
# loss tensor(42811.6992, grad_fn=<AddBackward0>) tensor(38621.8984, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4189.8022, grad_fn=<SumBackward0>)
# EPOCH: 175 loss: 42945.78125
# loss tensor(42940.0664, grad_fn=<AddBackward0>) tensor(38840.7812, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4099.2861, grad_fn=<SumBackward0>)
# EPOCH: 176 loss: 43151.24609375
# loss tensor(42817.5469, grad_fn=<AddBackward0>) tensor(38387.1562, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4430.3921, grad_fn=<SumBackward0>)
# EPOCH: 177 loss: 43043.953125
# loss tensor(42795.8711, grad_fn=<AddBackward0>) tensor(38466.7734, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4329.0977, grad_fn=<SumBackward0>)
# EPOCH: 178 loss: 42980.23828125
# loss tensor(43008.8203, grad_fn=<AddBackward0>) tensor(38673.0469, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4335.7734, grad_fn=<SumBackward0>)
# EPOCH: 179 loss: 43106.35546875
# loss tensor(43259.1016, grad_fn=<AddBackward0>) tensor(39227.8867, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4031.2139, grad_fn=<SumBackward0>)
# EPOCH: 180 loss: 43102.046875
# loss tensor(43027.8828, grad_fn=<AddBackward0>) tensor(38656.5508, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4371.3315, grad_fn=<SumBackward0>)
# EPOCH: 181 loss: 42939.09375
# loss tensor(43214.5703, grad_fn=<AddBackward0>) tensor(39009.4375, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4205.1318, grad_fn=<SumBackward0>)
# EPOCH: 182 loss: 43162.93359375
# loss tensor(42972.0820, grad_fn=<AddBackward0>) tensor(38863.8086, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4108.2720, grad_fn=<SumBackward0>)
# EPOCH: 183 loss: 43148.6171875
# loss tensor(42847.0352, grad_fn=<AddBackward0>) tensor(38320.7148, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4526.3203, grad_fn=<SumBackward0>)
# EPOCH: 184 loss: 43050.6484375
# loss tensor(42960.8828, grad_fn=<AddBackward0>) tensor(38809.4375, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4151.4443, grad_fn=<SumBackward0>)
# EPOCH: 185 loss: 42894.11328125
# loss tensor(43095.5273, grad_fn=<AddBackward0>) tensor(39045.0156, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4050.5122, grad_fn=<SumBackward0>)
# EPOCH: 186 loss: 43075.75
# loss tensor(42941.8555, grad_fn=<AddBackward0>) tensor(38405.3398, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4536.5171, grad_fn=<SumBackward0>)
# EPOCH: 187 loss: 42808.9921875
# loss tensor(43331.7188, grad_fn=<AddBackward0>) tensor(38267.8906, grad_fn=<BinaryCrossEntropyBackward0>) tensor(5063.8291, grad_fn=<SumBackward0>)
# EPOCH: 188 loss: 43089.02734375
# loss tensor(42662.9688, grad_fn=<AddBackward0>) tensor(38211.9883, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4450.9819, grad_fn=<SumBackward0>)
# EPOCH: 189 loss: 43246.91796875
# loss tensor(43848.4844, grad_fn=<AddBackward0>) tensor(38981.5859, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4866.8994, grad_fn=<SumBackward0>)
# EPOCH: 190 loss: 42727.01953125
# loss tensor(43118.5039, grad_fn=<AddBackward0>) tensor(38882.7148, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4235.7881, grad_fn=<SumBackward0>)
# EPOCH: 191 loss: 42960.859375
# loss tensor(42970.3945, grad_fn=<AddBackward0>) tensor(38875.6172, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4094.7778, grad_fn=<SumBackward0>)
# EPOCH: 192 loss: 42991.7265625
# loss tensor(42972.0078, grad_fn=<AddBackward0>) tensor(38668.0703, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4303.9375, grad_fn=<SumBackward0>)
# EPOCH: 193 loss: 43029.4296875
# loss tensor(43194.6680, grad_fn=<AddBackward0>) tensor(39241.7031, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3952.9636, grad_fn=<SumBackward0>)
# EPOCH: 194 loss: 42953.484375
# loss tensor(43044., grad_fn=<AddBackward0>) tensor(39245.1875, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3798.8115, grad_fn=<SumBackward0>)
# EPOCH: 195 loss: 43108.7421875
# loss tensor(43238.6133, grad_fn=<AddBackward0>) tensor(39337.3789, grad_fn=<BinaryCrossEntropyBackward0>) tensor(3901.2351, grad_fn=<SumBackward0>)
# EPOCH: 196 loss: 42993.49609375
# loss tensor(42875.7344, grad_fn=<AddBackward0>) tensor(38559.3477, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4316.3877, grad_fn=<SumBackward0>)
# EPOCH: 197 loss: 42930.85546875
# loss tensor(42781.6719, grad_fn=<AddBackward0>) tensor(38381.5469, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4400.1250, grad_fn=<SumBackward0>)
# EPOCH: 198 loss: 42990.8828125
# loss tensor(42907.5352, grad_fn=<AddBackward0>) tensor(38423.5742, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4483.9595, grad_fn=<SumBackward0>)
# EPOCH: 199 loss: 43075.1484375
# loss tensor(43035.8906, grad_fn=<AddBackward0>) tensor(38851.3906, grad_fn=<BinaryCrossEntropyBackward0>) tensor(4184.5010, grad_fn=<SumBackward0>)

# %% [markdown]
# 収束状況グラフを描画する

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %% [markdown]
# 生成された画像を描画する

# %%
n_img2=10
#x3=x[:n_img2]
x2 = x_train.clone().detach()
x3 = x2[:n_img2]

torch.reshape( x2, (-1,n_in) )

loss = vae( x2 )

o = vae.net.out.to('cpu').detach().numpy().copy()
print("O",o.shape)

plt.figure( figsize=(10,2))
for i in range(n_img2):
  #input image
  ax = plt.subplot(3,n_img2,i+1)
  plt.imshow( x3[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  #output image
  ax = plt.subplot(3,n_img2,i+1+n_img2)
  plt.imshow( o[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# O (1797, 64)

# %% [markdown]
# 潜在変数の空間を描画する

# %%
t2 = t_train #[:n_batch]

x2 = x_train.clone().detach()
torch.reshape( x2, (-1,n_in) )
loss = vae( x2 )

plt.figure(figsize=(8,8))
for i in range(10):
  zt = vae.net.z[t2==i]
  z_1 = zt[:,0]
  z_2 = zt[:,1]
  marker= "$"+str(i)+"$"
  plt.scatter(z_2.tolist(), z_1.tolist(), marker=marker,s=75)

plt.xlabel("z_2")
plt.ylabel("z_1")
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid()
plt.show()

# %% [markdown]
# 潜在変数を変化させたときの画像を描画する

# %%
n_img3=16
img_size_spaced = img_size + 2
matrix_image = np.zeros(( img_size_spaced*n_img3, img_size_spaced*n_img3 ))

z_1 = np.linspace( 3, -3, n_img3 )
z_2 = np.linspace( 3, -3, n_img3 )

with torch.set_grad_enabled(False):
  for i, z1 in enumerate(z_1):
    for j,z2 in enumerate(z_2):

      z = np.array([z1, z2])
      zz = torch.from_numpy( z ).float()
      
      y = F.relu( vae.net.fc3(zz) )
      o = torch.sigmoid( vae.net.fc4(y) )
      image = o.reshape(img_size, img_size)
      top  = i * img_size_spaced
      left = j * img_size_spaced
      matrix_image[top:top+img_size, left:left+img_size] = image

plt.figure(figsize=(8,8))
plt.imshow( matrix_image.tolist(), cmap="Greys_r" )
plt.tick_params( labelbottom=False, labelleft=False, bottom=False, left=False )
plt.show()

print(x.shape)
# Out:
# torch.Size([32, 64])

# %% [markdown]
# ミニバッチ用の学習用データファイル、学習ループのC++コードを生成する

# %%
CV.convert_data_file( project, folder, inp_data=dd )
CV.convert_train_code( project, folder, json_path, sol="vae", z="fc3", epochs=200, batch=32, lr=0.001, inp_data=dd )
# Out:
# datafile key :  inp_data
# param: inp_data  - str loop  5000  /  14375
# param: inp_data  - str loop  10000  /  14375
# [DATA] ./vae/vae2_class_data.cpp
# [JSON] ./network/vae2_class.json
# epoch_num :  200
# batch_size :  32
# lr :  0.001
# inp shape (1797, 64) 2
# inp  shape :  1 {1797,64}
# pred shape :  0
# target shape :  0
# div :  False
# nb,nk :  53 79
# batch_size: 32
# inp_shape: {1797,64}
# bce_no :  53
# unpack0 prim::TupleUnpack
# unpack1 prim::TupleConstruct 0
# unpack original no:  48 50
# vae z:  40  keyw: fc3
# [TRAIN]  ./vae/vae2_class_train.cpp

# %% [markdown]
# 学習用のC++コードをコンパイル、リンクする

# %%
# !g++ -std=c++14 ./vae/vae2_class.cpp ./vae/vae2_class_param.cpp ./vae/vae2_class_data.cpp ./vae/vae2_class_train.cpp -D_NOTEBOOK -D_TRAIN -I ../../../xtensor -lcblas -o ./vae/vae2_class_train

# %% [markdown]
# (注) xtensorフォルダにxtensor関連のincludeファイルを置いています。各自の環境に合わせて変更して下さい。

# %%
# !./vae/vae2_class_train
# Out:
# epoch_num : 200
# indata shape   : 1797,64
# batch  number  : 56,32
# learning ratio : 0.001
# total_loss : epoch 0 - loss 61548.5
# epoch 0 - loss 51670.9 ( 49610.1 , 2060.81 )
# total_loss : epoch 1 - loss 49755.9
# epoch 1 - loss 48785.1 ( 46717.4 , 2067.77 )
# total_loss : epoch 2 - loss 48305.3
# epoch 2 - loss 47748.8 ( 45903.4 , 1845.31 )
# total_loss : epoch 3 - loss 47500.1
# epoch 3 - loss 47145.5 ( 45435.1 , 1710.37 )
# total_loss : epoch 4 - loss 46864.9
# epoch 4 - loss 46375.5 ( 44024.7 , 2350.84 )
# total_loss : epoch 5 - loss 46317.2
# epoch 5 - loss 45884.3 ( 43558.7 , 2325.61 )
# total_loss : epoch 6 - loss 45957.7
# epoch 6 - loss 45909.4 ( 43528.3 , 2381.18 )
# total_loss : epoch 7 - loss 45810.9
# epoch 7 - loss 45708.3 ( 43267 , 2441.28 )
# total_loss : epoch 8 - loss 45783
# epoch 8 - loss 45764.5 ( 43300 , 2464.56 )
# total_loss : epoch 9 - loss 45681.2
# epoch 9 - loss 45610.2 ( 43111.3 , 2498.85 )
# total_loss : epoch 10 - loss 45623.4
# epoch 10 - loss 45543.4 ( 42834.2 , 2709.18 )
# total_loss : epoch 11 - loss 45565.5
# epoch 11 - loss 45309.2 ( 42762.6 , 2546.55 )
# total_loss : epoch 12 - loss 45524.8
# epoch 12 - loss 45369.7 ( 42543.4 , 2826.35 )
# total_loss : epoch 13 - loss 45393
# epoch 13 - loss 45212.1 ( 42553.9 , 2658.18 )
# total_loss : epoch 14 - loss 45386.2
# epoch 14 - loss 45163.8 ( 42350.4 , 2813.37 )
# total_loss : epoch 15 - loss 45234.7
# epoch 15 - loss 45208 ( 42461.4 , 2746.59 )
# total_loss : epoch 16 - loss 45139.8
# epoch 16 - loss 45031 ( 42160.9 , 2870.12 )
# total_loss : epoch 17 - loss 45147.6
# epoch 17 - loss 45100.5 ( 41990.3 , 3110.2 )
# total_loss : epoch 18 - loss 45125.7
# epoch 18 - loss 45057.2 ( 42038.7 , 3018.45 )
# total_loss : epoch 19 - loss 45104.6
# epoch 19 - loss 44844.8 ( 41727 , 3117.77 )
# total_loss : epoch 20 - loss 44935.8
# epoch 20 - loss 44894.4 ( 41853.9 , 3040.47 )
# total_loss : epoch 21 - loss 44889.7
# epoch 21 - loss 44765.8 ( 41623.8 , 3142.03 )
# total_loss : epoch 22 - loss 44829.2
# epoch 22 - loss 44547.7 ( 41381.2 , 3166.43 )
# total_loss : epoch 23 - loss 44861
# epoch 23 - loss 44485.1 ( 41208.2 , 3276.96 )
# total_loss : epoch 24 - loss 44721.4
# epoch 24 - loss 44670.1 ( 41200.7 , 3469.39 )
# total_loss : epoch 25 - loss 44663
# epoch 25 - loss 44491.2 ( 41191.7 , 3299.52 )
# total_loss : epoch 26 - loss 44542.3
# epoch 26 - loss 44229.2 ( 40831.5 , 3397.72 )
# total_loss : epoch 27 - loss 44567.5
# epoch 27 - loss 44609.4 ( 41195.2 , 3414.23 )
# total_loss : epoch 28 - loss 44559.1
# epoch 28 - loss 44173.9 ( 40539.4 , 3634.51 )
# total_loss : epoch 29 - loss 44549.8
# epoch 29 - loss 44093.1 ( 40728.7 , 3364.34 )
# total_loss : epoch 30 - loss 44624.7
# epoch 30 - loss 44484.9 ( 40751.4 , 3733.52 )
# total_loss : epoch 31 - loss 44468.7
# epoch 31 - loss 44101.9 ( 40629 , 3472.84 )
# total_loss : epoch 32 - loss 44372.6
# epoch 32 - loss 44181.7 ( 40890.1 , 3291.62 )
# total_loss : epoch 33 - loss 44418.2
# epoch 33 - loss 44327.6 ( 40698.7 , 3628.85 )
# total_loss : epoch 34 - loss 44381
# epoch 34 - loss 43911.4 ( 40347.1 , 3564.32 )
# total_loss : epoch 35 - loss 44406.8
# epoch 35 - loss 43867.9 ( 40312.6 , 3555.3 )
# total_loss : epoch 36 - loss 44472.5
# epoch 36 - loss 44046.6 ( 40570.1 , 3476.43 )
# total_loss : epoch 37 - loss 44489.8
# epoch 37 - loss 44007 ( 40260.9 , 3746.16 )
# total_loss : epoch 38 - loss 44328.7
# epoch 38 - loss 44018.9 ( 40435.5 , 3583.4 )
# total_loss : epoch 39 - loss 44422.1
# epoch 39 - loss 43922.3 ( 40272.5 , 3649.76 )
# total_loss : epoch 40 - loss 44251
# epoch 40 - loss 43745 ( 39893 , 3851.97 )
# total_loss : epoch 41 - loss 44265.7
# epoch 41 - loss 43668.9 ( 39864.5 , 3804.41 )
# total_loss : epoch 42 - loss 44134.9
# epoch 42 - loss 43793.6 ( 40036.1 , 3757.54 )
# total_loss : epoch 43 - loss 44488.5
# epoch 43 - loss 43964.8 ( 40288.5 , 3676.36 )
# total_loss : epoch 44 - loss 44311.8
# epoch 44 - loss 43740.8 ( 39894.5 , 3846.26 )
# total_loss : epoch 45 - loss 44280.9
# epoch 45 - loss 43656.7 ( 39948.9 , 3707.84 )
# total_loss : epoch 46 - loss 44304.8
# epoch 46 - loss 43536.6 ( 39685.2 , 3851.4 )
# total_loss : epoch 47 - loss 43903.7
# epoch 47 - loss 43823.9 ( 39956.3 , 3867.66 )
# total_loss : epoch 48 - loss 44178.5
# epoch 48 - loss 43726.6 ( 39885.2 , 3841.4 )
# total_loss : epoch 49 - loss 43989.9
# epoch 49 - loss 43695.9 ( 39885.9 , 3810.06 )
# total_loss : epoch 50 - loss 44216.6
# epoch 50 - loss 43798.6 ( 40106 , 3692.54 )
# total_loss : epoch 51 - loss 44105.9
# epoch 51 - loss 43884.7 ( 40129.2 , 3755.48 )
# total_loss : epoch 52 - loss 44243.5
# epoch 52 - loss 43627.2 ( 39939.5 , 3687.76 )
# total_loss : epoch 53 - loss 44093.1
# epoch 53 - loss 43559.6 ( 39754.9 , 3804.76 )
# total_loss : epoch 54 - loss 43998.9
# epoch 54 - loss 43468.1 ( 39451 , 4017.11 )
# total_loss : epoch 55 - loss 44317.4
# epoch 55 - loss 43551.8 ( 39789.5 , 3762.25 )
# total_loss : epoch 56 - loss 44014.7
# epoch 56 - loss 43745.1 ( 39838.5 , 3906.6 )
# total_loss : epoch 57 - loss 44201.4
# epoch 57 - loss 44169.3 ( 40348.1 , 3821.22 )
# total_loss : epoch 58 - loss 43881.9
# epoch 58 - loss 43623.8 ( 39638.1 , 3985.68 )
# total_loss : epoch 59 - loss 43949.4
# epoch 59 - loss 43488 ( 39479.8 , 4008.22 )
# total_loss : epoch 60 - loss 43994.7
# epoch 60 - loss 43393.1 ( 39499 , 3894.07 )
# total_loss : epoch 61 - loss 43828.7
# epoch 61 - loss 43427.5 ( 39569.2 , 3858.34 )
# total_loss : epoch 62 - loss 43923.7
# epoch 62 - loss 43412.1 ( 39445.7 , 3966.43 )
# total_loss : epoch 63 - loss 44029.3
# epoch 63 - loss 43636.3 ( 39966.9 , 3669.43 )
# total_loss : epoch 64 - loss 44206.4
# epoch 64 - loss 43591.4 ( 39433.9 , 4157.46 )
# total_loss : epoch 65 - loss 44129.9
# epoch 65 - loss 43513.8 ( 39584.3 , 3929.48 )
# total_loss : epoch 66 - loss 44179
# epoch 66 - loss 43493.9 ( 39424.8 , 4069.08 )
# total_loss : epoch 67 - loss 44202.6
# epoch 67 - loss 43440.4 ( 39496.8 , 3943.56 )
# total_loss : epoch 68 - loss 43888.7
# epoch 68 - loss 43399.9 ( 39463.7 , 3936.21 )
# total_loss : epoch 69 - loss 43985.6
# epoch 69 - loss 43310.7 ( 39343.1 , 3967.61 )
# total_loss : epoch 70 - loss 43901
# epoch 70 - loss 43518.4 ( 39517 , 4001.39 )
# total_loss : epoch 71 - loss 43854.9
# epoch 71 - loss 43328.7 ( 39489.3 , 3839.4 )
# total_loss : epoch 72 - loss 43765.6
# epoch 72 - loss 43409.1 ( 39552.5 , 3856.66 )
# total_loss : epoch 73 - loss 44017
# epoch 73 - loss 43430.6 ( 39316.2 , 4114.37 )
# total_loss : epoch 74 - loss 43814.8
# epoch 74 - loss 43537.2 ( 39462.3 , 4074.91 )
# total_loss : epoch 75 - loss 43779.5
# epoch 75 - loss 43700.9 ( 39766.9 , 3934.06 )
# total_loss : epoch 76 - loss 43887.2
# epoch 76 - loss 43219.4 ( 39263.5 , 3955.85 )
# total_loss : epoch 77 - loss 43847.5
# epoch 77 - loss 43564.2 ( 39652.1 , 3912.09 )
# total_loss : epoch 78 - loss 43921.1
# epoch 78 - loss 43625.6 ( 39519.2 , 4106.35 )
# total_loss : epoch 79 - loss 43980.1
# epoch 79 - loss 43338.4 ( 39301.8 , 4036.66 )
# total_loss : epoch 80 - loss 43701.2
# epoch 80 - loss 43328.3 ( 39622.1 , 3706.18 )
# total_loss : epoch 81 - loss 44131.1
# epoch 81 - loss 43846.1 ( 39875.3 , 3970.83 )
# total_loss : epoch 82 - loss 43844.9
# epoch 82 - loss 43310.5 ( 39328.1 , 3982.49 )
# total_loss : epoch 83 - loss 43693.6
# epoch 83 - loss 43358.7 ( 39550.2 , 3808.48 )
# total_loss : epoch 84 - loss 43735.2
# epoch 84 - loss 43234.7 ( 39246.3 , 3988.45 )
# total_loss : epoch 85 - loss 43977.2
# epoch 85 - loss 43341.9 ( 39459.8 , 3882.09 )
# total_loss : epoch 86 - loss 43647.5
# epoch 86 - loss 43336.6 ( 39517.7 , 3818.91 )
# total_loss : epoch 87 - loss 43723.6
# epoch 87 - loss 43327.1 ( 39376.5 , 3950.59 )
# total_loss : epoch 88 - loss 43733.8
# epoch 88 - loss 43478.2 ( 39603.3 , 3874.92 )
# total_loss : epoch 89 - loss 43921.9
# epoch 89 - loss 43476 ( 39544 , 3932.02 )
# total_loss : epoch 90 - loss 43748.5
# epoch 90 - loss 43165.6 ( 39269.5 , 3896.01 )
# total_loss : epoch 91 - loss 43909.6
# epoch 91 - loss 43245.1 ( 39122.2 , 4122.88 )
# total_loss : epoch 92 - loss 43720.5
# epoch 92 - loss 43272.1 ( 39136.9 , 4135.22 )
# total_loss : epoch 93 - loss 43687.6
# epoch 93 - loss 43669.8 ( 39630.5 , 4039.25 )
# total_loss : epoch 94 - loss 43988.8
# epoch 94 - loss 43445.1 ( 39171.3 , 4273.73 )
# total_loss : epoch 95 - loss 43934.6
# epoch 95 - loss 43187.5 ( 39132 , 4055.49 )
# total_loss : epoch 96 - loss 43949.2
# epoch 96 - loss 43491.1 ( 39472 , 4019.07 )
# total_loss : epoch 97 - loss 43655.1
# epoch 97 - loss 43292.3 ( 39220 , 4072.34 )
# total_loss : epoch 98 - loss 43646
# epoch 98 - loss 43438 ( 39430 , 4008.03 )
# total_loss : epoch 99 - loss 43784.4
# epoch 99 - loss 43223.7 ( 39188.7 , 4034.95 )
# total_loss : epoch 100 - loss 43694
# epoch 100 - loss 42998.5 ( 39040.8 , 3957.76 )
# total_loss : epoch 101 - loss 43943.6
# epoch 101 - loss 43132.7 ( 39181.3 , 3951.41 )
# total_loss : epoch 102 - loss 43667
# epoch 102 - loss 43269.6 ( 39172.8 , 4096.88 )
# total_loss : epoch 103 - loss 43601
# epoch 103 - loss 43058.9 ( 38911.8 , 4147.13 )
# total_loss : epoch 104 - loss 43788.5
# epoch 104 - loss 43107.5 ( 39061.4 , 4046.04 )
# total_loss : epoch 105 - loss 43953.9
# epoch 105 - loss 43071.7 ( 39172.2 , 3899.44 )
# total_loss : epoch 106 - loss 43767.2
# epoch 106 - loss 43311.1 ( 39300 , 4011.15 )
# total_loss : epoch 107 - loss 43875.5
# epoch 107 - loss 43005.5 ( 38760.5 , 4244.94 )
# total_loss : epoch 108 - loss 44107.1
# epoch 108 - loss 43619.1 ( 39157.5 , 4461.61 )
# total_loss : epoch 109 - loss 43757.1
# epoch 109 - loss 43136.8 ( 39050.8 , 4085.96 )
# total_loss : epoch 110 - loss 43781.3
# epoch 110 - loss 43156.4 ( 39134.8 , 4021.66 )
# total_loss : epoch 111 - loss 43682.6
# epoch 111 - loss 43060.3 ( 38891.3 , 4168.97 )
# total_loss : epoch 112 - loss 43745.2
# epoch 112 - loss 42985.8 ( 38996 , 3989.84 )
# total_loss : epoch 113 - loss 43652.9
# epoch 113 - loss 42954.6 ( 38921.4 , 4033.19 )
# total_loss : epoch 114 - loss 43724.1
# epoch 114 - loss 43989.2 ( 39789.5 , 4199.76 )
# total_loss : epoch 115 - loss 43806
# epoch 115 - loss 42937.3 ( 38777.2 , 4160.09 )
# total_loss : epoch 116 - loss 43679.6
# epoch 116 - loss 43119 ( 39006.4 , 4112.58 )
# total_loss : epoch 117 - loss 43880
# epoch 117 - loss 43065.5 ( 38882 , 4183.53 )
# total_loss : epoch 118 - loss 43598.9
# epoch 118 - loss 43034.2 ( 38880.8 , 4153.37 )
# total_loss : epoch 119 - loss 43593.8
# epoch 119 - loss 42964.8 ( 38749.7 , 4215.16 )
# total_loss : epoch 120 - loss 43582.4
# epoch 120 - loss 42943.4 ( 38924 , 4019.33 )
# total_loss : epoch 121 - loss 43454
# epoch 121 - loss 43038.4 ( 39188.6 , 3849.82 )
# total_loss : epoch 122 - loss 43662.1
# epoch 122 - loss 43107.9 ( 39194.6 , 3913.24 )
# total_loss : epoch 123 - loss 43672.1
# epoch 123 - loss 43064.3 ( 38638.4 , 4425.88 )
# total_loss : epoch 124 - loss 43917.5
# epoch 124 - loss 43121.1 ( 38621.6 , 4499.5 )
# total_loss : epoch 125 - loss 43642
# epoch 125 - loss 43312.2 ( 39304.8 , 4007.37 )
# total_loss : epoch 126 - loss 43692.6
# epoch 126 - loss 43126.5 ( 38950.9 , 4175.63 )
# total_loss : epoch 127 - loss 43709.4
# epoch 127 - loss 43196.1 ( 39099.8 , 4096.3 )
# total_loss : epoch 128 - loss 43727.2
# epoch 128 - loss 43059.2 ( 39022.3 , 4036.93 )
# total_loss : epoch 129 - loss 43559.1
# epoch 129 - loss 42958.1 ( 38677.6 , 4280.49 )
# total_loss : epoch 130 - loss 43627.3
# epoch 130 - loss 43061.5 ( 38869.5 , 4192.03 )
# total_loss : epoch 131 - loss 43733.7
# epoch 131 - loss 43089.5 ( 38923.9 , 4165.57 )
# total_loss : epoch 132 - loss 43565.2
# epoch 132 - loss 43212.6 ( 38919.6 , 4292.96 )
# total_loss : epoch 133 - loss 43910.2
# epoch 133 - loss 42926.9 ( 38844.2 , 4082.7 )
# total_loss : epoch 134 - loss 43709.5
# epoch 134 - loss 43342.2 ( 39209.8 , 4132.37 )
# total_loss : epoch 135 - loss 43796.1
# epoch 135 - loss 43557.1 ( 39323.9 , 4233.25 )
# total_loss : epoch 136 - loss 43754.9
# epoch 136 - loss 42934.1 ( 38707.1 , 4227.01 )
# total_loss : epoch 137 - loss 43584.7
# epoch 137 - loss 43024.1 ( 39104.1 , 3919.98 )
# total_loss : epoch 138 - loss 43549
# epoch 138 - loss 43200.7 ( 39083.7 , 4117.03 )
# total_loss : epoch 139 - loss 43602.4
# epoch 139 - loss 42868.2 ( 38777.5 , 4090.7 )
# total_loss : epoch 140 - loss 43758.9
# epoch 140 - loss 43118.3 ( 38901.7 , 4216.58 )
# total_loss : epoch 141 - loss 43694
# epoch 141 - loss 43040 ( 38899.6 , 4140.36 )
# total_loss : epoch 142 - loss 43777.5
# epoch 142 - loss 43035.7 ( 38807 , 4228.76 )
# total_loss : epoch 143 - loss 43644.5
# epoch 143 - loss 42922.5 ( 38760.4 , 4162.09 )
# total_loss : epoch 144 - loss 43481
# epoch 144 - loss 42937.5 ( 38766.4 , 4171.15 )
# total_loss : epoch 145 - loss 43622.2
# epoch 145 - loss 42842.6 ( 38665.3 , 4177.27 )
# total_loss : epoch 146 - loss 43616.5
# epoch 146 - loss 43138.2 ( 38956.6 , 4181.57 )
# total_loss : epoch 147 - loss 43478.8
# epoch 147 - loss 42874.5 ( 38639.7 , 4234.75 )
# total_loss : epoch 148 - loss 43645.3
# epoch 148 - loss 43076.4 ( 38821.8 , 4254.68 )
# total_loss : epoch 149 - loss 43701.6
# epoch 149 - loss 43348.7 ( 39179.5 , 4169.15 )
# total_loss : epoch 150 - loss 43598.3
# epoch 150 - loss 42931.7 ( 38784.4 , 4147.34 )
# total_loss : epoch 151 - loss 43635.8
# epoch 151 - loss 42824.7 ( 38652.7 , 4172.01 )
# total_loss : epoch 152 - loss 43796.4
# epoch 152 - loss 43031.8 ( 38947.8 , 4084.03 )
# total_loss : epoch 153 - loss 43555.8
# epoch 153 - loss 43022.1 ( 38910.4 , 4111.72 )
# total_loss : epoch 154 - loss 43601.4
# epoch 154 - loss 43578.9 ( 39354 , 4224.93 )
# total_loss : epoch 155 - loss 43607
# epoch 155 - loss 42835 ( 38611.2 , 4223.79 )
# total_loss : epoch 156 - loss 43663.9
# epoch 156 - loss 43239.6 ( 38892.9 , 4346.71 )
# total_loss : epoch 157 - loss 43657.7
# epoch 157 - loss 43037.8 ( 38859.7 , 4178.12 )
# total_loss : epoch 158 - loss 43521.9
# epoch 158 - loss 42993.9 ( 38841.2 , 4152.73 )
# total_loss : epoch 159 - loss 43446
# epoch 159 - loss 43010.8 ( 38966 , 4044.8 )
# total_loss : epoch 160 - loss 43658.5
# epoch 160 - loss 43251.9 ( 38548.2 , 4703.69 )
# total_loss : epoch 161 - loss 43580.4
# epoch 161 - loss 42936.7 ( 38682.6 , 4254.15 )
# total_loss : epoch 162 - loss 43818.1
# epoch 162 - loss 43036.8 ( 38772.6 , 4264.12 )
# total_loss : epoch 163 - loss 43506.7
# epoch 163 - loss 42992.4 ( 38745.9 , 4246.49 )
# total_loss : epoch 164 - loss 43820.4
# epoch 164 - loss 43524.9 ( 39275.1 , 4249.85 )
# total_loss : epoch 165 - loss 43499.2
# epoch 165 - loss 43096 ( 38940.5 , 4155.48 )
# total_loss : epoch 166 - loss 43578.8
# epoch 166 - loss 42825.4 ( 38794.7 , 4030.72 )
# total_loss : epoch 167 - loss 43508
# epoch 167 - loss 42846.6 ( 38423.6 , 4422.99 )
# total_loss : epoch 168 - loss 43807.4
# epoch 168 - loss 42981.7 ( 38889.7 , 4091.96 )
# total_loss : epoch 169 - loss 43519
# epoch 169 - loss 42911.8 ( 38829.2 , 4082.56 )
# total_loss : epoch 170 - loss 43399.6
# epoch 170 - loss 43272.1 ( 39012 , 4260.02 )
# total_loss : epoch 171 - loss 43848.8
# epoch 171 - loss 42843.8 ( 38562.4 , 4281.45 )
# total_loss : epoch 172 - loss 43645.5
# epoch 172 - loss 43351.5 ( 39241.8 , 4109.68 )
# total_loss : epoch 173 - loss 43570.4
# epoch 173 - loss 42922 ( 38570.2 , 4351.8 )
# total_loss : epoch 174 - loss 43373.9
# epoch 174 - loss 42814.6 ( 38659.4 , 4155.21 )
# total_loss : epoch 175 - loss 43343.2
# epoch 175 - loss 43298 ( 39069.9 , 4228.09 )
# total_loss : epoch 176 - loss 43404.2
# epoch 176 - loss 43244.5 ( 39102.4 , 4142.08 )
# total_loss : epoch 177 - loss 43507.1
# epoch 177 - loss 42818.8 ( 38728 , 4090.79 )
# total_loss : epoch 178 - loss 43512.6
# epoch 178 - loss 42778.5 ( 38509.4 , 4269.1 )
# total_loss : epoch 179 - loss 43371.7
# epoch 179 - loss 42887.5 ( 38783.1 , 4104.46 )
# total_loss : epoch 180 - loss 43445.4
# epoch 180 - loss 43394.6 ( 39072 , 4322.68 )
# total_loss : epoch 181 - loss 43535.6
# epoch 181 - loss 42819.4 ( 38702.5 , 4116.93 )
# total_loss : epoch 182 - loss 43455.4
# epoch 182 - loss 43155.7 ( 38964 , 4191.7 )
# total_loss : epoch 183 - loss 43536.8
# epoch 183 - loss 42961.4 ( 38831 , 4130.45 )
# total_loss : epoch 184 - loss 43614.5
# epoch 184 - loss 42840.1 ( 38694.3 , 4145.79 )
# total_loss : epoch 185 - loss 43676
# epoch 185 - loss 43264.7 ( 39022.7 , 4242.01 )
# total_loss : epoch 186 - loss 43628.1
# epoch 186 - loss 43045.4 ( 38934.5 , 4110.96 )
# total_loss : epoch 187 - loss 43642
# epoch 187 - loss 43050.5 ( 38807.7 , 4242.8 )
# total_loss : epoch 188 - loss 43688.3
# epoch 188 - loss 42836.2 ( 38648.8 , 4187.41 )
# total_loss : epoch 189 - loss 43675.7
# epoch 189 - loss 43759.3 ( 39359.1 , 4400.25 )
# total_loss : epoch 190 - loss 43960.3
# epoch 190 - loss 43006.3 ( 38777.1 , 4229.23 )
# total_loss : epoch 191 - loss 43447.3
# epoch 191 - loss 43234.8 ( 38790.5 , 4444.35 )
# total_loss : epoch 192 - loss 43742.3
# epoch 192 - loss 43196.1 ( 38949.5 , 4246.65 )
# total_loss : epoch 193 - loss 43718.3
# epoch 193 - loss 43202.4 ( 39193.7 , 4008.71 )
# total_loss : epoch 194 - loss 43677.5
# epoch 194 - loss 42914.3 ( 38739.2 , 4175.12 )
# total_loss : epoch 195 - loss 43504.9
# epoch 195 - loss 43430.8 ( 39570.1 , 3860.74 )
# total_loss : epoch 196 - loss 43409.4
# epoch 196 - loss 43284.1 ( 39310.3 , 3973.83 )
# total_loss : epoch 197 - loss 43596.1
# epoch 197 - loss 42878.4 ( 38800.4 , 4078 )
# total_loss : epoch 198 - loss 43773.9
# epoch 198 - loss 43111 ( 38902.1 , 4208.88 )
# total_loss : epoch 199 - loss 43646.5
# epoch 199 - loss 43431.2 ( 39159.2 , 4271.99 )

# %% [markdown]
# c++ からの出力ファイルの読み込み

# %%
# load out file
f = open('./vae/vae2_class.out', 'r')
epoch_loss = []
datalist = f.readlines()
for data in datalist:
  epoch_loss.append( float(data) )
f.close()

print("epoch =", len(epoch_loss))
print( epoch_loss)

# load pred file
f2 = open('./vae/vae2_class.pred', 'r')

datalist = f2.readlines()

n1 = 10
n2 = 64
k = 0
for data in datalist:
  ds = data.split(',')
  if k==0:
    n1 = int(ds[0])
    n2 = int(ds[1])
    global v_pred
    v_pred = np.zeros( (n1,n2))
  else:
    for i in range(n2):
      v_pred[k-1,i] = float(ds[i])
  k = k+1

f2.close()

# load z file
f3 = open('./vae/vae2_class.z', 'r')

datalist = f3.readlines()
n1 = 100
n2 = 2
k = 0
for data in datalist:
  ds = data.split(',')
  if k==0:
    nz1 = int(ds[0])
    nz2 = int(ds[1])
    z_pred = np.zeros( (nz1,nz2))
  else:
    z_pred[k-1,0] = float(ds[0])
    z_pred[k-1,1] = float(ds[1])
  k = k+1

f3.close()

print("z =", nz1,nz2 )
#print(z_pred)
# Out:
# epoch = 200
# [51670.914062, 48785.144531, 47748.757812, 47145.503906, 46375.507812, 45884.347656, 45909.433594, 45708.3125, 45764.53125, 45610.195312, 45543.390625, 45309.1875, 45369.742188, 45212.128906, 45163.8125, 45207.960938, 45031.027344, 45100.484375, 45057.152344, 44844.769531, 44894.390625, 44765.824219, 44547.664062, 44485.148438, 44670.050781, 44491.246094, 44229.183594, 44609.398438, 44173.917969, 44093.058594, 44484.917969, 44101.859375, 44181.695312, 44327.558594, 43911.394531, 43867.867188, 44046.582031, 44007.042969, 44018.90625, 43922.308594, 43744.964844, 43668.902344, 43793.640625, 43964.816406, 43740.789062, 43656.738281, 43536.632812, 43823.910156, 43726.566406, 43695.914062, 43798.554688, 43884.707031, 43627.230469, 43559.640625, 43468.144531, 43551.773438, 43745.101562, 44169.332031, 43623.765625, 43488.046875, 43393.117188, 43427.546875, 43412.078125, 43636.347656, 43591.351562, 43513.800781, 43493.851562, 43440.355469, 43399.925781, 43310.65625, 43518.375, 43328.691406, 43409.148438, 43430.578125, 43537.210938, 43700.90625, 43219.375, 43564.230469, 43625.597656, 43338.445312, 43328.300781, 43846.109375, 43310.542969, 43358.683594, 43234.726562, 43341.894531, 43336.628906, 43327.097656, 43478.207031, 43476.003906, 43165.550781, 43245.101562, 43272.136719, 43669.777344, 43445.074219, 43187.519531, 43491.101562, 43292.289062, 43438.007812, 43223.691406, 42998.546875, 43132.6875, 43269.636719, 43058.886719, 43107.460938, 43071.652344, 43311.101562, 43005.464844, 43619.066406, 43136.769531, 43156.414062, 43060.308594, 42985.847656, 42954.570312, 43989.21875, 42937.289062, 43119.003906, 43065.523438, 43034.191406, 42964.84375, 42943.378906, 43038.421875, 43107.871094, 43064.316406, 43121.074219, 43312.210938, 43126.53125, 43196.09375, 43059.21875, 42958.070312, 43061.480469, 43089.488281, 43212.585938, 42926.894531, 43342.191406, 43557.101562, 42934.089844, 43024.09375, 43200.695312, 42868.1875, 43118.308594, 43039.957031, 43035.726562, 42922.507812, 42937.511719, 42842.558594, 43138.167969, 42874.457031, 43076.441406, 43348.695312, 42931.722656, 42824.691406, 43031.785156, 43022.097656, 43578.929688, 42835.003906, 43239.644531, 43037.796875, 42993.90625, 43010.761719, 43251.875, 42936.726562, 43036.773438, 42992.410156, 43524.933594, 43095.972656, 42825.445312, 42846.597656, 42981.675781, 42911.769531, 43272.066406, 42843.8125, 43351.523438, 42921.988281, 42814.589844, 43298.0, 43244.460938, 42818.792969, 42778.53125, 42887.53125, 43394.632812, 42819.429688, 43155.695312, 42961.421875, 42840.121094, 43264.726562, 43045.417969, 43050.492188, 42836.191406, 43759.296875, 43006.34375, 43234.824219, 43196.132812, 43202.441406, 42914.34375, 43430.800781, 43284.085938, 42878.421875, 43110.984375, 43431.238281]
# z = 1797 2

# %% [markdown]
# 収束状況グラフを描画する

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %% [markdown]
# 生成された画像を描画する

# %%
n_img5 = 10
x2 = x[:n_img5]

plt.figure( figsize=(10,2))
for i in range(n_img5):
  # input image
  ax = plt.subplot(3,n_img5,i+1)
  plt.imshow( x2[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # output image
  ax = plt.subplot(3,n_img5,i+1+n_img5)
  plt.imshow( v_pred[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# 潜在変数の空間を描画する

# %%
t2 = t_train #[:n_batch]

plt.figure(figsize=(8,8))
for i in range(10):
  zt = z_pred[t2==i]
  z_1 = zt[:,0]
  z_2 = zt[:,1]
  marker= "$"+str(i)+"$"
  plt.scatter( z_2.tolist(),  z_1.tolist(), marker=marker,s=75 )

plt.xlabel("z_2")
plt.ylabel("z_1")
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid()
plt.show()
