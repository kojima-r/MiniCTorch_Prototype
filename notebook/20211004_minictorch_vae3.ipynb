# %% [markdown]
# vae3　オートエンコーダー
#
# 参考文献　【超初心者向け】VAEの分かりやすい説明とPyTorchの実装
#            https://tips-memo.com/vae-pytorch

# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# %cd "ctorch210929/MiniCTorch_Prototype/notebook"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch210929/MiniCTorch_Prototype/notebook

# %%
! pip install lark-parser
# Out:
# Collecting lark-parser
#   Downloading lark_parser-0.12.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 4.9 MB/s
# Installing collected packages: lark-parser
# Successfully installed lark-parser-0.12.0

# %%
import sys
sys.path.append("../")

import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import minictorch.generator as GN
import minictorch.converter as CV

# %% [markdown]
# サンプルデータ

# %%
import torch.utils as utils
from torchvision import datasets, transforms

transform = transforms.Compose([transforms.ToTensor(), transforms.Lambda(lambda x: x.view(-1))])

dataset_train = datasets.MNIST('~/mnist', train=True,  download=True, transform=transform)
dataset_valid = datasets.MNIST('~/mnist', train=False, download=True, transform=transform)

batch_size = 1000

dataloader_train = utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True, num_workers=4)
dataloader_valid = utils.data.DataLoader(dataset_valid, batch_size=batch_size, shuffle=True, num_workers=4)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /root/mnist/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /root/mnist/MNIST/raw/train-images-idx3-ubyte.gz to /root/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /root/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /root/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to /root/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /root/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /root/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /root/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /root/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/mnist/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ニューラルネットワークの定義

# %%
def mean_squared_error( x0, x1 ):
    diff = x0 - x1
    y = (diff**2).sum() / len(diff)
    return y;

def reconstruction( y, t ):
  eps = 1.0e-7
  e = t * torch.log(y+eps) + (1-t) * torch.log(1-y+eps) 
  z = e.sum() / len(y)
  return z;

def kl_divergence( mean, log_var ):
  g = 1 + log_var - mean**2 - torch.exp( log_var )
  y = 0.5 * g.sum() / len(mean)
  return y

import torch.distributions as td

class VAE(torch.nn.Module):
  def __init__( self,  t, x_dim,  z_dim ):
    super(VAE, self).__init__()
    self.x_dim = x_dim
    self.z_dim = z_dim
    self.fc1 = nn.Linear(x_dim, 20)
    self.bn1 = nn.BatchNorm1d(20)
    self.fc2_mean = nn.Linear(20, z_dim)
    self.fc2_var  = nn.Linear(20, z_dim)

    self.fc3   = nn.Linear(z_dim, 20)
    self.drop1 = nn.Dropout(p=0.2)
    self.fc4   = nn.Linear(20, x_dim)

    self.target = t

    #nn.init.constant_(self.fc1.bias,0)
    #nn.init.constant_(self.fc2_mean.bias,0)
    #nn.init.constant_(self.fc2_var.bias,0)
    #nn.init.constant_(self.fc3.bias,0)
    #nn.init.constant_(self.fc4.bias,0)

    self.bce1 = nn.BCELoss()
  
  def forward( self, x0 ):
    # encoder
    x = x0.view(-1, self.x_dim)
    x = F.relu( self.fc1(x) )
    x = self.bn1( x )
    self.mean    = self.fc2_mean(x)
    self.log_var = self.fc2_var(x)

    # reparametrization
    self.std = torch.exp( 0.5 * self.log_var )
    q_z = td.normal.Normal( self.mean, self.std )
    self.z = q_z.rsample()

    # decoder
    y = F.relu(self.fc3(self.z))
    y = self.drop1(y)
    #y = self.fc4(y)
    y = torch.sigmoid(self.fc4(y))
    ##return y
    self.out = y 
    #print("y ", len(y), y.size() )
    #print("x",x.shape)
    
    e1 = F.binary_cross_entropy( y , x0, reduction="mean" )
    #e1 = self.bce1(y, x)

    p_z = td.normal.Normal( torch.zeros_like(q_z.loc), torch.ones_like(q_z.scale) )
    e2  = td.kl_divergence( q_z, p_z ).sum()

    return (e1+e2)

# %%
def test( x, t ):
 
  model = VAE( t, x_dim=28*28, z_dim=10 )

  trace = torch.jit.trace( model, x, strict=True )
  print(trace.graph)

#x = x_train.clone().detach()
#torch.reshape( x, (-1,n_in) )

#x = x[0:n_batch,:]

#e = torch.randn( n_batch, 2 )

itr = iter(dataloader_train)
x, t = itr.next()

print(x.shape)
print(t.shape)

test( x, t )
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# torch.Size([1000, 784])
# torch.Size([1000])
# graph(%self.1 : __torch__.VAE,
#       %x0 : Float(1000, 784, strides=[784, 1], requires_grad=0, device=cpu)):
#   %207 : __torch__.torch.nn.modules.linear.___torch_mangle_3.Linear = prim::GetAttr[name="fc4"](%self.1)
#   %204 : __torch__.torch.nn.modules.dropout.Dropout = prim::GetAttr[name="drop1"](%self.1)
#   %203 : __torch__.torch.nn.modules.linear.___torch_mangle_2.Linear = prim::GetAttr[name="fc3"](%self.1)
#   %200 : __torch__.torch.nn.modules.linear.___torch_mangle_1.Linear = prim::GetAttr[name="fc2_var"](%self.1)
#   %197 : __torch__.torch.nn.modules.linear.___torch_mangle_0.Linear = prim::GetAttr[name="fc2_mean"](%self.1)
#   %194 : __torch__.torch.nn.modules.batchnorm.BatchNorm1d = prim::GetAttr[name="bn1"](%self.1)
#   %188 : __torch__.torch.nn.modules.linear.Linear = prim::GetAttr[name="fc1"](%self.1)
#   %43 : int = prim::Constant[value=-1]() # <ipython-input-8-c797bd6570ac>:45:0
#   %44 : int = prim::Constant[value=784]() # <ipython-input-8-c797bd6570ac>:45:0
#   %45 : int[] = prim::ListConstruct(%43, %44)
#   %input.1 : Float(1000, 784, strides=[784, 1], requires_grad=0, device=cpu) = aten::view(%x0, %45) # <ipython-input-8-c797bd6570ac>:45:0
#   %215 : Tensor = prim::CallMethod[name="forward"](%188, %input.1)
#   %input.5 : Float(1000, 20, strides=[20, 1], requires_grad=1, device=cpu) = aten::relu(%215) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1298:0
#   %216 : Tensor = prim::CallMethod[name="forward"](%194, %input.5)
#   %217 : Tensor = prim::CallMethod[name="forward"](%197, %216)
#   %218 : Tensor = prim::CallMethod[name="forward"](%200, %216)
#   %67 : Double(requires_grad=0, device=cpu) = prim::Constant[value={0.5}]() # <ipython-input-8-c797bd6570ac>:52:0
#   %68 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::mul(%218, %67) # <ipython-input-8-c797bd6570ac>:52:0
#   %69 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::exp(%68) # <ipython-input-8-c797bd6570ac>:52:0
#   %70 : Tensor[] = prim::ListConstruct(%217, %69)
#   %71 : Tensor[] = aten::broadcast_tensors(%70) # /usr/local/lib/python3.7/dist-packages/torch/functional.py:73:0
#   %loc.1 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu), %value.1 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = prim::ListUnpack(%71)
#   %74 : int = prim::Constant[value=0]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:49:0
#   %75 : int = aten::size(%loc.1, %74) # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:49:0
#   %76 : Long(device=cpu) = prim::NumToTensor(%75)
#   %93 : int = aten::Int(%76)
#   %85 : int = aten::Int(%76)
#   %77 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:49:0
#   %78 : int = aten::size(%loc.1, %77) # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:49:0
#   %79 : Long(device=cpu) = prim::NumToTensor(%78)
#   %94 : int = aten::Int(%79)
#   %86 : int = aten::Int(%79)
#   %87 : int[] = prim::ListConstruct(%85, %86)
#   %88 : int = prim::Constant[value=6]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:46:0
#   %89 : NoneType = prim::Constant()
#   %90 : Device = prim::Constant[value="cpu"]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:46:0
#   %91 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:46:0
#   %92 : Float(1000, 10, strides=[10, 1], requires_grad=0, device=cpu) = aten::zeros(%87, %88, %89, %90, %91) # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:46:0
#   %95 : int[] = prim::ListConstruct(%93, %94)
#   %96 : int = prim::Constant[value=6]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %97 : NoneType = prim::Constant()
#   %98 : Device = prim::Constant[value="cpu"]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %99 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %100 : Float(1000, 10, strides=[10, 1], requires_grad=0, device=cpu) = aten::ones(%95, %96, %97, %98, %99) # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %101 : NoneType = prim::Constant()
#   %eps : Float(1000, 10, strides=[10, 1], requires_grad=0, device=cpu) = aten::normal(%92, %100, %101) # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %103 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::mul(%eps, %value.1) # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:69:0
#   %104 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:69:0
#   %input.9 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::add(%loc.1, %103, %104) # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:69:0
#   %219 : Tensor = prim::CallMethod[name="forward"](%203, %input.9)
#   %input.13 : Float(1000, 20, strides=[20, 1], requires_grad=1, device=cpu) = aten::relu(%219) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1298:0
#   %220 : Tensor = prim::CallMethod[name="forward"](%204, %input.13)
#   %221 : Tensor = prim::CallMethod[name="forward"](%207, %220)
#   %input : Float(1000, 784, strides=[784, 1], requires_grad=1, device=cpu) = aten::sigmoid(%221) # <ipython-input-8-c797bd6570ac>:60:0
#   %127 : NoneType = prim::Constant()
#   %128 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2893:0
#   %e1 : Float(requires_grad=1, device=cpu) = aten::binary_cross_entropy(%input, %x0, %127, %128) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2893:0
#   %130 : int = prim::Constant[value=6]() # <ipython-input-8-c797bd6570ac>:69:0
#   %131 : int = prim::Constant[value=0]() # <ipython-input-8-c797bd6570ac>:69:0
#   %132 : Device = prim::Constant[value="cpu"]() # <ipython-input-8-c797bd6570ac>:69:0
#   %133 : bool = prim::Constant[value=0]() # <ipython-input-8-c797bd6570ac>:69:0
#   %134 : NoneType = prim::Constant()
#   %135 : Float(1000, 10, strides=[10, 1], requires_grad=0, device=cpu) = aten::zeros_like(%loc.1, %130, %131, %132, %133, %134) # <ipython-input-8-c797bd6570ac>:69:0
#   %136 : int = prim::Constant[value=6]() # <ipython-input-8-c797bd6570ac>:69:0
#   %137 : int = prim::Constant[value=0]() # <ipython-input-8-c797bd6570ac>:69:0
#   %138 : Device = prim::Constant[value="cpu"]() # <ipython-input-8-c797bd6570ac>:69:0
#   %139 : bool = prim::Constant[value=0]() # <ipython-input-8-c797bd6570ac>:69:0
#   %140 : NoneType = prim::Constant()
#   %141 : Float(1000, 10, strides=[10, 1], requires_grad=0, device=cpu) = aten::ones_like(%value.1, %136, %137, %138, %139, %140) # <ipython-input-8-c797bd6570ac>:69:0
#   %142 : Tensor[] = prim::ListConstruct(%135, %141)
#   %143 : Tensor[] = aten::broadcast_tensors(%142) # /usr/local/lib/python3.7/dist-packages/torch/functional.py:73:0
#   %loc : Float(1000, 10, strides=[10, 1], requires_grad=0, device=cpu), %value : Float(1000, 10, strides=[10, 1], requires_grad=0, device=cpu) = prim::ListUnpack(%143)
#   %157 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::div(%value.1, %value) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:407:0
#   %158 : int = prim::Constant[value=2]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:407:0
#   %var_ratio : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::pow(%157, %158) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:407:0
#   %160 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %161 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::sub(%loc.1, %loc, %160) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %162 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::div(%161, %value) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %163 : int = prim::Constant[value=2]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %t1 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::pow(%162, %163) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %165 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %166 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::add(%var_ratio, %t1, %165) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %167 : Long(requires_grad=0, device=cpu) = prim::Constant[value={1}]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %168 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %169 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::sub(%166, %167, %168) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %170 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::log(%var_ratio) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %171 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %172 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::sub(%169, %170, %171) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %173 : Double(requires_grad=0, device=cpu) = prim::Constant[value={0.5}]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %174 : Float(1000, 10, strides=[10, 1], requires_grad=1, device=cpu) = aten::mul(%172, %173) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %175 : NoneType = prim::Constant()
#   %e2 : Float(requires_grad=1, device=cpu) = aten::sum(%174, %175) # <ipython-input-8-c797bd6570ac>:70:0
#   %177 : int = prim::Constant[value=1]() # <ipython-input-8-c797bd6570ac>:72:0
#   %178 : Float(requires_grad=1, device=cpu) = aten::add(%e1, %e2, %177) # <ipython-input-8-c797bd6570ac>:72:0
#   return (%178)

# %%
def generate_json( json_path, input, t ):

    model = VAE( t, x_dim=28*28, z_dim=10 )

    model.eval()
    with torch.no_grad():
        print("[SAVE]", json_path )
        GN.generate_minictorch_file( model, input, json_path )

    return model

# %%
torch.manual_seed( 1 )

project = 'vae3'
json_path = '../network/' + project +'.json'

itr = iter(dataloader_train)
x, t = itr.next()

torch.manual_seed( 1 )

#model = generate_json( json_path, x, t )

e = torch.randn( 1000, 10 )
print("eps",e)
model = generate_json( json_path, x, e )

#x.requires_grad = True

with torch.set_grad_enabled(True):
  #model.eval()
  model.train()
  output = model( x )
  print("output",output)
  output.backward()
  #print("output",output.grad)
  print("input_grad",x.grad)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# eps tensor([[-1.5256, -0.7502, -0.6540,  ..., -1.6091, -0.7121,  0.3037],
#         [-0.7773, -0.2515, -0.2223,  ..., -1.1608,  0.6995,  0.1991],
#         [ 0.8657,  0.2444, -0.6629,  ..., -1.4465,  0.0612, -0.6177],
#         ...,
#         [ 0.0112, -0.4718,  2.0793,  ..., -1.4960,  0.7010, -0.3290],
#         [ 0.2317, -1.0762,  0.1955,  ...,  0.4263,  2.1063, -1.6123],
#         [ 0.7102,  0.1944, -0.2268,  ...,  0.8306,  0.3967, -0.8857]])
# [SAVE] ../network/vae3.json
# skip: VAE/Linear[fc1]/weight/177
# skip: VAE/Linear[fc1]/weight/177
# skip: VAE/BatchNorm1d[bn1]/weight/182
# skip: VAE/BatchNorm1d[bn1]/weight/182
# skip: VAE/BatchNorm1d[bn1]/weight/182
# skip: VAE/BatchNorm1d[bn1]/weight/182
# skip: VAE/Linear[fc2_mean]/weight/185
# skip: VAE/Linear[fc2_mean]/weight/185
# skip: VAE/Linear[fc2_var]/weight/188
# skip: VAE/Linear[fc2_var]/weight/188
# skip: VAE/Linear[fc3]/weight/191
# skip: VAE/Linear[fc3]/weight/191
# skip: VAE/Linear[fc4]/weight/195
# skip: VAE/Linear[fc4]/weight/195
# output tensor(2849.7642, grad_fn=<AddBackward0>)
# input_grad None

# %%
"""
def convert_json( project, folder, model, input_x, json_path, rand_flag=0 ):

    #folder = "src"
    cpp_fname   = project + ".cpp"
    param_fname = project + "_param.cpp"
    cpp_path    = folder + "/" + cpp_fname
    param_path  = folder + "/" + param_fname
    make_path   = folder + "/" + "Makefile"

    # load json file
    print( "[JSON]", json_path )
    fp = open( json_path )
    obj = json.load( fp )

    print("input shape",input_x.shape)
    print("input",input_x)

    # save parameter file
    code1 = CV.c_param_generator( obj, model, input_x )
    if len( code1 ) > 0:
       print( "[PARAM]", param_path )
       ofparam = open( param_path, "w" )
       ofparam.write( code1 )

    # save cpp file
    print( "[CPP]  ", cpp_path )
    code2 = CV.c_code_generator( obj, model, rand_flag )

    #ofp=open(args.path+"/"+args.output,"w")
    ofp = open( cpp_path, "w" )
    ofp.write( code2 )

    # save make file
    print( "[MAKE] ", make_path )
    make_code = CV.makefile_generator( cpp_fname )

    #makefp=open(args.path+"/"+"Makefile","w")
    makefp = open( make_path, "w" )
    makefp.write( make_code )

convert_json( project, "src", model, x, json_path )"""

# %%
CV.convert_json( project, "../src", model, x, json_path )
# Out:
# [JSON] ../network/vae3.json
# param: xin  - str loop  5000  /  97999
# param: xin  - str loop  10000  /  97999
# param: xin  - str loop  15000  /  97999
# param: xin  - str loop  20000  /  97999
# param: xin  - str loop  25000  /  97999
# param: xin  - str loop  30000  /  97999
# param: xin  - str loop  35000  /  97999
# param: xin  - str loop  40000  /  97999
# param: xin  - str loop  45000  /  97999
# param: xin  - str loop  50000  /  97999
# param: xin  - str loop  55000  /  97999
# param: xin  - str loop  60000  /  97999
# param: xin  - str loop  65000  /  97999
# param: xin  - str loop  70000  /  97999
# param: xin  - str loop  75000  /  97999
# param: xin  - str loop  80000  /  97999
# param: xin  - str loop  85000  /  97999
# param: xin  - str loop  90000  /  97999
# param: xin  - str loop  95000  /  97999
# {'name': 'VAE/Linear[fc1]/weight/211', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# {'name': 'VAE/Linear[fc1]/bias/210', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# {'name': 'VAE/BatchNorm1d[bn1]/weight/220', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [17], 'sorted_id': 9}
# {'name': 'VAE/BatchNorm1d[bn1]/bias/219', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [17], 'sorted_id': 10}
# {'name': 'VAE/BatchNorm1d[bn1]/running_mean/218', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [17], 'sorted_id': 11}
# {'name': 'VAE/BatchNorm1d[bn1]/running_var/217', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [17], 'sorted_id': 12}
# {'name': 'VAE/Linear[fc2_mean]/weight/223', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [20], 'sorted_id': 18}
# {'name': 'VAE/Linear[fc2_mean]/bias/222', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [20], 'sorted_id': 19}
# {'name': 'VAE/Linear[fc2_var]/weight/226', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [23], 'sorted_id': 21}
# {'name': 'VAE/Linear[fc2_var]/bias/225', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [23], 'sorted_id': 22}
# {'name': 'VAE/Linear[fc3]/weight/229', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [60], 'sorted_id': 58}
# {'name': 'VAE/Linear[fc3]/bias/228', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [60], 'sorted_id': 59}
# {'name': 'VAE/Linear[fc4]/weight/235', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [67], 'sorted_id': 65}
# {'name': 'VAE/Linear[fc4]/bias/234', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [67], 'sorted_id': 66}
# [PARAM] ../src/vae3_param.cpp
# {'name': 'input/x0', 'op': 'IO Node', 'in': [], 'output_id': 0, 'shape': [1000, 784], 'out': [4, 71], 'sorted_id': 0}
# {'name': 'VAE/43', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': -1.0, 'out': [3], 'sorted_id': 1}
# {'name': 'VAE/44', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 784.0, 'out': [3], 'sorted_id': 2}
# {'name': 'VAE/45', 'op': 'prim::ListConstruct', 'in': [1, 2], 'output_id': 0, 'shape': [], 'out': [4], 'sorted_id': 3}
# {'name': 'VAE/input.1', 'op': 'aten::view', 'in': [0, 3], 'output_id': 0, 'shape': [1000, 784], 'out': [7], 'sorted_id': 4}
# {'name': 'VAE/Linear[fc1]/weight/211', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# VAE/Linear[fc1]/weight/211  ->  fc1_weight
# {'name': 'VAE/Linear[fc1]/bias/210', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# VAE/Linear[fc1]/bias/210  ->  fc1_bias
# {'name': 'VAE/Linear[fc1]/input.3', 'op': 'aten::linear', 'in': [4, 5, 6], 'output_id': 0, 'shape': [1000, 20], 'out': [8], 'sorted_id': 7}
# {'name': 'VAE/input.5', 'op': 'aten::relu', 'in': [7], 'output_id': 0, 'shape': [1000, 20], 'out': [17], 'sorted_id': 8}
# {'name': 'VAE/BatchNorm1d[bn1]/weight/220', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [17], 'sorted_id': 9}
# VAE/BatchNorm1d[bn1]/weight/220  ->  bn1_weight
# {'name': 'VAE/BatchNorm1d[bn1]/bias/219', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [17], 'sorted_id': 10}
# VAE/BatchNorm1d[bn1]/bias/219  ->  bn1_bias
# {'name': 'VAE/BatchNorm1d[bn1]/running_mean/218', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [17], 'sorted_id': 11}
# VAE/BatchNorm1d[bn1]/running_mean/218  ->  bn1_running_mean
# {'name': 'VAE/BatchNorm1d[bn1]/running_var/217', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [17], 'sorted_id': 12}
# VAE/BatchNorm1d[bn1]/running_var/217  ->  bn1_running_var
# {'name': 'VAE/BatchNorm1d[bn1]/216', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [17], 'sorted_id': 13}
# {'name': 'VAE/BatchNorm1d[bn1]/215', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.1, 'out': [17], 'sorted_id': 14}
# {'name': 'VAE/BatchNorm1d[bn1]/214', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1e-05, 'out': [17], 'sorted_id': 15}
# {'name': 'VAE/BatchNorm1d[bn1]/213', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [17], 'sorted_id': 16}
# {'name': 'VAE/BatchNorm1d[bn1]/input.7', 'op': 'aten::batch_norm', 'in': [8, 9, 10, 11, 12, 13, 14, 15, 16], 'output_id': 0, 'shape': [1000, 20], 'out': [20, 23], 'sorted_id': 17}
# {'name': 'VAE/Linear[fc2_mean]/weight/223', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [20], 'sorted_id': 18}
# VAE/Linear[fc2_mean]/weight/223  ->  fc2_mean_weight
# {'name': 'VAE/Linear[fc2_mean]/bias/222', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [20], 'sorted_id': 19}
# VAE/Linear[fc2_mean]/bias/222  ->  fc2_mean_bias
# {'name': 'VAE/Linear[fc2_mean]/224', 'op': 'aten::linear', 'in': [17, 18, 19], 'output_id': 0, 'shape': [1000, 10], 'out': [27], 'sorted_id': 20}
# {'name': 'VAE/Linear[fc2_var]/weight/226', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [23], 'sorted_id': 21}
# VAE/Linear[fc2_var]/weight/226  ->  fc2_var_weight
# {'name': 'VAE/Linear[fc2_var]/bias/225', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [23], 'sorted_id': 22}
# VAE/Linear[fc2_var]/bias/225  ->  fc2_var_bias
# {'name': 'VAE/Linear[fc2_var]/227', 'op': 'aten::linear', 'in': [17, 21, 22], 'output_id': 0, 'shape': [1000, 10], 'out': [25], 'sorted_id': 23}
# {'name': 'VAE/56', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.5, 'out': [25], 'sorted_id': 24}
# {'name': 'VAE/57', 'op': 'aten::mul', 'in': [23, 24], 'output_id': 0, 'shape': [1000, 10], 'out': [26], 'sorted_id': 25}
# {'name': 'VAE/58', 'op': 'aten::exp', 'in': [25], 'output_id': 0, 'shape': [1000, 10], 'out': [27], 'sorted_id': 26}
# {'name': 'VAE/59', 'op': 'prim::ListConstruct', 'in': [20, 26], 'output_id': 0, 'shape': [], 'out': [28], 'sorted_id': 27}
# {'name': 'VAE/60', 'op': 'aten::broadcast_tensors', 'in': [27], 'output_id': 0, 'shape': [], 'out': [29, 54], 'sorted_id': 28}
# {'name': 'VAE/loc.1', 'op': 'prim::ListUnpack', 'in': [28], 'output_id': 0, 'shape': [1000, 10], 'out': [57, 77, 35, 92, 31], 'sorted_id': 29}
# {'name': 'VAE/63', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [31], 'sorted_id': 30}
# {'name': 'VAE/64', 'op': 'aten::size', 'in': [29, 30], 'output_id': 0, 'shape': [], 'out': [32], 'sorted_id': 31}
# {'name': 'VAE/65', 'op': 'prim::NumToTensor', 'in': [31], 'output_id': 0, 'shape': [], 'out': [33, 44], 'sorted_id': 32}
# {'name': 'VAE/74', 'op': 'aten::Int', 'in': [32], 'output_id': 0, 'shape': [], 'out': [38], 'sorted_id': 33}
# {'name': 'VAE/66', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [35], 'sorted_id': 34}
# {'name': 'VAE/67', 'op': 'aten::size', 'in': [29, 34], 'output_id': 0, 'shape': [], 'out': [36], 'sorted_id': 35}
# {'name': 'VAE/68', 'op': 'prim::NumToTensor', 'in': [35], 'output_id': 0, 'shape': [], 'out': [37, 45], 'sorted_id': 36}
# {'name': 'VAE/75', 'op': 'aten::Int', 'in': [36], 'output_id': 0, 'shape': [], 'out': [38], 'sorted_id': 37}
# {'name': 'VAE/76', 'op': 'prim::ListConstruct', 'in': [33, 37], 'output_id': 0, 'shape': [], 'out': [43], 'sorted_id': 38}
# {'name': 'VAE/77', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [43], 'sorted_id': 39}
# {'name': 'VAE/78', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [43], 'sorted_id': 40}
# {'name': 'VAE/79', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [43], 'sorted_id': 41}
# {'name': 'VAE/80', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [43], 'sorted_id': 42}
# {'name': 'VAE/81', 'op': 'aten::zeros', 'in': [38, 39, 40, 41, 42], 'output_id': 0, 'shape': [1000, 10], 'out': [53], 'sorted_id': 43}
# {'name': 'VAE/82', 'op': 'aten::Int', 'in': [32], 'output_id': 0, 'shape': [], 'out': [46], 'sorted_id': 44}
# {'name': 'VAE/83', 'op': 'aten::Int', 'in': [36], 'output_id': 0, 'shape': [], 'out': [46], 'sorted_id': 45}
# {'name': 'VAE/84', 'op': 'prim::ListConstruct', 'in': [44, 45], 'output_id': 0, 'shape': [], 'out': [51], 'sorted_id': 46}
# {'name': 'VAE/85', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [51], 'sorted_id': 47}
# {'name': 'VAE/86', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [51], 'sorted_id': 48}
# {'name': 'VAE/87', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [51], 'sorted_id': 49}
# {'name': 'VAE/88', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [51], 'sorted_id': 50}
# {'name': 'VAE/89', 'op': 'aten::ones', 'in': [46, 47, 48, 49, 50], 'output_id': 0, 'shape': [1000, 10], 'out': [53], 'sorted_id': 51}
# {'name': 'VAE/90', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [53], 'sorted_id': 52}
# {'name': 'VAE/eps', 'op': 'aten::normal', 'in': [43, 51, 52], 'output_id': 0, 'shape': [1000, 10], 'out': [55], 'sorted_id': 53}
# {'name': 'VAE/value.1', 'op': 'prim::ListUnpack', 'in': [28], 'output_id': 1, 'shape': [1000, 10], 'out': [87, 83, 55], 'sorted_id': 54}
# {'name': 'VAE/92', 'op': 'aten::mul', 'in': [53, 54], 'output_id': 0, 'shape': [1000, 10], 'out': [57], 'sorted_id': 55}
# {'name': 'VAE/93', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [57], 'sorted_id': 56}
# {'name': 'VAE/input.9', 'op': 'aten::add', 'in': [29, 55, 56], 'output_id': 0, 'shape': [1000, 10], 'out': [60], 'sorted_id': 57}
# {'name': 'VAE/Linear[fc3]/weight/229', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [60], 'sorted_id': 58}
# VAE/Linear[fc3]/weight/229  ->  fc3_weight
# {'name': 'VAE/Linear[fc3]/bias/228', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [60], 'sorted_id': 59}
# VAE/Linear[fc3]/bias/228  ->  fc3_bias
# {'name': 'VAE/Linear[fc3]/input.11', 'op': 'aten::linear', 'in': [57, 58, 59], 'output_id': 0, 'shape': [1000, 20], 'out': [61], 'sorted_id': 60}
# {'name': 'VAE/input.13', 'op': 'aten::relu', 'in': [60], 'output_id': 0, 'shape': [1000, 20], 'out': [64], 'sorted_id': 61}
# {'name': 'VAE/Dropout[drop1]/232', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.2, 'out': [64], 'sorted_id': 62}
# {'name': 'VAE/Dropout[drop1]/231', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [64], 'sorted_id': 63}
# {'name': 'VAE/Dropout[drop1]/input.15', 'op': 'aten::dropout', 'in': [61, 62, 63], 'output_id': 0, 'shape': [1000, 20], 'out': [67], 'sorted_id': 64}
# {'name': 'VAE/Linear[fc4]/weight/235', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [67], 'sorted_id': 65}
# VAE/Linear[fc4]/weight/235  ->  fc4_weight
# {'name': 'VAE/Linear[fc4]/bias/234', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [67], 'sorted_id': 66}
# VAE/Linear[fc4]/bias/234  ->  fc4_bias
# {'name': 'VAE/Linear[fc4]/236', 'op': 'aten::linear', 'in': [64, 65, 66], 'output_id': 0, 'shape': [1000, 784], 'out': [68], 'sorted_id': 67}
# {'name': 'VAE/input', 'op': 'aten::sigmoid', 'in': [67], 'output_id': 0, 'shape': [1000, 784], 'out': [71], 'sorted_id': 68}
# {'name': 'VAE/116', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [71], 'sorted_id': 69}
# {'name': 'VAE/117', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [71], 'sorted_id': 70}
# {'name': 'VAE/e1', 'op': 'aten::binary_cross_entropy', 'in': [68, 0, 69, 70], 'output_id': 0, 'shape': [], 'out': [109], 'sorted_id': 71}
# {'name': 'VAE/119', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [77], 'sorted_id': 72}
# {'name': 'VAE/120', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [77], 'sorted_id': 73}
# {'name': 'VAE/121', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [77], 'sorted_id': 74}
# {'name': 'VAE/122', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [77], 'sorted_id': 75}
# {'name': 'VAE/123', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [77], 'sorted_id': 76}
# {'name': 'VAE/124', 'op': 'aten::zeros_like', 'in': [29, 72, 73, 74, 75, 76], 'output_id': 0, 'shape': [1000, 10], 'out': [84], 'sorted_id': 77}
# {'name': 'VAE/125', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [83], 'sorted_id': 78}
# {'name': 'VAE/126', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [83], 'sorted_id': 79}
# {'name': 'VAE/127', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [83], 'sorted_id': 80}
# {'name': 'VAE/128', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [83], 'sorted_id': 81}
# {'name': 'VAE/129', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [83], 'sorted_id': 82}
# {'name': 'VAE/130', 'op': 'aten::ones_like', 'in': [54, 78, 79, 80, 81, 82], 'output_id': 0, 'shape': [1000, 10], 'out': [84], 'sorted_id': 83}
# {'name': 'VAE/131', 'op': 'prim::ListConstruct', 'in': [77, 83], 'output_id': 0, 'shape': [], 'out': [85], 'sorted_id': 84}
# {'name': 'VAE/132', 'op': 'aten::broadcast_tensors', 'in': [84], 'output_id': 0, 'shape': [], 'out': [86, 90], 'sorted_id': 85}
# {'name': 'VAE/value', 'op': 'prim::ListUnpack', 'in': [85], 'output_id': 1, 'shape': [1000, 10], 'out': [93, 87], 'sorted_id': 86}
# {'name': 'VAE/146', 'op': 'aten::div', 'in': [54, 86], 'output_id': 0, 'shape': [1000, 10], 'out': [89], 'sorted_id': 87}
# {'name': 'VAE/147', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 2.0, 'out': [89], 'sorted_id': 88}
# {'name': 'VAE/var_ratio', 'op': 'aten::pow', 'in': [87, 88], 'output_id': 0, 'shape': [1000, 10], 'out': [97, 101], 'sorted_id': 89}
# {'name': 'VAE/loc', 'op': 'prim::ListUnpack', 'in': [85], 'output_id': 0, 'shape': [1000, 10], 'out': [92], 'sorted_id': 90}
# {'name': 'VAE/149', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [92], 'sorted_id': 91}
# {'name': 'VAE/150', 'op': 'aten::sub', 'in': [29, 90, 91], 'output_id': 0, 'shape': [1000, 10], 'out': [93], 'sorted_id': 92}
# {'name': 'VAE/151', 'op': 'aten::div', 'in': [92, 86], 'output_id': 0, 'shape': [1000, 10], 'out': [95], 'sorted_id': 93}
# {'name': 'VAE/152', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 2.0, 'out': [95], 'sorted_id': 94}
# {'name': 'VAE/t1', 'op': 'aten::pow', 'in': [93, 94], 'output_id': 0, 'shape': [1000, 10], 'out': [97], 'sorted_id': 95}
# {'name': 'VAE/154', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [97], 'sorted_id': 96}
# {'name': 'VAE/155', 'op': 'aten::add', 'in': [89, 95, 96], 'output_id': 0, 'shape': [1000, 10], 'out': [100], 'sorted_id': 97}
# {'name': 'VAE/156', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [100], 'sorted_id': 98}
# {'name': 'VAE/157', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [100], 'sorted_id': 99}
# {'name': 'VAE/158', 'op': 'aten::sub', 'in': [97, 98, 99], 'output_id': 0, 'shape': [1000, 10], 'out': [103], 'sorted_id': 100}
# {'name': 'VAE/159', 'op': 'aten::log', 'in': [89], 'output_id': 0, 'shape': [1000, 10], 'out': [103], 'sorted_id': 101}
# {'name': 'VAE/160', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [103], 'sorted_id': 102}
# {'name': 'VAE/161', 'op': 'aten::sub', 'in': [100, 101, 102], 'output_id': 0, 'shape': [1000, 10], 'out': [105], 'sorted_id': 103}
# {'name': 'VAE/162', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.5, 'out': [105], 'sorted_id': 104}
# {'name': 'VAE/163', 'op': 'aten::mul', 'in': [103, 104], 'output_id': 0, 'shape': [1000, 10], 'out': [107], 'sorted_id': 105}
# {'name': 'VAE/164', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [107], 'sorted_id': 106}
# {'name': 'VAE/e2', 'op': 'aten::sum', 'in': [105, 106], 'output_id': 0, 'shape': [], 'out': [109], 'sorted_id': 107}
# {'name': 'VAE/166', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [109], 'sorted_id': 108}
# {'name': 'VAE/167', 'op': 'aten::add', 'in': [71, 107, 108], 'output_id': 0, 'shape': [], 'out': [110], 'sorted_id': 109}
# {'name': 'output/output.1', 'op': 'IO Node', 'in': [109], 'output_id': 0, 'shape': [], 'out': [], 'sorted_id': 110}
# [CPP]  ../src/vae3.cpp
# [MAKE] ../src/Makefile

# %%
# !g++ -std=c++14 ../src/vae3.cpp ../src/vae3_param.cpp  -I ../../../xtensor -lcblas -o ../bin/vae3

# %% [markdown]
# (注意) xtensorにxtensor関連のincludeを置いています。各自の環境に合わせて変更して下さい。

# %%
# !../bin/vae3
# Out:
# ### forward computation ...
# ndim=2
# { 2849.754395}
# ### backward computation ...
# input_grad{{-0.213298,  0.093343,  0.278396, ..., -0.041569,  0.156434, -0.147534},
#  { 0.075242,  0.074864,  0.075545, ..., -0.070674,  0.093789,  0.091534},
#  {-0.245654,  0.425683,  0.023375, ..., -0.074347, -0.078207,  0.111524},
#  ...,
#  {-0.08386 ,  0.088923,  0.00665 , ..., -0.045123,  0.000524,  0.017924},
#  {-0.17629 ,  0.145098, -0.061603, ...,  0.09536 , -0.144651,  0.082908},
#  { 0.450589, -0.301483, -0.302051, ..., -0.483272, -0.520281,  0.51357 }}

# %% [markdown]
# 以下、未完

# %%
torch.manual_seed( 1 )

project = 'vae3'

x = x_train.clone().detach()
torch.reshape( x, (-1,n_in) )

n_batch = 32 # 1792

x = x[0:n_batch,:]
#print(type(x))
#print(x.shape)
x.requires_grad = True

e = torch.randn( n_batch, 2 )
#print("eps",e)

net = Net( n_in, n_mid, n_out, n_z, e )
net.train()

lr=0.001
opt = torch.optim.SGD(net.parameters(), lr)
#mse = torch.nn.MSELoss()

epoch_loss = []
epoch_num = 5000; #201
for epoch in range(epoch_num):

  loss = net( x )

  print("loss",loss)

  opt.zero_grad()
  loss.backward()
  #print("output",output.grad)

  opt.step()
  print("EPOCH: {} loss: {}".format(epoch, loss))
  epoch_loss.append( loss )

# %% [markdown]
# 学習の収束の図化 (python)

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %%
n_img2=10
x2=x[:n_img2]

o = net.out.to('cpu').detach().numpy().copy()

plt.figure( figsize=(10,2))
for i in range(n_img2):
  #input image
  ax = plt.subplot(3,n_img2,i+1)
  plt.imshow( x2[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  #output image
  ax = plt.subplot(3,n_img2,i+1+n_img2)
  plt.imshow( o[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %%
t2 = t_train[:n_batch]

plt.figure(figsize=(8,8))
for i in range(10):
  zt = net.z[t2==i]
  z_1 = zt[:,0]
  z_2 = zt[:,1]
  marker= "$"+str(i)+"$"
  plt.scatter(z_2.tolist(), z_1.tolist(), marker=marker,s=75)

plt.xlabel("z_2")
plt.ylabel("z_1")
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid()
plt.show()

# %%
n_img3=16
img_size_spaced = img_size + 2
matrix_image = np.zeros(( img_size_spaced*n_img3, img_size_spaced*n_img3 ))

z_1 = np.linspace( 3, -3, n_img3 )
z_2 = np.linspace( 3, -3, n_img3 )

with torch.set_grad_enabled(False):
  for i, z1 in enumerate(z_1):
    for j,z2 in enumerate(z_2):

      z = np.array([z1, z2])
      zz = torch.from_numpy( z ).float()
      
      y = F.relu( net.fc3(zz) )
      o = torch.sigmoid( net.fc4(y) )
      image = o.reshape(img_size, img_size)
      top  = i * img_size_spaced
      left = j * img_size_spaced
      matrix_image[top:top+img_size, left:left+img_size] = image

plt.figure(figsize=(8,8))
plt.imshow( matrix_image.tolist(), cmap="Greys_r" )
plt.tick_params( labelbottom=False, labelleft=False, bottom=False, left=False )
plt.show()

# %% [markdown]
# 最適化実行

# %% [markdown]
# 全入力データを vae1_data.cpp に出力する

# %%
def output_datafile( folder, project, in_data ):
    data_fname = project + "_data.cpp"
    data_path  = folder + "/" + data_fname

    # save data file
    code = CV.c_data_generator( in_data )
    if len( code ) > 0:
       print( "[DATA]", data_path )
       ofparam = open( data_path, "w" )
       ofparam.write( code )

output_datafile( "src", project, dd )
# Out:
# [DATA] src/vae1_data.cpp

# %%
# !g++ -std=c++14 ./src/vae1_opt.cpp ./src/vae1_param.cpp  ./src/vae1_data.cpp  -I ./lib -lcblas -o ./bin/vae1_opt

# %%
# !./bin/vae1_opt

# %% [markdown]
# c++ からの出力ファイルの読み込み

# %%
#load out file
f = open('./vae1.out', 'r')

epoch_loss = []
datalist = f.readlines()
for data in datalist:
  #print(data)
  epoch_loss.append( float(data) )

f.close()

print("epoch =", len(epoch_loss))
print( epoch_loss)

# load pred file
f2 = open('vae1.pred', 'r')

datalist = f2.readlines()

n1 = 10
n2 = 64
k = 0
for data in datalist:
  ds = data.split(',')
  if k==0:
    n1 = int(ds[0])
    n2 = int(ds[1])
    global v_pred
    v_pred = np.zeros( (n1,n2))
  else:
    for i in range(n2):
      v_pred[k-1,i] = float(ds[i])
  k = k+1

f2.close()

print("pred =", n1,n2 )
#print( y_pred )

# load z file
f3 = open('vae1.z', 'r')

datalist = f3.readlines()
n1 = 100
n2 = 2
k = 0
for data in datalist:
  ds = data.split(',')
  if k==0:
    nz1 = int(ds[0])
    nz2 = int(ds[1])
    z_pred = np.zeros( (nz1,nz2))
  else:
    z_pred[k-1,0] = float(ds[0])
    z_pred[k-1,1] = float(ds[1])
  k = k+1

f3.close()

print("z =", nz1,nz2 )
#print(z_pred)
# Out:
# epoch = 200
# [33.315163, 29.588335, 28.864582, 28.606874, 28.399221, 28.196524, 28.112505, 27.971659, 27.893692, 27.743196, 27.667107, 27.463993, 27.312462, 27.131021, 26.991722, 26.916931, 26.820826, 26.766125, 26.719814, 26.643881, 26.562258, 26.530371, 26.381765, 26.348427, 26.247, 26.206261, 26.074146, 26.01207, 25.915354, 25.825443, 25.789684, 25.73243, 25.681158, 25.596586, 25.59939, 25.504528, 25.552197, 25.476049, 25.487141, 25.430082, 25.386908, 25.368185, 25.426172, 25.372349, 25.319706, 25.368671, 25.2885, 25.297209, 25.240149, 25.268908, 25.263052, 25.249092, 25.244768, 25.199209, 25.200945, 25.177311, 25.178787, 25.208733, 25.133116, 25.14896, 25.134329, 25.100975, 25.088497, 25.06917, 25.017958, 25.077044, 24.987011, 24.995789, 24.962414, 24.969925, 24.969854, 24.992798, 25.016535, 24.978632, 24.912752, 24.906364, 24.89068, 25.001881, 24.921247, 24.864115, 24.793262, 24.843008, 24.793819, 24.725113, 24.733715, 24.677114, 24.653231, 24.744532, 24.675917, 24.748131, 24.660444, 24.593372, 24.619499, 24.574203, 24.607534, 24.532194, 24.522036, 24.551098, 24.579596, 24.507343, 24.470636, 24.517673, 24.448736, 24.484411, 24.402483, 24.465029, 24.457096, 24.40391, 24.400007, 24.424862, 24.407576, 24.39806, 24.401407, 24.403807, 24.397408, 24.376724, 24.398626, 24.393099, 24.37656, 24.307018, 24.390856, 24.330894, 24.360329, 24.34416, 24.346897, 24.36034, 24.292782, 24.397715, 24.315985, 24.345535, 24.269131, 24.311544, 24.338606, 24.233688, 24.287987, 24.318197, 24.285587, 24.291986, 24.30197, 24.274052, 24.313921, 24.312073, 24.235132, 24.302488, 24.224588, 24.211945, 24.275396, 24.386234, 24.202124, 24.270226, 24.237055, 24.270016, 24.253262, 24.24678, 24.193449, 24.265184, 24.229855, 24.236362, 24.277729, 24.188421, 24.170517, 24.244736, 24.273596, 24.18359, 24.187487, 24.244764, 24.233372, 24.148352, 24.150372, 24.203941, 24.1786, 24.134375, 24.224047, 24.195965, 24.152401, 24.194818, 24.176741, 24.162062, 24.179214, 24.171041, 24.196543, 24.153149, 24.154221, 24.168444, 24.165615, 24.08419, 24.127739, 24.122755, 24.147953, 24.116945, 24.155815, 24.221359, 24.08577, 24.19202, 24.18874, 24.178465, 24.094398, 24.09944, 24.115948, 24.108459]
# pred = 10 64
# z = 1797 2

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %%
n_img5 = 10
x2 = x[:n_img5]

plt.figure( figsize=(10,2))
for i in range(n_img5):
  # input image
  ax = plt.subplot(3,n_img5,i+1)
  plt.imshow( x2[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # output image
  ax = plt.subplot(3,n_img5,i+1+n_img5)
  plt.imshow( v_pred[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %%
t2 = t_train #[:n_batch]

plt.figure(figsize=(8,8))
for i in range(10):
  zt = z_pred[t2==i]
  z_1 = zt[:,0]
  z_2 = zt[:,1]
  marker= "$"+str(i)+"$"
  plt.scatter( z_2.tolist(),  z_1.tolist(), marker=marker,s=75 )

plt.xlabel("z_2")
plt.ylabel("z_1")
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid()
plt.show()

# %%
import torch.distributions as tdist

n = tdist.Normal(torch.tensor([0.0]), torch.tensor([1.0]))

e = n.sample((n_mid,))

# %%
e2= torch.randn(n_mid)
print(e2)
# Out:
# tensor([ 1.4625,  0.0852,  0.2403, -0.7425, -1.1566, -1.9472, -0.0739,  1.4408,
#         -1.5811,  0.1749,  1.1583,  0.6945, -0.4813, -0.2892,  1.3323, -0.9172])
