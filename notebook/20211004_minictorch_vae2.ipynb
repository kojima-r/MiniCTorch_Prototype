# %% [markdown]
# vae2　オートエンコーダー
#
# 参考文献　我妻幸長　「はじめてのディープラーニング２」

# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# フォルダは自分の指定のものに変更して下さい。

# %%
# %cd "ctorch210929/MiniCTorch_Prototype/notebook"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch210929/MiniCTorch_Prototype/notebook

# %%
! pip install lark-parser
# Out:
# Collecting lark-parser
#   Downloading lark_parser-0.12.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 6.3 MB/s
# Installing collected packages: lark-parser
# Successfully installed lark-parser-0.12.0

# %%
import sys
sys.path.append("../")

import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import minictorch.generator as GN
import minictorch.converter as CV

# %% [markdown]
# サンプルデータ

# %%
import torch.utils as utils
from torchvision import datasets, transforms
from sklearn import datasets

img_size = 8
n_in = img_size * img_size
n_mid = 16
n_out = n_in
n_z = 2
n_batch = 32

digits_data = datasets.load_digits()
dd = np.asarray( digits_data.data, dtype=np.float32 )
dd /= 15
x_train = torch.from_numpy( dd ).clone()
t_train = digits_data.target
print(len(x_train))
# Out:
# 1797

# %% [markdown]
# サンプルデータの図化

# %%
import matplotlib.pyplot as plt
n_img = 16

plt.figure( figsize=(16,3))
for i in range(n_img):
  ax = plt.subplot(3,n_img,i+1)
  plt.imshow(dd[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %% [markdown]
# ニューラルネットワークの定義

# %%
def mean_squared_error( x0, x1 ):
    diff = x0 - x1
    y = (diff**2).sum() / len(diff)
    return y;

def reconstruction( y, t ):
  eps = 1.0e-7
  e = t * torch.log(y+eps) + (1-t) * torch.log(1-y+eps) 
  z = e.sum() / len(y)
  return z;

def kl_divergence( mean, log_var ):
  g = 1 + log_var - mean**2 - torch.exp( log_var )
  y = 0.5 * g.sum() / len(mean)
  return y

import torch.distributions as td

class Net(torch.nn.Module):
  def __init__( self, n_in, n_mid, n_out, n_z, e ):
    super(Net, self).__init__()
    self.fc1 = nn.Linear(n_in, n_mid)
    self.fc2_mean = nn.Linear(n_mid, n_z)
    self.fc2_var  = nn.Linear(n_mid, n_z)
    self.fc3 = nn.Linear(n_z  ,n_mid)
    self.fc4 = nn.Linear(n_mid,n_out)
    self.eps = e

    nn.init.constant_(self.fc1.bias,0)
    nn.init.constant_(self.fc2_mean.bias,0)
    nn.init.constant_(self.fc2_var.bias,0)
    nn.init.constant_(self.fc3.bias,0)
    nn.init.constant_(self.fc4.bias,0)

    #self.bce1 = nn.BCELoss()
  
  def forward( self, x ):
    # encoder
    x2 = F.relu( self.fc1(x) )
    self.mean    = self.fc2_mean(x2)
    self.log_var = self.fc2_var(x2)

    # reparametrization
    #eps = torch.randn( self.mean.shape )
    #nm = td.Normal( 0.0, 1.0 ) #torch.tensor([0.0]), torch.tensor([1.0]))
    #eps = nm.sample([ n_batch, n_z ])
    #eps = torch.normal( 0.0,1.0,[32,2] )
    #print("eps",eps)
    #self.z = self.mean + eps * torch.exp( 0.5 * self.log_var )
    #self.z = self.mean + self.eps * torch.exp( 0.5 * self.log_var )

    self.std = torch.exp( 0.5 * self.log_var )
    q_z = td.normal.Normal( self.mean, self.std )
    self.z = q_z.rsample()

    # decoder
    y = F.relu( self.fc3(self.z) )
    y = torch.sigmoid( self.fc4(y) )
    ##return y
    self.out = y
    
    # vae1
    #e1 = reconstruction( y, x )
    #e2 = kl_divergence( self.mean, self.log_var )
    #return -(e1+e2)

    e1 = F.binary_cross_entropy( y , x, reduction="mean" )
    #e1 = self.bce1(y, x)
    p_z = td.normal.Normal( torch.zeros_like(q_z.loc), torch.ones_like(q_z.scale) )
    e2  = td.kl_divergence( q_z, p_z ).sum()
    #print("e1,e2",e1,e2)

    self.loss1 = e1
    self.loss2 = e2
    return (e1+e2)

# %%
def test(x,e):
  model = Net( n_in, n_mid, n_out, n_z, e )

  trace = torch.jit.trace(model, x, strict=True)
  print(trace.graph)

x = x_train.clone().detach()
torch.reshape( x, (-1,n_in) )

x = x[0:n_batch,:]

e = torch.randn( n_batch, 2 )

test(x,e)
# Out:
# graph(%self.1 : __torch__.Net,
#       %x : Float(32, 64, strides=[64, 1], requires_grad=0, device=cpu)):
#   %161 : __torch__.torch.nn.modules.linear.___torch_mangle_3.Linear = prim::GetAttr[name="fc4"](%self.1)
#   %158 : __torch__.torch.nn.modules.linear.___torch_mangle_2.Linear = prim::GetAttr[name="fc3"](%self.1)
#   %155 : __torch__.torch.nn.modules.linear.___torch_mangle_1.Linear = prim::GetAttr[name="fc2_var"](%self.1)
#   %152 : __torch__.torch.nn.modules.linear.___torch_mangle_0.Linear = prim::GetAttr[name="fc2_mean"](%self.1)
#   %149 : __torch__.torch.nn.modules.linear.Linear = prim::GetAttr[name="fc1"](%self.1)
#   %167 : Tensor = prim::CallMethod[name="forward"](%149, %x)
#   %input.3 : Float(32, 16, strides=[16, 1], requires_grad=1, device=cpu) = aten::relu(%167) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1298:0
#   %168 : Tensor = prim::CallMethod[name="forward"](%152, %input.3)
#   %169 : Tensor = prim::CallMethod[name="forward"](%155, %input.3)
#   %33 : Double(requires_grad=0, device=cpu) = prim::Constant[value={0.5}]() # <ipython-input-9-73e3ea54ff9f>:52:0
#   %34 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::mul(%169, %33) # <ipython-input-9-73e3ea54ff9f>:52:0
#   %35 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::exp(%34) # <ipython-input-9-73e3ea54ff9f>:52:0
#   %36 : Tensor[] = prim::ListConstruct(%168, %35)
#   %37 : Tensor[] = aten::broadcast_tensors(%36) # /usr/local/lib/python3.7/dist-packages/torch/functional.py:73:0
#   %loc.1 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu), %value.1 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = prim::ListUnpack(%37)
#   %40 : int = prim::Constant[value=0]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:49:0
#   %41 : int = aten::size(%loc.1, %40) # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:49:0
#   %42 : Long(device=cpu) = prim::NumToTensor(%41)
#   %59 : int = aten::Int(%42)
#   %51 : int = aten::Int(%42)
#   %43 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:49:0
#   %44 : int = aten::size(%loc.1, %43) # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:49:0
#   %45 : Long(device=cpu) = prim::NumToTensor(%44)
#   %60 : int = aten::Int(%45)
#   %52 : int = aten::Int(%45)
#   %53 : int[] = prim::ListConstruct(%51, %52)
#   %54 : int = prim::Constant[value=6]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:46:0
#   %55 : NoneType = prim::Constant()
#   %56 : Device = prim::Constant[value="cpu"]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:46:0
#   %57 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:46:0
#   %58 : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = aten::zeros(%53, %54, %55, %56, %57) # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:46:0
#   %61 : int[] = prim::ListConstruct(%59, %60)
#   %62 : int = prim::Constant[value=6]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %63 : NoneType = prim::Constant()
#   %64 : Device = prim::Constant[value="cpu"]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %65 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %66 : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = aten::ones(%61, %62, %63, %64, %65) # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %67 : NoneType = prim::Constant()
#   %eps : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = aten::normal(%58, %66, %67) # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
#   %69 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::mul(%eps, %value.1) # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:69:0
#   %70 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:69:0
#   %input.5 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::add(%loc.1, %69, %70) # /usr/local/lib/python3.7/dist-packages/torch/distributions/normal.py:69:0
#   %170 : Tensor = prim::CallMethod[name="forward"](%158, %input.5)
#   %input.9 : Float(32, 16, strides=[16, 1], requires_grad=1, device=cpu) = aten::relu(%170) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1298:0
#   %171 : Tensor = prim::CallMethod[name="forward"](%161, %input.9)
#   %input : Float(32, 64, strides=[64, 1], requires_grad=1, device=cpu) = aten::sigmoid(%171) # <ipython-input-9-73e3ea54ff9f>:58:0
#   %90 : NoneType = prim::Constant()
#   %91 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2893:0
#   %e1 : Float(requires_grad=1, device=cpu) = aten::binary_cross_entropy(%input, %x, %90, %91) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2893:0
#   %93 : int = prim::Constant[value=6]() # <ipython-input-9-73e3ea54ff9f>:69:0
#   %94 : int = prim::Constant[value=0]() # <ipython-input-9-73e3ea54ff9f>:69:0
#   %95 : Device = prim::Constant[value="cpu"]() # <ipython-input-9-73e3ea54ff9f>:69:0
#   %96 : bool = prim::Constant[value=0]() # <ipython-input-9-73e3ea54ff9f>:69:0
#   %97 : NoneType = prim::Constant()
#   %98 : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = aten::zeros_like(%loc.1, %93, %94, %95, %96, %97) # <ipython-input-9-73e3ea54ff9f>:69:0
#   %99 : int = prim::Constant[value=6]() # <ipython-input-9-73e3ea54ff9f>:69:0
#   %100 : int = prim::Constant[value=0]() # <ipython-input-9-73e3ea54ff9f>:69:0
#   %101 : Device = prim::Constant[value="cpu"]() # <ipython-input-9-73e3ea54ff9f>:69:0
#   %102 : bool = prim::Constant[value=0]() # <ipython-input-9-73e3ea54ff9f>:69:0
#   %103 : NoneType = prim::Constant()
#   %104 : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = aten::ones_like(%value.1, %99, %100, %101, %102, %103) # <ipython-input-9-73e3ea54ff9f>:69:0
#   %105 : Tensor[] = prim::ListConstruct(%98, %104)
#   %106 : Tensor[] = aten::broadcast_tensors(%105) # /usr/local/lib/python3.7/dist-packages/torch/functional.py:73:0
#   %loc : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu), %value : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = prim::ListUnpack(%106)
#   %120 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::div(%value.1, %value) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:407:0
#   %121 : int = prim::Constant[value=2]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:407:0
#   %var_ratio : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::pow(%120, %121) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:407:0
#   %123 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %124 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::sub(%loc.1, %loc, %123) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %125 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::div(%124, %value) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %126 : int = prim::Constant[value=2]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %t1 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::pow(%125, %126) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:408:0
#   %128 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %129 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::add(%var_ratio, %t1, %128) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %130 : Long(requires_grad=0, device=cpu) = prim::Constant[value={1}]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %131 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %132 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::sub(%129, %130, %131) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %133 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::log(%var_ratio) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %134 : int = prim::Constant[value=1]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %135 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::sub(%132, %133, %134) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %136 : Double(requires_grad=0, device=cpu) = prim::Constant[value={0.5}]() # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %137 : Float(32, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::mul(%135, %136) # /usr/local/lib/python3.7/dist-packages/torch/distributions/kl.py:409:0
#   %138 : NoneType = prim::Constant()
#   %e2 : Float(requires_grad=1, device=cpu) = aten::sum(%137, %138) # <ipython-input-9-73e3ea54ff9f>:70:0
#   %140 : int = prim::Constant[value=1]() # <ipython-input-9-73e3ea54ff9f>:75:0
#   %141 : Float(requires_grad=1, device=cpu) = aten::add(%e1, %e2, %140) # <ipython-input-9-73e3ea54ff9f>:75:0
#   return (%141)
# /usr/local/lib/python3.7/dist-packages/torch/jit/_trace.py:985: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%eps : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = aten::normal(%58, %66, %67) # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _module_class,
# /usr/local/lib/python3.7/dist-packages/torch/jit/_trace.py:985: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# With rtol=1e-05 and atol=1e-05, found 1 element(s) (out of 1) whose difference(s) exceeded the margin of error (including 0 nan comparisons). The greatest difference was 0.004278659820556641 (2.2170138359069824 vs. 2.212735176086426), which occurred at index 0.
#   _module_class,

# %%
def generate_json( json_path, input, e ):

    model = Net( n_in, n_mid, n_out, n_z, e )

    model.eval()
    with torch.no_grad():
        print("[SAVE]", json_path )
        GN.generate_minictorch_file( model, input, json_path )

    return model

# %%
torch.manual_seed( 1 )

project = 'vae2'
json_path = '../network/' + project +'.json'

x = x_train.clone().detach()
torch.reshape( x, (-1,n_in) )

x = x[0:n_batch,:]
#print(type(x))
print(x.shape)
#x.requires_grad = True

e = torch.randn( n_batch, 2 )
#print("eps",e)

model = generate_json( json_path, x, e )

#x.requires_grad = True

with torch.set_grad_enabled(True):
  model.eval()
  output = model( x )
  print("output",output)
  output.backward()
  #print("output",output.grad)
  print("loss1",model.loss1)
  print("loss2",model.loss2)
  print("input_grad",x.grad)
# Out:
# torch.Size([32, 64])
# [SAVE] ../network/vae2.json
# skip: Net/Linear[fc1]/weight/149
# skip: Net/Linear[fc1]/weight/149
# skip: Net/Linear[fc2_mean]/weight/152
# skip: Net/Linear[fc2_mean]/weight/152
# skip: Net/Linear[fc2_var]/weight/155
# skip: Net/Linear[fc2_var]/weight/155
# skip: Net/Linear[fc3]/weight/158
# skip: Net/Linear[fc3]/weight/158
# skip: Net/Linear[fc4]/weight/161
# skip: Net/Linear[fc4]/weight/161
# /usr/local/lib/python3.7/dist-packages/torch/jit/_trace.py:985: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%eps : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = aten::normal(%58, %66, %67) # /usr/local/lib/python3.7/dist-packages/torch/distributions/utils.py:47:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _module_class,
# /usr/local/lib/python3.7/dist-packages/torch/jit/_trace.py:985: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# With rtol=1e-05 and atol=1e-05, found 1 element(s) (out of 1) whose difference(s) exceeded the margin of error (including 0 nan comparisons). The greatest difference was 0.00352323055267334 (1.3834935426712036 vs. 1.3799703121185303), which occurred at index 0.
#   _module_class,
# output tensor(1.3793, grad_fn=<AddBackward0>)
# loss1 tensor(0.6970, grad_fn=<BinaryCrossEntropyBackward>)
# loss2 tensor(0.6824, grad_fn=<SumBackward0>)
# input_grad None

# %%
"""
def convert_json( project, folder, model, input_x, json_path, rand_flag=0 ):

    #folder = "src"
    cpp_fname   = project + ".cpp"
    param_fname = project + "_param.cpp"
    cpp_path    = folder + "/" + cpp_fname
    param_path  = folder + "/" + param_fname
    make_path   = folder + "/" + "Makefile"

    # load json file
    print( "[JSON]", json_path )
    fp = open( json_path )
    obj = json.load( fp )

    # save parameter file
    code1 = CV.c_param_generator( obj, model, input_x )
    if len( code1 ) > 0:
       print( "[PARAM]", param_path )
       ofparam = open( param_path, "w" )
       ofparam.write( code1 )

    # save cpp file
    print( "[CPP]  ", cpp_path )
    code2 = CV.c_code_generator( obj, model, rand_flag )

    #ofp=open(args.path+"/"+args.output,"w")
    ofp = open( cpp_path, "w" )
    ofp.write( code2 )

    # save make file
    print( "[MAKE] ", make_path )
    make_code = CV.makefile_generator( cpp_fname )

    #makefp=open(args.path+"/"+"Makefile","w")
    makefp = open( make_path, "w" )
    makefp.write( make_code )

convert_json( project, "src", model, x, json_path )
"""

# %%
CV.convert_json( project, "../src", model, x, json_path )
# Out:
# [JSON] ../network/vae2.json
# {'name': 'Net/Linear[fc1]/weight/173', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# {'name': 'Net/Linear[fc1]/bias/172', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# {'name': 'Net/Linear[fc2_mean]/weight/176', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# {'name': 'Net/Linear[fc2_mean]/bias/175', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# {'name': 'Net/Linear[fc2_var]/weight/179', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [10], 'sorted_id': 8}
# {'name': 'Net/Linear[fc2_var]/bias/178', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [10], 'sorted_id': 9}
# {'name': 'Net/Linear[fc3]/weight/182', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [47], 'sorted_id': 45}
# {'name': 'Net/Linear[fc3]/bias/181', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [47], 'sorted_id': 46}
# {'name': 'Net/Linear[fc4]/weight/185', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [51], 'sorted_id': 49}
# {'name': 'Net/Linear[fc4]/bias/184', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [51], 'sorted_id': 50}
# [PARAM] ../src/vae2_param.cpp
# {'name': 'input/x', 'op': 'IO Node', 'in': [], 'output_id': 0, 'shape': [32, 64], 'out': [55, 3], 'sorted_id': 0}
# {'name': 'Net/Linear[fc1]/weight/173', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# Net/Linear[fc1]/weight/173  ->  fc1_weight
# {'name': 'Net/Linear[fc1]/bias/172', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# Net/Linear[fc1]/bias/172  ->  fc1_bias
# {'name': 'Net/Linear[fc1]/input.1', 'op': 'aten::linear', 'in': [0, 1, 2], 'output_id': 0, 'shape': [32, 16], 'out': [4], 'sorted_id': 3}
# {'name': 'Net/input.3', 'op': 'aten::relu', 'in': [3], 'output_id': 0, 'shape': [32, 16], 'out': [7, 10], 'sorted_id': 4}
# {'name': 'Net/Linear[fc2_mean]/weight/176', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# Net/Linear[fc2_mean]/weight/176  ->  fc2_mean_weight
# {'name': 'Net/Linear[fc2_mean]/bias/175', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# Net/Linear[fc2_mean]/bias/175  ->  fc2_mean_bias
# {'name': 'Net/Linear[fc2_mean]/177', 'op': 'aten::linear', 'in': [4, 5, 6], 'output_id': 0, 'shape': [32, 2], 'out': [14], 'sorted_id': 7}
# {'name': 'Net/Linear[fc2_var]/weight/179', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [10], 'sorted_id': 8}
# Net/Linear[fc2_var]/weight/179  ->  fc2_var_weight
# {'name': 'Net/Linear[fc2_var]/bias/178', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [10], 'sorted_id': 9}
# Net/Linear[fc2_var]/bias/178  ->  fc2_var_bias
# {'name': 'Net/Linear[fc2_var]/180', 'op': 'aten::linear', 'in': [4, 8, 9], 'output_id': 0, 'shape': [32, 2], 'out': [12], 'sorted_id': 10}
# {'name': 'Net/33', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.5, 'out': [12], 'sorted_id': 11}
# {'name': 'Net/34', 'op': 'aten::mul', 'in': [10, 11], 'output_id': 0, 'shape': [32, 2], 'out': [13], 'sorted_id': 12}
# {'name': 'Net/35', 'op': 'aten::exp', 'in': [12], 'output_id': 0, 'shape': [32, 2], 'out': [14], 'sorted_id': 13}
# {'name': 'Net/36', 'op': 'prim::ListConstruct', 'in': [7, 13], 'output_id': 0, 'shape': [], 'out': [15], 'sorted_id': 14}
# {'name': 'Net/37', 'op': 'aten::broadcast_tensors', 'in': [14], 'output_id': 0, 'shape': [], 'out': [41, 16], 'sorted_id': 15}
# {'name': 'Net/loc.1', 'op': 'prim::ListUnpack', 'in': [15], 'output_id': 0, 'shape': [32, 2], 'out': [61, 18, 22, 44, 76], 'sorted_id': 16}
# {'name': 'Net/40', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [18], 'sorted_id': 17}
# {'name': 'Net/41', 'op': 'aten::size', 'in': [16, 17], 'output_id': 0, 'shape': [], 'out': [19], 'sorted_id': 18}
# {'name': 'Net/42', 'op': 'prim::NumToTensor', 'in': [18], 'output_id': 0, 'shape': [], 'out': [20, 31], 'sorted_id': 19}
# {'name': 'Net/51', 'op': 'aten::Int', 'in': [19], 'output_id': 0, 'shape': [], 'out': [25], 'sorted_id': 20}
# {'name': 'Net/43', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [22], 'sorted_id': 21}
# {'name': 'Net/44', 'op': 'aten::size', 'in': [16, 21], 'output_id': 0, 'shape': [], 'out': [23], 'sorted_id': 22}
# {'name': 'Net/45', 'op': 'prim::NumToTensor', 'in': [22], 'output_id': 0, 'shape': [], 'out': [24, 32], 'sorted_id': 23}
# {'name': 'Net/52', 'op': 'aten::Int', 'in': [23], 'output_id': 0, 'shape': [], 'out': [25], 'sorted_id': 24}
# {'name': 'Net/53', 'op': 'prim::ListConstruct', 'in': [20, 24], 'output_id': 0, 'shape': [], 'out': [30], 'sorted_id': 25}
# {'name': 'Net/54', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [30], 'sorted_id': 26}
# {'name': 'Net/55', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [30], 'sorted_id': 27}
# {'name': 'Net/56', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [30], 'sorted_id': 28}
# {'name': 'Net/57', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [30], 'sorted_id': 29}
# {'name': 'Net/58', 'op': 'aten::zeros', 'in': [25, 26, 27, 28, 29], 'output_id': 0, 'shape': [32, 2], 'out': [40], 'sorted_id': 30}
# {'name': 'Net/59', 'op': 'aten::Int', 'in': [19], 'output_id': 0, 'shape': [], 'out': [33], 'sorted_id': 31}
# {'name': 'Net/60', 'op': 'aten::Int', 'in': [23], 'output_id': 0, 'shape': [], 'out': [33], 'sorted_id': 32}
# {'name': 'Net/61', 'op': 'prim::ListConstruct', 'in': [31, 32], 'output_id': 0, 'shape': [], 'out': [38], 'sorted_id': 33}
# {'name': 'Net/62', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [38], 'sorted_id': 34}
# {'name': 'Net/63', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [38], 'sorted_id': 35}
# {'name': 'Net/64', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [38], 'sorted_id': 36}
# {'name': 'Net/65', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [38], 'sorted_id': 37}
# {'name': 'Net/66', 'op': 'aten::ones', 'in': [33, 34, 35, 36, 37], 'output_id': 0, 'shape': [32, 2], 'out': [40], 'sorted_id': 38}
# {'name': 'Net/67', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [40], 'sorted_id': 39}
# {'name': 'Net/eps', 'op': 'aten::normal', 'in': [30, 38, 39], 'output_id': 0, 'shape': [32, 2], 'out': [42], 'sorted_id': 40}
# {'name': 'Net/value.1', 'op': 'prim::ListUnpack', 'in': [15], 'output_id': 1, 'shape': [32, 2], 'out': [42, 71, 67], 'sorted_id': 41}
# {'name': 'Net/69', 'op': 'aten::mul', 'in': [40, 41], 'output_id': 0, 'shape': [32, 2], 'out': [44], 'sorted_id': 42}
# {'name': 'Net/70', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [44], 'sorted_id': 43}
# {'name': 'Net/input.5', 'op': 'aten::add', 'in': [16, 42, 43], 'output_id': 0, 'shape': [32, 2], 'out': [47], 'sorted_id': 44}
# {'name': 'Net/Linear[fc3]/weight/182', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [47], 'sorted_id': 45}
# Net/Linear[fc3]/weight/182  ->  fc3_weight
# {'name': 'Net/Linear[fc3]/bias/181', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [47], 'sorted_id': 46}
# Net/Linear[fc3]/bias/181  ->  fc3_bias
# {'name': 'Net/Linear[fc3]/input.7', 'op': 'aten::linear', 'in': [44, 45, 46], 'output_id': 0, 'shape': [32, 16], 'out': [48], 'sorted_id': 47}
# {'name': 'Net/input.9', 'op': 'aten::relu', 'in': [47], 'output_id': 0, 'shape': [32, 16], 'out': [51], 'sorted_id': 48}
# {'name': 'Net/Linear[fc4]/weight/185', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [51], 'sorted_id': 49}
# Net/Linear[fc4]/weight/185  ->  fc4_weight
# {'name': 'Net/Linear[fc4]/bias/184', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [51], 'sorted_id': 50}
# Net/Linear[fc4]/bias/184  ->  fc4_bias
# {'name': 'Net/Linear[fc4]/186', 'op': 'aten::linear', 'in': [48, 49, 50], 'output_id': 0, 'shape': [32, 64], 'out': [52], 'sorted_id': 51}
# {'name': 'Net/input', 'op': 'aten::sigmoid', 'in': [51], 'output_id': 0, 'shape': [32, 64], 'out': [55], 'sorted_id': 52}
# {'name': 'Net/90', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [55], 'sorted_id': 53}
# {'name': 'Net/91', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [55], 'sorted_id': 54}
# {'name': 'Net/e1', 'op': 'aten::binary_cross_entropy', 'in': [52, 0, 53, 54], 'output_id': 0, 'shape': [], 'out': [93], 'sorted_id': 55}
# {'name': 'Net/93', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [61], 'sorted_id': 56}
# {'name': 'Net/94', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [61], 'sorted_id': 57}
# {'name': 'Net/95', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [61], 'sorted_id': 58}
# {'name': 'Net/96', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [61], 'sorted_id': 59}
# {'name': 'Net/97', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [61], 'sorted_id': 60}
# {'name': 'Net/98', 'op': 'aten::zeros_like', 'in': [16, 56, 57, 58, 59, 60], 'output_id': 0, 'shape': [32, 2], 'out': [68], 'sorted_id': 61}
# {'name': 'Net/99', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [67], 'sorted_id': 62}
# {'name': 'Net/100', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [67], 'sorted_id': 63}
# {'name': 'Net/101', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [67], 'sorted_id': 64}
# {'name': 'Net/102', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [67], 'sorted_id': 65}
# {'name': 'Net/103', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [67], 'sorted_id': 66}
# {'name': 'Net/104', 'op': 'aten::ones_like', 'in': [41, 62, 63, 64, 65, 66], 'output_id': 0, 'shape': [32, 2], 'out': [68], 'sorted_id': 67}
# {'name': 'Net/105', 'op': 'prim::ListConstruct', 'in': [61, 67], 'output_id': 0, 'shape': [], 'out': [69], 'sorted_id': 68}
# {'name': 'Net/106', 'op': 'aten::broadcast_tensors', 'in': [68], 'output_id': 0, 'shape': [], 'out': [74, 70], 'sorted_id': 69}
# {'name': 'Net/value', 'op': 'prim::ListUnpack', 'in': [69], 'output_id': 1, 'shape': [32, 2], 'out': [77, 71], 'sorted_id': 70}
# {'name': 'Net/120', 'op': 'aten::div', 'in': [41, 70], 'output_id': 0, 'shape': [32, 2], 'out': [73], 'sorted_id': 71}
# {'name': 'Net/121', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 2.0, 'out': [73], 'sorted_id': 72}
# {'name': 'Net/var_ratio', 'op': 'aten::pow', 'in': [71, 72], 'output_id': 0, 'shape': [32, 2], 'out': [81, 85], 'sorted_id': 73}
# {'name': 'Net/loc', 'op': 'prim::ListUnpack', 'in': [69], 'output_id': 0, 'shape': [32, 2], 'out': [76], 'sorted_id': 74}
# {'name': 'Net/123', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [76], 'sorted_id': 75}
# {'name': 'Net/124', 'op': 'aten::sub', 'in': [16, 74, 75], 'output_id': 0, 'shape': [32, 2], 'out': [77], 'sorted_id': 76}
# {'name': 'Net/125', 'op': 'aten::div', 'in': [76, 70], 'output_id': 0, 'shape': [32, 2], 'out': [79], 'sorted_id': 77}
# {'name': 'Net/126', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 2.0, 'out': [79], 'sorted_id': 78}
# {'name': 'Net/t1', 'op': 'aten::pow', 'in': [77, 78], 'output_id': 0, 'shape': [32, 2], 'out': [81], 'sorted_id': 79}
# {'name': 'Net/128', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [81], 'sorted_id': 80}
# {'name': 'Net/129', 'op': 'aten::add', 'in': [73, 79, 80], 'output_id': 0, 'shape': [32, 2], 'out': [84], 'sorted_id': 81}
# {'name': 'Net/130', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [84], 'sorted_id': 82}
# {'name': 'Net/131', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [84], 'sorted_id': 83}
# {'name': 'Net/132', 'op': 'aten::sub', 'in': [81, 82, 83], 'output_id': 0, 'shape': [32, 2], 'out': [87], 'sorted_id': 84}
# {'name': 'Net/133', 'op': 'aten::log', 'in': [73], 'output_id': 0, 'shape': [32, 2], 'out': [87], 'sorted_id': 85}
# {'name': 'Net/134', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [87], 'sorted_id': 86}
# {'name': 'Net/135', 'op': 'aten::sub', 'in': [84, 85, 86], 'output_id': 0, 'shape': [32, 2], 'out': [89], 'sorted_id': 87}
# {'name': 'Net/136', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.5, 'out': [89], 'sorted_id': 88}
# {'name': 'Net/137', 'op': 'aten::mul', 'in': [87, 88], 'output_id': 0, 'shape': [32, 2], 'out': [91], 'sorted_id': 89}
# {'name': 'Net/138', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [91], 'sorted_id': 90}
# {'name': 'Net/e2', 'op': 'aten::sum', 'in': [89, 90], 'output_id': 0, 'shape': [], 'out': [93], 'sorted_id': 91}
# {'name': 'Net/140', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [93], 'sorted_id': 92}
# {'name': 'Net/141', 'op': 'aten::add', 'in': [55, 91, 92], 'output_id': 0, 'shape': [], 'out': [94], 'sorted_id': 93}
# {'name': 'output/output.1', 'op': 'IO Node', 'in': [93], 'output_id': 0, 'shape': [], 'out': [], 'sorted_id': 94}
# [CPP]  ../src/vae2.cpp
# [MAKE] ../src/Makefile

# %%
# !g++ -std=c++14 ../src/vae2.cpp ../src/vae2_param.cpp  -I ../../../xtensor -lcblas -o ../bin/vae2

# %% [markdown]
# (注意) xtensorにxtensor関連のincludeを置いています。各自の環境に合わせて変更して下さい。

# %%
# !../bin/vae2
# Out:
# ### forward computation ...
# { 1.377269}
# ### backward computation ...
# input_grad{{-0.00321 , -0.002135,  0.004704, ..., -0.000628, -0.004311, -0.005155},
#  {-0.011554, -0.000128,  0.00318 , ..., -0.000509, -0.010749, -0.008572},
#  {-0.007079,  0.004047,  0.002193, ...,  0.001067, -0.004554, -0.004626},
#  ...,
#  {-0.00756 ,  0.002112,  0.002471, ...,  0.000837, -0.003364, -0.00645 },
#  {-0.003647, -0.002078,  0.005188, ..., -0.000259, -0.004205, -0.005217},
#  {-0.001296,  0.000206,  0.001456, ...,  0.002875, -0.000528, -0.006141}}

# %% [markdown]
# 勾配計算

# %%
torch.manual_seed( 1 )

project = 'vae2'

x = x_train.clone().detach()
torch.reshape( x, (-1,n_in) )

x = x[0:n_batch,:]
#print(type(x))
#print(x.shape)
#x.requires_grad = True

e = torch.randn( n_batch, 2 )
#print("eps",e)

net = Net( n_in, n_mid, n_out, n_z, e )
net.train()

lr=0.001
opt = torch.optim.SGD(net.parameters(), lr)

epoch_loss = []
epoch_num = 200; 
for epoch in range(epoch_num):

  loss = net( x )

  print("loss",loss)

  opt.zero_grad()
  loss.backward()
  #print("output",output.grad)

  opt.step()
  print("EPOCH: {} loss: {}".format(epoch, loss))
  epoch_loss.append( loss )
# Out:
# loss tensor(1.3787, grad_fn=<AddBackward0>)
# EPOCH: 0 loss: 1.3786983489990234
# loss tensor(1.2888, grad_fn=<AddBackward0>)
# EPOCH: 1 loss: 1.2888193130493164
# loss tensor(1.2150, grad_fn=<AddBackward0>)
# EPOCH: 2 loss: 1.2149816751480103
# loss tensor(1.1518, grad_fn=<AddBackward0>)
# EPOCH: 3 loss: 1.1518285274505615
# loss tensor(1.1027, grad_fn=<AddBackward0>)
# EPOCH: 4 loss: 1.1026856899261475
# loss tensor(1.0644, grad_fn=<AddBackward0>)
# EPOCH: 5 loss: 1.0643843412399292
# loss tensor(1.0292, grad_fn=<AddBackward0>)
# EPOCH: 6 loss: 1.0291879177093506
# loss tensor(1.0013, grad_fn=<AddBackward0>)
# EPOCH: 7 loss: 1.001307725906372
# loss tensor(0.9833, grad_fn=<AddBackward0>)
# EPOCH: 8 loss: 0.983328104019165
# loss tensor(0.9605, grad_fn=<AddBackward0>)
# EPOCH: 9 loss: 0.9605247378349304
# loss tensor(0.9389, grad_fn=<AddBackward0>)
# EPOCH: 10 loss: 0.938908576965332
# loss tensor(0.9269, grad_fn=<AddBackward0>)
# EPOCH: 11 loss: 0.9268635511398315
# loss tensor(0.9124, grad_fn=<AddBackward0>)
# EPOCH: 12 loss: 0.9124072790145874
# loss tensor(0.9030, grad_fn=<AddBackward0>)
# EPOCH: 13 loss: 0.9030369520187378
# loss tensor(0.8938, grad_fn=<AddBackward0>)
# EPOCH: 14 loss: 0.8938140869140625
# loss tensor(0.8830, grad_fn=<AddBackward0>)
# EPOCH: 15 loss: 0.883007287979126
# loss tensor(0.8818, grad_fn=<AddBackward0>)
# EPOCH: 16 loss: 0.88182532787323
# loss tensor(0.8681, grad_fn=<AddBackward0>)
# EPOCH: 17 loss: 0.8680629134178162
# loss tensor(0.8659, grad_fn=<AddBackward0>)
# EPOCH: 18 loss: 0.8659484386444092
# loss tensor(0.8557, grad_fn=<AddBackward0>)
# EPOCH: 19 loss: 0.8557280898094177
# loss tensor(0.8537, grad_fn=<AddBackward0>)
# EPOCH: 20 loss: 0.8537173867225647
# loss tensor(0.8515, grad_fn=<AddBackward0>)
# EPOCH: 21 loss: 0.8514957427978516
# loss tensor(0.8460, grad_fn=<AddBackward0>)
# EPOCH: 22 loss: 0.845978856086731
# loss tensor(0.8416, grad_fn=<AddBackward0>)
# EPOCH: 23 loss: 0.8415571451187134
# loss tensor(0.8389, grad_fn=<AddBackward0>)
# EPOCH: 24 loss: 0.8388770818710327
# loss tensor(0.8346, grad_fn=<AddBackward0>)
# EPOCH: 25 loss: 0.8345543146133423
# loss tensor(0.8322, grad_fn=<AddBackward0>)
# EPOCH: 26 loss: 0.8321525454521179
# loss tensor(0.8331, grad_fn=<AddBackward0>)
# EPOCH: 27 loss: 0.8331491351127625
# loss tensor(0.8313, grad_fn=<AddBackward0>)
# EPOCH: 28 loss: 0.8312951922416687
# loss tensor(0.8277, grad_fn=<AddBackward0>)
# EPOCH: 29 loss: 0.8276944756507874
# loss tensor(0.8242, grad_fn=<AddBackward0>)
# EPOCH: 30 loss: 0.824203610420227
# loss tensor(0.8255, grad_fn=<AddBackward0>)
# EPOCH: 31 loss: 0.8255430459976196
# loss tensor(0.8193, grad_fn=<AddBackward0>)
# EPOCH: 32 loss: 0.8193057179450989
# loss tensor(0.8195, grad_fn=<AddBackward0>)
# EPOCH: 33 loss: 0.8194833397865295
# loss tensor(0.8173, grad_fn=<AddBackward0>)
# EPOCH: 34 loss: 0.8172929286956787
# loss tensor(0.8119, grad_fn=<AddBackward0>)
# EPOCH: 35 loss: 0.8118857145309448
# loss tensor(0.8176, grad_fn=<AddBackward0>)
# EPOCH: 36 loss: 0.8175743222236633
# loss tensor(0.8138, grad_fn=<AddBackward0>)
# EPOCH: 37 loss: 0.8137933611869812
# loss tensor(0.8143, grad_fn=<AddBackward0>)
# EPOCH: 38 loss: 0.8142654299736023
# loss tensor(0.8095, grad_fn=<AddBackward0>)
# EPOCH: 39 loss: 0.8095207810401917
# loss tensor(0.8126, grad_fn=<AddBackward0>)
# EPOCH: 40 loss: 0.8125845193862915
# loss tensor(0.8081, grad_fn=<AddBackward0>)
# EPOCH: 41 loss: 0.8080717921257019
# loss tensor(0.8085, grad_fn=<AddBackward0>)
# EPOCH: 42 loss: 0.808521568775177
# loss tensor(0.8064, grad_fn=<AddBackward0>)
# EPOCH: 43 loss: 0.8063690662384033
# loss tensor(0.8089, grad_fn=<AddBackward0>)
# EPOCH: 44 loss: 0.8088644742965698
# loss tensor(0.8051, grad_fn=<AddBackward0>)
# EPOCH: 45 loss: 0.805149257183075
# loss tensor(0.8039, grad_fn=<AddBackward0>)
# EPOCH: 46 loss: 0.8039332628250122
# loss tensor(0.8037, grad_fn=<AddBackward0>)
# EPOCH: 47 loss: 0.803718090057373
# loss tensor(0.8037, grad_fn=<AddBackward0>)
# EPOCH: 48 loss: 0.8037222623825073
# loss tensor(0.8004, grad_fn=<AddBackward0>)
# EPOCH: 49 loss: 0.800448477268219
# loss tensor(0.7998, grad_fn=<AddBackward0>)
# EPOCH: 50 loss: 0.7997536659240723
# loss tensor(0.8017, grad_fn=<AddBackward0>)
# EPOCH: 51 loss: 0.8016960620880127
# loss tensor(0.7981, grad_fn=<AddBackward0>)
# EPOCH: 52 loss: 0.7981093525886536
# loss tensor(0.7933, grad_fn=<AddBackward0>)
# EPOCH: 53 loss: 0.7933035492897034
# loss tensor(0.7941, grad_fn=<AddBackward0>)
# EPOCH: 54 loss: 0.7940592765808105
# loss tensor(0.7960, grad_fn=<AddBackward0>)
# EPOCH: 55 loss: 0.7960211634635925
# loss tensor(0.7970, grad_fn=<AddBackward0>)
# EPOCH: 56 loss: 0.7970105409622192
# loss tensor(0.7924, grad_fn=<AddBackward0>)
# EPOCH: 57 loss: 0.7924354076385498
# loss tensor(0.7913, grad_fn=<AddBackward0>)
# EPOCH: 58 loss: 0.7913121581077576
# loss tensor(0.7919, grad_fn=<AddBackward0>)
# EPOCH: 59 loss: 0.7919336557388306
# loss tensor(0.7946, grad_fn=<AddBackward0>)
# EPOCH: 60 loss: 0.7946262359619141
# loss tensor(0.7917, grad_fn=<AddBackward0>)
# EPOCH: 61 loss: 0.7917267084121704
# loss tensor(0.7870, grad_fn=<AddBackward0>)
# EPOCH: 62 loss: 0.7870422601699829
# loss tensor(0.7871, grad_fn=<AddBackward0>)
# EPOCH: 63 loss: 0.787055253982544
# loss tensor(0.7912, grad_fn=<AddBackward0>)
# EPOCH: 64 loss: 0.7912304401397705
# loss tensor(0.7855, grad_fn=<AddBackward0>)
# EPOCH: 65 loss: 0.7854995727539062
# loss tensor(0.7883, grad_fn=<AddBackward0>)
# EPOCH: 66 loss: 0.7882986068725586
# loss tensor(0.7865, grad_fn=<AddBackward0>)
# EPOCH: 67 loss: 0.7865034341812134
# loss tensor(0.7888, grad_fn=<AddBackward0>)
# EPOCH: 68 loss: 0.7887815237045288
# loss tensor(0.7860, grad_fn=<AddBackward0>)
# EPOCH: 69 loss: 0.7860128879547119
# loss tensor(0.7839, grad_fn=<AddBackward0>)
# EPOCH: 70 loss: 0.7839052081108093
# loss tensor(0.7826, grad_fn=<AddBackward0>)
# EPOCH: 71 loss: 0.7826328873634338
# loss tensor(0.7848, grad_fn=<AddBackward0>)
# EPOCH: 72 loss: 0.7848064303398132
# loss tensor(0.7831, grad_fn=<AddBackward0>)
# EPOCH: 73 loss: 0.7831236720085144
# loss tensor(0.7828, grad_fn=<AddBackward0>)
# EPOCH: 74 loss: 0.7828302979469299
# loss tensor(0.7827, grad_fn=<AddBackward0>)
# EPOCH: 75 loss: 0.7826898694038391
# loss tensor(0.7790, grad_fn=<AddBackward0>)
# EPOCH: 76 loss: 0.7790220975875854
# loss tensor(0.7794, grad_fn=<AddBackward0>)
# EPOCH: 77 loss: 0.7794262170791626
# loss tensor(0.7780, grad_fn=<AddBackward0>)
# EPOCH: 78 loss: 0.778008222579956
# loss tensor(0.7800, grad_fn=<AddBackward0>)
# EPOCH: 79 loss: 0.7800216674804688
# loss tensor(0.7808, grad_fn=<AddBackward0>)
# EPOCH: 80 loss: 0.7807959914207458
# loss tensor(0.7782, grad_fn=<AddBackward0>)
# EPOCH: 81 loss: 0.7781952619552612
# loss tensor(0.7780, grad_fn=<AddBackward0>)
# EPOCH: 82 loss: 0.7779756784439087
# loss tensor(0.7754, grad_fn=<AddBackward0>)
# EPOCH: 83 loss: 0.7754312753677368
# loss tensor(0.7772, grad_fn=<AddBackward0>)
# EPOCH: 84 loss: 0.7771593332290649
# loss tensor(0.7797, grad_fn=<AddBackward0>)
# EPOCH: 85 loss: 0.7796835899353027
# loss tensor(0.7760, grad_fn=<AddBackward0>)
# EPOCH: 86 loss: 0.7759726643562317
# loss tensor(0.7764, grad_fn=<AddBackward0>)
# EPOCH: 87 loss: 0.7763896584510803
# loss tensor(0.7798, grad_fn=<AddBackward0>)
# EPOCH: 88 loss: 0.7798102498054504
# loss tensor(0.7740, grad_fn=<AddBackward0>)
# EPOCH: 89 loss: 0.7739747166633606
# loss tensor(0.7728, grad_fn=<AddBackward0>)
# EPOCH: 90 loss: 0.7727802395820618
# loss tensor(0.7751, grad_fn=<AddBackward0>)
# EPOCH: 91 loss: 0.7751415967941284
# loss tensor(0.7745, grad_fn=<AddBackward0>)
# EPOCH: 92 loss: 0.7744756937026978
# loss tensor(0.7711, grad_fn=<AddBackward0>)
# EPOCH: 93 loss: 0.7711390852928162
# loss tensor(0.7708, grad_fn=<AddBackward0>)
# EPOCH: 94 loss: 0.7708397507667542
# loss tensor(0.7717, grad_fn=<AddBackward0>)
# EPOCH: 95 loss: 0.7717114686965942
# loss tensor(0.7677, grad_fn=<AddBackward0>)
# EPOCH: 96 loss: 0.7677023410797119
# loss tensor(0.7696, grad_fn=<AddBackward0>)
# EPOCH: 97 loss: 0.7696049213409424
# loss tensor(0.7711, grad_fn=<AddBackward0>)
# EPOCH: 98 loss: 0.7710703611373901
# loss tensor(0.7682, grad_fn=<AddBackward0>)
# EPOCH: 99 loss: 0.7682092189788818
# loss tensor(0.7705, grad_fn=<AddBackward0>)
# EPOCH: 100 loss: 0.7705099582672119
# loss tensor(0.7673, grad_fn=<AddBackward0>)
# EPOCH: 101 loss: 0.7673336267471313
# loss tensor(0.7650, grad_fn=<AddBackward0>)
# EPOCH: 102 loss: 0.7649962306022644
# loss tensor(0.7663, grad_fn=<AddBackward0>)
# EPOCH: 103 loss: 0.7663146257400513
# loss tensor(0.7656, grad_fn=<AddBackward0>)
# EPOCH: 104 loss: 0.7655999064445496
# loss tensor(0.7679, grad_fn=<AddBackward0>)
# EPOCH: 105 loss: 0.767851710319519
# loss tensor(0.7636, grad_fn=<AddBackward0>)
# EPOCH: 106 loss: 0.7635527849197388
# loss tensor(0.7656, grad_fn=<AddBackward0>)
# EPOCH: 107 loss: 0.7656331658363342
# loss tensor(0.7680, grad_fn=<AddBackward0>)
# EPOCH: 108 loss: 0.7679895162582397
# loss tensor(0.7634, grad_fn=<AddBackward0>)
# EPOCH: 109 loss: 0.7634421586990356
# loss tensor(0.7663, grad_fn=<AddBackward0>)
# EPOCH: 110 loss: 0.7663049101829529
# loss tensor(0.7654, grad_fn=<AddBackward0>)
# EPOCH: 111 loss: 0.7653838396072388
# loss tensor(0.7655, grad_fn=<AddBackward0>)
# EPOCH: 112 loss: 0.7655370235443115
# loss tensor(0.7619, grad_fn=<AddBackward0>)
# EPOCH: 113 loss: 0.7618840336799622
# loss tensor(0.7578, grad_fn=<AddBackward0>)
# EPOCH: 114 loss: 0.7577518224716187
# loss tensor(0.7616, grad_fn=<AddBackward0>)
# EPOCH: 115 loss: 0.761572003364563
# loss tensor(0.7616, grad_fn=<AddBackward0>)
# EPOCH: 116 loss: 0.7615523934364319
# loss tensor(0.7646, grad_fn=<AddBackward0>)
# EPOCH: 117 loss: 0.7645661234855652
# loss tensor(0.7637, grad_fn=<AddBackward0>)
# EPOCH: 118 loss: 0.7637203931808472
# loss tensor(0.7656, grad_fn=<AddBackward0>)
# EPOCH: 119 loss: 0.7656236290931702
# loss tensor(0.7626, grad_fn=<AddBackward0>)
# EPOCH: 120 loss: 0.7626176476478577
# loss tensor(0.7564, grad_fn=<AddBackward0>)
# EPOCH: 121 loss: 0.7564334273338318
# loss tensor(0.7595, grad_fn=<AddBackward0>)
# EPOCH: 122 loss: 0.7595008611679077
# loss tensor(0.7573, grad_fn=<AddBackward0>)
# EPOCH: 123 loss: 0.7573208808898926
# loss tensor(0.7556, grad_fn=<AddBackward0>)
# EPOCH: 124 loss: 0.755638062953949
# loss tensor(0.7557, grad_fn=<AddBackward0>)
# EPOCH: 125 loss: 0.7557473182678223
# loss tensor(0.7609, grad_fn=<AddBackward0>)
# EPOCH: 126 loss: 0.760867714881897
# loss tensor(0.7617, grad_fn=<AddBackward0>)
# EPOCH: 127 loss: 0.7616838812828064
# loss tensor(0.7547, grad_fn=<AddBackward0>)
# EPOCH: 128 loss: 0.7547132968902588
# loss tensor(0.7558, grad_fn=<AddBackward0>)
# EPOCH: 129 loss: 0.7557755708694458
# loss tensor(0.7591, grad_fn=<AddBackward0>)
# EPOCH: 130 loss: 0.7590720057487488
# loss tensor(0.7564, grad_fn=<AddBackward0>)
# EPOCH: 131 loss: 0.7564155459403992
# loss tensor(0.7540, grad_fn=<AddBackward0>)
# EPOCH: 132 loss: 0.7539842128753662
# loss tensor(0.7582, grad_fn=<AddBackward0>)
# EPOCH: 133 loss: 0.7582188844680786
# loss tensor(0.7583, grad_fn=<AddBackward0>)
# EPOCH: 134 loss: 0.758307933807373
# loss tensor(0.7487, grad_fn=<AddBackward0>)
# EPOCH: 135 loss: 0.7487367987632751
# loss tensor(0.7492, grad_fn=<AddBackward0>)
# EPOCH: 136 loss: 0.7492034435272217
# loss tensor(0.7523, grad_fn=<AddBackward0>)
# EPOCH: 137 loss: 0.7522856593132019
# loss tensor(0.7573, grad_fn=<AddBackward0>)
# EPOCH: 138 loss: 0.7573354244232178
# loss tensor(0.7563, grad_fn=<AddBackward0>)
# EPOCH: 139 loss: 0.7563177347183228
# loss tensor(0.7530, grad_fn=<AddBackward0>)
# EPOCH: 140 loss: 0.7529748678207397
# loss tensor(0.7515, grad_fn=<AddBackward0>)
# EPOCH: 141 loss: 0.7515022158622742
# loss tensor(0.7502, grad_fn=<AddBackward0>)
# EPOCH: 142 loss: 0.7501739263534546
# loss tensor(0.7531, grad_fn=<AddBackward0>)
# EPOCH: 143 loss: 0.7531353235244751
# loss tensor(0.7516, grad_fn=<AddBackward0>)
# EPOCH: 144 loss: 0.7515665292739868
# loss tensor(0.7509, grad_fn=<AddBackward0>)
# EPOCH: 145 loss: 0.7509320378303528
# loss tensor(0.7498, grad_fn=<AddBackward0>)
# EPOCH: 146 loss: 0.7498002648353577
# loss tensor(0.7524, grad_fn=<AddBackward0>)
# EPOCH: 147 loss: 0.7523708343505859
# loss tensor(0.7510, grad_fn=<AddBackward0>)
# EPOCH: 148 loss: 0.7509819865226746
# loss tensor(0.7552, grad_fn=<AddBackward0>)
# EPOCH: 149 loss: 0.7552475333213806
# loss tensor(0.7542, grad_fn=<AddBackward0>)
# EPOCH: 150 loss: 0.754244327545166
# loss tensor(0.7507, grad_fn=<AddBackward0>)
# EPOCH: 151 loss: 0.7506670951843262
# loss tensor(0.7461, grad_fn=<AddBackward0>)
# EPOCH: 152 loss: 0.7461146116256714
# loss tensor(0.7462, grad_fn=<AddBackward0>)
# EPOCH: 153 loss: 0.7461522817611694
# loss tensor(0.7483, grad_fn=<AddBackward0>)
# EPOCH: 154 loss: 0.7483488321304321
# loss tensor(0.7461, grad_fn=<AddBackward0>)
# EPOCH: 155 loss: 0.7461214065551758
# loss tensor(0.7490, grad_fn=<AddBackward0>)
# EPOCH: 156 loss: 0.7490198612213135
# loss tensor(0.7444, grad_fn=<AddBackward0>)
# EPOCH: 157 loss: 0.7444168329238892
# loss tensor(0.7518, grad_fn=<AddBackward0>)
# EPOCH: 158 loss: 0.7517824172973633
# loss tensor(0.7465, grad_fn=<AddBackward0>)
# EPOCH: 159 loss: 0.7465423941612244
# loss tensor(0.7443, grad_fn=<AddBackward0>)
# EPOCH: 160 loss: 0.7442983388900757
# loss tensor(0.7454, grad_fn=<AddBackward0>)
# EPOCH: 161 loss: 0.7454314827919006
# loss tensor(0.7437, grad_fn=<AddBackward0>)
# EPOCH: 162 loss: 0.7436537146568298
# loss tensor(0.7423, grad_fn=<AddBackward0>)
# EPOCH: 163 loss: 0.742255449295044
# loss tensor(0.7464, grad_fn=<AddBackward0>)
# EPOCH: 164 loss: 0.7464032769203186
# loss tensor(0.7458, grad_fn=<AddBackward0>)
# EPOCH: 165 loss: 0.7457813620567322
# loss tensor(0.7457, grad_fn=<AddBackward0>)
# EPOCH: 166 loss: 0.7456550598144531
# loss tensor(0.7436, grad_fn=<AddBackward0>)
# EPOCH: 167 loss: 0.7435707449913025
# loss tensor(0.7438, grad_fn=<AddBackward0>)
# EPOCH: 168 loss: 0.7437665462493896
# loss tensor(0.7414, grad_fn=<AddBackward0>)
# EPOCH: 169 loss: 0.7413983345031738
# loss tensor(0.7451, grad_fn=<AddBackward0>)
# EPOCH: 170 loss: 0.7450525760650635
# loss tensor(0.7470, grad_fn=<AddBackward0>)
# EPOCH: 171 loss: 0.7470359802246094
# loss tensor(0.7444, grad_fn=<AddBackward0>)
# EPOCH: 172 loss: 0.7443679571151733
# loss tensor(0.7441, grad_fn=<AddBackward0>)
# EPOCH: 173 loss: 0.7440657019615173
# loss tensor(0.7409, grad_fn=<AddBackward0>)
# EPOCH: 174 loss: 0.7408998608589172
# loss tensor(0.7408, grad_fn=<AddBackward0>)
# EPOCH: 175 loss: 0.7407828569412231
# loss tensor(0.7418, grad_fn=<AddBackward0>)
# EPOCH: 176 loss: 0.741755485534668
# loss tensor(0.7401, grad_fn=<AddBackward0>)
# EPOCH: 177 loss: 0.7401463985443115
# loss tensor(0.7405, grad_fn=<AddBackward0>)
# EPOCH: 178 loss: 0.7405094504356384
# loss tensor(0.7416, grad_fn=<AddBackward0>)
# EPOCH: 179 loss: 0.7415810227394104
# loss tensor(0.7401, grad_fn=<AddBackward0>)
# EPOCH: 180 loss: 0.7401480078697205
# loss tensor(0.7420, grad_fn=<AddBackward0>)
# EPOCH: 181 loss: 0.7420111298561096
# loss tensor(0.7364, grad_fn=<AddBackward0>)
# EPOCH: 182 loss: 0.7363978028297424
# loss tensor(0.7377, grad_fn=<AddBackward0>)
# EPOCH: 183 loss: 0.7377204298973083
# loss tensor(0.7376, grad_fn=<AddBackward0>)
# EPOCH: 184 loss: 0.7375921607017517
# loss tensor(0.7326, grad_fn=<AddBackward0>)
# EPOCH: 185 loss: 0.7326443791389465
# loss tensor(0.7383, grad_fn=<AddBackward0>)
# EPOCH: 186 loss: 0.7383407950401306
# loss tensor(0.7380, grad_fn=<AddBackward0>)
# EPOCH: 187 loss: 0.7380411624908447
# loss tensor(0.7391, grad_fn=<AddBackward0>)
# EPOCH: 188 loss: 0.7390775084495544
# loss tensor(0.7383, grad_fn=<AddBackward0>)
# EPOCH: 189 loss: 0.7383291125297546
# loss tensor(0.7419, grad_fn=<AddBackward0>)
# EPOCH: 190 loss: 0.7418510317802429
# loss tensor(0.7398, grad_fn=<AddBackward0>)
# EPOCH: 191 loss: 0.7398033738136292
# loss tensor(0.7357, grad_fn=<AddBackward0>)
# EPOCH: 192 loss: 0.7356743216514587
# loss tensor(0.7365, grad_fn=<AddBackward0>)
# EPOCH: 193 loss: 0.7364534735679626
# loss tensor(0.7370, grad_fn=<AddBackward0>)
# EPOCH: 194 loss: 0.7370200157165527
# loss tensor(0.7404, grad_fn=<AddBackward0>)
# EPOCH: 195 loss: 0.7404000759124756
# loss tensor(0.7337, grad_fn=<AddBackward0>)
# EPOCH: 196 loss: 0.7336668372154236
# loss tensor(0.7417, grad_fn=<AddBackward0>)
# EPOCH: 197 loss: 0.7416771650314331
# loss tensor(0.7383, grad_fn=<AddBackward0>)
# EPOCH: 198 loss: 0.7383254766464233
# loss tensor(0.7340, grad_fn=<AddBackward0>)
# EPOCH: 199 loss: 0.7340483069419861

# %% [markdown]
# ミニバッチのよる最適化

# %%
torch.manual_seed( 1 )

epochs = 200
batch_size = 32
#interval = 5  # 経過の表示間隔

e = torch.randn( batch_size, 2 )
#print("eps",e)

net = Net( n_in, n_mid, n_out, n_z, e )
net.train()

lr = 0.01
type=1
if type==1:
  opt = torch.optim.SGD(net.parameters(), lr)
if type==2:
  #opt = torch.optim.Adagrad(net.parameters(), lr)
  opt = torch.optim.Adam(net.parameters(), lr )

epoch_loss = []
epoch_loss2 = []

n_batch = len(x_train) // batch_size  # 1エポックあたりのバッチ数
print("batch",n_batch,len(x_train),batch_size)

for i in range(epochs):
        
    # -- 学習 -- 
    index_random = np.arange(len(x_train))
    np.random.shuffle(index_random)  # インデックスをシャッフルする

    total_loss = 0.0
    for j in range(n_batch):
        
        # ミニバッチを取り出す
        mb_index = index_random[ j*batch_size : (j+1)*batch_size ]
        x_mb = x_train[mb_index, :]
        #x_mb.requires_grad = True
        
        # 順伝播と逆伝播
        loss = net( x_mb )
        total_loss += loss;

        opt.zero_grad()
        loss.backward()
        opt.step()
        #print("EPOCH: {} {} loss: {}".format(i,j, loss))

    # -- 誤差を求める --
    print("EPOCH: {} loss: {}".format(i, total_loss))

    x2 = x_train.clone().detach()
    torch.reshape( x2, (-1,n_in) )

    net.eval()
    loss = net( x2 )
    print("loss ",loss,net.loss1,net.loss2)
    if type==1:
      epoch_loss.append( loss )
    if type==2:
      epoch_loss2.append( loss )
# Out:
# batch 56 1797 32
# EPOCH: 0 loss: 42.952213287353516
# loss  tensor(2.0798, grad_fn=<AddBackward0>) tensor(0.6991, grad_fn=<BinaryCrossEntropyBackward>) tensor(1.3807, grad_fn=<SumBackward0>)
# EPOCH: 1 loss: 40.00406265258789
# loss  tensor(1.2680, grad_fn=<AddBackward0>) tensor(0.6970, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.5710, grad_fn=<SumBackward0>)
# EPOCH: 2 loss: 39.38795852661133
# loss  tensor(1.0240, grad_fn=<AddBackward0>) tensor(0.6955, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.3285, grad_fn=<SumBackward0>)
# EPOCH: 3 loss: 39.14167022705078
# loss  tensor(0.9003, grad_fn=<AddBackward0>) tensor(0.6934, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.2069, grad_fn=<SumBackward0>)
# EPOCH: 4 loss: 38.94472885131836
# loss  tensor(0.8318, grad_fn=<AddBackward0>) tensor(0.6917, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.1401, grad_fn=<SumBackward0>)
# EPOCH: 5 loss: 38.81594467163086
# loss  tensor(0.7913, grad_fn=<AddBackward0>) tensor(0.6901, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.1012, grad_fn=<SumBackward0>)
# EPOCH: 6 loss: 38.6829833984375
# loss  tensor(0.7659, grad_fn=<AddBackward0>) tensor(0.6883, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0775, grad_fn=<SumBackward0>)
# EPOCH: 7 loss: 38.552555084228516
# loss  tensor(0.7483, grad_fn=<AddBackward0>) tensor(0.6867, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0616, grad_fn=<SumBackward0>)
# EPOCH: 8 loss: 38.432701110839844
# loss  tensor(0.7352, grad_fn=<AddBackward0>) tensor(0.6847, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0505, grad_fn=<SumBackward0>)
# EPOCH: 9 loss: 38.34645080566406
# loss  tensor(0.7252, grad_fn=<AddBackward0>) tensor(0.6829, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0423, grad_fn=<SumBackward0>)
# EPOCH: 10 loss: 38.239662170410156
# loss  tensor(0.7168, grad_fn=<AddBackward0>) tensor(0.6816, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0352, grad_fn=<SumBackward0>)
# EPOCH: 11 loss: 38.13865661621094
# loss  tensor(0.7099, grad_fn=<AddBackward0>) tensor(0.6799, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0300, grad_fn=<SumBackward0>)
# EPOCH: 12 loss: 38.04009246826172
# loss  tensor(0.7039, grad_fn=<AddBackward0>) tensor(0.6780, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0260, grad_fn=<SumBackward0>)
# EPOCH: 13 loss: 37.96211242675781
# loss  tensor(0.6987, grad_fn=<AddBackward0>) tensor(0.6763, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0224, grad_fn=<SumBackward0>)
# EPOCH: 14 loss: 37.85431671142578
# loss  tensor(0.6949, grad_fn=<AddBackward0>) tensor(0.6751, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0198, grad_fn=<SumBackward0>)
# EPOCH: 15 loss: 37.77513122558594
# loss  tensor(0.6906, grad_fn=<AddBackward0>) tensor(0.6731, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0176, grad_fn=<SumBackward0>)
# EPOCH: 16 loss: 37.66864013671875
# loss  tensor(0.6877, grad_fn=<AddBackward0>) tensor(0.6720, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0157, grad_fn=<SumBackward0>)
# EPOCH: 17 loss: 37.58806228637695
# loss  tensor(0.6844, grad_fn=<AddBackward0>) tensor(0.6703, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0141, grad_fn=<SumBackward0>)
# EPOCH: 18 loss: 37.48897933959961
# loss  tensor(0.6816, grad_fn=<AddBackward0>) tensor(0.6689, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0127, grad_fn=<SumBackward0>)
# EPOCH: 19 loss: 37.38174819946289
# loss  tensor(0.6788, grad_fn=<AddBackward0>) tensor(0.6672, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0116, grad_fn=<SumBackward0>)
# EPOCH: 20 loss: 37.30423355102539
# loss  tensor(0.6762, grad_fn=<AddBackward0>) tensor(0.6655, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0107, grad_fn=<SumBackward0>)
# EPOCH: 21 loss: 37.222537994384766
# loss  tensor(0.6735, grad_fn=<AddBackward0>) tensor(0.6639, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0096, grad_fn=<SumBackward0>)
# EPOCH: 22 loss: 37.142120361328125
# loss  tensor(0.6714, grad_fn=<AddBackward0>) tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0090, grad_fn=<SumBackward0>)
# EPOCH: 23 loss: 37.06237030029297
# loss  tensor(0.6690, grad_fn=<AddBackward0>) tensor(0.6607, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0082, grad_fn=<SumBackward0>)
# EPOCH: 24 loss: 36.963653564453125
# loss  tensor(0.6674, grad_fn=<AddBackward0>) tensor(0.6597, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0076, grad_fn=<SumBackward0>)
# EPOCH: 25 loss: 36.83464431762695
# loss  tensor(0.6650, grad_fn=<AddBackward0>) tensor(0.6579, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0071, grad_fn=<SumBackward0>)
# EPOCH: 26 loss: 36.8204460144043
# loss  tensor(0.6632, grad_fn=<AddBackward0>) tensor(0.6565, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0067, grad_fn=<SumBackward0>)
# EPOCH: 27 loss: 36.72660827636719
# loss  tensor(0.6615, grad_fn=<AddBackward0>) tensor(0.6552, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0064, grad_fn=<SumBackward0>)
# EPOCH: 28 loss: 36.630043029785156
# loss  tensor(0.6593, grad_fn=<AddBackward0>) tensor(0.6532, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0060, grad_fn=<SumBackward0>)
# EPOCH: 29 loss: 36.54683303833008
# loss  tensor(0.6583, grad_fn=<AddBackward0>) tensor(0.6526, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0056, grad_fn=<SumBackward0>)
# EPOCH: 30 loss: 36.47773742675781
# loss  tensor(0.6561, grad_fn=<AddBackward0>) tensor(0.6508, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0053, grad_fn=<SumBackward0>)
# EPOCH: 31 loss: 36.374420166015625
# loss  tensor(0.6545, grad_fn=<AddBackward0>) tensor(0.6493, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0052, grad_fn=<SumBackward0>)
# EPOCH: 32 loss: 36.327049255371094
# loss  tensor(0.6524, grad_fn=<AddBackward0>) tensor(0.6475, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0048, grad_fn=<SumBackward0>)
# EPOCH: 33 loss: 36.23698806762695
# loss  tensor(0.6508, grad_fn=<AddBackward0>) tensor(0.6462, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0046, grad_fn=<SumBackward0>)
# EPOCH: 34 loss: 36.20714569091797
# loss  tensor(0.6493, grad_fn=<AddBackward0>) tensor(0.6448, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0044, grad_fn=<SumBackward0>)
# EPOCH: 35 loss: 36.031349182128906
# loss  tensor(0.6473, grad_fn=<AddBackward0>) tensor(0.6432, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0041, grad_fn=<SumBackward0>)
# EPOCH: 36 loss: 35.94174575805664
# loss  tensor(0.6456, grad_fn=<AddBackward0>) tensor(0.6415, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0041, grad_fn=<SumBackward0>)
# EPOCH: 37 loss: 35.9268798828125
# loss  tensor(0.6441, grad_fn=<AddBackward0>) tensor(0.6404, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0038, grad_fn=<SumBackward0>)
# EPOCH: 38 loss: 35.82103729248047
# loss  tensor(0.6433, grad_fn=<AddBackward0>) tensor(0.6395, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0037, grad_fn=<SumBackward0>)
# EPOCH: 39 loss: 35.74866485595703
# loss  tensor(0.6407, grad_fn=<AddBackward0>) tensor(0.6371, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0036, grad_fn=<SumBackward0>)
# EPOCH: 40 loss: 35.67164993286133
# loss  tensor(0.6396, grad_fn=<AddBackward0>) tensor(0.6362, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0034, grad_fn=<SumBackward0>)
# EPOCH: 41 loss: 35.61115264892578
# loss  tensor(0.6394, grad_fn=<AddBackward0>) tensor(0.6361, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0033, grad_fn=<SumBackward0>)
# EPOCH: 42 loss: 35.46900939941406
# loss  tensor(0.6377, grad_fn=<AddBackward0>) tensor(0.6342, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0035, grad_fn=<SumBackward0>)
# EPOCH: 43 loss: 35.398582458496094
# loss  tensor(0.6354, grad_fn=<AddBackward0>) tensor(0.6321, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0034, grad_fn=<SumBackward0>)
# EPOCH: 44 loss: 35.27104187011719
# loss  tensor(0.6338, grad_fn=<AddBackward0>) tensor(0.6308, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0030, grad_fn=<SumBackward0>)
# EPOCH: 45 loss: 35.271141052246094
# loss  tensor(0.6323, grad_fn=<AddBackward0>) tensor(0.6293, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0030, grad_fn=<SumBackward0>)
# EPOCH: 46 loss: 35.15410232543945
# loss  tensor(0.6302, grad_fn=<AddBackward0>) tensor(0.6274, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0028, grad_fn=<SumBackward0>)
# EPOCH: 47 loss: 35.12355041503906
# loss  tensor(0.6286, grad_fn=<AddBackward0>) tensor(0.6257, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0029, grad_fn=<SumBackward0>)
# EPOCH: 48 loss: 35.01901626586914
# loss  tensor(0.6279, grad_fn=<AddBackward0>) tensor(0.6249, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0030, grad_fn=<SumBackward0>)
# EPOCH: 49 loss: 34.985111236572266
# loss  tensor(0.6258, grad_fn=<AddBackward0>) tensor(0.6231, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0028, grad_fn=<SumBackward0>)
# EPOCH: 50 loss: 34.9138298034668
# loss  tensor(0.6244, grad_fn=<AddBackward0>) tensor(0.6216, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0028, grad_fn=<SumBackward0>)
# EPOCH: 51 loss: 34.80844497680664
# loss  tensor(0.6233, grad_fn=<AddBackward0>) tensor(0.6207, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0026, grad_fn=<SumBackward0>)
# EPOCH: 52 loss: 34.73424530029297
# loss  tensor(0.6214, grad_fn=<AddBackward0>) tensor(0.6188, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0026, grad_fn=<SumBackward0>)
# EPOCH: 53 loss: 34.615020751953125
# loss  tensor(0.6198, grad_fn=<AddBackward0>) tensor(0.6174, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0024, grad_fn=<SumBackward0>)
# EPOCH: 54 loss: 34.541587829589844
# loss  tensor(0.6177, grad_fn=<AddBackward0>) tensor(0.6154, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0023, grad_fn=<SumBackward0>)
# EPOCH: 55 loss: 34.469459533691406
# loss  tensor(0.6178, grad_fn=<AddBackward0>) tensor(0.6156, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0023, grad_fn=<SumBackward0>)
# EPOCH: 56 loss: 34.350650787353516
# loss  tensor(0.6144, grad_fn=<AddBackward0>) tensor(0.6121, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0023, grad_fn=<SumBackward0>)
# EPOCH: 57 loss: 34.33625030517578
# loss  tensor(0.6150, grad_fn=<AddBackward0>) tensor(0.6125, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0025, grad_fn=<SumBackward0>)
# EPOCH: 58 loss: 34.30093765258789
# loss  tensor(0.6133, grad_fn=<AddBackward0>) tensor(0.6109, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0023, grad_fn=<SumBackward0>)
# EPOCH: 59 loss: 34.19059753417969
# loss  tensor(0.6118, grad_fn=<AddBackward0>) tensor(0.6095, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0023, grad_fn=<SumBackward0>)
# EPOCH: 60 loss: 34.02846145629883
# loss  tensor(0.6106, grad_fn=<AddBackward0>) tensor(0.6086, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 61 loss: 33.964073181152344
# loss  tensor(0.6083, grad_fn=<AddBackward0>) tensor(0.6062, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0021, grad_fn=<SumBackward0>)
# EPOCH: 62 loss: 33.8350715637207
# loss  tensor(0.6074, grad_fn=<AddBackward0>) tensor(0.6053, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 63 loss: 33.81124496459961
# loss  tensor(0.6052, grad_fn=<AddBackward0>) tensor(0.6032, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 64 loss: 33.7181282043457
# loss  tensor(0.6044, grad_fn=<AddBackward0>) tensor(0.6025, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0019, grad_fn=<SumBackward0>)
# EPOCH: 65 loss: 33.63184356689453
# loss  tensor(0.6013, grad_fn=<AddBackward0>) tensor(0.5992, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 66 loss: 33.63930130004883
# loss  tensor(0.5993, grad_fn=<AddBackward0>) tensor(0.5973, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 67 loss: 33.46282958984375
# loss  tensor(0.5989, grad_fn=<AddBackward0>) tensor(0.5967, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0022, grad_fn=<SumBackward0>)
# EPOCH: 68 loss: 33.421878814697266
# loss  tensor(0.5981, grad_fn=<AddBackward0>) tensor(0.5961, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 69 loss: 33.40019226074219
# loss  tensor(0.5965, grad_fn=<AddBackward0>) tensor(0.5945, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 70 loss: 33.266326904296875
# loss  tensor(0.5950, grad_fn=<AddBackward0>) tensor(0.5929, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0021, grad_fn=<SumBackward0>)
# EPOCH: 71 loss: 33.21885681152344
# loss  tensor(0.5929, grad_fn=<AddBackward0>) tensor(0.5911, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 72 loss: 33.085330963134766
# loss  tensor(0.5925, grad_fn=<AddBackward0>) tensor(0.5904, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 73 loss: 32.9576416015625
# loss  tensor(0.5904, grad_fn=<AddBackward0>) tensor(0.5886, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 74 loss: 32.983642578125
# loss  tensor(0.5888, grad_fn=<AddBackward0>) tensor(0.5868, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0020, grad_fn=<SumBackward0>)
# EPOCH: 75 loss: 32.87424850463867
# loss  tensor(0.5887, grad_fn=<AddBackward0>) tensor(0.5869, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 76 loss: 32.822288513183594
# loss  tensor(0.5852, grad_fn=<AddBackward0>) tensor(0.5836, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0017, grad_fn=<SumBackward0>)
# EPOCH: 77 loss: 32.73775863647461
# loss  tensor(0.5849, grad_fn=<AddBackward0>) tensor(0.5830, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0019, grad_fn=<SumBackward0>)
# EPOCH: 78 loss: 32.655818939208984
# loss  tensor(0.5835, grad_fn=<AddBackward0>) tensor(0.5818, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0017, grad_fn=<SumBackward0>)
# EPOCH: 79 loss: 32.54046630859375
# loss  tensor(0.5830, grad_fn=<AddBackward0>) tensor(0.5813, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0017, grad_fn=<SumBackward0>)
# EPOCH: 80 loss: 32.447017669677734
# loss  tensor(0.5811, grad_fn=<AddBackward0>) tensor(0.5792, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0019, grad_fn=<SumBackward0>)
# EPOCH: 81 loss: 32.432132720947266
# loss  tensor(0.5791, grad_fn=<AddBackward0>) tensor(0.5773, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 82 loss: 32.26521682739258
# loss  tensor(0.5781, grad_fn=<AddBackward0>) tensor(0.5765, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 83 loss: 32.24929428100586
# loss  tensor(0.5780, grad_fn=<AddBackward0>) tensor(0.5763, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0017, grad_fn=<SumBackward0>)
# EPOCH: 84 loss: 32.12427520751953
# loss  tensor(0.5728, grad_fn=<AddBackward0>) tensor(0.5713, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 85 loss: 32.0052375793457
# loss  tensor(0.5726, grad_fn=<AddBackward0>) tensor(0.5708, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 86 loss: 31.93135643005371
# loss  tensor(0.5725, grad_fn=<AddBackward0>) tensor(0.5709, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 87 loss: 31.888254165649414
# loss  tensor(0.5715, grad_fn=<AddBackward0>) tensor(0.5700, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 88 loss: 31.848955154418945
# loss  tensor(0.5685, grad_fn=<AddBackward0>) tensor(0.5667, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 89 loss: 31.799985885620117
# loss  tensor(0.5678, grad_fn=<AddBackward0>) tensor(0.5661, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 90 loss: 31.69011116027832
# loss  tensor(0.5658, grad_fn=<AddBackward0>) tensor(0.5642, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 91 loss: 31.571582794189453
# loss  tensor(0.5654, grad_fn=<AddBackward0>) tensor(0.5639, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 92 loss: 31.49176788330078
# loss  tensor(0.5636, grad_fn=<AddBackward0>) tensor(0.5619, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0017, grad_fn=<SumBackward0>)
# EPOCH: 93 loss: 31.367429733276367
# loss  tensor(0.5620, grad_fn=<AddBackward0>) tensor(0.5603, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0017, grad_fn=<SumBackward0>)
# EPOCH: 94 loss: 31.347911834716797
# loss  tensor(0.5598, grad_fn=<AddBackward0>) tensor(0.5582, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 95 loss: 31.232479095458984
# loss  tensor(0.5582, grad_fn=<AddBackward0>) tensor(0.5565, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0017, grad_fn=<SumBackward0>)
# EPOCH: 96 loss: 31.117944717407227
# loss  tensor(0.5554, grad_fn=<AddBackward0>) tensor(0.5536, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 97 loss: 31.096311569213867
# loss  tensor(0.5556, grad_fn=<AddBackward0>) tensor(0.5541, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 98 loss: 31.04646110534668
# loss  tensor(0.5545, grad_fn=<AddBackward0>) tensor(0.5529, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 99 loss: 30.9475040435791
# loss  tensor(0.5532, grad_fn=<AddBackward0>) tensor(0.5514, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0018, grad_fn=<SumBackward0>)
# EPOCH: 100 loss: 30.809600830078125
# loss  tensor(0.5524, grad_fn=<AddBackward0>) tensor(0.5509, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 101 loss: 30.72307777404785
# loss  tensor(0.5509, grad_fn=<AddBackward0>) tensor(0.5490, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0019, grad_fn=<SumBackward0>)
# EPOCH: 102 loss: 30.672922134399414
# loss  tensor(0.5496, grad_fn=<AddBackward0>) tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 103 loss: 30.587892532348633
# loss  tensor(0.5475, grad_fn=<AddBackward0>) tensor(0.5459, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 104 loss: 30.514432907104492
# loss  tensor(0.5467, grad_fn=<AddBackward0>) tensor(0.5452, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 105 loss: 30.525421142578125
# loss  tensor(0.5456, grad_fn=<AddBackward0>) tensor(0.5441, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 106 loss: 30.374441146850586
# loss  tensor(0.5430, grad_fn=<AddBackward0>) tensor(0.5415, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 107 loss: 30.26768684387207
# loss  tensor(0.5408, grad_fn=<AddBackward0>) tensor(0.5392, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 108 loss: 30.21959686279297
# loss  tensor(0.5411, grad_fn=<AddBackward0>) tensor(0.5396, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 109 loss: 30.161680221557617
# loss  tensor(0.5391, grad_fn=<AddBackward0>) tensor(0.5378, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0013, grad_fn=<SumBackward0>)
# EPOCH: 110 loss: 30.138917922973633
# loss  tensor(0.5389, grad_fn=<AddBackward0>) tensor(0.5374, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 111 loss: 30.005353927612305
# loss  tensor(0.5366, grad_fn=<AddBackward0>) tensor(0.5352, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 112 loss: 29.969181060791016
# loss  tensor(0.5352, grad_fn=<AddBackward0>) tensor(0.5336, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 113 loss: 29.948060989379883
# loss  tensor(0.5325, grad_fn=<AddBackward0>) tensor(0.5310, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 114 loss: 29.80191993713379
# loss  tensor(0.5313, grad_fn=<AddBackward0>) tensor(0.5301, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0013, grad_fn=<SumBackward0>)
# EPOCH: 115 loss: 29.770973205566406
# loss  tensor(0.5308, grad_fn=<AddBackward0>) tensor(0.5295, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 116 loss: 29.644145965576172
# loss  tensor(0.5309, grad_fn=<AddBackward0>) tensor(0.5294, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 117 loss: 29.63921356201172
# loss  tensor(0.5279, grad_fn=<AddBackward0>) tensor(0.5265, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 118 loss: 29.528301239013672
# loss  tensor(0.5272, grad_fn=<AddBackward0>) tensor(0.5258, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 119 loss: 29.441160202026367
# loss  tensor(0.5278, grad_fn=<AddBackward0>) tensor(0.5262, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 120 loss: 29.353818893432617
# loss  tensor(0.5253, grad_fn=<AddBackward0>) tensor(0.5237, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0016, grad_fn=<SumBackward0>)
# EPOCH: 121 loss: 29.274263381958008
# loss  tensor(0.5215, grad_fn=<AddBackward0>) tensor(0.5200, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 122 loss: 29.152170181274414
# loss  tensor(0.5205, grad_fn=<AddBackward0>) tensor(0.5191, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 123 loss: 29.14470100402832
# loss  tensor(0.5213, grad_fn=<AddBackward0>) tensor(0.5197, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 124 loss: 29.062000274658203
# loss  tensor(0.5206, grad_fn=<AddBackward0>) tensor(0.5192, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 125 loss: 28.916181564331055
# loss  tensor(0.5184, grad_fn=<AddBackward0>) tensor(0.5170, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0014, grad_fn=<SumBackward0>)
# EPOCH: 126 loss: 28.90898895263672
# loss  tensor(0.5183, grad_fn=<AddBackward0>) tensor(0.5168, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 127 loss: 28.852649688720703
# loss  tensor(0.5157, grad_fn=<AddBackward0>) tensor(0.5142, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0015, grad_fn=<SumBackward0>)
# EPOCH: 128 loss: 28.694171905517578
# loss  tensor(0.5136, grad_fn=<AddBackward0>) tensor(0.5124, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0012, grad_fn=<SumBackward0>)
# EPOCH: 129 loss: 28.698524475097656
# loss  tensor(0.5124, grad_fn=<AddBackward0>) tensor(0.5113, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0011, grad_fn=<SumBackward0>)
# EPOCH: 130 loss: 28.605287551879883
# loss  tensor(0.5123, grad_fn=<AddBackward0>) tensor(0.5110, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0013, grad_fn=<SumBackward0>)
# EPOCH: 131 loss: 28.537534713745117
# loss  tensor(0.5104, grad_fn=<AddBackward0>) tensor(0.5092, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0012, grad_fn=<SumBackward0>)
# EPOCH: 132 loss: 28.454256057739258
# loss  tensor(0.5103, grad_fn=<AddBackward0>) tensor(0.5092, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0011, grad_fn=<SumBackward0>)
# EPOCH: 133 loss: 28.511390686035156
# loss  tensor(0.5079, grad_fn=<AddBackward0>) tensor(0.5068, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0011, grad_fn=<SumBackward0>)
# EPOCH: 134 loss: 28.33724594116211
# loss  tensor(0.5076, grad_fn=<AddBackward0>) tensor(0.5065, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0011, grad_fn=<SumBackward0>)
# EPOCH: 135 loss: 28.274091720581055
# loss  tensor(0.5062, grad_fn=<AddBackward0>) tensor(0.5051, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0011, grad_fn=<SumBackward0>)
# EPOCH: 136 loss: 28.302881240844727
# loss  tensor(0.5054, grad_fn=<AddBackward0>) tensor(0.5043, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0011, grad_fn=<SumBackward0>)
# EPOCH: 137 loss: 28.150293350219727
# loss  tensor(0.5029, grad_fn=<AddBackward0>) tensor(0.5020, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 138 loss: 28.054367065429688
# loss  tensor(0.5027, grad_fn=<AddBackward0>) tensor(0.5016, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0011, grad_fn=<SumBackward0>)
# EPOCH: 139 loss: 28.04681968688965
# loss  tensor(0.5017, grad_fn=<AddBackward0>) tensor(0.5008, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0009, grad_fn=<SumBackward0>)
# EPOCH: 140 loss: 27.988323211669922
# loss  tensor(0.4991, grad_fn=<AddBackward0>) tensor(0.4982, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0009, grad_fn=<SumBackward0>)
# EPOCH: 141 loss: 27.970205307006836
# loss  tensor(0.4983, grad_fn=<AddBackward0>) tensor(0.4974, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0009, grad_fn=<SumBackward0>)
# EPOCH: 142 loss: 27.87876319885254
# loss  tensor(0.4978, grad_fn=<AddBackward0>) tensor(0.4968, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 143 loss: 27.771780014038086
# loss  tensor(0.4974, grad_fn=<AddBackward0>) tensor(0.4964, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 144 loss: 27.6491641998291
# loss  tensor(0.4946, grad_fn=<AddBackward0>) tensor(0.4937, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0009, grad_fn=<SumBackward0>)
# EPOCH: 145 loss: 27.749155044555664
# loss  tensor(0.4963, grad_fn=<AddBackward0>) tensor(0.4953, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 146 loss: 27.692771911621094
# loss  tensor(0.4930, grad_fn=<AddBackward0>) tensor(0.4920, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 147 loss: 27.62856674194336
# loss  tensor(0.4920, grad_fn=<AddBackward0>) tensor(0.4911, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0009, grad_fn=<SumBackward0>)
# EPOCH: 148 loss: 27.56670379638672
# loss  tensor(0.4912, grad_fn=<AddBackward0>) tensor(0.4902, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 149 loss: 27.48771095275879
# loss  tensor(0.4901, grad_fn=<AddBackward0>) tensor(0.4891, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 150 loss: 27.31584930419922
# loss  tensor(0.4888, grad_fn=<AddBackward0>) tensor(0.4880, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0008, grad_fn=<SumBackward0>)
# EPOCH: 151 loss: 27.37704849243164
# loss  tensor(0.4883, grad_fn=<AddBackward0>) tensor(0.4874, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0009, grad_fn=<SumBackward0>)
# EPOCH: 152 loss: 27.23902130126953
# loss  tensor(0.4881, grad_fn=<AddBackward0>) tensor(0.4872, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 153 loss: 27.182647705078125
# loss  tensor(0.4865, grad_fn=<AddBackward0>) tensor(0.4855, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0010, grad_fn=<SumBackward0>)
# EPOCH: 154 loss: 27.213912963867188
# loss  tensor(0.4860, grad_fn=<AddBackward0>) tensor(0.4853, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0008, grad_fn=<SumBackward0>)
# EPOCH: 155 loss: 27.094730377197266
# loss  tensor(0.4852, grad_fn=<AddBackward0>) tensor(0.4845, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0007, grad_fn=<SumBackward0>)
# EPOCH: 156 loss: 27.126123428344727
# loss  tensor(0.4848, grad_fn=<AddBackward0>) tensor(0.4840, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0009, grad_fn=<SumBackward0>)
# EPOCH: 157 loss: 27.01902961730957
# loss  tensor(0.4819, grad_fn=<AddBackward0>) tensor(0.4810, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0009, grad_fn=<SumBackward0>)
# EPOCH: 158 loss: 26.98322105407715
# loss  tensor(0.4825, grad_fn=<AddBackward0>) tensor(0.4818, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0007, grad_fn=<SumBackward0>)
# EPOCH: 159 loss: 26.86874008178711
# loss  tensor(0.4804, grad_fn=<AddBackward0>) tensor(0.4796, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0008, grad_fn=<SumBackward0>)
# EPOCH: 160 loss: 26.808700561523438
# loss  tensor(0.4801, grad_fn=<AddBackward0>) tensor(0.4794, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0008, grad_fn=<SumBackward0>)
# EPOCH: 161 loss: 26.87196159362793
# loss  tensor(0.4792, grad_fn=<AddBackward0>) tensor(0.4786, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0007, grad_fn=<SumBackward0>)
# EPOCH: 162 loss: 26.74871826171875
# loss  tensor(0.4784, grad_fn=<AddBackward0>) tensor(0.4777, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0007, grad_fn=<SumBackward0>)
# EPOCH: 163 loss: 26.68349266052246
# loss  tensor(0.4774, grad_fn=<AddBackward0>) tensor(0.4766, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0007, grad_fn=<SumBackward0>)
# EPOCH: 164 loss: 26.68947982788086
# loss  tensor(0.4776, grad_fn=<AddBackward0>) tensor(0.4769, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0007, grad_fn=<SumBackward0>)
# EPOCH: 165 loss: 26.624027252197266
# loss  tensor(0.4763, grad_fn=<AddBackward0>) tensor(0.4756, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0007, grad_fn=<SumBackward0>)
# EPOCH: 166 loss: 26.525144577026367
# loss  tensor(0.4751, grad_fn=<AddBackward0>) tensor(0.4744, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0007, grad_fn=<SumBackward0>)
# EPOCH: 167 loss: 26.54168128967285
# loss  tensor(0.4752, grad_fn=<AddBackward0>) tensor(0.4745, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 168 loss: 26.479156494140625
# loss  tensor(0.4725, grad_fn=<AddBackward0>) tensor(0.4719, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 169 loss: 26.403884887695312
# loss  tensor(0.4724, grad_fn=<AddBackward0>) tensor(0.4718, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 170 loss: 26.33922004699707
# loss  tensor(0.4720, grad_fn=<AddBackward0>) tensor(0.4714, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 171 loss: 26.409574508666992
# loss  tensor(0.4705, grad_fn=<AddBackward0>) tensor(0.4699, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 172 loss: 26.355545043945312
# loss  tensor(0.4707, grad_fn=<AddBackward0>) tensor(0.4701, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 173 loss: 26.262170791625977
# loss  tensor(0.4699, grad_fn=<AddBackward0>) tensor(0.4692, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 174 loss: 26.252588272094727
# loss  tensor(0.4682, grad_fn=<AddBackward0>) tensor(0.4676, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 175 loss: 26.1856632232666
# loss  tensor(0.4684, grad_fn=<AddBackward0>) tensor(0.4679, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0005, grad_fn=<SumBackward0>)
# EPOCH: 176 loss: 26.174840927124023
# loss  tensor(0.4673, grad_fn=<AddBackward0>) tensor(0.4668, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 177 loss: 26.156709671020508
# loss  tensor(0.4659, grad_fn=<AddBackward0>) tensor(0.4654, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0006, grad_fn=<SumBackward0>)
# EPOCH: 178 loss: 26.096179962158203
# loss  tensor(0.4660, grad_fn=<AddBackward0>) tensor(0.4655, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 179 loss: 26.110530853271484
# loss  tensor(0.4653, grad_fn=<AddBackward0>) tensor(0.4648, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0005, grad_fn=<SumBackward0>)
# EPOCH: 180 loss: 26.034210205078125
# loss  tensor(0.4647, grad_fn=<AddBackward0>) tensor(0.4642, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0005, grad_fn=<SumBackward0>)
# EPOCH: 181 loss: 26.039466857910156
# loss  tensor(0.4641, grad_fn=<AddBackward0>) tensor(0.4636, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 182 loss: 25.91067123413086
# loss  tensor(0.4633, grad_fn=<AddBackward0>) tensor(0.4629, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 183 loss: 25.920475006103516
# loss  tensor(0.4618, grad_fn=<AddBackward0>) tensor(0.4613, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0005, grad_fn=<SumBackward0>)
# EPOCH: 184 loss: 25.891563415527344
# loss  tensor(0.4622, grad_fn=<AddBackward0>) tensor(0.4618, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 185 loss: 25.840801239013672
# loss  tensor(0.4612, grad_fn=<AddBackward0>) tensor(0.4608, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 186 loss: 25.787172317504883
# loss  tensor(0.4606, grad_fn=<AddBackward0>) tensor(0.4602, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 187 loss: 25.768552780151367
# loss  tensor(0.4605, grad_fn=<AddBackward0>) tensor(0.4601, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 188 loss: 25.716957092285156
# loss  tensor(0.4595, grad_fn=<AddBackward0>) tensor(0.4591, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 189 loss: 25.759239196777344
# loss  tensor(0.4589, grad_fn=<AddBackward0>) tensor(0.4585, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 190 loss: 25.658071517944336
# loss  tensor(0.4587, grad_fn=<AddBackward0>) tensor(0.4584, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0003, grad_fn=<SumBackward0>)
# EPOCH: 191 loss: 25.667409896850586
# loss  tensor(0.4577, grad_fn=<AddBackward0>) tensor(0.4573, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 192 loss: 25.643688201904297
# loss  tensor(0.4575, grad_fn=<AddBackward0>) tensor(0.4571, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 193 loss: 25.595993041992188
# loss  tensor(0.4572, grad_fn=<AddBackward0>) tensor(0.4568, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 194 loss: 25.541793823242188
# loss  tensor(0.4568, grad_fn=<AddBackward0>) tensor(0.4565, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0003, grad_fn=<SumBackward0>)
# EPOCH: 195 loss: 25.53534507751465
# loss  tensor(0.4562, grad_fn=<AddBackward0>) tensor(0.4558, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 196 loss: 25.549957275390625
# loss  tensor(0.4553, grad_fn=<AddBackward0>) tensor(0.4549, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0003, grad_fn=<SumBackward0>)
# EPOCH: 197 loss: 25.4658260345459
# loss  tensor(0.4546, grad_fn=<AddBackward0>) tensor(0.4543, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0003, grad_fn=<SumBackward0>)
# EPOCH: 198 loss: 25.481708526611328
# loss  tensor(0.4551, grad_fn=<AddBackward0>) tensor(0.4547, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0004, grad_fn=<SumBackward0>)
# EPOCH: 199 loss: 25.40416145324707
# loss  tensor(0.4531, grad_fn=<AddBackward0>) tensor(0.4528, grad_fn=<BinaryCrossEntropyBackward>) tensor(0.0003, grad_fn=<SumBackward0>)

# %% [markdown]
# 学習の収束の図化 (python)

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %%
n_img2=10
x2=x[:n_img2]

o = net.out.to('cpu').detach().numpy().copy()

plt.figure( figsize=(10,2))
for i in range(n_img2):
  #input image
  ax = plt.subplot(3,n_img2,i+1)
  plt.imshow( x2[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  #output image
  ax = plt.subplot(3,n_img2,i+1+n_img2)
  plt.imshow( o[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %%
t2 = t_train #[:n_batch]

plt.figure(figsize=(8,8))
for i in range(10):
  zt = net.z[t2==i]
  z_1 = zt[:,0]
  z_2 = zt[:,1]
  marker= "$"+str(i)+"$"
  plt.scatter(z_2.tolist(), z_1.tolist(), marker=marker,s=75)

plt.xlabel("z_2")
plt.ylabel("z_1")
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid()
plt.show()

# %%
n_img3=16
img_size_spaced = img_size + 2
matrix_image = np.zeros(( img_size_spaced*n_img3, img_size_spaced*n_img3 ))

z_1 = np.linspace( 3, -3, n_img3 )
z_2 = np.linspace( 3, -3, n_img3 )

with torch.set_grad_enabled(False):
  for i, z1 in enumerate(z_1):
    for j,z2 in enumerate(z_2):

      z = np.array([z1, z2])
      zz = torch.from_numpy( z ).float()
      
      y = F.relu( net.fc3(zz) )
      o = torch.sigmoid( net.fc4(y) )
      image = o.reshape(img_size, img_size)
      top  = i * img_size_spaced
      left = j * img_size_spaced
      matrix_image[top:top+img_size, left:left+img_size] = image

plt.figure(figsize=(8,8))
plt.imshow( matrix_image.tolist(), cmap="Greys_r" )
plt.tick_params( labelbottom=False, labelleft=False, bottom=False, left=False )
plt.show()

# %% [markdown]
# 最適化実行

# %% [markdown]
# 全入力データを vae2_data.cpp に出力する. ( vae1_data.cppと同じ)

# %%
def output_datafile( folder, project, in_data ):
    data_fname = project + "_data.cpp"
    data_path  = folder + "/" + data_fname

    # save data file
    code = CV.c_data_generator( in_data )
    if len( code ) > 0:
       print( "[DATA]", data_path )
       ofparam = open( data_path, "w" )
       ofparam.write( code )

output_datafile( "../src", project, dd )
# Out:
# param: indata  - str loop  5000  /  14375
# param: indata  - str loop  10000  /  14375
# [DATA] ../src/vae1_data.cpp

# %%
# !g++ -std=c++14 ../src/vae2.cpp ../src/vae2_param.cpp  ../src/vae1_data.cpp ../src/vae2_train.cpp -I ../../../xtensor -lcblas -o ../bin/vae2_train

# %% [markdown]
# (注意) xtensorにxtensor関連のincludeを置いています。各自の環境に合わせて変更して下さい。

# %%
# !../bin/vae2_train
# Out:
# indata 1797,64
# batch  56,32
# epoch_num : 200
# total_loss 0 loss-42.9931
# epoch 0 - loss { 2.03243 } (  0.699403 , { 1.333027} )
# total_loss 1 loss-39.9503
# epoch 1 - loss { 1.241983} (  0.69745  , { 0.544533} )
# total_loss 2 loss-39.3924
# epoch 2 - loss { 1.005754} (  0.695129 , { 0.310625} )
# total_loss 3 loss-39.102
# epoch 3 - loss { 0.890006} (  0.693781 , { 0.196225} )
# total_loss 4 loss-38.9617
# epoch 4 - loss { 0.824428} (  0.691774 , { 0.132654} )
# total_loss 5 loss-38.7827
# epoch 5 - loss { 0.787032} (  0.689885 , { 0.097147} )
# total_loss 6 loss-38.6474
# epoch 6 - loss { 0.762749} (  0.687791 , { 0.074958} )
# total_loss 7 loss-38.5406
# epoch 7 - loss { 0.746094} (  0.686235 , { 0.059859} )
# total_loss 8 loss-38.4299
# epoch 8 - loss { 0.732967} (  0.684519 , { 0.048448} )
# total_loss 9 loss-38.3523
# epoch 9 - loss { 0.723055} (  0.683008 , { 0.040047} )
# total_loss 10 loss-38.234
# epoch 10 - loss { 0.714784} (  0.681151 , { 0.033632} )
# total_loss 11 loss-38.1429
# epoch 11 - loss { 0.708046} (  0.679683 , { 0.028363} )
# total_loss 12 loss-38.0334
# epoch 12 - loss { 0.702309} (  0.677787 , { 0.024522} )
# total_loss 13 loss-37.9408
# epoch 13 - loss { 0.697234} (  0.676053 , { 0.021182} )
# total_loss 14 loss-37.856
# epoch 14 - loss { 0.693655} (  0.675048 , { 0.018607} )
# total_loss 15 loss-37.767
# epoch 15 - loss { 0.690148} (  0.673484 , { 0.016664} )
# total_loss 16 loss-37.6493
# epoch 16 - loss { 0.686773} (  0.671825 , { 0.014948} )
# total_loss 17 loss-37.5884
# epoch 17 - loss { 0.683383} (  0.67001  , { 0.013373} )
# total_loss 18 loss-37.4795
# epoch 18 - loss { 0.680911} (  0.66871  , { 0.012202} )
# total_loss 19 loss-37.4024
# epoch 19 - loss { 0.677763} (  0.666776 , { 0.010987} )
# total_loss 20 loss-37.3202
# epoch 20 - loss { 0.675662} (  0.665441 , { 0.010221} )
# total_loss 21 loss-37.237
# epoch 21 - loss { 0.672792} (  0.663526 , { 0.009266} )
# total_loss 22 loss-37.1455
# epoch 22 - loss { 0.670292} (  0.661674 , { 0.008618} )
# total_loss 23 loss-37.0489
# epoch 23 - loss { 0.669262} (  0.661359 , { 0.007903} )
# total_loss 24 loss-37.0014
# epoch 24 - loss { 0.666203} (  0.658837 , { 0.007366} )
# total_loss 25 loss-36.8945
# epoch 25 - loss { 0.664792} (  0.657864 , { 0.006928} )
# total_loss 26 loss-36.8027
# epoch 26 - loss { 0.662757} (  0.656306 , { 0.006451} )
# total_loss 27 loss-36.7
# epoch 27 - loss { 0.660837} (  0.654658 , { 0.006179} )
# total_loss 28 loss-36.6168
# epoch 28 - loss { 0.658634} (  0.652774 , { 0.00586 } )
# total_loss 29 loss-36.5802
# epoch 29 - loss { 0.657342} (  0.651735 , { 0.005607} )
# total_loss 30 loss-36.4423
# epoch 30 - loss { 0.656315} (  0.651074 , { 0.005241} )
# total_loss 31 loss-36.3671
# epoch 31 - loss { 0.653537} (  0.648504 , { 0.005033} )
# total_loss 32 loss-36.3418
# epoch 32 - loss { 0.652915} (  0.648133 , { 0.004782} )
# total_loss 33 loss-36.1847
# epoch 33 - loss { 0.650521} (  0.646071 , { 0.00445 } )
# total_loss 34 loss-36.1684
# epoch 34 - loss { 0.649258} (  0.644957 , { 0.004301} )
# total_loss 35 loss-36.0751
# epoch 35 - loss { 0.647233} (  0.643014 , { 0.004219} )
# total_loss 36 loss-35.9511
# epoch 36 - loss { 0.645505} (  0.641522 , { 0.003984} )
# total_loss 37 loss-35.9144
# epoch 37 - loss { 0.644312} (  0.640512 , { 0.003801} )
# total_loss 38 loss-35.8365
# epoch 38 - loss { 0.642777} (  0.639148 , { 0.003629} )
# total_loss 39 loss-35.6863
# epoch 39 - loss { 0.641545} (  0.638031 , { 0.003514} )
# total_loss 40 loss-35.6886
# epoch 40 - loss { 0.638933} (  0.635554 , { 0.003379} )
# total_loss 41 loss-35.5739
# epoch 41 - loss { 0.637772} (  0.634518 , { 0.003254} )
# total_loss 42 loss-35.4562
# epoch 42 - loss { 0.635336} (  0.632049 , { 0.003287} )
# total_loss 43 loss-35.3838
# epoch 43 - loss { 0.634856} (  0.631713 , { 0.003143} )
# total_loss 44 loss-35.3917
# epoch 44 - loss { 0.632829} (  0.629897 , { 0.002932} )
# total_loss 45 loss-35.2887
# epoch 45 - loss { 0.631955} (  0.629015 , { 0.00294 } )
# total_loss 46 loss-35.1978
# epoch 46 - loss { 0.630904} (  0.628054 , { 0.00285 } )
# total_loss 47 loss-35.1336
# epoch 47 - loss { 0.628717} (  0.62595  , { 0.002767} )
# total_loss 48 loss-34.9886
# epoch 48 - loss { 0.626733} (  0.624044 , { 0.002689} )
# total_loss 49 loss-34.8872
# epoch 49 - loss { 0.625162} (  0.62254  , { 0.002622} )
# total_loss 50 loss-34.8297
# epoch 50 - loss { 0.624549} (  0.622021 , { 0.002528} )
# total_loss 51 loss-34.8599
# epoch 51 - loss { 0.623329} (  0.620859 , { 0.00247 } )
# total_loss 52 loss-34.6815
# epoch 52 - loss { 0.62202 } (  0.619485 , { 0.002535} )
# total_loss 53 loss-34.589
# epoch 53 - loss { 0.620627} (  0.617908 , { 0.002719} )
# total_loss 54 loss-34.4933
# epoch 54 - loss { 0.618255} (  0.615863 , { 0.002392} )
# total_loss 55 loss-34.4728
# epoch 55 - loss { 0.617752} (  0.615407 , { 0.002345} )
# total_loss 56 loss-34.4058
# epoch 56 - loss { 0.614755} (  0.612329 , { 0.002425} )
# total_loss 57 loss-34.2806
# epoch 57 - loss { 0.613161} (  0.610947 , { 0.002215} )
# total_loss 58 loss-34.2161
# epoch 58 - loss { 0.611243} (  0.608945 , { 0.002298} )
# total_loss 59 loss-34.1385
# epoch 59 - loss { 0.610395} (  0.608111 , { 0.002285} )
# total_loss 60 loss-34.0121
# epoch 60 - loss { 0.610251} (  0.608171 , { 0.00208 } )
# total_loss 61 loss-34.0241
# epoch 61 - loss { 0.607691} (  0.605498 , { 0.002193} )
# total_loss 62 loss-33.9598
# epoch 62 - loss { 0.605408} (  0.603314 , { 0.002094} )
# total_loss 63 loss-33.8058
# epoch 63 - loss { 0.605461} (  0.60327  , { 0.002191} )
# total_loss 64 loss-33.7045
# epoch 64 - loss { 0.60371 } (  0.601658 , { 0.002051} )
# total_loss 65 loss-33.6761
# epoch 65 - loss { 0.602948} (  0.600827 , { 0.002121} )
# total_loss 66 loss-33.5776
# epoch 66 - loss { 0.600366} (  0.598425 , { 0.001941} )
# total_loss 67 loss-33.4962
# epoch 67 - loss { 0.598961} (  0.596935 , { 0.002026} )
# total_loss 68 loss-33.3846
# epoch 68 - loss { 0.597267} (  0.595138 , { 0.002129} )
# total_loss 69 loss-33.2434
# epoch 69 - loss { 0.596535} (  0.594569 , { 0.001966} )
# total_loss 70 loss-33.2897
# epoch 70 - loss { 0.594922} (  0.592885 , { 0.002037} )
# total_loss 71 loss-33.1509
# epoch 71 - loss { 0.593888} (  0.591983 , { 0.001904} )
# total_loss 72 loss-33.0964
# epoch 72 - loss { 0.591869} (  0.589751 , { 0.002118} )
# total_loss 73 loss-33.0084
# epoch 73 - loss { 0.590582} (  0.588626 , { 0.001956} )
# total_loss 74 loss-32.9124
# epoch 74 - loss { 0.59017 } (  0.588472 , { 0.001698} )
# total_loss 75 loss-32.7944
# epoch 75 - loss { 0.588283} (  0.586478 , { 0.001805} )
# total_loss 76 loss-32.7657
# epoch 76 - loss { 0.584844} (  0.583046 , { 0.001799} )
# total_loss 77 loss-32.6605
# epoch 77 - loss { 0.583497} (  0.581864 , { 0.001633} )
# total_loss 78 loss-32.5479
# epoch 78 - loss { 0.584223} (  0.582394 , { 0.001828} )
# total_loss 79 loss-32.533
# epoch 79 - loss { 0.581492} (  0.579681 , { 0.001811} )
# total_loss 80 loss-32.4194
# epoch 80 - loss { 0.581223} (  0.579239 , { 0.001984} )
# total_loss 81 loss-32.3653
# epoch 81 - loss { 0.578911} (  0.57727  , { 0.001641} )
# total_loss 82 loss-32.3012
# epoch 82 - loss { 0.57801 } (  0.576171 , { 0.001839} )
# total_loss 83 loss-32.25
# epoch 83 - loss { 0.577418} (  0.575672 , { 0.001746} )
# total_loss 84 loss-32.2113
# epoch 84 - loss { 0.574255} (  0.572676 , { 0.001579} )
# total_loss 85 loss-31.9822
# epoch 85 - loss { 0.574675} (  0.573008 , { 0.001667} )
# total_loss 86 loss-31.8567
# epoch 86 - loss { 0.57064 } (  0.569112 , { 0.001529} )
# total_loss 87 loss-31.8355
# epoch 87 - loss { 0.570047} (  0.568399 , { 0.001648} )
# total_loss 88 loss-31.7948
# epoch 88 - loss { 0.569531} (  0.567934 , { 0.001596} )
# total_loss 89 loss-31.679
# epoch 89 - loss { 0.567154} (  0.565663 , { 0.00149 } )
# total_loss 90 loss-31.5562
# epoch 90 - loss { 0.565991} (  0.564078 , { 0.001913} )
# total_loss 91 loss-31.5954
# epoch 91 - loss { 0.563802} (  0.562257 , { 0.001545} )
# total_loss 92 loss-31.4869
# epoch 92 - loss { 0.564302} (  0.562752 , { 0.00155 } )
# total_loss 93 loss-31.4234
# epoch 93 - loss { 0.562303} (  0.560652 , { 0.001652} )
# total_loss 94 loss-31.2656
# epoch 94 - loss { 0.560614} (  0.559327 , { 0.001287} )
# total_loss 95 loss-31.2432
# epoch 95 - loss { 0.56047 } (  0.558867 , { 0.001603} )
# total_loss 96 loss-31.1858
# epoch 96 - loss { 0.55809 } (  0.556343 , { 0.001747} )
# total_loss 97 loss-31.084
# epoch 97 - loss { 0.555576} (  0.553884 , { 0.001691} )
# total_loss 98 loss-30.9234
# epoch 98 - loss { 0.555227} (  0.553663 , { 0.001565} )
# total_loss 99 loss-30.8233
# epoch 99 - loss { 0.552823} (  0.551171 , { 0.001652} )
# total_loss 100 loss-30.8141
# epoch 100 - loss { 0.551915} (  0.55038  , { 0.001535} )
# total_loss 101 loss-30.7993
# epoch 101 - loss { 0.548714} (  0.546964 , { 0.00175 } )
# total_loss 102 loss-30.675
# epoch 102 - loss { 0.549052} (  0.54742  , { 0.001632} )
# total_loss 103 loss-30.641
# epoch 103 - loss { 0.547201} (  0.545717 , { 0.001484} )
# total_loss 104 loss-30.5652
# epoch 104 - loss { 0.546041} (  0.544342 , { 0.001699} )
# total_loss 105 loss-30.5122
# epoch 105 - loss { 0.544962} (  0.543502 , { 0.00146 } )
# total_loss 106 loss-30.3898
# epoch 106 - loss { 0.541491} (  0.540048 , { 0.001444} )
# total_loss 107 loss-30.3146
# epoch 107 - loss { 0.542588} (  0.541137 , { 0.001451} )
# total_loss 108 loss-30.2225
# epoch 108 - loss { 0.541245} (  0.5397   , { 0.001545} )
# total_loss 109 loss-30.2069
# epoch 109 - loss { 0.538625} (  0.537213 , { 0.001412} )
# total_loss 110 loss-30.0368
# epoch 110 - loss { 0.537573} (  0.536052 , { 0.00152 } )
# total_loss 111 loss-29.973
# epoch 111 - loss { 0.535427} (  0.534014 , { 0.001413} )
# total_loss 112 loss-29.8248
# epoch 112 - loss { 0.533605} (  0.532325 , { 0.00128 } )
# total_loss 113 loss-29.7892
# epoch 113 - loss { 0.533362} (  0.531877 , { 0.001486} )
# total_loss 114 loss-29.7992
# epoch 114 - loss { 0.531851} (  0.53037  , { 0.001481} )
# total_loss 115 loss-29.6937
# epoch 115 - loss { 0.529751} (  0.528278 , { 0.001473} )
# total_loss 116 loss-29.6635
# epoch 116 - loss { 0.529218} (  0.52787  , { 0.001348} )
# total_loss 117 loss-29.5837
# epoch 117 - loss { 0.526625} (  0.525072 , { 0.001553} )
# total_loss 118 loss-29.377
# epoch 118 - loss { 0.526572} (  0.525233 , { 0.001339} )
# total_loss 119 loss-29.4872
# epoch 119 - loss { 0.525647} (  0.524228 , { 0.00142 } )
# total_loss 120 loss-29.2797
# epoch 120 - loss { 0.524742} (  0.523436 , { 0.001306} )
# total_loss 121 loss-29.2407
# epoch 121 - loss { 0.523913} (  0.522504 , { 0.001409} )
# total_loss 122 loss-29.1832
# epoch 122 - loss { 0.521476} (  0.520088 , { 0.001388} )
# total_loss 123 loss-29.0958
# epoch 123 - loss { 0.51939 } (  0.517991 , { 0.001399} )
# total_loss 124 loss-29.04
# epoch 124 - loss { 0.518922} (  0.517641 , { 0.001282} )
# total_loss 125 loss-28.9485
# epoch 125 - loss { 0.518008} (  0.516639 , { 0.001369} )
# total_loss 126 loss-28.9026
# epoch 126 - loss { 0.51561 } (  0.514358 , { 0.001252} )
# total_loss 127 loss-28.8493
# epoch 127 - loss { 0.514671} (  0.51343  , { 0.001241} )
# total_loss 128 loss-28.7617
# epoch 128 - loss { 0.514654} (  0.513528 , { 0.001126} )
# total_loss 129 loss-28.7555
# epoch 129 - loss { 0.513015} (  0.511781 , { 0.001234} )
# total_loss 130 loss-28.6084
# epoch 130 - loss { 0.510946} (  0.50972  , { 0.001226} )
# total_loss 131 loss-28.4412
# epoch 131 - loss { 0.50965 } (  0.50854  , { 0.001109} )
# total_loss 132 loss-28.5296
# epoch 132 - loss { 0.507785} (  0.506571 , { 0.001215} )
# total_loss 133 loss-28.4183
# epoch 133 - loss { 0.508089} (  0.506888 , { 0.001201} )
# total_loss 134 loss-28.3803
# epoch 134 - loss { 0.507243} (  0.506038 , { 0.001205} )
# total_loss 135 loss-28.363
# epoch 135 - loss { 0.506021} (  0.505042 , { 0.00098 } )
# total_loss 136 loss-28.1941
# epoch 136 - loss { 0.503454} (  0.502279 , { 0.001174} )
# total_loss 137 loss-28.1423
# epoch 137 - loss { 0.503178} (  0.502011 , { 0.001167} )
# total_loss 138 loss-28.1499
# epoch 138 - loss { 0.502773} (  0.501838 , { 0.000935} )
# total_loss 139 loss-28.1106
# epoch 139 - loss { 0.501437} (  0.500394 , { 0.001043} )
# total_loss 140 loss-28.0113
# epoch 140 - loss { 0.500222} (  0.499175 , { 0.001048} )
# total_loss 141 loss-27.9558
# epoch 141 - loss { 0.498959} (  0.497806 , { 0.001153} )
# total_loss 142 loss-27.852
# epoch 142 - loss { 0.497379} (  0.496577 , { 0.000803} )
# total_loss 143 loss-27.7988
# epoch 143 - loss { 0.497046} (  0.496022 , { 0.001023} )
# total_loss 144 loss-27.7295
# epoch 144 - loss { 0.496129} (  0.495008 , { 0.00112 } )
# total_loss 145 loss-27.6911
# epoch 145 - loss { 0.495148} (  0.49413  , { 0.001018} )
# total_loss 146 loss-27.6015
# epoch 146 - loss { 0.493648} (  0.492748 , { 0.0009  } )
# total_loss 147 loss-27.601
# epoch 147 - loss { 0.492623} (  0.491656 , { 0.000967} )
# total_loss 148 loss-27.5409
# epoch 148 - loss { 0.490691} (  0.489695 , { 0.000995} )
# total_loss 149 loss-27.3695
# epoch 149 - loss { 0.48959 } (  0.488705 , { 0.000885} )
# total_loss 150 loss-27.4158
# epoch 150 - loss { 0.490622} (  0.48963  , { 0.000992} )
# total_loss 151 loss-27.3479
# epoch 151 - loss { 0.4891  } (  0.488229 , { 0.000871} )
# total_loss 152 loss-27.2942
# epoch 152 - loss { 0.488383} (  0.487409 , { 0.000974} )
# total_loss 153 loss-27.2858
# epoch 153 - loss { 0.486458} (  0.485639 , { 0.000819} )
# total_loss 154 loss-27.1758
# epoch 154 - loss { 0.485115} (  0.484303 , { 0.000812} )
# total_loss 155 loss-27.1171
# epoch 155 - loss { 0.483849} (  0.483097 , { 0.000752} )
# total_loss 156 loss-27.0785
# epoch 156 - loss { 0.484644} (  0.483921 , { 0.000724} )
# total_loss 157 loss-26.9771
# epoch 157 - loss { 0.482581} (  0.481733 , { 0.000848} )
# total_loss 158 loss-26.9737
# epoch 158 - loss { 0.481928} (  0.481136 , { 0.000791} )
# total_loss 159 loss-26.9037
# epoch 159 - loss { 0.481101} (  0.480271 , { 0.00083 } )
# total_loss 160 loss-26.8012
# epoch 160 - loss { 0.481266} (  0.480657 , { 0.000609} )
# total_loss 161 loss-26.8772
# epoch 161 - loss { 0.479077} (  0.478354 , { 0.000723} )
# total_loss 162 loss-26.7173
# epoch 162 - loss { 0.47942 } (  0.478711 , { 0.000708} )
# total_loss 163 loss-26.7081
# epoch 163 - loss { 0.477167} (  0.476517 , { 0.00065 } )
# total_loss 164 loss-26.6901
# epoch 164 - loss { 0.476923} (  0.476269 , { 0.000655} )
# total_loss 165 loss-26.6284
# epoch 165 - loss { 0.476813} (  0.476173 , { 0.00064 } )
# total_loss 166 loss-26.6746
# epoch 166 - loss { 0.474807} (  0.474168 , { 0.000639} )
# total_loss 167 loss-26.5333
# epoch 167 - loss { 0.474043} (  0.473346 , { 0.000697} )
# total_loss 168 loss-26.4618
# epoch 168 - loss { 0.474049} (  0.47341  , { 0.00064 } )
# total_loss 169 loss-26.3678
# epoch 169 - loss { 0.472309} (  0.471677 , { 0.000631} )
# total_loss 170 loss-26.4498
# epoch 170 - loss { 0.471829} (  0.471236 , { 0.000592} )
# total_loss 171 loss-26.3321
# epoch 171 - loss { 0.471268} (  0.470811 , { 0.000457} )
# total_loss 172 loss-26.3664
# epoch 172 - loss { 0.469799} (  0.46918  , { 0.000619} )
# total_loss 173 loss-26.2471
# epoch 173 - loss { 0.469829} (  0.469332 , { 0.000497} )
# total_loss 174 loss-26.2292
# epoch 174 - loss { 0.468817} (  0.468255 , { 0.000561} )
# total_loss 175 loss-26.2064
# epoch 175 - loss { 0.468892} (  0.46834  , { 0.000552} )
# total_loss 176 loss-26.1683
# epoch 176 - loss { 0.4682  } (  0.467706 , { 0.000494} )
# total_loss 177 loss-26.1042
# epoch 177 - loss { 0.467349} (  0.466752 , { 0.000597} )
# total_loss 178 loss-26.0177
# epoch 178 - loss { 0.465847} (  0.465351 , { 0.000496} )
# total_loss 179 loss-26.0392
# epoch 179 - loss { 0.46447 } (  0.463986 , { 0.000485} )
# total_loss 180 loss-26.0525
# epoch 180 - loss { 0.464016} (  0.463595 , { 0.000421} )
# total_loss 181 loss-25.974
# epoch 181 - loss { 0.4641  } (  0.463674 , { 0.000427} )
# total_loss 182 loss-25.968
# epoch 182 - loss { 0.463793} (  0.463314 , { 0.000479} )
# total_loss 183 loss-25.8549
# epoch 183 - loss { 0.463374} (  0.463015 , { 0.000359} )
# total_loss 184 loss-25.8277
# epoch 184 - loss { 0.462223} (  0.461752 , { 0.000471} )
# total_loss 185 loss-25.8687
# epoch 185 - loss { 0.460751} (  0.460289 , { 0.000462} )
# total_loss 186 loss-25.7938
# epoch 186 - loss { 0.461775} (  0.46136  , { 0.000415} )
# total_loss 187 loss-25.7801
# epoch 187 - loss { 0.460751} (  0.460333 , { 0.000418} )
# total_loss 188 loss-25.7967
# epoch 188 - loss { 0.460239} (  0.459879 , { 0.000361} )
# total_loss 189 loss-25.698
# epoch 189 - loss { 0.459073} (  0.458672 , { 0.000401} )
# total_loss 190 loss-25.7293
# epoch 190 - loss { 0.459037} (  0.458638 , { 0.000399} )
# total_loss 191 loss-25.6654
# epoch 191 - loss { 0.457787} (  0.457381 , { 0.000406} )
# total_loss 192 loss-25.6332
# epoch 192 - loss { 0.457929} (  0.457527 , { 0.000402} )
# total_loss 193 loss-25.6283
# epoch 193 - loss { 0.45761 } (  0.457269 , { 0.000341} )
# total_loss 194 loss-25.5345
# epoch 194 - loss { 0.456747} (  0.456409 , { 0.000338} )
# total_loss 195 loss-25.5308
# epoch 195 - loss { 0.455653} (  0.455263 , { 0.00039 } )
# total_loss 196 loss-25.5411
# epoch 196 - loss { 0.455247} (  0.454907 , { 0.000341} )
# total_loss 197 loss-25.4671
# epoch 197 - loss { 0.455169} (  0.454839 , { 0.00033 } )
# total_loss 198 loss-25.5034
# epoch 198 - loss { 0.454876} (  0.454545 , { 0.000331} )
# total_loss 199 loss-25.45
# epoch 199 - loss { 0.454313} (  0.454039 , { 0.000274} )

# %% [markdown]
# c++ からの出力ファイルの読み込み

# %%
# load out file
f = open('./vae1.out', 'r')
epoch_loss = []
datalist = f.readlines()
for data in datalist:
  epoch_loss.append( float(data) )
f.close()

print("epoch =", len(epoch_loss))
print( epoch_loss)

# load pred file
f2 = open('vae1.pred', 'r')

datalist = f2.readlines()

n1 = 10
n2 = 64
k = 0
for data in datalist:
  ds = data.split(',')
  if k==0:
    n1 = int(ds[0])
    n2 = int(ds[1])
    global v_pred
    v_pred = np.zeros( (n1,n2))
  else:
    for i in range(n2):
      v_pred[k-1,i] = float(ds[i])
  k = k+1

f2.close()

# load z file
f3 = open('vae1.z', 'r')

datalist = f3.readlines()
n1 = 100
n2 = 2
k = 0
for data in datalist:
  ds = data.split(',')
  if k==0:
    nz1 = int(ds[0])
    nz2 = int(ds[1])
    z_pred = np.zeros( (nz1,nz2))
  else:
    z_pred[k-1,0] = float(ds[0])
    z_pred[k-1,1] = float(ds[1])
  k = k+1

f3.close()

print("z =", nz1,nz2 )
#print(z_pred)
# Out:
# epoch = 200
# [33.315163, 29.588337, 28.864582, 28.606874, 28.399221, 28.196524, 28.112505, 27.971659, 27.893692, 27.743196, 27.667103, 27.463993, 27.312462, 27.131021, 26.99172, 26.916931, 26.820824, 26.766123, 26.719816, 26.643881, 26.562258, 26.530367, 26.381763, 26.348427, 26.247, 26.206259, 26.074146, 26.01207, 25.915354, 25.825445, 25.789684, 25.732431, 25.681158, 25.596584, 25.599388, 25.504528, 25.552197, 25.476049, 25.487141, 25.430086, 25.386909, 25.368185, 25.42617, 25.372347, 25.319706, 25.36867, 25.2885, 25.297209, 25.240147, 25.268906, 25.26305, 25.249092, 25.24477, 25.199209, 25.200945, 25.177311, 25.178785, 25.208733, 25.133114, 25.14896, 25.134329, 25.100973, 25.088497, 25.069168, 25.01796, 25.07704, 24.987013, 24.995789, 24.962414, 24.969923, 24.969856, 24.9928, 25.016535, 24.978628, 24.912752, 24.906364, 24.89068, 25.001881, 24.921247, 24.864115, 24.793262, 24.843006, 24.793827, 24.725113, 24.733711, 24.677113, 24.653231, 24.744532, 24.675917, 24.748131, 24.660444, 24.59337, 24.619499, 24.574203, 24.607534, 24.532196, 24.522036, 24.551098, 24.579597, 24.507343, 24.470636, 24.517673, 24.448736, 24.484411, 24.402477, 24.465029, 24.457092, 24.40391, 24.400003, 24.424858, 24.407576, 24.398056, 24.401405, 24.403807, 24.397409, 24.376724, 24.398626, 24.393099, 24.37656, 24.307018, 24.390856, 24.330898, 24.360329, 24.34416, 24.346897, 24.36034, 24.292782, 24.397713, 24.31599, 24.345535, 24.269131, 24.311544, 24.338608, 24.233688, 24.287989, 24.318197, 24.285587, 24.291986, 24.301968, 24.274048, 24.313921, 24.312073, 24.235134, 24.30249, 24.22459, 24.211948, 24.275396, 24.386234, 24.202122, 24.270226, 24.237055, 24.270012, 24.253262, 24.246784, 24.193449, 24.265184, 24.229855, 24.236362, 24.277729, 24.188421, 24.170511, 24.24474, 24.273594, 24.18359, 24.187487, 24.244764, 24.233372, 24.148352, 24.150372, 24.203945, 24.178602, 24.134373, 24.224047, 24.195965, 24.152403, 24.194818, 24.176743, 24.162062, 24.179213, 24.171041, 24.196543, 24.153152, 24.154221, 24.168444, 24.165615, 24.08419, 24.127739, 24.122755, 24.147955, 24.116947, 24.155817, 24.221359, 24.08577, 24.19202, 24.188744, 24.178463, 24.094397, 24.09944, 24.115948, 24.108465]
# z = 1797 2

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %%
n_img5 = 10
x2 = x[:n_img5]

plt.figure( figsize=(10,2))
for i in range(n_img5):
  # input image
  ax = plt.subplot(3,n_img5,i+1)
  plt.imshow( x2[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # output image
  ax = plt.subplot(3,n_img5,i+1+n_img5)
  plt.imshow( v_pred[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %%
t2 = t_train #[:n_batch]

plt.figure(figsize=(8,8))
for i in range(10):
  zt = z_pred[t2==i]
  z_1 = zt[:,0]
  z_2 = zt[:,1]
  marker= "$"+str(i)+"$"
  plt.scatter( z_2.tolist(),  z_1.tolist(), marker=marker,s=75 )

plt.xlabel("z_2")
plt.ylabel("z_1")
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid()
plt.show()

# %%
import torch.distributions as tdist

n = tdist.Normal(torch.tensor([0.0]), torch.tensor([1.0]))

e = n.sample((n_mid,))

# %%
e
# Out:
# tensor([[ 0.5516],
#         [-1.4746],
#         [-1.2032],
#         [-0.4709],
#         [ 1.0430],
#         [-0.9447],
#         [ 0.7663],
#         [-0.8108],
#         [-0.7571],
#         [ 0.6683],
#         [-0.9177],
#         [-0.1356],
#         [-0.8786],
#         [ 3.5638],
#         [-1.4244],
#         [-0.5050]])

# %%
e2= torch.randn(n_mid)
print(e2)
# Out:
# tensor([ 1.4625,  0.0852,  0.2403, -0.7425, -1.1566, -1.9472, -0.0739,  1.4408,
#         -1.5811,  0.1749,  1.1583,  0.6945, -0.4813, -0.2892,  1.3323, -0.9172])
