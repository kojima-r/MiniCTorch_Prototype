# %% [markdown]
# VAE　オートエンコーダー
#
# 参考文献　我妻幸長　「はじめてのディープラーニング２」

# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# フォルダは自分の指定のものに変更して下さい。

# %%
# %cd "ctorch210929/MiniCTorch_Prototype/notebook"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch210929/MiniCTorch_Prototype/notebook

# %%
! pip install lark-parser
# Out:
# Requirement already satisfied: lark-parser in /usr/local/lib/python3.7/dist-packages (0.12.0)

# %%
import sys
sys.path.append("../")

import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import minictorch.generator as GN
import minictorch.converter as CV

# %% [markdown]
# サンプルデータ

# %%
import torch.utils as utils
from torchvision import datasets, transforms
from sklearn import datasets

img_size = 8
n_in = img_size * img_size
n_mid = 16
n_out = n_in
n_z = 2
n_batch = 32

digits_data = datasets.load_digits()
dd = np.asarray( digits_data.data, dtype=np.float32 )
dd /= 15
x_train = torch.from_numpy( dd ).clone()
t_train = digits_data.target
print(len(x_train))
# Out:
# 1797

# %% [markdown]
# サンプルデータの図化

# %%
import matplotlib.pyplot as plt
n_img = 16

plt.figure( figsize=(16,3))
for i in range(n_img):
  ax = plt.subplot(3,n_img,i+1)
  plt.imshow(dd[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %% [markdown]
# ニューラルネットワークの定義

# %%
def mean_squared_error( x0, x1 ):
    diff = x0 - x1
    y = (diff**2).sum() / len(diff)
    return y;

def reconstruction( y, t ):
  eps = 1.0e-7
  e = t * torch.log(y+eps) + (1-t) * torch.log(1-y+eps) 
  z = e.sum() / len(y)
  return z;

def kl_divergence( mean, log_var ):
  g = 1 + log_var - mean**2 - torch.exp( log_var )
  y = 0.5 * g.sum() / len(mean)
  return y

import torch.distributions as tdist

class Net(torch.nn.Module):
  def __init__( self, n_in, n_mid, n_out, n_z, e ):
    super(Net, self).__init__()
    self.fc1 = nn.Linear(n_in, n_mid)
    #self.bn1 = nn.BatchNorm1d(n_mid)
    self.fc2_mean = nn.Linear(n_mid, n_z)
    self.fc2_var  = nn.Linear(n_mid, n_z)
    self.fc3 = nn.Linear(n_z  ,n_mid)
    self.fc4 = nn.Linear(n_mid,n_out)
    #self.drop1 = nn.Dropout(p=0.2)
    self.eps = e

    nn.init.constant_(self.fc1.bias,0)
    nn.init.constant_(self.fc2_mean.bias,0)
    nn.init.constant_(self.fc2_var.bias,0)
    nn.init.constant_(self.fc3.bias,0)
    nn.init.constant_(self.fc4.bias,0)
  
  def forward( self, x ):
    # encoder
    self.x2 = F.relu( self.fc1(x) )
    #self.x2 = self.bn1( self.x1 )
    self.mean    = self.fc2_mean( self.x2 )
    self.log_var = self.fc2_var( self.x2 )

    # reparametrization
    #eps = torch.randn( n_batch, n_z )
    eps = torch.randn( self.mean.shape )
    #nm = tdist.Normal( 0.0, 1.0 ) #torch.tensor([0.0]), torch.tensor([1.0]))
    #eps = nm.sample([ n_batch, n_z ])
    #eps = torch.normal(0.0,1.0,[32,2])
    #print("eps",eps)
    self.z = self.mean + eps * torch.exp( 0.5 * self.log_var )
    #self.z = self.mean + self.eps * torch.exp( 0.5 * self.log_var )

    # decoder
    self.y1 = F.relu( self.fc3( self.z ) )
    #self.y2 = self.drop1( self.y1)
    y = torch.sigmoid( self.fc4( self.y1 ) )
    self.out = y 
    
    e1 = reconstruction( y, x )
    e2 = kl_divergence( self.mean, self.log_var )
    return -(e1+e2)

# %%
def generate_json( json_path, input, e ):

    model = Net( n_in, n_mid, n_out, n_z, e )

    model.eval()
    with torch.no_grad():
        print("[SAVE]", json_path )
        GN.generate_minictorch_file( model, input, json_path )

    return model

# %%
torch.manual_seed( 1 )

project = 'vae1'
json_path = '../network/' + project +'.json'

x = x_train.clone().detach()
torch.reshape( x, (-1,n_in) )

x = x[0:n_batch,:]
#print(type(x))
#print(x.shape)
x.requires_grad = True

e = torch.randn( n_batch, 2 )
print("eps",e)

model = generate_json( json_path, x, e )

with torch.set_grad_enabled(True):
  model.eval()
  output = model( x )
  print("output",output)
  output.backward()
  print("input_grad",x.grad)
# Out:
# eps tensor([[-1.5256, -0.7502],
#         [-0.6540, -1.6095],
#         [-0.1002, -0.6092],
#         [-0.9798, -1.6091],
#         [-0.7121,  0.3037],
#         [-0.7773, -0.2515],
#         [-0.2223,  1.6871],
#         [ 0.2284,  0.4676],
#         [-0.6970, -1.1608],
#         [ 0.6995,  0.1991],
#         [ 0.8657,  0.2444],
#         [-0.6629,  0.8073],
#         [ 1.1017, -0.1759],
#         [-2.2456, -1.4465],
#         [ 0.0612, -0.6177],
#         [-0.7981, -0.1316],
#         [ 1.8793, -0.0721],
#         [ 0.1578, -0.7735],
#         [ 0.1991,  0.0457],
#         [ 0.1530, -0.4757],
#         [-0.1110,  0.2927],
#         [-0.1578, -0.0288],
#         [ 2.3571, -1.0373],
#         [ 1.5748, -0.6298],
#         [-0.9274,  0.5451],
#         [ 0.0663, -0.4370],
#         [ 0.7626,  0.4415],
#         [ 1.1651,  2.0154],
#         [ 0.1374,  0.9386],
#         [-0.1860, -0.6446],
#         [ 1.5392, -0.8696],
#         [-3.3312, -0.7479]])
# [SAVE] ../network/vae1.json
# skip: Net/Linear[fc1]/weight/117
# skip: Net/Linear[fc1]/weight/117
# skip: Net/Linear[fc2_mean]/weight/120
# skip: Net/Linear[fc2_mean]/weight/120
# skip: Net/Linear[fc2_var]/weight/123
# skip: Net/Linear[fc2_var]/weight/123
# skip: Net/Linear[fc3]/weight/126
# skip: Net/Linear[fc3]/weight/126
# skip: Net/Linear[fc4]/weight/129
# skip: Net/Linear[fc4]/weight/129
# output tensor(44.6278, grad_fn=<NegBackward>)
# input_grad tensor([[-0.0011,  0.0029, -0.0030,  ..., -0.0023, -0.0009,  0.0014],
#         [-0.0014,  0.0004, -0.0045,  ...,  0.0017, -0.0025,  0.0007],
#         [-0.0050, -0.0056, -0.0005,  ...,  0.0007, -0.0029,  0.0018],
#         ...,
#         [-0.0056, -0.0023, -0.0014,  ...,  0.0010, -0.0032,  0.0004],
#         [ 0.0017,  0.0118, -0.0115,  ..., -0.0052, -0.0053, -0.0001],
#         [-0.0085, -0.0030, -0.0036,  ...,  0.0020, -0.0051,  0.0005]])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#
# /usr/local/lib/python3.7/dist-packages/torch/jit/_trace.py:985: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%eps : Float(32, 2, strides=[2, 1], requires_grad=0, device=cpu) = aten::randn(%41, %42, %43, %44, %45) # <ipython-input-13-8f9dd27cbeb0>:46:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _module_class,
# /usr/local/lib/python3.7/dist-packages/torch/jit/_trace.py:985: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# With rtol=1e-05 and atol=1e-05, found 1 element(s) (out of 1) whose difference(s) exceeded the margin of error (including 0 nan comparisons). The greatest difference was 0.22548294067382812 (44.893035888671875 vs. 44.66755294799805), which occurred at index 0.
#   _module_class,

# %%
"""
def convert_json( project, folder, model, input_x, json_path, rand_flag=0 ):

    #folder = "src"
    cpp_fname   = project + ".cpp"
    param_fname = project + "_param.cpp"
    cpp_path    = folder + "/" + cpp_fname
    param_path  = folder + "/" + param_fname
    make_path   = folder + "/" + "Makefile"

    # load json file
    print( "[JSON]", json_path )
    fp = open( json_path )
    obj = json.load( fp )

    # save parameter file
    code1 = CV.c_param_generator( obj, model, input_x )
    if len( code1 ) > 0:
       print( "[PARAM]", param_path )
       ofparam = open( param_path, "w" )
       ofparam.write( code1 )

    # save cpp file
    print( "[CPP]  ", cpp_path )
    code2 = CV.c_code_generator( obj, model, rand_flag )

    #ofp=open(args.path+"/"+args.output,"w")
    ofp = open( cpp_path, "w" )
    ofp.write( code2 )

    # save make file
    print( "[MAKE] ", make_path )
    make_code = CV.makefile_generator( cpp_fname )

    #makefp=open(args.path+"/"+"Makefile","w")
    makefp = open( make_path, "w" )
    makefp.write( make_code )

convert_json( project, "src", model, x, json_path )
"""

# %%
CV.convert_json( project, "../src", model, x, json_path )
# Out:
# [JSON] ../network/vae1.json
# {'name': 'Net/Linear[fc1]/weight/141', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# {'name': 'Net/Linear[fc1]/bias/140', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# {'name': 'Net/Linear[fc2_mean]/weight/144', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# {'name': 'Net/Linear[fc2_mean]/bias/143', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# {'name': 'Net/Linear[fc2_var]/weight/147', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [24], 'sorted_id': 22}
# {'name': 'Net/Linear[fc2_var]/bias/146', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [24], 'sorted_id': 23}
# {'name': 'Net/Linear[fc3]/weight/150', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [33], 'sorted_id': 31}
# {'name': 'Net/Linear[fc3]/bias/149', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [33], 'sorted_id': 32}
# {'name': 'Net/Linear[fc4]/weight/153', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [37], 'sorted_id': 35}
# {'name': 'Net/Linear[fc4]/bias/152', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [37], 'sorted_id': 36}
# [PARAM] ../src/vae1_param.cpp
# {'name': 'input/x', 'op': 'IO Node', 'in': [], 'output_id': 0, 'shape': [32, 64], 'out': [43, 46, 3], 'sorted_id': 0}
# {'name': 'Net/Linear[fc1]/weight/141', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 1}
# Net/Linear[fc1]/weight/141  ->  fc1_weight
# {'name': 'Net/Linear[fc1]/bias/140', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [3], 'sorted_id': 2}
# Net/Linear[fc1]/bias/140  ->  fc1_bias
# {'name': 'Net/Linear[fc1]/input.1', 'op': 'aten::linear', 'in': [0, 1, 2], 'output_id': 0, 'shape': [32, 16], 'out': [4], 'sorted_id': 3}
# {'name': 'Net/input.3', 'op': 'aten::relu', 'in': [3], 'output_id': 0, 'shape': [32, 16], 'out': [7, 24], 'sorted_id': 4}
# {'name': 'Net/Linear[fc2_mean]/weight/144', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 5}
# Net/Linear[fc2_mean]/weight/144  ->  fc2_mean_weight
# {'name': 'Net/Linear[fc2_mean]/bias/143', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [7], 'sorted_id': 6}
# Net/Linear[fc2_mean]/bias/143  ->  fc2_mean_bias
# {'name': 'Net/Linear[fc2_mean]/mean', 'op': 'aten::linear', 'in': [4, 5, 6], 'output_id': 0, 'shape': [32, 2], 'out': [30, 65, 9, 13], 'sorted_id': 7}
# {'name': 'Net/33', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [9], 'sorted_id': 8}
# {'name': 'Net/34', 'op': 'aten::size', 'in': [7, 8], 'output_id': 0, 'shape': [], 'out': [10], 'sorted_id': 9}
# {'name': 'Net/35', 'op': 'prim::NumToTensor', 'in': [9], 'output_id': 0, 'shape': [], 'out': [11], 'sorted_id': 10}
# {'name': 'Net/39', 'op': 'aten::Int', 'in': [10], 'output_id': 0, 'shape': [], 'out': [16], 'sorted_id': 11}
# {'name': 'Net/36', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [13], 'sorted_id': 12}
# {'name': 'Net/37', 'op': 'aten::size', 'in': [7, 12], 'output_id': 0, 'shape': [], 'out': [14], 'sorted_id': 13}
# {'name': 'Net/38', 'op': 'prim::NumToTensor', 'in': [13], 'output_id': 0, 'shape': [], 'out': [15], 'sorted_id': 14}
# {'name': 'Net/40', 'op': 'aten::Int', 'in': [14], 'output_id': 0, 'shape': [], 'out': [16], 'sorted_id': 15}
# {'name': 'Net/41', 'op': 'prim::ListConstruct', 'in': [11, 15], 'output_id': 0, 'shape': [], 'out': [21], 'sorted_id': 16}
# {'name': 'Net/42', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 6.0, 'out': [21], 'sorted_id': 17}
# {'name': 'Net/43', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [21], 'sorted_id': 18}
# {'name': 'Net/44', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [21], 'sorted_id': 19}
# {'name': 'Net/45', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.0, 'out': [21], 'sorted_id': 20}
# {'name': 'Net/eps', 'op': 'aten::randn', 'in': [16, 17, 18, 19, 20], 'output_id': 0, 'shape': [32, 2], 'out': [28], 'sorted_id': 21}
# {'name': 'Net/Linear[fc2_var]/weight/147', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [24], 'sorted_id': 22}
# Net/Linear[fc2_var]/weight/147  ->  fc2_var_weight
# {'name': 'Net/Linear[fc2_var]/bias/146', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [24], 'sorted_id': 23}
# Net/Linear[fc2_var]/bias/146  ->  fc2_var_bias
# {'name': 'Net/Linear[fc2_var]/log_var', 'op': 'aten::linear', 'in': [4, 22, 23], 'output_id': 0, 'shape': [32, 2], 'out': [26, 63, 68], 'sorted_id': 24}
# {'name': 'Net/47', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.5, 'out': [26], 'sorted_id': 25}
# {'name': 'Net/48', 'op': 'aten::mul', 'in': [24, 25], 'output_id': 0, 'shape': [32, 2], 'out': [27], 'sorted_id': 26}
# {'name': 'Net/49', 'op': 'aten::exp', 'in': [26], 'output_id': 0, 'shape': [32, 2], 'out': [28], 'sorted_id': 27}
# {'name': 'Net/50', 'op': 'aten::mul', 'in': [21, 27], 'output_id': 0, 'shape': [32, 2], 'out': [30], 'sorted_id': 28}
# {'name': 'Net/51', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [30], 'sorted_id': 29}
# {'name': 'Net/input.5', 'op': 'aten::add', 'in': [7, 28, 29], 'output_id': 0, 'shape': [32, 2], 'out': [33], 'sorted_id': 30}
# {'name': 'Net/Linear[fc3]/weight/150', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [33], 'sorted_id': 31}
# Net/Linear[fc3]/weight/150  ->  fc3_weight
# {'name': 'Net/Linear[fc3]/bias/149', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [33], 'sorted_id': 32}
# Net/Linear[fc3]/bias/149  ->  fc3_bias
# {'name': 'Net/Linear[fc3]/input.7', 'op': 'aten::linear', 'in': [30, 31, 32], 'output_id': 0, 'shape': [32, 16], 'out': [34], 'sorted_id': 33}
# {'name': 'Net/input', 'op': 'aten::relu', 'in': [33], 'output_id': 0, 'shape': [32, 16], 'out': [37], 'sorted_id': 34}
# {'name': 'Net/Linear[fc4]/weight/153', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [37], 'sorted_id': 35}
# Net/Linear[fc4]/weight/153  ->  fc4_weight
# {'name': 'Net/Linear[fc4]/bias/152', 'op': 'prim::GetAttr', 'in': [], 'output_id': 0, 'shape': [], 'out': [37], 'sorted_id': 36}
# Net/Linear[fc4]/bias/152  ->  fc4_bias
# {'name': 'Net/Linear[fc4]/154', 'op': 'aten::linear', 'in': [34, 35, 36], 'output_id': 0, 'shape': [32, 64], 'out': [38], 'sorted_id': 37}
# {'name': 'Net/y', 'op': 'aten::sigmoid', 'in': [37], 'output_id': 0, 'shape': [32, 64], 'out': [41, 49], 'sorted_id': 38}
# {'name': 'Net/57', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1e-07, 'out': [41], 'sorted_id': 39}
# {'name': 'Net/58', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [41], 'sorted_id': 40}
# {'name': 'Net/59', 'op': 'aten::add', 'in': [38, 39, 40], 'output_id': 0, 'shape': [32, 64], 'out': [42], 'sorted_id': 41}
# {'name': 'Net/60', 'op': 'aten::log', 'in': [41], 'output_id': 0, 'shape': [32, 64], 'out': [43], 'sorted_id': 42}
# {'name': 'Net/61', 'op': 'aten::mul', 'in': [0, 42], 'output_id': 0, 'shape': [32, 64], 'out': [56], 'sorted_id': 43}
# {'name': 'Net/62', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [46], 'sorted_id': 44}
# {'name': 'Net/63', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [46], 'sorted_id': 45}
# {'name': 'Net/64', 'op': 'aten::rsub', 'in': [0, 44, 45], 'output_id': 0, 'shape': [32, 64], 'out': [54], 'sorted_id': 46}
# {'name': 'Net/65', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [49], 'sorted_id': 47}
# {'name': 'Net/66', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [49], 'sorted_id': 48}
# {'name': 'Net/67', 'op': 'aten::rsub', 'in': [38, 47, 48], 'output_id': 0, 'shape': [32, 64], 'out': [52], 'sorted_id': 49}
# {'name': 'Net/68', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1e-07, 'out': [52], 'sorted_id': 50}
# {'name': 'Net/69', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [52], 'sorted_id': 51}
# {'name': 'Net/70', 'op': 'aten::add', 'in': [49, 50, 51], 'output_id': 0, 'shape': [32, 64], 'out': [53], 'sorted_id': 52}
# {'name': 'Net/71', 'op': 'aten::log', 'in': [52], 'output_id': 0, 'shape': [32, 64], 'out': [54], 'sorted_id': 53}
# {'name': 'Net/72', 'op': 'aten::mul', 'in': [46, 53], 'output_id': 0, 'shape': [32, 64], 'out': [56], 'sorted_id': 54}
# {'name': 'Net/73', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [56], 'sorted_id': 55}
# {'name': 'Net/e', 'op': 'aten::add', 'in': [43, 54, 55], 'output_id': 0, 'shape': [32, 64], 'out': [58], 'sorted_id': 56}
# {'name': 'Net/75', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [58], 'sorted_id': 57}
# {'name': 'Net/76', 'op': 'aten::sum', 'in': [56, 57], 'output_id': 0, 'shape': [], 'out': [60], 'sorted_id': 58}
# {'name': 'Net/83', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 32.0, 'out': [60], 'sorted_id': 59}
# {'name': 'Net/e1', 'op': 'aten::div', 'in': [58, 59], 'output_id': 0, 'shape': [], 'out': [78], 'sorted_id': 60}
# {'name': 'Net/85', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [63], 'sorted_id': 61}
# {'name': 'Net/86', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [63], 'sorted_id': 62}
# {'name': 'Net/87', 'op': 'aten::add', 'in': [24, 61, 62], 'output_id': 0, 'shape': [32, 2], 'out': [67], 'sorted_id': 63}
# {'name': 'Net/88', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 2.0, 'out': [65], 'sorted_id': 64}
# {'name': 'Net/89', 'op': 'aten::pow', 'in': [7, 64], 'output_id': 0, 'shape': [32, 2], 'out': [67], 'sorted_id': 65}
# {'name': 'Net/90', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [67], 'sorted_id': 66}
# {'name': 'Net/91', 'op': 'aten::sub', 'in': [63, 65, 66], 'output_id': 0, 'shape': [32, 2], 'out': [70], 'sorted_id': 67}
# {'name': 'Net/92', 'op': 'aten::exp', 'in': [24], 'output_id': 0, 'shape': [32, 2], 'out': [70], 'sorted_id': 68}
# {'name': 'Net/93', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [70], 'sorted_id': 69}
# {'name': 'Net/g', 'op': 'aten::sub', 'in': [67, 68, 69], 'output_id': 0, 'shape': [32, 2], 'out': [72], 'sorted_id': 70}
# {'name': 'Net/95', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'out': [72], 'sorted_id': 71}
# {'name': 'Net/96', 'op': 'aten::sum', 'in': [70, 71], 'output_id': 0, 'shape': [], 'out': [74], 'sorted_id': 72}
# {'name': 'Net/97', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 0.5, 'out': [74], 'sorted_id': 73}
# {'name': 'Net/98', 'op': 'aten::mul', 'in': [72, 73], 'output_id': 0, 'shape': [], 'out': [76], 'sorted_id': 74}
# {'name': 'Net/105', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 32.0, 'out': [76], 'sorted_id': 75}
# {'name': 'Net/e2', 'op': 'aten::div', 'in': [74, 75], 'output_id': 0, 'shape': [], 'out': [78], 'sorted_id': 76}
# {'name': 'Net/107', 'op': 'prim::Constant', 'in': [], 'output_id': 0, 'shape': [], 'constant_value': 1.0, 'out': [78], 'sorted_id': 77}
# {'name': 'Net/108', 'op': 'aten::add', 'in': [60, 76, 77], 'output_id': 0, 'shape': [], 'out': [79], 'sorted_id': 78}
# {'name': 'Net/109', 'op': 'aten::neg', 'in': [78], 'output_id': 0, 'shape': [], 'out': [80], 'sorted_id': 79}
# {'name': 'output/output.1', 'op': 'IO Node', 'in': [79], 'output_id': 0, 'shape': [], 'out': [], 'sorted_id': 80}
# [CPP]  ../src/vae1.cpp
# [MAKE] ../src/Makefile

# %%
# !g++ -std=c++14 ../src/vae1.cpp ../src/vae1_param.cpp -I ../../../xtensor -lcblas -o ../bin/vae1

# %% [markdown]
# (注意) xtensorにxtensor関連のincludeを置いています。各自の環境に合わせて変更して下さい。

# %%
# !../bin/vae1
# Out:
# ### forward computation ...
# { 44.494682}
# ### backward computation ...
# input_grad{{-0.002586, -0.001948, -0.000243, ...,  0.000267, -0.001652,  0.000374},
#  {-0.000897, -0.001041, -0.000241, ...,  0.000115, -0.00004 ,  0.000886},
#  {-0.007821, -0.006974,  0.000222, ...,  0.001697, -0.003437,  0.003318},
#  ...,
#  { 0.000084, -0.000341, -0.000042, ..., -0.000469, -0.000338,  0.000462},
#  {-0.002681,  0.000023,  0.000841, ...,  0.001294,  0.000238,  0.002403},
#  {-0.003409, -0.000474,  0.001231, ...,  0.001605, -0.000005,  0.005013}}

# %% [markdown]
# 最適化実行

# %% [markdown]
# 全入力データを vae1_data.cpp に出力する

# %%
def output_datafile( folder, project, in_data ):
    data_fname = project + "_data.cpp"
    data_path  = folder + "/" + data_fname

    # save data file
    code = CV.c_data_generator( in_data )
    if len( code ) > 0:
       print( "[DATA]", data_path )
       ofparam = open( data_path, "w" )
       ofparam.write( code )

output_datafile( "../src", project, dd )
# Out:
# param: indata  - str loop  5000  /  14375
# param: indata  - str loop  10000  /  14375
# [DATA] ../src/vae1_data.cpp

# %%
# !g++ -std=c++14 ../src/vae1.cpp ../src/vae1_param.cpp ../src/vae1_data.cpp ../src/vae1_train.cpp  -I ../../../xtensor -lcblas -o ../bin/vae1_train

# %%
# !../bin/vae1_train
# Out:
# batch1 1797,64
# batch2 56,32
# epoch_num : 200
# total_loss 0 loss - 2252.21
# epoch 0 - loss { 33.315163}
# total_loss 1 loss - 1722.82
# epoch 1 - loss { 29.588337}
# total_loss 2 loss - 1636.86
# epoch 2 - loss { 28.864582}
# total_loss 3 loss - 1608.91
# epoch 3 - loss { 28.606874}
# total_loss 4 loss - 1596.23
# epoch 4 - loss { 28.399221}
# total_loss 5 loss - 1585.78
# epoch 5 - loss { 28.196524}
# total_loss 6 loss - 1577.11
# epoch 6 - loss { 28.112505}
# total_loss 7 loss - 1569.49
# epoch 7 - loss { 27.971659}
# total_loss 8 loss - 1561.71
# epoch 8 - loss { 27.893692}
# total_loss 9 loss - 1558.49
# epoch 9 - loss { 27.743196}
# total_loss 10 loss - 1550.25
# epoch 10 - loss { 27.667103}
# total_loss 11 loss - 1542.64
# epoch 11 - loss { 27.463993}
# total_loss 12 loss - 1531.02
# epoch 12 - loss { 27.312462}
# total_loss 13 loss - 1523.03
# epoch 13 - loss { 27.131021}
# total_loss 14 loss - 1516.12
# epoch 14 - loss { 26.99172 }
# total_loss 15 loss - 1509.93
# epoch 15 - loss { 26.916931}
# total_loss 16 loss - 1504.78
# epoch 16 - loss { 26.820824}
# total_loss 17 loss - 1500.34
# epoch 17 - loss { 26.766123}
# total_loss 18 loss - 1496.89
# epoch 18 - loss { 26.719816}
# total_loss 19 loss - 1493.51
# epoch 19 - loss { 26.643881}
# total_loss 20 loss - 1488.39
# epoch 20 - loss { 26.562258}
# total_loss 21 loss - 1485.01
# epoch 21 - loss { 26.530367}
# total_loss 22 loss - 1479.56
# epoch 22 - loss { 26.381763}
# total_loss 23 loss - 1477.71
# epoch 23 - loss { 26.348427}
# total_loss 24 loss - 1473.43
# epoch 24 - loss { 26.247   }
# total_loss 25 loss - 1470.39
# epoch 25 - loss { 26.206259}
# total_loss 26 loss - 1465.83
# epoch 26 - loss { 26.074146}
# total_loss 27 loss - 1458.6
# epoch 27 - loss { 26.01207 }
# total_loss 28 loss - 1456.81
# epoch 28 - loss { 25.915354}
# total_loss 29 loss - 1451.73
# epoch 29 - loss { 25.825445}
# total_loss 30 loss - 1445.71
# epoch 30 - loss { 25.789684}
# total_loss 31 loss - 1441.03
# epoch 31 - loss { 25.732431}
# total_loss 32 loss - 1438.16
# epoch 32 - loss { 25.681158}
# total_loss 33 loss - 1436.63
# epoch 33 - loss { 25.596584}
# total_loss 34 loss - 1433.85
# epoch 34 - loss { 25.599388}
# total_loss 35 loss - 1432.82
# epoch 35 - loss { 25.504528}
# total_loss 36 loss - 1429.55
# epoch 36 - loss { 25.552197}
# total_loss 37 loss - 1430.92
# epoch 37 - loss { 25.476049}
# total_loss 38 loss - 1426.39
# epoch 38 - loss { 25.487141}
# total_loss 39 loss - 1426.39
# epoch 39 - loss { 25.430086}
# total_loss 40 loss - 1425.06
# epoch 40 - loss { 25.386909}
# total_loss 41 loss - 1421.68
# epoch 41 - loss { 25.368185}
# total_loss 42 loss - 1420.01
# epoch 42 - loss { 25.42617 }
# total_loss 43 loss - 1424.07
# epoch 43 - loss { 25.372347}
# total_loss 44 loss - 1419.98
# epoch 44 - loss { 25.319706}
# total_loss 45 loss - 1420.94
# epoch 45 - loss { 25.36867 }
# total_loss 46 loss - 1421.81
# epoch 46 - loss { 25.2885  }
# total_loss 47 loss - 1416.07
# epoch 47 - loss { 25.297209}
# total_loss 48 loss - 1418.33
# epoch 48 - loss { 25.240147}
# total_loss 49 loss - 1417.89
# epoch 49 - loss { 25.268906}
# total_loss 50 loss - 1418.99
# epoch 50 - loss { 25.26305 }
# total_loss 51 loss - 1414.53
# epoch 51 - loss { 25.249092}
# total_loss 52 loss - 1414.64
# epoch 52 - loss { 25.24477 }
# total_loss 53 loss - 1413.82
# epoch 53 - loss { 25.199209}
# total_loss 54 loss - 1412.34
# epoch 54 - loss { 25.200945}
# total_loss 55 loss - 1412.17
# epoch 55 - loss { 25.177311}
# total_loss 56 loss - 1411.53
# epoch 56 - loss { 25.178785}
# total_loss 57 loss - 1412.39
# epoch 57 - loss { 25.208733}
# total_loss 58 loss - 1410.13
# epoch 58 - loss { 25.133114}
# total_loss 59 loss - 1408.11
# epoch 59 - loss { 25.14896 }
# total_loss 60 loss - 1407.26
# epoch 60 - loss { 25.134329}
# total_loss 61 loss - 1404.25
# epoch 61 - loss { 25.100973}
# total_loss 62 loss - 1407.48
# epoch 62 - loss { 25.088497}
# total_loss 63 loss - 1406.57
# epoch 63 - loss { 25.069168}
# total_loss 64 loss - 1406.82
# epoch 64 - loss { 25.01796 }
# total_loss 65 loss - 1403.42
# epoch 65 - loss { 25.07704 }
# total_loss 66 loss - 1405.1
# epoch 66 - loss { 24.987013}
# total_loss 67 loss - 1404.21
# epoch 67 - loss { 24.995789}
# total_loss 68 loss - 1400.45
# epoch 68 - loss { 24.962414}
# total_loss 69 loss - 1400.84
# epoch 69 - loss { 24.969923}
# total_loss 70 loss - 1401.35
# epoch 70 - loss { 24.969856}
# total_loss 71 loss - 1397.19
# epoch 71 - loss { 24.9928  }
# total_loss 72 loss - 1398.48
# epoch 72 - loss { 25.016535}
# total_loss 73 loss - 1395.28
# epoch 73 - loss { 24.978628}
# total_loss 74 loss - 1396.93
# epoch 74 - loss { 24.912752}
# total_loss 75 loss - 1396.98
# epoch 75 - loss { 24.906364}
# total_loss 76 loss - 1396.24
# epoch 76 - loss { 24.89068 }
# total_loss 77 loss - 1396.8
# epoch 77 - loss { 25.001881}
# total_loss 78 loss - 1392.98
# epoch 78 - loss { 24.921247}
# total_loss 79 loss - 1391.99
# epoch 79 - loss { 24.864115}
# total_loss 80 loss - 1389.69
# epoch 80 - loss { 24.793262}
# total_loss 81 loss - 1390.62
# epoch 81 - loss { 24.843006}
# total_loss 82 loss - 1387.43
# epoch 82 - loss { 24.793827}
# total_loss 83 loss - 1386.86
# epoch 83 - loss { 24.725113}
# total_loss 84 loss - 1386.84
# epoch 84 - loss { 24.733711}
# total_loss 85 loss - 1385.55
# epoch 85 - loss { 24.677113}
# total_loss 86 loss - 1384.18
# epoch 86 - loss { 24.653231}
# total_loss 87 loss - 1384.95
# epoch 87 - loss { 24.744532}
# total_loss 88 loss - 1379.3
# epoch 88 - loss { 24.675917}
# total_loss 89 loss - 1381.4
# epoch 89 - loss { 24.748131}
# total_loss 90 loss - 1381.23
# epoch 90 - loss { 24.660444}
# total_loss 91 loss - 1380.48
# epoch 91 - loss { 24.59337 }
# total_loss 92 loss - 1376.75
# epoch 92 - loss { 24.619499}
# total_loss 93 loss - 1381.53
# epoch 93 - loss { 24.574203}
# total_loss 94 loss - 1384.54
# epoch 94 - loss { 24.607534}
# total_loss 95 loss - 1378.27
# epoch 95 - loss { 24.532196}
# total_loss 96 loss - 1377.77
# epoch 96 - loss { 24.522036}
# total_loss 97 loss - 1375.36
# epoch 97 - loss { 24.551098}
# total_loss 98 loss - 1374.95
# epoch 98 - loss { 24.579597}
# total_loss 99 loss - 1374.27
# epoch 99 - loss { 24.507343}
# total_loss 100 loss - 1374.16
# epoch 100 - loss { 24.470636}
# total_loss 101 loss - 1376.86
# epoch 101 - loss { 24.517673}
# total_loss 102 loss - 1374.39
# epoch 102 - loss { 24.448736}
# total_loss 103 loss - 1374.35
# epoch 103 - loss { 24.484411}
# total_loss 104 loss - 1372.01
# epoch 104 - loss { 24.402477}
# total_loss 105 loss - 1370.57
# epoch 105 - loss { 24.465029}
# total_loss 106 loss - 1369.93
# epoch 106 - loss { 24.457092}
# total_loss 107 loss - 1372.87
# epoch 107 - loss { 24.40391 }
# total_loss 108 loss - 1373.29
# epoch 108 - loss { 24.400003}
# total_loss 109 loss - 1368.17
# epoch 109 - loss { 24.424858}
# total_loss 110 loss - 1369.58
# epoch 110 - loss { 24.407576}
# total_loss 111 loss - 1370.14
# epoch 111 - loss { 24.398056}
# total_loss 112 loss - 1366.32
# epoch 112 - loss { 24.401405}
# total_loss 113 loss - 1373.07
# epoch 113 - loss { 24.403807}
# total_loss 114 loss - 1365.8
# epoch 114 - loss { 24.397409}
# total_loss 115 loss - 1366.89
# epoch 115 - loss { 24.376724}
# total_loss 116 loss - 1368.78
# epoch 116 - loss { 24.398626}
# total_loss 117 loss - 1369.46
# epoch 117 - loss { 24.393099}
# total_loss 118 loss - 1368.34
# epoch 118 - loss { 24.37656 }
# total_loss 119 loss - 1365.72
# epoch 119 - loss { 24.307018}
# total_loss 120 loss - 1365.58
# epoch 120 - loss { 24.390856}
# total_loss 121 loss - 1365.73
# epoch 121 - loss { 24.330898}
# total_loss 122 loss - 1368.11
# epoch 122 - loss { 24.360329}
# total_loss 123 loss - 1368.88
# epoch 123 - loss { 24.34416 }
# total_loss 124 loss - 1364.1
# epoch 124 - loss { 24.346897}
# total_loss 125 loss - 1362.34
# epoch 125 - loss { 24.36034 }
# total_loss 126 loss - 1365.18
# epoch 126 - loss { 24.292782}
# total_loss 127 loss - 1365.71
# epoch 127 - loss { 24.397713}
# total_loss 128 loss - 1364.19
# epoch 128 - loss { 24.31599 }
# total_loss 129 loss - 1365.81
# epoch 129 - loss { 24.345535}
# total_loss 130 loss - 1362.27
# epoch 130 - loss { 24.269131}
# total_loss 131 loss - 1364.72
# epoch 131 - loss { 24.311544}
# total_loss 132 loss - 1361.36
# epoch 132 - loss { 24.338608}
# total_loss 133 loss - 1363.01
# epoch 133 - loss { 24.233688}
# total_loss 134 loss - 1364.36
# epoch 134 - loss { 24.287989}
# total_loss 135 loss - 1365.33
# epoch 135 - loss { 24.318197}
# total_loss 136 loss - 1363.37
# epoch 136 - loss { 24.285587}
# total_loss 137 loss - 1360.68
# epoch 137 - loss { 24.291986}
# total_loss 138 loss - 1363.31
# epoch 138 - loss { 24.301968}
# total_loss 139 loss - 1361.49
# epoch 139 - loss { 24.274048}
# total_loss 140 loss - 1360.51
# epoch 140 - loss { 24.313921}
# total_loss 141 loss - 1364.08
# epoch 141 - loss { 24.312073}
# total_loss 142 loss - 1364.92
# epoch 142 - loss { 24.235134}
# total_loss 143 loss - 1361.23
# epoch 143 - loss { 24.30249 }
# total_loss 144 loss - 1358.46
# epoch 144 - loss { 24.22459 }
# total_loss 145 loss - 1360.98
# epoch 145 - loss { 24.211948}
# total_loss 146 loss - 1360.76
# epoch 146 - loss { 24.275396}
# total_loss 147 loss - 1360.77
# epoch 147 - loss { 24.386234}
# total_loss 148 loss - 1356.89
# epoch 148 - loss { 24.202122}
# total_loss 149 loss - 1358.93
# epoch 149 - loss { 24.270226}
# total_loss 150 loss - 1360.39
# epoch 150 - loss { 24.237055}
# total_loss 151 loss - 1358.64
# epoch 151 - loss { 24.270012}
# total_loss 152 loss - 1357.65
# epoch 152 - loss { 24.253262}
# total_loss 153 loss - 1357.28
# epoch 153 - loss { 24.246784}
# total_loss 154 loss - 1360.17
# epoch 154 - loss { 24.193449}
# total_loss 155 loss - 1359.24
# epoch 155 - loss { 24.265184}
# total_loss 156 loss - 1357.27
# epoch 156 - loss { 24.229855}
# total_loss 157 loss - 1358.16
# epoch 157 - loss { 24.236362}
# total_loss 158 loss - 1358.59
# epoch 158 - loss { 24.277729}
# total_loss 159 loss - 1356.27
# epoch 159 - loss { 24.188421}
# total_loss 160 loss - 1360.22
# epoch 160 - loss { 24.170511}
# total_loss 161 loss - 1356.81
# epoch 161 - loss { 24.24474 }
# total_loss 162 loss - 1359.44
# epoch 162 - loss { 24.273594}
# total_loss 163 loss - 1353.88
# epoch 163 - loss { 24.18359 }
# total_loss 164 loss - 1358.6
# epoch 164 - loss { 24.187487}
# total_loss 165 loss - 1352.76
# epoch 165 - loss { 24.244764}
# total_loss 166 loss - 1353.14
# epoch 166 - loss { 24.233372}
# total_loss 167 loss - 1355.77
# epoch 167 - loss { 24.148352}
# total_loss 168 loss - 1357.77
# epoch 168 - loss { 24.150372}
# total_loss 169 loss - 1354.94
# epoch 169 - loss { 24.203945}
# total_loss 170 loss - 1357.63
# epoch 170 - loss { 24.178602}
# total_loss 171 loss - 1355.96
# epoch 171 - loss { 24.134373}
# total_loss 172 loss - 1356.41
# epoch 172 - loss { 24.224047}
# total_loss 173 loss - 1353.7
# epoch 173 - loss { 24.195965}
# total_loss 174 loss - 1352.5
# epoch 174 - loss { 24.152403}
# total_loss 175 loss - 1351.14
# epoch 175 - loss { 24.194818}
# total_loss 176 loss - 1354.12
# epoch 176 - loss { 24.176743}
# total_loss 177 loss - 1352.33
# epoch 177 - loss { 24.162062}
# total_loss 178 loss - 1353.42
# epoch 178 - loss { 24.179213}
# total_loss 179 loss - 1351.98
# epoch 179 - loss { 24.171041}
# total_loss 180 loss - 1351.93
# epoch 180 - loss { 24.196543}
# total_loss 181 loss - 1349.35
# epoch 181 - loss { 24.153152}
# total_loss 182 loss - 1353.59
# epoch 182 - loss { 24.154221}
# total_loss 183 loss - 1352.06
# epoch 183 - loss { 24.168444}
# total_loss 184 loss - 1353
# epoch 184 - loss { 24.165615}
# total_loss 185 loss - 1352.34
# epoch 185 - loss { 24.08419 }
# total_loss 186 loss - 1350.09
# epoch 186 - loss { 24.127739}
# total_loss 187 loss - 1351.82
# epoch 187 - loss { 24.122755}
# total_loss 188 loss - 1355.02
# epoch 188 - loss { 24.147955}
# total_loss 189 loss - 1356.42
# epoch 189 - loss { 24.116947}
# total_loss 190 loss - 1354.64
# epoch 190 - loss { 24.155817}
# total_loss 191 loss - 1355.08
# epoch 191 - loss { 24.221359}
# total_loss 192 loss - 1353.59
# epoch 192 - loss { 24.08577 }
# total_loss 193 loss - 1353.68
# epoch 193 - loss { 24.19202 }
# total_loss 194 loss - 1352.68
# epoch 194 - loss { 24.188744}
# total_loss 195 loss - 1348.63
# epoch 195 - loss { 24.178463}
# total_loss 196 loss - 1348.6
# epoch 196 - loss { 24.094397}
# total_loss 197 loss - 1353.42
# epoch 197 - loss { 24.09944 }
# total_loss 198 loss - 1353.94
# epoch 198 - loss { 24.115948}
# total_loss 199 loss - 1351.63
# epoch 199 - loss { 24.108465}

# %% [markdown]
# c++ からの出力ファイルの読み込み

# %%
#load out file
f = open('./vae1.out', 'r')

epoch_loss = []
datalist = f.readlines()
for data in datalist:
  #print(data)
  epoch_loss.append( float(data) )

f.close()

print("epoch =", len(epoch_loss))
print( epoch_loss)

# load pred file
f2 = open('vae1.pred', 'r')

datalist = f2.readlines()

n1 = 10
n2 = 64
k = 0
for data in datalist:
  ds = data.split(',')
  if k==0:
    n1 = int(ds[0])
    n2 = int(ds[1])
    global v_pred
    v_pred = np.zeros( (n1,n2))
  else:
    for i in range(n2):
      v_pred[k-1,i] = float(ds[i])
  k = k+1

f2.close()

print("pred =", n1,n2 )
#print( y_pred )

# load z file
f3 = open('vae1.z', 'r')

datalist = f3.readlines()
n1 = 100
n2 = 2
k = 0
for data in datalist:
  ds = data.split(',')
  if k==0:
    nz1 = int(ds[0])
    nz2 = int(ds[1])
    z_pred = np.zeros( (nz1,nz2))
  else:
    z_pred[k-1,0] = float(ds[0])
    z_pred[k-1,1] = float(ds[1])
  k = k+1

f3.close()

print("z =", nz1,nz2 )
#print(z_pred)
# Out:
# epoch = 200
# [33.315163, 29.588337, 28.864582, 28.606874, 28.399221, 28.196524, 28.112505, 27.971659, 27.893692, 27.743196, 27.667103, 27.463993, 27.312462, 27.131021, 26.99172, 26.916931, 26.820824, 26.766123, 26.719816, 26.643881, 26.562258, 26.530367, 26.381763, 26.348427, 26.247, 26.206259, 26.074146, 26.01207, 25.915354, 25.825445, 25.789684, 25.732431, 25.681158, 25.596584, 25.599388, 25.504528, 25.552197, 25.476049, 25.487141, 25.430086, 25.386909, 25.368185, 25.42617, 25.372347, 25.319706, 25.36867, 25.2885, 25.297209, 25.240147, 25.268906, 25.26305, 25.249092, 25.24477, 25.199209, 25.200945, 25.177311, 25.178785, 25.208733, 25.133114, 25.14896, 25.134329, 25.100973, 25.088497, 25.069168, 25.01796, 25.07704, 24.987013, 24.995789, 24.962414, 24.969923, 24.969856, 24.9928, 25.016535, 24.978628, 24.912752, 24.906364, 24.89068, 25.001881, 24.921247, 24.864115, 24.793262, 24.843006, 24.793827, 24.725113, 24.733711, 24.677113, 24.653231, 24.744532, 24.675917, 24.748131, 24.660444, 24.59337, 24.619499, 24.574203, 24.607534, 24.532196, 24.522036, 24.551098, 24.579597, 24.507343, 24.470636, 24.517673, 24.448736, 24.484411, 24.402477, 24.465029, 24.457092, 24.40391, 24.400003, 24.424858, 24.407576, 24.398056, 24.401405, 24.403807, 24.397409, 24.376724, 24.398626, 24.393099, 24.37656, 24.307018, 24.390856, 24.330898, 24.360329, 24.34416, 24.346897, 24.36034, 24.292782, 24.397713, 24.31599, 24.345535, 24.269131, 24.311544, 24.338608, 24.233688, 24.287989, 24.318197, 24.285587, 24.291986, 24.301968, 24.274048, 24.313921, 24.312073, 24.235134, 24.30249, 24.22459, 24.211948, 24.275396, 24.386234, 24.202122, 24.270226, 24.237055, 24.270012, 24.253262, 24.246784, 24.193449, 24.265184, 24.229855, 24.236362, 24.277729, 24.188421, 24.170511, 24.24474, 24.273594, 24.18359, 24.187487, 24.244764, 24.233372, 24.148352, 24.150372, 24.203945, 24.178602, 24.134373, 24.224047, 24.195965, 24.152403, 24.194818, 24.176743, 24.162062, 24.179213, 24.171041, 24.196543, 24.153152, 24.154221, 24.168444, 24.165615, 24.08419, 24.127739, 24.122755, 24.147955, 24.116947, 24.155817, 24.221359, 24.08577, 24.19202, 24.188744, 24.178463, 24.094397, 24.09944, 24.115948, 24.108465]
# pred = 10 64
# z = 1797 2

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %%
n_img5 = 10
x2 = x[:n_img5]

plt.figure( figsize=(10,2))
for i in range(n_img5):
  # input image
  ax = plt.subplot(3,n_img5,i+1)
  plt.imshow( x2[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # output image
  ax = plt.subplot(3,n_img5,i+1+n_img5)
  plt.imshow( v_pred[i].reshape(img_size,-1).tolist(),cmap="Greys_r")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %%
t2 = t_train #[:n_batch]

plt.figure(figsize=(8,8))
for i in range(10):
  zt = z_pred[t2==i]
  z_1 = zt[:,0]
  z_2 = zt[:,1]
  marker= "$"+str(i)+"$"
  plt.scatter( z_2.tolist(),  z_1.tolist(), marker=marker,s=75 )

plt.xlabel("z_2")
plt.ylabel("z_1")
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid()
plt.show()

# %%
# yet

n_img3=16
img_size_spaced = img_size + 2
matrix_image = np.zeros(( img_size_spaced*n_img3, img_size_spaced*n_img3 ))

z_1 = np.linspace( 3, -3, n_img3 )
z_2 = np.linspace( 3, -3, n_img3 )

with torch.set_grad_enabled(False):
  for i, z1 in enumerate(z_1):
    for j,z2 in enumerate(z_2):

      z = np.array([z1, z2])
      zz = torch.from_numpy( z ).float()
      
      y = F.relu( net.fc3(zz) )
      o = torch.sigmoid( net.fc4(y) )
      image = o.reshape(img_size, img_size)
      top  = i * img_size_spaced
      left = j * img_size_spaced
      matrix_image[top:top+img_size, left:left+img_size] = image

plt.figure(figsize=(8,8))
plt.imshow( matrix_image.tolist(), cmap="Greys_r" )
plt.tick_params( labelbottom=False, labelleft=False, bottom=False, left=False )
plt.show()
