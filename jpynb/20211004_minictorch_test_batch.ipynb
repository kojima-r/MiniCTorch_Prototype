# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# フォルダは自分の指定のものに変更してね。

# %%
# %cd "ctorch210929/MiniCTorch_Prototype/jpynb"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch210929/MiniCTorch_Prototype/jpynb

# %%
# !g++ -std=c++14 ../src/test_batch.cpp -lcblas -I ../../../ctorch/lib -o ../bin/test_batch

# %%
# !../bin/test_batch
# Out:
# {{{ 1.,  2.,  3.},
#   { 1.,  2.,  3.}},
#  {{ 4.,  5.,  6.},
#   { 4.,  5.,  6.}},
#  {{ 4.,  5.,  6.},
#   { 4.,  5.,  6.}},
#  {{ 7.,  8.,  9.},
#   { 7.,  8.,  9.}}}
# ==
# a{{{  1.,   2.,   3.,   4.},
#   {  4.,   5.,   6.,   7.},
#   {  7.,   8.,   9.,  10.}},
#  {{  1.,   2.,   3.,   4.},
#   {  4.,   5.,   6.,   7.},
#   {  7.,   8.,   9.,   9.}}}
# b{{ 1.,  2.,  3.},
#  { 4.,  5.,  6.},
#  { 4.,  5.,  6.},
#  { 7.,  8.,  9.}}
# c{{{  49.,   59.,   69.},
#   {  97.,  119.,  141.},
#   { 145.,  179.,  213.}},
#  {{  49.,   59.,   69.},
#   {  97.,  119.,  141.},
#   { 138.,  171.,  204.}}}
# ==
# ==
#  x_t  shape  (2,4,3,)
#  y    shape  (2,3,3,)
# b:x_t shape  (2,4,3,)
# b:y   shape  (2,3,3,)
# temp shape  (4,3,)
# temp shape  (4,3,)
# gb shape  (2,4,3,)
# va_grad{{{  6.,  15.,  15.,  24.},
#   {  6.,  15.,  15.,  24.},
#   {  6.,  15.,  15.,  24.}},
#  {{  6.,  15.,  15.,  24.},
#   {  6.,  15.,  15.,  24.},
#   {  6.,  15.,  15.,  24.}}}
# vb_grad{{{ 12.,  12.,  12.},
#   { 15.,  15.,  15.},
#   { 18.,  18.,  18.},
#   { 21.,  21.,  21.}},
#  {{ 12.,  12.,  12.},
#   { 15.,  15.,  15.},
#   { 18.,  18.,  18.},
#   { 20.,  20.,  20.}}}
