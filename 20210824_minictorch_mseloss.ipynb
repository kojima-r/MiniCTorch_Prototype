# %% [markdown]
# MSE Loss　回帰問題
# 　　参考：https://axa.biopapyrus.jp/deep-learning/pytorch/regression-multiple-features.html

# %%
#　colaboraory用: Google drive をマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# colaboratory用: フォルダを移る
# %cd "drive/My Drive/Colab Notebooks/"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/'
# /content/drive/My Drive/Colab Notebooks/ctorch210824/MiniCTorch_Prototype

# %% [markdown]
# フォルダは自分の指定のものに変更してね。

# %%
# %cd "ctorch210824/MiniCTorch_Prototype"
# Out:
# /content/drive/My Drive/Colab Notebooks/ctorch210824/MiniCTorch_Prototype

# %% [markdown]
# サンプルデータ

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(2020)

_x = np.random.uniform(0, 10, 100)

x1 = np.sin(_x)
x2 = np.exp(_x / 5)
x = np.stack([x1, x2], axis=1)
y = 3 * x1 + 2 * x2 + np.random.uniform(-1, 1, 100)

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %%
print(x)
print(y)
# Out:
# [[-0.42412035  7.18901134]
#  [ 0.63719906  5.73612498]
#  [-0.92677354  2.77178371]
#  [ 0.41071262  1.72231864]
#  [-0.22563483  1.96175103]
#  [ 0.82604285  1.5432777 ]
#  [ 0.36796658  1.73838111]
#  [-0.28744987  1.98701038]
#  [ 0.71957396  5.60869387]
#  [ 0.99999278  1.36806775]
#  [ 0.98691895  1.32547978]
#  [ 0.9601721   4.54560377]
#  [ 0.88198791  4.36077519]
#  [-0.40322494  2.03669049]
#  [-0.26609289  1.97819741]
#  [ 0.37541566  3.79470283]
#  [ 0.82521699  1.54372955]
#  [-0.62013555  3.07361368]
#  [ 0.94636315  1.28191821]
#  [-0.05574328  1.89548164]
#  [-0.10715464  6.72900809]
#  [ 0.98061344  1.31615365]
#  [-0.55557499  3.1231003 ]
#  [-0.32581805  7.03804875]
#  [-0.94883148  2.73664884]
#  [ 0.38338332  3.80124412]
#  [ 0.33529184  1.07077533]
#  [-0.98859175  2.4898905 ]
#  [ 0.99992457  1.36574863]
#  [-0.99884339  2.59114   ]
#  [ 0.99204381  1.40411172]
#  [ 0.4459135   6.00454495]
#  [-0.55830798  2.1102101 ]
#  [-0.60942619  2.13696342]
#  [ 0.74571816  5.56575796]
#  [ 0.17649582  3.64050391]
#  [-0.43367595  3.21209507]
#  [ 0.38970842  3.80646164]
#  [ 0.97862519  1.42701556]
#  [ 0.80299152  5.46572095]
#  [-0.95862529  2.42236701]
#  [ 0.89574353  5.27477181]
#  [ 0.97702449  4.60821893]
#  [ 0.22590134  6.29264791]
#  [ 0.64859288  1.15159375]
#  [ 0.99995821  1.36660674]
#  [ 0.08565194  3.57436831]
#  [-0.66405442  3.03858326]
#  [ 0.93988914  1.46793614]
#  [-0.89789634  2.3427184 ]
#  [-0.91234813  2.7922296 ]
#  [ 0.43299864  1.71387206]
#  [-0.28881142  3.31361599]
#  [ 0.80747151  1.55324748]
#  [ 0.13257623  1.82526465]
#  [ 0.46527463  1.10162787]
#  [-0.59718318  3.09144963]
#  [ 0.06441129  6.50170474]
#  [ 0.98450028  4.98311543]
#  [ 0.63643397  4.03340244]
#  [-0.99514825  2.51624712]
#  [ 0.33458122  3.76169338]
#  [ 0.93683572  4.47869306]
#  [-0.8241141   2.89478194]
#  [-0.9933128   2.62641619]
#  [ 0.28857897  1.06029637]
#  [ 0.46350521  5.98087099]
#  [ 0.89545716  5.27545097]
#  [ 0.88904241  4.37403937]
#  [ 0.42576301  6.03149313]
#  [ 0.74079375  1.58640156]
#  [ 0.97393728  1.43321621]
#  [-0.14113133  3.41547387]
#  [ 0.1659239   1.03390094]
#  [ 0.14782643  1.81965058]
#  [ 0.39146533  3.80791485]
#  [-0.10057606  6.72011234]
#  [ 0.95291495  5.11621048]
#  [ 0.70229937  1.1685042 ]
#  [ 0.97486834  1.30895074]
#  [-0.49488644  3.16798657]
#  [ 0.9796693   1.42554935]
#  [-0.49671441  7.30761825]
#  [ 0.92220668  1.26459225]
#  [ 0.85018134  5.37462963]
#  [ 0.13980779  1.02845066]
#  [ 0.65024214  5.71660426]
#  [ 0.39007267  6.07883758]
#  [-0.97582226  2.45569284]
#  [-0.10119205  3.4430715 ]
#  [-0.35695244  7.08483274]
#  [-0.73873543  2.21346015]
#  [-0.9713188   2.44601866]
#  [ 0.72359238  1.59443583]
#  [ 0.10727732  6.4459934 ]
#  [ 0.40187904  1.72565198]
#  [ 0.10132584  6.45371276]
#  [-0.83641661  2.28521702]
#  [ 0.9993525   1.37899759]
#  [-0.99970322  2.55385774]]
# [12.64423894 14.2723843   2.35412865  3.97989485  2.79168415  6.29464611
#   5.41438479  3.61123232 14.17655375  4.78092647  4.69362115 12.76882985
#  11.76910039  3.20240026  3.26380772  9.16113596  6.27097268  4.50485785
#   5.30775468  3.21705249 13.3977919   5.58821731  4.31998774 12.37507003
#   3.14517203  9.6705946   2.70548244  2.47561456  5.13110494  2.47328848
#   5.19010176 12.44771343  2.28948714  1.47383369 12.56783396  8.80919351
#   5.9747083   9.41185465  5.23465108 12.53526661  2.85993997 13.76104426
#  11.80486661 14.11491521  4.66033235  4.84667655  7.39564145  3.87461612
#   5.87840398  2.45395777  3.00503798  3.80262077  5.15158199  5.86117802
#   4.46254431  3.23517313  3.88502238 13.87355383 12.08780092 10.48869971
#   2.47963413  8.42318727 10.86394492  3.66305847  1.66550258  3.87423056
#  13.47054368 13.89993668 11.09506581 12.75261097  5.41871301  6.76981998
#   7.1658944   1.7559778   4.08080851  8.99435242 12.38100913 12.88330675
#   4.64551785  5.46355049  4.32451011  5.00182604 14.09473771  4.30893539
#  12.38579183  2.97648848 13.86318332 14.32598314  2.1930965   5.89659098
#  12.27552003  2.91583986  2.31361935  4.9452253  12.38854956  4.28321188
#  14.1509032   2.68496911  5.22713727  1.9708892 ]

# %%
! pip install lark-parser
# Out:
# Requirement already satisfied: lark-parser in /usr/local/lib/python3.7/dist-packages (0.11.3)

# %%
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import minictorch
import minictorch.generator as GN
import minictorch.converter as CV

# %% [markdown]
# ニューラルネットワークの定義

# %%
def mean_squared_error( x0, x1 ):
    diff = x0 - x1
    y = (diff**2).sum() / len(diff)
    return y;

class Net(torch.nn.Module):
  
  def __init__( self, t ):
    super(Net, self).__init__()
    self.fc1 = torch.nn.Linear(2, 64)
    self.fc2 = torch.nn.Linear(64, 32)
    self.fc3 = torch.nn.Linear(32, 1)
    self.target = t

  def forward(self, x):
    x = torch.nn.functional.relu(self.fc1(x))
    x = torch.nn.functional.relu(self.fc2(x))
    x = self.fc3(x)

    #y = mean_squared_error( x, self.target )
    loss = nn.MSELoss()
    y = loss( x, self.target )
    print('loss', y )
    return y

# %%
def generate_json( json_path, input, target ):

    model = Net( target )

    model.eval()
    with torch.no_grad():
        print("[SAVE]", json_path )
        GN.generate_minictorch_file( model, input, json_path )

    return model

# %%
torch.manual_seed( 1 )

x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y.reshape(-1, 1)).float()

project = 'mse1'
json_path = 'network/' + project +'.json'

x_tensor.requires_grad = True

model = generate_json( json_path, x_tensor, y_tensor )

with torch.set_grad_enabled(True):
  #model.train()
  yy = model( x_tensor )
  print(yy)
  yy.backward()
  print("input",x_tensor.grad)
# Out:
# [SAVE] network/mse1.json
# loss tensor(67.4897)
# loss tensor(67.4897)
# loss tensor(67.4897)
# skip: Net/Linear[fc1]/weight/91
# skip: Net/Linear[fc1]/weight/91
# skip: Net/Linear[fc2]/weight/94
# skip: Net/Linear[fc2]/weight/94
# skip: Net/Linear[fc3]/weight/97
# skip: Net/Linear[fc3]/weight/97
# loss tensor(67.4897, grad_fn=<MseLossBackward>)
# tensor(67.4897, grad_fn=<MseLossBackward>)
# input tensor([[ 6.7952e-03,  4.8823e-04],
#         [-8.7210e-03,  1.5778e-03],
#         [-1.4692e-03, -5.7918e-04],
#         [ 5.0851e-03, -3.3004e-03],
#         [-3.1918e-03, -6.0882e-04],
#         [ 7.3107e-03, -3.7030e-03],
#         [ 8.1786e-03, -5.5729e-03],
#         [-4.1216e-03, -7.8619e-04],
#         [-5.0728e-03,  8.8635e-04],
#         [ 3.6004e-04, -8.5637e-05],
#         [ 3.5354e-04, -8.4092e-05],
#         [-4.3465e-03,  7.3654e-04],
#         [-4.0067e-03,  6.7897e-04],
#         [-3.4841e-03, -5.3126e-04],
#         [-3.7277e-03, -7.1106e-04],
#         [ 6.2141e-05,  9.6287e-04],
#         [ 7.2834e-03, -3.6891e-03],
#         [-4.4959e-03, -3.9537e-04],
#         [ 3.9924e-04, -9.4964e-05],
#         [-3.5350e-03, -7.2280e-04],
#         [-5.3305e-04,  2.0967e-03],
#         [ 4.2013e-04, -9.9932e-05],
#         [-4.3099e-03, -3.7900e-04],
#         [-5.4635e-05,  1.1250e-03],
#         [-2.3520e-03, -7.7544e-04],
#         [ 6.5595e-05,  1.0163e-03],
#         [-2.8174e-04, -2.5140e-03],
#         [-7.3042e-05,  7.3730e-04],
#         [ 3.8610e-04, -9.1838e-05],
#         [-1.3349e-03, -3.4530e-04],
#         [ 3.9049e-04, -9.2882e-05],
#         [-7.6121e-03,  1.3772e-03],
#         [-2.6267e-03, -4.2821e-04],
#         [-1.7136e-03, -2.7936e-04],
#         [-4.4977e-03,  7.8585e-04],
#         [-2.1708e-03,  1.3491e-03],
#         [-5.9388e-03, -5.2225e-04],
#         [ 6.3840e-05,  9.8919e-04],
#         [ 3.9380e-04, -9.3669e-05],
#         [-4.4856e-03,  7.8374e-04],
#         [-8.4061e-05,  8.4853e-04],
#         [-4.9228e-03,  8.6014e-04],
#         [-4.0186e-03,  6.8098e-04],
#         [-3.4811e-03,  2.1633e-03],
#         [ 3.0112e-03, -1.4009e-03],
#         [ 3.6493e-04, -8.6802e-05],
#         [-1.8208e-03,  6.9478e-04],
#         [-3.8754e-03, -3.4080e-04],
#         [ 1.4418e-03, -9.3774e-04],
#         [ 4.3009e-05,  7.0248e-04],
#         [-9.6583e-04, -4.9340e-04],
#         [ 4.0602e-03, -2.6449e-03],
#         [-5.1178e-03, -4.5006e-04],
#         [ 6.8097e-03, -3.4492e-03],
#         [-7.0340e-03, -1.0018e-03],
#         [ 3.7568e-03, -2.7978e-03],
#         [-3.8822e-03, -3.4139e-04],
#         [-5.5184e-04,  2.1706e-03],
#         [-4.1151e-03,  6.9734e-04],
#         [-3.6962e-03,  6.3108e-04],
#         [-7.3169e-05,  7.3858e-04],
#         [ 5.7143e-05,  8.8541e-04],
#         [-3.6987e-03,  6.2676e-04],
#         [-4.1779e-03, -6.8109e-04],
#         [-1.2692e-03, -4.1847e-04],
#         [-4.0164e-04, -3.5837e-03],
#         [-8.2358e-03,  1.4901e-03],
#         [-4.9725e-03,  8.6881e-04],
#         [-3.7774e-03,  6.4012e-04],
#         [-7.7986e-03,  1.4110e-03],
#         [ 5.3231e-03, -3.4821e-03],
#         [ 1.6586e-03, -1.0787e-03],
#         [-7.1008e-03, -6.2444e-04],
#         [ 1.5773e-03, -4.1490e-04],
#         [-6.4321e-03, -9.1612e-04],
#         [ 6.1015e-05,  9.4538e-04],
#         [-4.9271e-04,  1.9380e-03],
#         [-4.6086e-03,  8.0524e-04],
#         [ 3.0026e-03, -1.3970e-03],
#         [ 4.1085e-04, -9.7724e-05],
#         [-4.3112e-03, -3.7912e-04],
#         [ 3.7647e-04, -8.9546e-05],
#         [ 7.5713e-03,  5.4400e-04],
#         [ 3.2488e-04, -7.7277e-05],
#         [-4.4317e-03,  7.7433e-04],
#         [ 2.7303e-03, -7.1365e-04],
#         [-4.9614e-03,  8.6687e-04],
#         [-8.7595e-03,  1.5848e-03],
#         [-6.4906e-05,  6.5517e-04],
#         [-7.3791e-03, -5.9744e-04],
#         [-5.4198e-05,  1.1160e-03],
#         [-9.5431e-04,  1.3051e-03],
#         [-6.8366e-05,  6.9010e-04],
#         [ 4.8607e-03, -3.1796e-03],
#         [-3.0570e-03,  1.8998e-03],
#         [ 5.4695e-03, -3.5499e-03],
#         [-5.6283e-04,  2.2138e-03],
#         [-1.6223e-03,  1.0441e-03],
#         [ 3.9325e-04, -9.3538e-05],
#         [-5.8560e-05,  5.9112e-04]])

# %%
def convert_json( project, folder, model, input_x, json_path, rand_flag=0 ):

    #folder = "src"
    cpp_fname   = project + ".cpp"
    param_fname = project + "_param.cpp"
    cpp_path    = folder + "/" + cpp_fname
    param_path  = folder + "/" + param_fname
    make_path   = folder + "/" + "Makefile"

    # load json file
    print( "[JSON]", json_path )
    fp = open( json_path )
    obj = json.load( fp )

    # save parameter file
    code1 = CV.c_param_generator( obj, model, input_x )
    if len( code1 ) > 0:
       print( "[PARAM]", param_path )
       ofparam = open( param_path, "w" )
       ofparam.write( code1 )

    # save cpp file
    print( "[CPP]  ", cpp_path )
    code2 = CV.c_code_generator( obj, model, rand_flag )

    #print("[SAVE]",args.path+"/"+args.output)
    #ofp=open(args.path+"/"+args.output,"w")
    ofp = open( cpp_path, "w" )
    ofp.write( code2 )

    # save make file
    print( "[MAKE] ", make_path )
    make_code = CV.makefile_generator( cpp_fname )

    #makefp=open(args.path+"/"+"Makefile","w")
    makefp = open( make_path, "w" )
    makefp.write( make_code )

convert_json( project, "src", model, x_tensor, json_path )
# Out:
# [JSON] network/mse1.json
# {'name': 'Net/Linear[fc1]/weight/105', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [3], 'sorted_id': 1}
# {'name': 'Net/Linear[fc1]/bias/104', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [3], 'sorted_id': 2}
# {'name': 'Net/Linear[fc2]/weight/108', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [7], 'sorted_id': 5}
# {'name': 'Net/Linear[fc2]/bias/107', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [7], 'sorted_id': 6}
# {'name': 'Net/Linear[fc3]/weight/111', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [11], 'sorted_id': 9}
# {'name': 'Net/Linear[fc3]/bias/110', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [11], 'sorted_id': 10}
# [PARAM] src/mse1_param.cpp
# [CPP]   src/mse1.cpp
# {'name': 'input/x', 'op': 'IO Node', 'in': [], 'shape': [100, 2], 'out': [3], 'sorted_id': 0}
# {'name': 'Net/Linear[fc1]/weight/105', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [3], 'sorted_id': 1}
# Net/Linear[fc1]/weight/105  ->  fc1_weight
# {'name': 'Net/Linear[fc1]/bias/104', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [3], 'sorted_id': 2}
# Net/Linear[fc1]/bias/104  ->  fc1_bias
# {'name': 'Net/Linear[fc1]/input.1', 'op': 'aten::linear', 'in': [0, 1, 2], 'shape': [100, 64], 'out': [4], 'sorted_id': 3}
# {'name': 'Net/input.3', 'op': 'aten::relu', 'in': [3], 'shape': [100, 64], 'out': [7], 'sorted_id': 4}
# {'name': 'Net/Linear[fc2]/weight/108', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [7], 'sorted_id': 5}
# Net/Linear[fc2]/weight/108  ->  fc2_weight
# {'name': 'Net/Linear[fc2]/bias/107', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [7], 'sorted_id': 6}
# Net/Linear[fc2]/bias/107  ->  fc2_bias
# {'name': 'Net/Linear[fc2]/input.5', 'op': 'aten::linear', 'in': [4, 5, 6], 'shape': [100, 32], 'out': [8], 'sorted_id': 7}
# {'name': 'Net/input.7', 'op': 'aten::relu', 'in': [7], 'shape': [100, 32], 'out': [11], 'sorted_id': 8}
# {'name': 'Net/Linear[fc3]/weight/111', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [11], 'sorted_id': 9}
# Net/Linear[fc3]/weight/111  ->  fc3_weight
# {'name': 'Net/Linear[fc3]/bias/110', 'op': 'prim::GetAttr', 'in': [], 'shape': [], 'out': [11], 'sorted_id': 10}
# Net/Linear[fc3]/bias/110  ->  fc3_bias
# {'name': 'Net/Linear[fc3]/input.9', 'op': 'aten::linear', 'in': [8, 9, 10], 'shape': [100, 1], 'out': [13], 'sorted_id': 11}
# {'name': 'Net/target.1', 'op': 'prim::Constant', 'in': [], 'shape': [100, 1], 'constant_value': [12.6442, 14.2724, 2.3541, 3.9799, 2.7917, 6.2946, 5.4144, 3.6112, 14.1766, 4.7809, 4.6936, 12.7688, 11.7691, 3.2024, 3.2638, 9.1611, 6.271, 4.5049, 5.3078, 3.2171, 13.3978, 5.5882, 4.32, 12.3751, 3.1452, 9.6706, 2.7055, 2.4756, 5.1311, 2.4733, 5.1901, 12.4477, 2.2895, 1.4738, 12.5678, 8.8092, 5.9747, 9.4119, 5.2347, 12.5353, 2.8599, 13.761, 11.8049, 14.1149, 4.6603, 4.8467, 7.3956, 3.8746, 5.8784, 2.454, 3.005, 3.8026, 5.1516, 5.8612, 4.4625, 3.2352, 3.885, 13.8736, 12.0878, 10.4887, 2.4796, 8.4232, 10.8639, 3.6631, 1.6655, 3.8742, 13.4705, 13.8999, 11.0951, 12.7526, 5.4187, 6.7698, 7.1659, 1.756, 4.0808, 8.9944, 12.381, 12.8833, 4.6455, 5.4636, 4.3245, 5.0018, 14.0947, 4.3089, 12.3858, 2.9765, 13.8632, 14.326, 2.1931, 5.8966, 12.2755, 2.9158, 2.3136, 4.9452, 12.3885, 4.2832, 14.1509, 2.685, 5.2271, 1.9709], 'out': [13], 'sorted_id': 12}
# {'name': 'Net/39', 'op': 'prim::ListConstruct', 'in': [11, 12], 'shape': [], 'out': [14], 'sorted_id': 13}
# {'name': 'Net/40', 'op': 'aten::broadcast_tensors', 'in': [13], 'shape': [], 'out': [15, 16], 'sorted_id': 14}
# {'name': 'Net/input', 'op': 'prim::ListUnpack', 'in': [14], 'shape': [100, 1], 'out': [18], 'sorted_id': 15}
# {'name': 'Net/target', 'op': 'prim::ListUnpack', 'in': [14], 'shape': [100, 1], 'out': [18], 'sorted_id': 16}
# {'name': 'Net/43', 'op': 'prim::Constant', 'in': [], 'shape': [], 'constant_value': 1.0, 'out': [18], 'sorted_id': 17}
# {'name': 'Net/tensor', 'op': 'aten::mse_loss', 'in': [15, 16, 17], 'shape': [], 'out': [19], 'sorted_id': 18}
# {'name': 'output/output.1', 'op': 'IO Node', 'in': [18], 'shape': [], 'out': [], 'sorted_id': 19}
# [MAKE]  src/Makefile

# %%
# !g++ -std=c++14 ./src/mse1.cpp ./src/mse1_param.cpp -I ../../ctorch/lib  -lcblas -o ./bin/mse1

# %% [markdown]
# (注意) ctorch/libにxtensor関連のincludeを置いています。

# %%
# !./bin/mse1
# Out:
# ### forward computation ...
#  67.489609
# ### backward computation ...
# input_grad{{ 0.006795,  0.000488},
#  {-0.008721,  0.001578},
#  {-0.001469, -0.000579},
#  { 0.005085, -0.0033  },
#  {-0.003192, -0.000609},
#  { 0.007311, -0.003703},
#  { 0.008179, -0.005573},
#  {-0.004122, -0.000786},
#  {-0.005073,  0.000886},
#  { 0.00036 , -0.000086},
#  { 0.000354, -0.000084},
#  {-0.004346,  0.000737},
#  {-0.004007,  0.000679},
#  {-0.003484, -0.000531},
#  {-0.003728, -0.000711},
#  { 0.000062,  0.000963},
#  { 0.007283, -0.003689},
#  {-0.004496, -0.000395},
#  { 0.000399, -0.000095},
#  {-0.003535, -0.000723},
#  {-0.000533,  0.002097},
#  { 0.00042 , -0.0001  },
#  {-0.00431 , -0.000379},
#  {-0.000055,  0.001125},
#  {-0.002352, -0.000775},
#  { 0.000066,  0.001016},
#  {-0.000282, -0.002514},
#  {-0.000073,  0.000737},
#  { 0.000386, -0.000092},
#  {-0.001335, -0.000345},
#  { 0.00039 , -0.000093},
#  {-0.007612,  0.001377},
#  {-0.002627, -0.000428},
#  {-0.001714, -0.000279},
#  {-0.004498,  0.000786},
#  {-0.002171,  0.001349},
#  {-0.005939, -0.000522},
#  { 0.000064,  0.000989},
#  { 0.000394, -0.000094},
#  {-0.004486,  0.000784},
#  {-0.000084,  0.000849},
#  {-0.004923,  0.00086 },
#  {-0.004019,  0.000681},
#  {-0.003481,  0.002163},
#  { 0.003011, -0.001401},
#  { 0.000365, -0.000087},
#  {-0.001821,  0.000695},
#  {-0.003875, -0.000341},
#  { 0.001442, -0.000938},
#  { 0.000043,  0.000702},
#  {-0.000966, -0.000493},
#  { 0.00406 , -0.002645},
#  {-0.005118, -0.00045 },
#  { 0.00681 , -0.003449},
#  {-0.007034, -0.001002},
#  { 0.003757, -0.002798},
#  {-0.003882, -0.000341},
#  {-0.000552,  0.002171},
#  {-0.004115,  0.000697},
#  {-0.003696,  0.000631},
#  {-0.000073,  0.000739},
#  { 0.000057,  0.000885},
#  {-0.003699,  0.000627},
#  {-0.004178, -0.000681},
#  {-0.001269, -0.000418},
#  {-0.000402, -0.003584},
#  {-0.008236,  0.00149 },
#  {-0.004972,  0.000869},
#  {-0.003777,  0.00064 },
#  {-0.007799,  0.001411},
#  { 0.005323, -0.003482},
#  { 0.001659, -0.001079},
#  {-0.007101, -0.000624},
#  { 0.001577, -0.000415},
#  {-0.006432, -0.000916},
#  { 0.000061,  0.000945},
#  {-0.000493,  0.001938},
#  {-0.004609,  0.000805},
#  { 0.003003, -0.001397},
#  { 0.000411, -0.000098},
#  {-0.004311, -0.000379},
#  { 0.000376, -0.00009 },
#  { 0.007571,  0.000544},
#  { 0.000325, -0.000077},
#  {-0.004432,  0.000774},
#  { 0.00273 , -0.000714},
#  {-0.004961,  0.000867},
#  {-0.008759,  0.001585},
#  {-0.000065,  0.000655},
#  {-0.007379, -0.000597},
#  {-0.000054,  0.001116},
#  {-0.000954,  0.001305},
#  {-0.000068,  0.00069 },
#  { 0.004861, -0.00318 },
#  {-0.003057,  0.0019  },
#  { 0.00547 , -0.00355 },
#  {-0.000563,  0.002214},
#  {-0.001622,  0.001044},
#  { 0.000393, -0.000094},
#  {-0.000059,  0.000591}}

# %% [markdown]
# 学習の実行

# %%
class Net(torch.nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = torch.nn.Linear(2, 64)
    self.fc2 = torch.nn.Linear(64, 32)
    self.fc3 = torch.nn.Linear(32, 1)

  def forward(self, x):
    x = torch.nn.functional.relu(self.fc1(x))
    x = torch.nn.functional.relu(self.fc2(x))
    x = self.fc3(x)
    return x

# %%
torch.manual_seed( 1 )
 
x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y.reshape(-1, 1)).float()

project = 'test4'
json_path = 'network/' + project +'.json'

x_tensor.requires_grad = True

net = Net()
net.train()
lr=0.01
opt=torch.optim.SGD(net.parameters(), lr)
mse=torch.nn.MSELoss()

for epoch in range(3):
  out=net(x_tensor)
  loss=mse(out,y_tensor)
  print("loss",loss)

  opt.zero_grad()
  loss.backward()
  opt.step();
# Out:
# loss tensor(67.4897, grad_fn=<MseLossBackward>)
# loss tensor(36.1833, grad_fn=<MseLossBackward>)
# loss tensor(3.8057, grad_fn=<MseLossBackward>)

# %% [markdown]
# C++のコードは手作業で修正しています。

# %%
# !g++ -std=c++14 ./src/mse1_opt.cpp ./src/mse1_param.cpp -I ../../ctorch/lib -lblas -o ./bin/mse1_opt

# %% [markdown]
# (注意) ctorch/libにxtensor関連のincludeを置いています。

# %%
# !./bin/mse1_opt
# Out:
# ### forward computation ...
# epoch 0 - loss 67.4896
# ### backward computation ...
# ### forward computation ...
# epoch 1 - loss 36.1833
# ### backward computation ...
# ### forward computation ...
# epoch 2 - loss 3.80568
# ### backward computation ...
# ### forward computation ...
# epoch 3 - loss 5.00023
# ### backward computation ...
# ### forward computation ...
# epoch 4 - loss 8.29694
# ### backward computation ...
# ### forward computation ...
# epoch 5 - loss 23.9232
# ### backward computation ...
# ### forward computation ...
# epoch 6 - loss 8.93714
# ### backward computation ...
# ### forward computation ...
# epoch 7 - loss 25.941
# ### backward computation ...
# ### forward computation ...
# epoch 8 - loss 5.53436
# ### backward computation ...
# ### forward computation ...
# epoch 9 - loss 14.0319
# ### backward computation ...
# ### forward computation ...
# epoch 10 - loss 10.9611
# ### backward computation ...
# ### forward computation ...
# epoch 11 - loss 31.012
# ### backward computation ...
# ### forward computation ...
# epoch 12 - loss 1.59738
# ### backward computation ...
# ### forward computation ...
# epoch 13 - loss 1.55511
# ### backward computation ...
# ### forward computation ...
# epoch 14 - loss 1.66699
# ### backward computation ...
# ### forward computation ...
# epoch 15 - loss 2.34855
# ### backward computation ...
# ### forward computation ...
# epoch 16 - loss 3.642
# ### backward computation ...
# ### forward computation ...
# epoch 17 - loss 9.31776
# ### backward computation ...
# ### forward computation ...
# epoch 18 - loss 9.30898
# ### backward computation ...
# ### forward computation ...
# epoch 19 - loss 26.372
# ### backward computation ...
# ### forward computation ...
# epoch 20 - loss 1.44156
# ### backward computation ...
# ### forward computation ...
# epoch 21 - loss 2.28406
# ### backward computation ...
# ### forward computation ...
# epoch 22 - loss 3.39267
# ### backward computation ...
# ### forward computation ...
# epoch 23 - loss 8.3717
# ### backward computation ...
# ### forward computation ...
# epoch 24 - loss 7.26356
# ### backward computation ...
# ### forward computation ...
# epoch 25 - loss 19.5553
# ### backward computation ...
# ### forward computation ...
# epoch 26 - loss 2.92074
# ### backward computation ...
# ### forward computation ...
# epoch 27 - loss 6.62614
# ### backward computation ...
# ### forward computation ...
# epoch 28 - loss 5.92828
# ### backward computation ...
# ### forward computation ...
# epoch 29 - loss 15.0171
# ### backward computation ...
# ### forward computation ...
# epoch 30 - loss 3.91599
# ### backward computation ...
# ### forward computation ...
# epoch 31 - loss 9.14596
# ### backward computation ...
# ### forward computation ...
# epoch 32 - loss 5.23805
# ### backward computation ...
# ### forward computation ...
# epoch 33 - loss 12.5484
# ### backward computation ...
# ### forward computation ...
# epoch 34 - loss 4.02987
# ### backward computation ...
# ### forward computation ...
# epoch 35 - loss 9.12676
# ### backward computation ...
# ### forward computation ...
# epoch 36 - loss 4.57761
# ### backward computation ...
# ### forward computation ...
# epoch 37 - loss 10.4066
# ### backward computation ...
# ### forward computation ...
# epoch 38 - loss 4.05323
# ### backward computation ...
# ### forward computation ...
# epoch 39 - loss 8.92109
# ### backward computation ...
# ### forward computation ...
# epoch 40 - loss 4.11703
# ### backward computation ...
# ### forward computation ...
# epoch 41 - loss 8.97003
# ### backward computation ...
# ### forward computation ...
# epoch 42 - loss 3.90764
# ### backward computation ...
# ### forward computation ...
# epoch 43 - loss 8.34062
# ### backward computation ...
# ### forward computation ...
# epoch 44 - loss 3.82469
# ### backward computation ...
# ### forward computation ...
# epoch 45 - loss 8.04971
# ### backward computation ...
# ### forward computation ...
# epoch 46 - loss 3.70605
# ### backward computation ...
# ### forward computation ...
# epoch 47 - loss 7.68514
# ### backward computation ...
# ### forward computation ...
# epoch 48 - loss 3.61045
# ### backward computation ...
# ### forward computation ...
# epoch 49 - loss 7.38872
# ### backward computation ...
# ### forward computation ...
# epoch 50 - loss 3.51833
# ### backward computation ...
# ### forward computation ...
# epoch 51 - loss 7.11027
# ### backward computation ...
# ### forward computation ...
# epoch 52 - loss 3.43334
# ### backward computation ...
# ### forward computation ...
# epoch 53 - loss 6.85664
# ### backward computation ...
# ### forward computation ...
# epoch 54 - loss 3.35463
# ### backward computation ...
# ### forward computation ...
# epoch 55 - loss 6.62465
# ### backward computation ...
# ### forward computation ...
# epoch 56 - loss 3.27981
# ### backward computation ...
# ### forward computation ...
# epoch 57 - loss 6.40787
# ### backward computation ...
# ### forward computation ...
# epoch 58 - loss 3.20931
# ### backward computation ...
# ### forward computation ...
# epoch 59 - loss 6.20591
# ### backward computation ...
# ### forward computation ...
# epoch 60 - loss 3.1429
# ### backward computation ...
# ### forward computation ...
# epoch 61 - loss 6.01766
# ### backward computation ...
# ### forward computation ...
# epoch 62 - loss 3.07968
# ### backward computation ...
# ### forward computation ...
# epoch 63 - loss 5.84109
# ### backward computation ...
# ### forward computation ...
# epoch 64 - loss 3.02022
# ### backward computation ...
# ### forward computation ...
# epoch 65 - loss 5.67529
# ### backward computation ...
# ### forward computation ...
# epoch 66 - loss 2.96111
# ### backward computation ...
# ### forward computation ...
# epoch 67 - loss 5.51285
# ### backward computation ...
# ### forward computation ...
# epoch 68 - loss 2.9056
# ### backward computation ...
# ### forward computation ...
# epoch 69 - loss 5.36332
# ### backward computation ...
# ### forward computation ...
# epoch 70 - loss 2.85267
# ### backward computation ...
# ### forward computation ...
# epoch 71 - loss 5.22294
# ### backward computation ...
# ### forward computation ...
# epoch 72 - loss 2.8034
# ### backward computation ...
# ### forward computation ...
# epoch 73 - loss 5.09347
# ### backward computation ...
# ### forward computation ...
# epoch 74 - loss 2.75746
# ### backward computation ...
# ### forward computation ...
# epoch 75 - loss 4.97001
# ### backward computation ...
# ### forward computation ...
# epoch 76 - loss 2.71284
# ### backward computation ...
# ### forward computation ...
# epoch 77 - loss 4.85773
# ### backward computation ...
# ### forward computation ...
# epoch 78 - loss 2.67019
# ### backward computation ...
# ### forward computation ...
# epoch 79 - loss 4.74421
# ### backward computation ...
# ### forward computation ...
# epoch 80 - loss 2.62858
# ### backward computation ...
# ### forward computation ...
# epoch 81 - loss 4.63749
# ### backward computation ...
# ### forward computation ...
# epoch 82 - loss 2.58819
# ### backward computation ...
# ### forward computation ...
# epoch 83 - loss 4.53794
# ### backward computation ...
# ### forward computation ...
# epoch 84 - loss 2.5491
# ### backward computation ...
# ### forward computation ...
# epoch 85 - loss 4.43666
# ### backward computation ...
# ### forward computation ...
# epoch 86 - loss 2.5115
# ### backward computation ...
# ### forward computation ...
# epoch 87 - loss 4.34301
# ### backward computation ...
# ### forward computation ...
# epoch 88 - loss 2.47651
# ### backward computation ...
# ### forward computation ...
# epoch 89 - loss 4.25915
# ### backward computation ...
# ### forward computation ...
# epoch 90 - loss 2.44236
# ### backward computation ...
# ### forward computation ...
# epoch 91 - loss 4.17156
# ### backward computation ...
# ### forward computation ...
# epoch 92 - loss 2.40812
# ### backward computation ...
# ### forward computation ...
# epoch 93 - loss 4.09119
# ### backward computation ...
# ### forward computation ...
# epoch 94 - loss 2.37554
# ### backward computation ...
# ### forward computation ...
# epoch 95 - loss 4.009
# ### backward computation ...
# ### forward computation ...
# epoch 96 - loss 2.34326
# ### backward computation ...
# ### forward computation ...
# epoch 97 - loss 3.93198
# ### backward computation ...
# ### forward computation ...
# epoch 98 - loss 2.31195
# ### backward computation ...
# ### forward computation ...
# epoch 99 - loss 3.85888
# ### backward computation ...
# ### forward computation ...
# epoch 100 - loss 2.28128
# ### backward computation ...
# ### forward computation ...
# epoch 101 - loss 3.78277
# ### backward computation ...
# ### forward computation ...
# epoch 102 - loss 2.25089
# ### backward computation ...
# ### forward computation ...
# epoch 103 - loss 3.71078
# ### backward computation ...
# ### forward computation ...
# epoch 104 - loss 2.22143
# ### backward computation ...
# ### forward computation ...
# epoch 105 - loss 3.64411
# ### backward computation ...
# ### forward computation ...
# epoch 106 - loss 2.19223
# ### backward computation ...
# ### forward computation ...
# epoch 107 - loss 3.57406
# ### backward computation ...
# ### forward computation ...
# epoch 108 - loss 2.16324
# ### backward computation ...
# ### forward computation ...
# epoch 109 - loss 3.50741
# ### backward computation ...
# ### forward computation ...
# epoch 110 - loss 2.13645
# ### backward computation ...
# ### forward computation ...
# epoch 111 - loss 3.44898
# ### backward computation ...
# ### forward computation ...
# epoch 112 - loss 2.11107
# ### backward computation ...
# ### forward computation ...
# epoch 113 - loss 3.38839
# ### backward computation ...
# ### forward computation ...
# epoch 114 - loss 2.08484
# ### backward computation ...
# ### forward computation ...
# epoch 115 - loss 3.3307
# ### backward computation ...
# ### forward computation ...
# epoch 116 - loss 2.05966
# ### backward computation ...
# ### forward computation ...
# epoch 117 - loss 3.27158
# ### backward computation ...
# ### forward computation ...
# epoch 118 - loss 2.03412
# ### backward computation ...
# ### forward computation ...
# epoch 119 - loss 3.21736
# ### backward computation ...
# ### forward computation ...
# epoch 120 - loss 2.01061
# ### backward computation ...
# ### forward computation ...
# epoch 121 - loss 3.16267
# ### backward computation ...
# ### forward computation ...
# epoch 122 - loss 1.98644
# ### backward computation ...
# ### forward computation ...
# epoch 123 - loss 3.11265
# ### backward computation ...
# ### forward computation ...
# epoch 124 - loss 1.9634
# ### backward computation ...
# ### forward computation ...
# epoch 125 - loss 3.05963
# ### backward computation ...
# ### forward computation ...
# epoch 126 - loss 1.93975
# ### backward computation ...
# ### forward computation ...
# epoch 127 - loss 3.00851
# ### backward computation ...
# ### forward computation ...
# epoch 128 - loss 1.91683
# ### backward computation ...
# ### forward computation ...
# epoch 129 - loss 2.96151
# ### backward computation ...
# ### forward computation ...
# epoch 130 - loss 1.89502
# ### backward computation ...
# ### forward computation ...
# epoch 131 - loss 2.91217
# ### backward computation ...
# ### forward computation ...
# epoch 132 - loss 1.87245
# ### backward computation ...
# ### forward computation ...
# epoch 133 - loss 2.86465
# ### backward computation ...
# ### forward computation ...
# epoch 134 - loss 1.85041
# ### backward computation ...
# ### forward computation ...
# epoch 135 - loss 2.8175
# ### backward computation ...
# ### forward computation ...
# epoch 136 - loss 1.82862
# ### backward computation ...
# ### forward computation ...
# epoch 137 - loss 2.77373
# ### backward computation ...
# ### forward computation ...
# epoch 138 - loss 1.80789
# ### backward computation ...
# ### forward computation ...
# epoch 139 - loss 2.72837
# ### backward computation ...
# ### forward computation ...
# epoch 140 - loss 1.78675
# ### backward computation ...
# ### forward computation ...
# epoch 141 - loss 2.68435
# ### backward computation ...
# ### forward computation ...
# epoch 142 - loss 1.766
# ### backward computation ...
# ### forward computation ...
# epoch 143 - loss 2.63821
# ### backward computation ...
# ### forward computation ...
# epoch 144 - loss 1.74461
# ### backward computation ...
# ### forward computation ...
# epoch 145 - loss 2.59523
# ### backward computation ...
# ### forward computation ...
# epoch 146 - loss 1.72466
# ### backward computation ...
# ### forward computation ...
# epoch 147 - loss 2.5574
# ### backward computation ...
# ### forward computation ...
# epoch 148 - loss 1.70566
# ### backward computation ...
# ### forward computation ...
# epoch 149 - loss 2.51576
# ### backward computation ...
# ### forward computation ...
# epoch 150 - loss 1.68583
# ### backward computation ...
# ### forward computation ...
# epoch 151 - loss 2.47588
# ### backward computation ...
# ### forward computation ...
# epoch 152 - loss 1.66648
# ### backward computation ...
# ### forward computation ...
# epoch 153 - loss 2.43738
# ### backward computation ...
# ### forward computation ...
# epoch 154 - loss 1.64759
# ### backward computation ...
# ### forward computation ...
# epoch 155 - loss 2.39969
# ### backward computation ...
# ### forward computation ...
# epoch 156 - loss 1.62893
# ### backward computation ...
# ### forward computation ...
# epoch 157 - loss 2.36567
# ### backward computation ...
# ### forward computation ...
# epoch 158 - loss 1.61165
# ### backward computation ...
# ### forward computation ...
# epoch 159 - loss 2.32862
# ### backward computation ...
# ### forward computation ...
# epoch 160 - loss 1.59422
# ### backward computation ...
# ### forward computation ...
# epoch 161 - loss 2.29407
# ### backward computation ...
# ### forward computation ...
# epoch 162 - loss 1.57704
# ### backward computation ...
# ### forward computation ...
# epoch 163 - loss 2.26248
# ### backward computation ...
# ### forward computation ...
# epoch 164 - loss 1.56095
# ### backward computation ...
# ### forward computation ...
# epoch 165 - loss 2.2291
# ### backward computation ...
# ### forward computation ...
# epoch 166 - loss 1.54384
# ### backward computation ...
# ### forward computation ...
# epoch 167 - loss 2.19589
# ### backward computation ...
# ### forward computation ...
# epoch 168 - loss 1.52811
# ### backward computation ...
# ### forward computation ...
# epoch 169 - loss 2.1683
# ### backward computation ...
# ### forward computation ...
# epoch 170 - loss 1.51335
# ### backward computation ...
# ### forward computation ...
# epoch 171 - loss 2.13908
# ### backward computation ...
# ### forward computation ...
# epoch 172 - loss 1.49868
# ### backward computation ...
# ### forward computation ...
# epoch 173 - loss 2.11138
# ### backward computation ...
# ### forward computation ...
# epoch 174 - loss 1.48318
# ### backward computation ...
# ### forward computation ...
# epoch 175 - loss 2.07874
# ### backward computation ...
# ### forward computation ...
# epoch 176 - loss 1.46758
# ### backward computation ...
# ### forward computation ...
# epoch 177 - loss 2.04927
# ### backward computation ...
# ### forward computation ...
# epoch 178 - loss 1.45171
# ### backward computation ...
# ### forward computation ...
# epoch 179 - loss 2.02289
# ### backward computation ...
# ### forward computation ...
# epoch 180 - loss 1.43724
# ### backward computation ...
# ### forward computation ...
# epoch 181 - loss 1.99246
# ### backward computation ...
# ### forward computation ...
# epoch 182 - loss 1.42186
# ### backward computation ...
# ### forward computation ...
# epoch 183 - loss 1.96571
# ### backward computation ...
# ### forward computation ...
# epoch 184 - loss 1.40629
# ### backward computation ...
# ### forward computation ...
# epoch 185 - loss 1.93731
# ### backward computation ...
# ### forward computation ...
# epoch 186 - loss 1.39191
# ### backward computation ...
# ### forward computation ...
# epoch 187 - loss 1.90929
# ### backward computation ...
# ### forward computation ...
# epoch 188 - loss 1.37638
# ### backward computation ...
# ### forward computation ...
# epoch 189 - loss 1.88029
# ### backward computation ...
# ### forward computation ...
# epoch 190 - loss 1.3617
# ### backward computation ...
# ### forward computation ...
# epoch 191 - loss 1.85355
# ### backward computation ...
# ### forward computation ...
# epoch 192 - loss 1.34666
# ### backward computation ...
# ### forward computation ...
# epoch 193 - loss 1.82866
# ### backward computation ...
# ### forward computation ...
# epoch 194 - loss 1.33363
# ### backward computation ...
# ### forward computation ...
# epoch 195 - loss 1.80281
# ### backward computation ...
# ### forward computation ...
# epoch 196 - loss 1.31901
# ### backward computation ...
# ### forward computation ...
# epoch 197 - loss 1.77678
# ### backward computation ...
# ### forward computation ...
# epoch 198 - loss 1.30558
# ### backward computation ...
# ### forward computation ...
# epoch 199 - loss 1.75257
# ### backward computation ...
# ### forward computation ...
# epoch 200 - loss 1.29166
# ### backward computation ...
# ### forward computation ...
# epoch 201 - loss 1.72808
# ### backward computation ...
# ### forward computation ...
# epoch 202 - loss 1.27829
# ### backward computation ...
# ### forward computation ...
# epoch 203 - loss 1.7044
# ### backward computation ...
# ### forward computation ...
# epoch 204 - loss 1.26476
# ### backward computation ...
# ### forward computation ...
# epoch 205 - loss 1.68263
# ### backward computation ...
# ### forward computation ...
# epoch 206 - loss 1.25296
# ### backward computation ...
# ### forward computation ...
# epoch 207 - loss 1.65975
# ### backward computation ...
# ### forward computation ...
# epoch 208 - loss 1.2397
# ### backward computation ...
# ### forward computation ...
# epoch 209 - loss 1.63653
# ### backward computation ...
# ### forward computation ...
# epoch 210 - loss 1.22688
# ### backward computation ...
# ### forward computation ...
# epoch 211 - loss 1.61417
# ### backward computation ...
# ### forward computation ...
# epoch 212 - loss 1.21399
# ### backward computation ...
# ### forward computation ...
# epoch 213 - loss 1.59203
# ### backward computation ...
# ### forward computation ...
# epoch 214 - loss 1.20217
# ### backward computation ...
# ### forward computation ...
# epoch 215 - loss 1.57153
# ### backward computation ...
# ### forward computation ...
# epoch 216 - loss 1.18999
# ### backward computation ...
# ### forward computation ...
# epoch 217 - loss 1.55054
# ### backward computation ...
# ### forward computation ...
# epoch 218 - loss 1.17839
# ### backward computation ...
# ### forward computation ...
# epoch 219 - loss 1.53073
# ### backward computation ...
# ### forward computation ...
# epoch 220 - loss 1.16644
# ### backward computation ...
# ### forward computation ...
# epoch 221 - loss 1.51029
# ### backward computation ...
# ### forward computation ...
# epoch 222 - loss 1.15465
# ### backward computation ...
# ### forward computation ...
# epoch 223 - loss 1.49007
# ### backward computation ...
# ### forward computation ...
# epoch 224 - loss 1.14266
# ### backward computation ...
# ### forward computation ...
# epoch 225 - loss 1.46985
# ### backward computation ...
# ### forward computation ...
# epoch 226 - loss 1.13114
# ### backward computation ...
# ### forward computation ...
# epoch 227 - loss 1.45069
# ### backward computation ...
# ### forward computation ...
# epoch 228 - loss 1.11962
# ### backward computation ...
# ### forward computation ...
# epoch 229 - loss 1.43156
# ### backward computation ...
# ### forward computation ...
# epoch 230 - loss 1.10862
# ### backward computation ...
# ### forward computation ...
# epoch 231 - loss 1.41315
# ### backward computation ...
# ### forward computation ...
# epoch 232 - loss 1.09755
# ### backward computation ...
# ### forward computation ...
# epoch 233 - loss 1.39499
# ### backward computation ...
# ### forward computation ...
# epoch 234 - loss 1.08693
# ### backward computation ...
# ### forward computation ...
# epoch 235 - loss 1.37745
# ### backward computation ...
# ### forward computation ...
# epoch 236 - loss 1.07626
# ### backward computation ...
# ### forward computation ...
# epoch 237 - loss 1.35981
# ### backward computation ...
# ### forward computation ...
# epoch 238 - loss 1.06586
# ### backward computation ...
# ### forward computation ...
# epoch 239 - loss 1.34291
# ### backward computation ...
# ### forward computation ...
# epoch 240 - loss 1.05537
# ### backward computation ...
# ### forward computation ...
# epoch 241 - loss 1.32558
# ### backward computation ...
# ### forward computation ...
# epoch 242 - loss 1.04549
# ### backward computation ...
# ### forward computation ...
# epoch 243 - loss 1.3095
# ### backward computation ...
# ### forward computation ...
# epoch 244 - loss 1.03541
# ### backward computation ...
# ### forward computation ...
# epoch 245 - loss 1.29325
# ### backward computation ...
# ### forward computation ...
# epoch 246 - loss 1.02584
# ### backward computation ...
# ### forward computation ...
# epoch 247 - loss 1.27769
# ### backward computation ...
# ### forward computation ...
# epoch 248 - loss 1.0161
# ### backward computation ...
# ### forward computation ...
# epoch 249 - loss 1.26197
# ### backward computation ...
# ### forward computation ...
# epoch 250 - loss 1.00679
# ### backward computation ...
# ### forward computation ...
# epoch 251 - loss 1.24717
# ### backward computation ...
# ### forward computation ...
# epoch 252 - loss 0.99743
# ### backward computation ...
# ### forward computation ...
# epoch 253 - loss 1.23224
# ### backward computation ...
# ### forward computation ...
# epoch 254 - loss 0.988423
# ### backward computation ...
# ### forward computation ...
# epoch 255 - loss 1.21676
# ### backward computation ...
# ### forward computation ...
# epoch 256 - loss 0.97881
# ### backward computation ...
# ### forward computation ...
# epoch 257 - loss 1.20287
# ### backward computation ...
# ### forward computation ...
# epoch 258 - loss 0.970362
# ### backward computation ...
# ### forward computation ...
# epoch 259 - loss 1.18842
# ### backward computation ...
# ### forward computation ...
# epoch 260 - loss 0.961246
# ### backward computation ...
# ### forward computation ...
# epoch 261 - loss 1.17536
# ### backward computation ...
# ### forward computation ...
# epoch 262 - loss 0.95321
# ### backward computation ...
# ### forward computation ...
# epoch 263 - loss 1.16158
# ### backward computation ...
# ### forward computation ...
# epoch 264 - loss 0.944357
# ### backward computation ...
# ### forward computation ...
# epoch 265 - loss 1.149
# ### backward computation ...
# ### forward computation ...
# epoch 266 - loss 0.936367
# ### backward computation ...
# ### forward computation ...
# epoch 267 - loss 1.13544
# ### backward computation ...
# ### forward computation ...
# epoch 268 - loss 0.92811
# ### backward computation ...
# ### forward computation ...
# epoch 269 - loss 1.12379
# ### backward computation ...
# ### forward computation ...
# epoch 270 - loss 0.920421
# ### backward computation ...
# ### forward computation ...
# epoch 271 - loss 1.11076
# ### backward computation ...
# ### forward computation ...
# epoch 272 - loss 0.9128
# ### backward computation ...
# ### forward computation ...
# epoch 273 - loss 1.10014
# ### backward computation ...
# ### forward computation ...
# epoch 274 - loss 0.905777
# ### backward computation ...
# ### forward computation ...
# epoch 275 - loss 1.08928
# ### backward computation ...
# ### forward computation ...
# epoch 276 - loss 0.898904
# ### backward computation ...
# ### forward computation ...
# epoch 277 - loss 1.0787
# ### backward computation ...
# ### forward computation ...
# epoch 278 - loss 0.89173
# ### backward computation ...
# ### forward computation ...
# epoch 279 - loss 1.0677
# ### backward computation ...
# ### forward computation ...
# epoch 280 - loss 0.884642
# ### backward computation ...
# ### forward computation ...
# epoch 281 - loss 1.0569
# ### backward computation ...
# ### forward computation ...
# epoch 282 - loss 0.87798
# ### backward computation ...
# ### forward computation ...
# epoch 283 - loss 1.04647
# ### backward computation ...
# ### forward computation ...
# epoch 284 - loss 0.870945
# ### backward computation ...
# ### forward computation ...
# epoch 285 - loss 1.0348
# ### backward computation ...
# ### forward computation ...
# epoch 286 - loss 0.863384
# ### backward computation ...
# ### forward computation ...
# epoch 287 - loss 1.02451
# ### backward computation ...
# ### forward computation ...
# epoch 288 - loss 0.85683
# ### backward computation ...
# ### forward computation ...
# epoch 289 - loss 1.0146
# ### backward computation ...
# ### forward computation ...
# epoch 290 - loss 0.850097
# ### backward computation ...
# ### forward computation ...
# epoch 291 - loss 1.00453
# ### backward computation ...
# ### forward computation ...
# epoch 292 - loss 0.843442
# ### backward computation ...
# ### forward computation ...
# epoch 293 - loss 0.994588
# ### backward computation ...
# ### forward computation ...
# epoch 294 - loss 0.837039
# ### backward computation ...
# ### forward computation ...
# epoch 295 - loss 0.98395
# ### backward computation ...
# ### forward computation ...
# epoch 296 - loss 0.830492
# ### backward computation ...
# ### forward computation ...
# epoch 297 - loss 0.975231
# ### backward computation ...
# ### forward computation ...
# epoch 298 - loss 0.824644
# ### backward computation ...
# ### forward computation ...
# epoch 299 - loss 0.966518
# ### backward computation ...
# ### forward computation ...
# epoch 300 - loss 0.818941
# ### backward computation ...
# ### forward computation ...
# epoch 301 - loss 0.958065
# ### backward computation ...
# ### forward computation ...
# epoch 302 - loss 0.813043
# ### backward computation ...
# ### forward computation ...
# epoch 303 - loss 0.949313
# ### backward computation ...
# ### forward computation ...
# epoch 304 - loss 0.807155
# ### backward computation ...
# ### forward computation ...
# epoch 305 - loss 0.94065
# ### backward computation ...
# ### forward computation ...
# epoch 306 - loss 0.801468
# ### backward computation ...
# ### forward computation ...
# epoch 307 - loss 0.932268
# ### backward computation ...
# ### forward computation ...
# epoch 308 - loss 0.795611
# ### backward computation ...
# ### forward computation ...
# epoch 309 - loss 0.923687
# ### backward computation ...
# ### forward computation ...
# epoch 310 - loss 0.789879
# ### backward computation ...
# ### forward computation ...
# epoch 311 - loss 0.915306
# ### backward computation ...
# ### forward computation ...
# epoch 312 - loss 0.784077
# ### backward computation ...
# ### forward computation ...
# epoch 313 - loss 0.906874
# ### backward computation ...
# ### forward computation ...
# epoch 314 - loss 0.778478
# ### backward computation ...
# ### forward computation ...
# epoch 315 - loss 0.898674
# ### backward computation ...
# ### forward computation ...
# epoch 316 - loss 0.772788
# ### backward computation ...
# ### forward computation ...
# epoch 317 - loss 0.890451
# ### backward computation ...
# ### forward computation ...
# epoch 318 - loss 0.767278
# ### backward computation ...
# ### forward computation ...
# epoch 319 - loss 0.882493
# ### backward computation ...
# ### forward computation ...
# epoch 320 - loss 0.761721
# ### backward computation ...
# ### forward computation ...
# epoch 321 - loss 0.874506
# ### backward computation ...
# ### forward computation ...
# epoch 322 - loss 0.756359
# ### backward computation ...
# ### forward computation ...
# epoch 323 - loss 0.866809
# ### backward computation ...
# ### forward computation ...
# epoch 324 - loss 0.751061
# ### backward computation ...
# ### forward computation ...
# epoch 325 - loss 0.859232
# ### backward computation ...
# ### forward computation ...
# epoch 326 - loss 0.745837
# ### backward computation ...
# ### forward computation ...
# epoch 327 - loss 0.851785
# ### backward computation ...
# ### forward computation ...
# epoch 328 - loss 0.74083
# ### backward computation ...
# ### forward computation ...
# epoch 329 - loss 0.844644
# ### backward computation ...
# ### forward computation ...
# epoch 330 - loss 0.735717
# ### backward computation ...
# ### forward computation ...
# epoch 331 - loss 0.837378
# ### backward computation ...
# ### forward computation ...
# epoch 332 - loss 0.730726
# ### backward computation ...
# ### forward computation ...
# epoch 333 - loss 0.830426
# ### backward computation ...
# ### forward computation ...
# epoch 334 - loss 0.725961
# ### backward computation ...
# ### forward computation ...
# epoch 335 - loss 0.823671
# ### backward computation ...
# ### forward computation ...
# epoch 336 - loss 0.721091
# ### backward computation ...
# ### forward computation ...
# epoch 337 - loss 0.81681
# ### backward computation ...
# ### forward computation ...
# epoch 338 - loss 0.716391
# ### backward computation ...
# ### forward computation ...
# epoch 339 - loss 0.810178
# ### backward computation ...
# ### forward computation ...
# epoch 340 - loss 0.711644
# ### backward computation ...
# ### forward computation ...
# epoch 341 - loss 0.803612
# ### backward computation ...
# ### forward computation ...
# epoch 342 - loss 0.707068
# ### backward computation ...
# ### forward computation ...
# epoch 343 - loss 0.797165
# ### backward computation ...
# ### forward computation ...
# epoch 344 - loss 0.702597
# ### backward computation ...
# ### forward computation ...
# epoch 345 - loss 0.790905
# ### backward computation ...
# ### forward computation ...
# epoch 346 - loss 0.698181
# ### backward computation ...
# ### forward computation ...
# epoch 347 - loss 0.784808
# ### backward computation ...
# ### forward computation ...
# epoch 348 - loss 0.693881
# ### backward computation ...
# ### forward computation ...
# epoch 349 - loss 0.778838
# ### backward computation ...
# ### forward computation ...
# epoch 350 - loss 0.689753
# ### backward computation ...
# ### forward computation ...
# epoch 351 - loss 0.773098
# ### backward computation ...
# ### forward computation ...
# epoch 352 - loss 0.685532
# ### backward computation ...
# ### forward computation ...
# epoch 353 - loss 0.767205
# ### backward computation ...
# ### forward computation ...
# epoch 354 - loss 0.681374
# ### backward computation ...
# ### forward computation ...
# epoch 355 - loss 0.761524
# ### backward computation ...
# ### forward computation ...
# epoch 356 - loss 0.67737
# ### backward computation ...
# ### forward computation ...
# epoch 357 - loss 0.756739
# ### backward computation ...
# ### forward computation ...
# epoch 358 - loss 0.673781
# ### backward computation ...
# ### forward computation ...
# epoch 359 - loss 0.750995
# ### backward computation ...
# ### forward computation ...
# epoch 360 - loss 0.669664
# ### backward computation ...
# ### forward computation ...
# epoch 361 - loss 0.745328
# ### backward computation ...
# ### forward computation ...
# epoch 362 - loss 0.665729
# ### backward computation ...
# ### forward computation ...
# epoch 363 - loss 0.739898
# ### backward computation ...
# ### forward computation ...
# epoch 364 - loss 0.661739
# ### backward computation ...
# ### forward computation ...
# epoch 365 - loss 0.735254
# ### backward computation ...
# ### forward computation ...
# epoch 366 - loss 0.658463
# ### backward computation ...
# ### forward computation ...
# epoch 367 - loss 0.729994
# ### backward computation ...
# ### forward computation ...
# epoch 368 - loss 0.654515
# ### backward computation ...
# ### forward computation ...
# epoch 369 - loss 0.724652
# ### backward computation ...
# ### forward computation ...
# epoch 370 - loss 0.650641
# ### backward computation ...
# ### forward computation ...
# epoch 371 - loss 0.720101
# ### backward computation ...
# ### forward computation ...
# epoch 372 - loss 0.647408
# ### backward computation ...
# ### forward computation ...
# epoch 373 - loss 0.714905
# ### backward computation ...
# ### forward computation ...
# epoch 374 - loss 0.643597
# ### backward computation ...
# ### forward computation ...
# epoch 375 - loss 0.709827
# ### backward computation ...
# ### forward computation ...
# epoch 376 - loss 0.639933
# ### backward computation ...
# ### forward computation ...
# epoch 377 - loss 0.70557
# ### backward computation ...
# ### forward computation ...
# epoch 378 - loss 0.63682
# ### backward computation ...
# ### forward computation ...
# epoch 379 - loss 0.700627
# ### backward computation ...
# ### forward computation ...
# epoch 380 - loss 0.63313
# ### backward computation ...
# ### forward computation ...
# epoch 381 - loss 0.695694
# ### backward computation ...
# ### forward computation ...
# epoch 382 - loss 0.629508
# ### backward computation ...
# ### forward computation ...
# epoch 383 - loss 0.690809
# ### backward computation ...
# ### forward computation ...
# epoch 384 - loss 0.626004
# ### backward computation ...
# ### forward computation ...
# epoch 385 - loss 0.686737
# ### backward computation ...
# ### forward computation ...
# epoch 386 - loss 0.623077
# ### backward computation ...
# ### forward computation ...
# epoch 387 - loss 0.682174
# ### backward computation ...
# ### forward computation ...
# epoch 388 - loss 0.619741
# ### backward computation ...
# ### forward computation ...
# epoch 389 - loss 0.677681
# ### backward computation ...
# ### forward computation ...
# epoch 390 - loss 0.616352
# ### backward computation ...
# ### forward computation ...
# epoch 391 - loss 0.67389
# ### backward computation ...
# ### forward computation ...
# epoch 392 - loss 0.613501
# ### backward computation ...
# ### forward computation ...
# epoch 393 - loss 0.669376
# ### backward computation ...
# ### forward computation ...
# epoch 394 - loss 0.610243
# ### backward computation ...
# ### forward computation ...
# epoch 395 - loss 0.665109
# ### backward computation ...
# ### forward computation ...
# epoch 396 - loss 0.607025
# ### backward computation ...
# ### forward computation ...
# epoch 397 - loss 0.66078
# ### backward computation ...
# ### forward computation ...
# epoch 398 - loss 0.603841
# ### backward computation ...
# ### forward computation ...
# epoch 399 - loss 0.657267
# ### backward computation ...
# ### forward computation ...
# epoch 400 - loss 0.601222
# ### backward computation ...
# ### forward computation ...
# epoch 401 - loss 0.653265
# ### backward computation ...
# ### forward computation ...
# epoch 402 - loss 0.598153
# ### backward computation ...
# ### forward computation ...
# epoch 403 - loss 0.649136
# ### backward computation ...
# ### forward computation ...
# epoch 404 - loss 0.595063
# ### backward computation ...
# ### forward computation ...
# epoch 405 - loss 0.645839
# ### backward computation ...
# ### forward computation ...
# epoch 406 - loss 0.592626
# ### backward computation ...
# ### forward computation ...
# epoch 407 - loss 0.642062
# ### backward computation ...
# ### forward computation ...
# epoch 408 - loss 0.589744
# ### backward computation ...
# ### forward computation ...
# epoch 409 - loss 0.638111
# ### backward computation ...
# ### forward computation ...
# epoch 410 - loss 0.586737
# ### backward computation ...
# ### forward computation ...
# epoch 411 - loss 0.634164
# ### backward computation ...
# ### forward computation ...
# epoch 412 - loss 0.583832
# ### backward computation ...
# ### forward computation ...
# epoch 413 - loss 0.631198
# ### backward computation ...
# ### forward computation ...
# epoch 414 - loss 0.581493
# ### backward computation ...
# ### forward computation ...
# epoch 415 - loss 0.627331
# ### backward computation ...
# ### forward computation ...
# epoch 416 - loss 0.578749
# ### backward computation ...
# ### forward computation ...
# epoch 417 - loss 0.623716
# ### backward computation ...
# ### forward computation ...
# epoch 418 - loss 0.575927
# ### backward computation ...
# ### forward computation ...
# epoch 419 - loss 0.620928
# ### backward computation ...
# ### forward computation ...
# epoch 420 - loss 0.573858
# ### backward computation ...
# ### forward computation ...
# epoch 421 - loss 0.61732
# ### backward computation ...
# ### forward computation ...
# epoch 422 - loss 0.571121
# ### backward computation ...
# ### forward computation ...
# epoch 423 - loss 0.61397
# ### backward computation ...
# ### forward computation ...
# epoch 424 - loss 0.568454
# ### backward computation ...
# ### forward computation ...
# epoch 425 - loss 0.610362
# ### backward computation ...
# ### forward computation ...
# epoch 426 - loss 0.565843
# ### backward computation ...
# ### forward computation ...
# epoch 427 - loss 0.607794
# ### backward computation ...
# ### forward computation ...
# epoch 428 - loss 0.563822
# ### backward computation ...
# ### forward computation ...
# epoch 429 - loss 0.604352
# ### backward computation ...
# ### forward computation ...
# epoch 430 - loss 0.56108
# ### backward computation ...
# ### forward computation ...
# epoch 431 - loss 0.600823
# ### backward computation ...
# ### forward computation ...
# epoch 432 - loss 0.558492
# ### backward computation ...
# ### forward computation ...
# epoch 433 - loss 0.597635
# ### backward computation ...
# ### forward computation ...
# epoch 434 - loss 0.556074
# ### backward computation ...
# ### forward computation ...
# epoch 435 - loss 0.595019
# ### backward computation ...
# ### forward computation ...
# epoch 436 - loss 0.553841
# ### backward computation ...
# ### forward computation ...
# epoch 437 - loss 0.591761
# ### backward computation ...
# ### forward computation ...
# epoch 438 - loss 0.551562
# ### backward computation ...
# ### forward computation ...
# epoch 439 - loss 0.588638
# ### backward computation ...
# ### forward computation ...
# epoch 440 - loss 0.549095
# ### backward computation ...
# ### forward computation ...
# epoch 441 - loss 0.585487
# ### backward computation ...
# ### forward computation ...
# epoch 442 - loss 0.546524
# ### backward computation ...
# ### forward computation ...
# epoch 443 - loss 0.582979
# ### backward computation ...
# ### forward computation ...
# epoch 444 - loss 0.544755
# ### backward computation ...
# ### forward computation ...
# epoch 445 - loss 0.579935
# ### backward computation ...
# ### forward computation ...
# epoch 446 - loss 0.542336
# ### backward computation ...
# ### forward computation ...
# epoch 447 - loss 0.577011
# ### backward computation ...
# ### forward computation ...
# epoch 448 - loss 0.539938
# ### backward computation ...
# ### forward computation ...
# epoch 449 - loss 0.57385
# ### backward computation ...
# ### forward computation ...
# epoch 450 - loss 0.537625
# ### backward computation ...
# ### forward computation ...
# epoch 451 - loss 0.571626
# ### backward computation ...
# ### forward computation ...
# epoch 452 - loss 0.535928
# ### backward computation ...
# ### forward computation ...
# epoch 453 - loss 0.568764
# ### backward computation ...
# ### forward computation ...
# epoch 454 - loss 0.533476
# ### backward computation ...
# ### forward computation ...
# epoch 455 - loss 0.565637
# ### backward computation ...
# ### forward computation ...
# epoch 456 - loss 0.531236
# ### backward computation ...
# ### forward computation ...
# epoch 457 - loss 0.562651
# ### backward computation ...
# ### forward computation ...
# epoch 458 - loss 0.52895
# ### backward computation ...
# ### forward computation ...
# epoch 459 - loss 0.560469
# ### backward computation ...
# ### forward computation ...
# epoch 460 - loss 0.527141
# ### backward computation ...
# ### forward computation ...
# epoch 461 - loss 0.557493
# ### backward computation ...
# ### forward computation ...
# epoch 462 - loss 0.524704
# ### backward computation ...
# ### forward computation ...
# epoch 463 - loss 0.554451
# ### backward computation ...
# ### forward computation ...
# epoch 464 - loss 0.522554
# ### backward computation ...
# ### forward computation ...
# epoch 465 - loss 0.551834
# ### backward computation ...
# ### forward computation ...
# epoch 466 - loss 0.520393
# ### backward computation ...
# ### forward computation ...
# epoch 467 - loss 0.549641
# ### backward computation ...
# ### forward computation ...
# epoch 468 - loss 0.518671
# ### backward computation ...
# ### forward computation ...
# epoch 469 - loss 0.546955
# ### backward computation ...
# ### forward computation ...
# epoch 470 - loss 0.516482
# ### backward computation ...
# ### forward computation ...
# epoch 471 - loss 0.544165
# ### backward computation ...
# ### forward computation ...
# epoch 472 - loss 0.514369
# ### backward computation ...
# ### forward computation ...
# epoch 473 - loss 0.541609
# ### backward computation ...
# ### forward computation ...
# epoch 474 - loss 0.512406
# ### backward computation ...
# ### forward computation ...
# epoch 475 - loss 0.539558
# ### backward computation ...
# ### forward computation ...
# epoch 476 - loss 0.510711
# ### backward computation ...
# ### forward computation ...
# epoch 477 - loss 0.537078
# ### backward computation ...
# ### forward computation ...
# epoch 478 - loss 0.508846
# ### backward computation ...
# ### forward computation ...
# epoch 479 - loss 0.534597
# ### backward computation ...
# ### forward computation ...
# epoch 480 - loss 0.506869
# ### backward computation ...
# ### forward computation ...
# epoch 481 - loss 0.532258
# ### backward computation ...
# ### forward computation ...
# epoch 482 - loss 0.505086
# ### backward computation ...
# ### forward computation ...
# epoch 483 - loss 0.530418
# ### backward computation ...
# ### forward computation ...
# epoch 484 - loss 0.503381
# ### backward computation ...
# ### forward computation ...
# epoch 485 - loss 0.527939
# ### backward computation ...
# ### forward computation ...
# epoch 486 - loss 0.501567
# ### backward computation ...
# ### forward computation ...
# epoch 487 - loss 0.52557
# ### backward computation ...
# ### forward computation ...
# epoch 488 - loss 0.499711
# ### backward computation ...
# ### forward computation ...
# epoch 489 - loss 0.523413
# ### backward computation ...
# ### forward computation ...
# epoch 490 - loss 0.49799
# ### backward computation ...
# ### forward computation ...
# epoch 491 - loss 0.521733
# ### backward computation ...
# ### forward computation ...
# epoch 492 - loss 0.496619
# ### backward computation ...
# ### forward computation ...
# epoch 493 - loss 0.519575
# ### backward computation ...
# ### forward computation ...
# epoch 494 - loss 0.494777
# ### backward computation ...
# ### forward computation ...
# epoch 495 - loss 0.517211
# ### backward computation ...
# ### forward computation ...
# epoch 496 - loss 0.493011
# ### backward computation ...
# ### forward computation ...
# epoch 497 - loss 0.515635
# ### backward computation ...
# ### forward computation ...
# epoch 498 - loss 0.491702
# ### backward computation ...
# ### forward computation ...
# epoch 499 - loss 0.513431
# ### backward computation ...
# ### forward computation ...

# %%
f = open('./mse1.out', 'r')

epoch_loss = []

datalist = f.readlines()
for data in datalist:
  #print(data)
  epoch_loss.append( float(data) )

f.close()

print("epoch =", len(epoch_loss))
print( epoch_loss)


f2 = open('./mse1.pred', 'r')

x_new = []
y_pred = []
datalist = f2.readlines()
for data in datalist:
  #print(data)
  ds = data.split(',')
  x_new.append( float(ds[0]))
  y_pred.append( float(ds[1]))
  #x_new.append( float(data) )

f2.close()

print("pred =", len(x_new))
print( x_new )
print( y_pred )
# Out:
# epoch = 500
# [67.489609, 36.183304, 3.805676, 5.000232, 8.296937, 23.923233, 8.937137, 25.941015, 5.534361, 14.031943, 10.961138, 31.011953, 1.597384, 1.555107, 1.666991, 2.348547, 3.641995, 9.317761, 9.308985, 26.372009, 1.441564, 2.284064, 3.39267, 8.371698, 7.263563, 19.555326, 2.920745, 6.626138, 5.928283, 15.017142, 3.915987, 9.145955, 5.238049, 12.548389, 4.02987, 9.126759, 4.57761, 10.406572, 4.053232, 8.921091, 4.117034, 8.970029, 3.907644, 8.34062, 3.824693, 8.049714, 3.706047, 7.685143, 3.610447, 7.388716, 3.518332, 7.110267, 3.433344, 6.856637, 3.354631, 6.624651, 3.279814, 6.407872, 3.209307, 6.205914, 3.142904, 6.017657, 3.079684, 5.841089, 3.020224, 5.675289, 2.961113, 5.512846, 2.905597, 5.363316, 2.852674, 5.222943, 2.8034, 5.093474, 2.757457, 4.97001, 2.712841, 4.857728, 2.670185, 4.744214, 2.628576, 4.637486, 2.588187, 4.537941, 2.549103, 4.436662, 2.5115, 4.343015, 2.47651, 4.259153, 2.442359, 4.171563, 2.408118, 4.09119, 2.375538, 4.009001, 2.343258, 3.93198, 2.311955, 3.858878, 2.281277, 3.782773, 2.250893, 3.710782, 2.221426, 3.644112, 2.192225, 3.574064, 2.16324, 3.507414, 2.136454, 3.448985, 2.111066, 3.388389, 2.084836, 3.330698, 2.059659, 3.271584, 2.034118, 3.217358, 2.010614, 3.162671, 1.986441, 3.112653, 1.9634, 3.059628, 1.939745, 3.008514, 1.916833, 2.961514, 1.895017, 2.912173, 1.872449, 2.864652, 1.850412, 2.817496, 1.828621, 2.77373, 1.807887, 2.728372, 1.786753, 2.68435, 1.765995, 2.638206, 1.744609, 2.595235, 1.724663, 2.5574, 1.705659, 2.515758, 1.685833, 2.475879, 1.666482, 2.437381, 1.647587, 2.399689, 1.62893, 2.365669, 1.61165, 2.32862, 1.594216, 2.294068, 1.577038, 2.262481, 1.560949, 2.229096, 1.543836, 2.195889, 1.528111, 2.168299, 1.513354, 2.139075, 1.498681, 2.111382, 1.483185, 2.07874, 1.467579, 2.049271, 1.451712, 2.02289, 1.437237, 1.992464, 1.421859, 1.965706, 1.406294, 1.937307, 1.39191, 1.909294, 1.376379, 1.88029, 1.3617, 1.85355, 1.346662, 1.828657, 1.333632, 1.80281, 1.31901, 1.776782, 1.305579, 1.752565, 1.291665, 1.728083, 1.278291, 1.704401, 1.264757, 1.682629, 1.252962, 1.659752, 1.2397, 1.636525, 1.226879, 1.614169, 1.213991, 1.592034, 1.202172, 1.571535, 1.189989, 1.550536, 1.178391, 1.530729, 1.166436, 1.510292, 1.154654, 1.490071, 1.142662, 1.469853, 1.131137, 1.450692, 1.119623, 1.431564, 1.108619, 1.413153, 1.097553, 1.394992, 1.086925, 1.377445, 1.076257, 1.359815, 1.065857, 1.34291, 1.055369, 1.325575, 1.045486, 1.309499, 1.035415, 1.293249, 1.025836, 1.277695, 1.016099, 1.261969, 1.006785, 1.247171, 0.99743, 1.232241, 0.988423, 1.216763, 0.97881, 1.202875, 0.970362, 1.188419, 0.961246, 1.175361, 0.95321, 1.161581, 0.944357, 1.148996, 0.936367, 1.135436, 0.92811, 1.12379, 0.920421, 1.110764, 0.9128, 1.100138, 0.905777, 1.089276, 0.898904, 1.078695, 0.89173, 1.067698, 0.884642, 1.0569, 0.87798, 1.046468, 0.870945, 1.034801, 0.863384, 1.02451, 0.85683, 1.014597, 0.850097, 1.004529, 0.843442, 0.994588, 0.837039, 0.98395, 0.830492, 0.975231, 0.824644, 0.966518, 0.818941, 0.958065, 0.813043, 0.949313, 0.807155, 0.94065, 0.801468, 0.932268, 0.795611, 0.923687, 0.789879, 0.915306, 0.784077, 0.906874, 0.778478, 0.898674, 0.772788, 0.890451, 0.767278, 0.882493, 0.761721, 0.874506, 0.756359, 0.866809, 0.751061, 0.859232, 0.745837, 0.851785, 0.74083, 0.844644, 0.735717, 0.837378, 0.730726, 0.830426, 0.725961, 0.823671, 0.721091, 0.81681, 0.716391, 0.810178, 0.711644, 0.803612, 0.707068, 0.797165, 0.702597, 0.790905, 0.698181, 0.784808, 0.693881, 0.778838, 0.689753, 0.773098, 0.685532, 0.767205, 0.681374, 0.761524, 0.67737, 0.756739, 0.673781, 0.750995, 0.669664, 0.745328, 0.665729, 0.739898, 0.661739, 0.735254, 0.658463, 0.729994, 0.654515, 0.724652, 0.650641, 0.720101, 0.647408, 0.714905, 0.643597, 0.709827, 0.639933, 0.70557, 0.63682, 0.700627, 0.63313, 0.695694, 0.629508, 0.690809, 0.626004, 0.686737, 0.623077, 0.682174, 0.619741, 0.677681, 0.616352, 0.67389, 0.613501, 0.669376, 0.610243, 0.665109, 0.607025, 0.66078, 0.603841, 0.657267, 0.601222, 0.653265, 0.598153, 0.649136, 0.59 ...
# pred = 1000
# [0.0, 0.01001, 0.02002, 0.03003, 0.04004, 0.05005, 0.06006, 0.07007, 0.08008, 0.09009, 0.1001, 0.11011, 0.12012, 0.13013, 0.14014, 0.15015, 0.16016, 0.17017, 0.18018, 0.19019, 0.2002, 0.21021, 0.22022, 0.23023, 0.24024, 0.25025, 0.26026, 0.27027, 0.28028, 0.29029, 0.3003, 0.31031, 0.32032, 0.33033, 0.34034, 0.35035, 0.36036, 0.37037, 0.38038, 0.39039, 0.4004, 0.41041, 0.42042, 0.43043, 0.44044, 0.45045, 0.46046, 0.47047, 0.48048, 0.49049, 0.500501, 0.510511, 0.520521, 0.530531, 0.540541, 0.550551, 0.560561, 0.570571, 0.580581, 0.590591, 0.600601, 0.610611, 0.620621, 0.630631, 0.640641, 0.650651, 0.660661, 0.670671, 0.680681, 0.690691, 0.700701, 0.710711, 0.720721, 0.730731, 0.740741, 0.750751, 0.760761, 0.770771, 0.780781, 0.790791, 0.800801, 0.810811, 0.820821, 0.830831, 0.840841, 0.850851, 0.860861, 0.870871, 0.880881, 0.890891, 0.900901, 0.910911, 0.920921, 0.930931, 0.940941, 0.950951, 0.960961, 0.970971, 0.980981, 0.990991, 1.001001, 1.011011, 1.021021, 1.031031, 1.041041, 1.051051, 1.061061, 1.071071, 1.081081, 1.091091, 1.101101, 1.111111, 1.121121, 1.131131, 1.141141, 1.151151, 1.161161, 1.171171, 1.181181, 1.191191, 1.201201, 1.211211, 1.221221, 1.231231, 1.241241, 1.251251, 1.261261, 1.271271, 1.281281, 1.291291, 1.301301, 1.311311, 1.321321, 1.331331, 1.341341, 1.351351, 1.361361, 1.371371, 1.381381, 1.391391, 1.401401, 1.411411, 1.421421, 1.431431, 1.441441, 1.451451, 1.461461, 1.471471, 1.481481, 1.491491, 1.501502, 1.511512, 1.521522, 1.531532, 1.541542, 1.551552, 1.561562, 1.571572, 1.581582, 1.591592, 1.601602, 1.611612, 1.621622, 1.631632, 1.641642, 1.651652, 1.661662, 1.671672, 1.681682, 1.691692, 1.701702, 1.711712, 1.721722, 1.731732, 1.741742, 1.751752, 1.761762, 1.771772, 1.781782, 1.791792, 1.801802, 1.811812, 1.821822, 1.831832, 1.841842, 1.851852, 1.861862, 1.871872, 1.881882, 1.891892, 1.901902, 1.911912, 1.921922, 1.931932, 1.941942, 1.951952, 1.961962, 1.971972, 1.981982, 1.991992, 2.002002, 2.012012, 2.022022, 2.032032, 2.042042, 2.052052, 2.062062, 2.072072, 2.082082, 2.092092, 2.102102, 2.112112, 2.122122, 2.132132, 2.142142, 2.152152, 2.162162, 2.172172, 2.182182, 2.192192, 2.202202, 2.212212, 2.222222, 2.232232, 2.242242, 2.252252, 2.262262, 2.272272, 2.282282, 2.292292, 2.302302, 2.312312, 2.322322, 2.332332, 2.342342, 2.352352, 2.362362, 2.372372, 2.382382, 2.392392, 2.402402, 2.412412, 2.422422, 2.432432, 2.442442, 2.452452, 2.462462, 2.472472, 2.482482, 2.492492, 2.502502, 2.512512, 2.522522, 2.532532, 2.542542, 2.552552, 2.562562, 2.572572, 2.582582, 2.592592, 2.602603, 2.612613, 2.622623, 2.632633, 2.642643, 2.652653, 2.662663, 2.672673, 2.682683, 2.692693, 2.702703, 2.712713, 2.722723, 2.732733, 2.742743, 2.752753, 2.762763, 2.772773, 2.782783, 2.792793, 2.802803, 2.812813, 2.822823, 2.832833, 2.842843, 2.852853, 2.862863, 2.872873, 2.882883, 2.892893, 2.902903, 2.912913, 2.922923, 2.932933, 2.942943, 2.952953, 2.962963, 2.972973, 2.982983, 2.992993, 3.003003, 3.013013, 3.023023, 3.033033, 3.043043, 3.053053, 3.063063, 3.073073, 3.083083, 3.093093, 3.103103, 3.113113, 3.123123, 3.133133, 3.143143, 3.153153, 3.163163, 3.173173, 3.183183, 3.193193, 3.203203, 3.213213, 3.223223, 3.233233, 3.243243, 3.253253, 3.263263, 3.273273, 3.283283, 3.293293, 3.303303, 3.313313, 3.323323, 3.333333, 3.343343, 3.353353, 3.363363, 3.373373, 3.383383, 3.393393, 3.403404, 3.413414, 3.423424, 3.433434, 3.443444, 3.453454, 3.463464, 3.473474, 3.483484, 3.493494, 3.503504, 3.513514, 3.523524, 3.533534, 3.543544, 3.553554, 3.563564, 3.573574, 3.583584, 3.593594, 3.603604, 3.613614, 3.623624, 3.633634, 3.643644, 3.653654, 3.663664, 3.673674, 3.683684, 3.693694, 3.703704, 3.713714, 3.723724, 3.733734, 3.743744, 3.753754, 3.763764, 3.773774, 3.783784, 3.793794, 3.803804, 3.813814, 3.823824, 3.833834, 3.843844, 3.853854, 3.863864, 3.873874, 3.883884, 3.893894, 3.903904, 3.913914, 3.923924, 3.933934, 3.943944, 3.953954, 3.963964, 3.973974, 3.983984, 3.993994, 4.004004, 4.014014, 4.024024, 4.034034, 4.044044, 4.05405 ...
# [2.313752, 2.332247, 2.350268, 2.368179, 2.385911, 2.404669, 2.424042, 2.44341, 2.462773, 2.484101, 2.509953, 2.535789, 2.561608, 2.587407, 2.613185, 2.638938, 2.664665, 2.690363, 2.716032, 2.741666, 2.767267, 2.792829, 2.818353, 2.843834, 2.869785, 2.896508, 2.92318, 2.949799, 2.976362, 3.004577, 3.03533, 3.066011, 3.095962, 3.125634, 3.155228, 3.185075, 3.215474, 3.245785, 3.276006, 3.306134, 3.336166, 3.366155, 3.396047, 3.425837, 3.455521, 3.485097, 3.514562, 3.543915, 3.573152, 3.602272, 3.631271, 3.660147, 3.688898, 3.717522, 3.746016, 3.774378, 3.80261, 3.830708, 3.858789, 3.888024, 3.917107, 3.946324, 3.975574, 4.004661, 4.033584, 4.062339, 4.090925, 4.119339, 4.147579, 4.175643, 4.203528, 4.231233, 4.258754, 4.28609, 4.313238, 4.340198, 4.366964, 4.393537, 4.419913, 4.446101, 4.472167, 4.49803, 4.523687, 4.549136, 4.574375, 4.599402, 4.624215, 4.648812, 4.673191, 4.69735, 4.721288, 4.745002, 4.768491, 4.791753, 4.814786, 4.837589, 4.860159, 4.882495, 4.904596, 4.926459, 4.948082, 4.969466, 4.990607, 5.011505, 5.032157, 5.052563, 5.072721, 5.092628, 5.112285, 5.131689, 5.150839, 5.169734, 5.188373, 5.206753, 5.224875, 5.242736, 5.260335, 5.277673, 5.294745, 5.310794, 5.326586, 5.342127, 5.357414, 5.372448, 5.387227, 5.40175, 5.416017, 5.430027, 5.443778, 5.457269, 5.470502, 5.483474, 5.496184, 5.508633, 5.52082, 5.532743, 5.544401, 5.555795, 5.566926, 5.577789, 5.588388, 5.598719, 5.608784, 5.618582, 5.628112, 5.637373, 5.646367, 5.655091, 5.663548, 5.671735, 5.679652, 5.687299, 5.694678, 5.701786, 5.708626, 5.715194, 5.721501, 5.727597, 5.733423, 5.738979, 5.744265, 5.74928, 5.754026, 5.758502, 5.762709, 5.766645, 5.770314, 5.773713, 5.776844, 5.779706, 5.7823, 5.784627, 5.786719, 5.788603, 5.790224, 5.791581, 5.792674, 5.793505, 5.794074, 5.79438, 5.794426, 5.794213, 5.79374, 5.793007, 5.792017, 5.79077, 5.789266, 5.787506, 5.785491, 5.783222, 5.7807, 5.777926, 5.774901, 5.771626, 5.768112, 5.764368, 5.760377, 5.756139, 5.751659, 5.746934, 5.741967, 5.73676, 5.731311, 5.725626, 5.719702, 5.713542, 5.707147, 5.70052, 5.693659, 5.686568, 5.679248, 5.6717, 5.663926, 5.655927, 5.647704, 5.639259, 5.629893, 5.620238, 5.610354, 5.600239, 5.589899, 5.579332, 5.568542, 5.55753, 5.546298, 5.534848, 5.523181, 5.511302, 5.499209, 5.486906, 5.474395, 5.461677, 5.448755, 5.43563, 5.422305, 5.408782, 5.395063, 5.38115, 5.367045, 5.352751, 5.338339, 5.324222, 5.309926, 5.295455, 5.280808, 5.265991, 5.251004, 5.23585, 5.220531, 5.20505, 5.189408, 5.173609, 5.157654, 5.141546, 5.125287, 5.10888, 5.092327, 5.075631, 5.058793, 5.041818, 5.024705, 5.00746, 4.990084, 4.97258, 4.954949, 4.937196, 4.919322, 4.90133, 4.883223, 4.865002, 4.847222, 4.829401, 4.811477, 4.793453, 4.775335, 4.757132, 4.738837, 4.720453, 4.701982, 4.683446, 4.664833, 4.646141, 4.627373, 4.608533, 4.589623, 4.570646, 4.551604, 4.531947, 4.512146, 4.492288, 4.472374, 4.452409, 4.432395, 4.412333, 4.392228, 4.372082, 4.3519, 4.331681, 4.31143, 4.29109, 4.270363, 4.249372, 4.227016, 4.204639, 4.182578, 4.160667, 4.138745, 4.116816, 4.0938, 4.070321, 4.046842, 4.023366, 3.999897, 3.976439, 3.952993, 3.929563, 3.906152, 3.882714, 3.859163, 3.835668, 3.812204, 3.788776, 3.765386, 3.742038, 3.718783, 3.695786, 3.672841, 3.64995, 3.627115, 3.604417, 3.5818, 3.559248, 3.536766, 3.514357, 3.492023, 3.470349, 3.44876, 3.427254, 3.405834, 3.384143, 3.362808, 3.341607, 3.320502, 3.299422, 3.277798, 3.25625, 3.234813, 3.213488, 3.19228, 3.17119, 3.150223, 3.129379, 3.108664, 3.088079, 3.067628, 3.047313, 3.027137, 3.007103, 2.987215, 2.967474, 2.947883, 2.928447, 2.909165, 2.890043, 2.871082, 2.852286, 2.833657, 2.815197, 2.796911, 2.7788, 2.760866, 2.743113, 2.725543, 2.708157, 2.690938, 2.673909, 2.657074, 2.640435, 2.623996, 2.607841, 2.595153, 2.583185, 2.571396, 2.562633, 2.554174, 2.547655, 2.54165, 2.535749, 2.53088, 2.526231, 2.521673, 2.517208, 2.512836, 2.508559, 2.504377, 2.50029, 2.496301, 2.49241, 2.488617, 2.484923, 2.48133, 2.477834, 2.474037, 2.470348, 2.466769, ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.plot( x_new, y_pred, c='orange')
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %% [markdown]
# 学習

# %%
num_epochs = 1000

x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y.reshape(-1, 1)).float()

net = Net()
net.train()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()

epoch_loss = []
for epoch in range(num_epochs):
  
  outputs = net(x_tensor)
  loss = criterion(outputs, y_tensor)
    
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
    
  epoch_loss.append(loss.data.numpy().tolist())
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=1, bias=True)
# )
# True
# True
# True
# True
# True
# True
# <generator object Module.named_parameters at 0x7f99790439d0>
# fc1.weight
# True
# None
# ---
# fc1.bias
# True
# None
# ---
# fc2.weight
# True
# None
# ---
# fc2.bias
# True
# None
# ---
# fc3.weight
# True
# None
# ---
# fc3.bias
# True
# None
# ---
# Parameter containing:
# tensor([[ 0.3874, -0.5647],
#         [-0.6766,  0.6111],
#         [ 0.4934, -0.6330],
#         [ 0.5197,  0.3673],
#         [-0.2603, -0.0761],
#         [-0.3394,  0.0356],
#         [ 0.4697, -0.0500],
#         [-0.3039,  0.2805],
#         [ 0.1860, -0.6480],
#         [ 0.3688, -0.1265],
#         [ 0.2277, -0.5620],
#         [ 0.6186, -0.1891],
#         [ 0.4563, -0.3899],
#         [-0.0606,  0.5275],
#         [-0.2258, -0.6937],
#         [-0.6117,  0.6076],
#         [-0.1122,  0.6290],
#         [-0.3709,  0.4826],
#         [ 0.2488, -0.6291],
#         [ 0.3292,  0.6114],
#         [ 0.3217,  0.3992],
#         [-0.0649, -0.2912],
#         [-0.4742,  0.2912],
#         [-0.6123, -0.5004],
#         [ 0.4389, -0.2268],
#         [-0.4978,  0.6258],
#         [ 0.3140,  0.0377],
#         [ 0.3305,  0.3085],
#         [ 0.6995, -0.3024],
#         [ 0.2129,  0.2592],
#         [ 0.2770, -0.0453],
#         [ 0.2095, -0.0995],
#         [-0.3780,  0.1701],
#         [-0.5502, -0.3046],
#         [ 0.5532, -0.0504],
#         [-0.6565, -0.4028],
#         [-0.5443,  0.5956],
#         [-0.5551,  0.6634],
#         [ 0.0022, -0.3858],
#         [ 0.6274, -0.0873],
#         [ 0.2521,  0.2400],
#         [-0.5472, -0.1241],
#         [-0.2464,  0.2157],
#         [ 0.1812,  0.6282],
#         [-0.0033,  0.4497],
#         [ 0.3939, -0.2850],
#         [-0.4224, -0.5739],
#         [ 0.0893, -0.0360],
#         [-0.7055, -0.3926],
#         [-0.0435,  0.1849],
#         [-0.1636, -0.5669],
#         [-0.5485, -0.2755],
#         [ 0.6801, -0.3804],
#         [ 0.4860, -0.5582],
#         [ 0.5098,  0.4628],
#         [ 0.3876,  0.3581],
#         [ 0.0072,  0.3753],
#         [ 0.5108, -0.4711],
#         [ 0.1961, -0.6495],
#         [-0.2921,  0.3380],
#         [-0.0751,  0.5578],
#         [ 0.6284, -0.6240],
#         [ 0.6936, -0.6959],
#         [ 0.6185,  0.4071]], requires_grad=True)
# Parameter containing:
# tensor([-0.0496, -0.0880, -0.1924, -0.6547, -0.4498, -0.4681, -0.0112,  0.2777,
#          0.5326, -0.0246, -0.3511, -0.2808,  0.3130, -0.3792,  0.0641, -0.2834,
#          0.1871,  0.6836, -0.3702, -0.2328, -0.5259,  0.3564, -0.1728,  0.6914,
#         -0.6369, -0.2857,  0.4633, -0.6449, -0.2866, -0.5386,  0.3787, -0.0430,
#         -0.5644, -0.6919, -0.1616, -0.1238, -0.4502,  0.6048, -0.3602,  0.2825,
#         -0.4983,  0.2452, -0.5587, -0.2200, -0.0042,  0.4363,  0.0134, -0.5673,
#         -0.1924, -0.5274, -0.1785,  0.4260, -0.3300, -0.3874,  0.5215, -0.2541,
#         -0.3085,  0.5492, -0.1846, -0.5105,  0.5818,  0.6412,  0.0354,  0.0159],
#        requires_grad=True)
# OrderedDict([('fc1.weight', tensor([[ 0.3874, -0.5647],
#         [-0.6766,  0.6111],
#         [ 0.4934, -0.6330],
#         [ 0.5197,  0.3673],
#         [-0.2603, -0.0761],
#         [-0.3394,  0.0356],
#         [ 0.4697, -0.0500],
#         [-0.3039,  0.2805],
#         [ 0.1860, -0.6480],
#         [ 0.3688, -0.1265],
#         [ 0.2277, -0.5620],
#         [ 0.6186, -0.1891],
#         [ 0.4563, -0.3899],
#         [-0.0606,  0.5275],
#         [-0.2258, -0.6937],
#         [-0.6117,  0.6076],
#         [-0.1122,  0.6290],
#         [-0.3709,  0.4826],
#         [ 0.2488, -0.6291],
#         [ 0.3292,  0.6114],
#         [ 0.3217,  0.3992],
#         [-0.0649, -0.2912],
#         [-0.4742,  0.2912],
#         [-0.6123, -0.5004],
#         [ 0.4389, -0.2268],
#         [-0.4978,  0.6258],
#         [ 0.3140,  0.0377],
#         [ 0.3305,  0.3085],
#         [ 0.6995, -0.3024],
#         [ 0.2129,  0.2592],
#         [ 0.2770, -0.0453],
#         [ 0.2095, -0.0995],
#         [-0.3780,  0.1701],
#         [-0.5502, -0.3046],
#         [ 0.5532, -0.0504],
#         [-0.6565, -0.4028],
#         [-0.5443,  0.5956],
#         [-0.5551,  0.6634],
#         [ 0.0022, -0.3858],
#         [ 0.6274, -0.0873],
#         [ 0.2521,  0.2400],
#         [-0.5472, -0.1241],
#         [-0.2464,  0.2157],
#         [ 0.1812,  0.6282],
#         [-0.0033,  0.4497],
#         [ 0.3939, -0.2850],
#         [-0.4224, -0.5739],
#         [ 0.0893, -0.0360],
#         [-0.7055, -0.3926],
#         [-0.0435,  0.1849],
#         [-0.1636, -0.5669],
#         [-0.5485, -0.2755],
#         [ 0.6801, -0.3804],
#         [ 0.4860, -0.5582],
#         [ 0.5098,  0.4628],
#         [ 0.3876,  0.3581],
#         [ 0.0072,  0.3753],
#         [ 0.5108, -0.4711],
#         [ 0.1961, -0.6495],
#         [-0.2921,  0.3380],
#         [-0.0751,  0.5578],
#         [ 0.6284, -0.6240],
#         [ 0.6936, -0.6959],
#         [ 0.6185,  0.4071]])), ('fc1.bias', tensor([-0.0496, -0.0880, -0.1924, -0.6547, -0.4498, -0.4681, -0.0112,  0.2777,
#          0.5326, -0.0246, -0.3511, -0.2808,  0.3130, -0.3792,  0.0641, -0.2834,
#          0.1871,  0.6836, -0.3702, -0.2328, -0.5259,  0.3564, -0.1728,  0.6914,
#         -0.6369, -0.2857,  0.4633, -0.6449, -0.2866, -0.5386,  0.3787, -0.0430,
#         -0.5644, -0.6919, -0.1616, -0.1238, -0.4502,  0.6048, -0.3602,  0.2825,
#         -0.4983,  0.2452, -0.5587, -0.2200, -0.0042,  0.4363,  0.0134, -0.5673,
#         -0.1924, -0.5274, -0.1785,  0.4260, -0.3300, -0.3874,  0.5215, -0.2541,
#         -0.3085,  0.5492, -0.1846, -0.5105,  0.5818,  0.6412,  0.0354,  0.0159])), ('fc2.weight', tensor([[-0.0172, -0.0436,  0.0498,  ...,  0.0113, -0.0273,  0.0175],
#         [-0.0068,  0.0477,  0.0754,  ..., -0.0360,  0.0404, -0.0660],
#         [ 0.0725, -0.0036,  0.0990,  ...,  0.0152,  0.0963, -0.0857],
#         ...,
#         [ 0.0385, -0.0177,  0.0519,  ..., -0.0950,  0.0802,  0.0731],
#         [ 0.1232, -0.0715, -0.1201,  ..., -0.0822,  0.1247,  0.0124],
#         [ 0.1235,  0.0842, -0.0918,  ...,  0.0094, -0.0529, -0.0078]])), ('fc2.bias', tensor([-0.0188, -0.0585, -0.0066,  0.1040,  0.1140, -0.0592,  0.0688, -0.0143,
#          0.0989, -0.0312, -0.0463, -0.0146, -0.0183, -0.1153, -0.1101,  0.1229,
#          0.0568, -0.0013, -0.0279,  0.0698, -0.0616,  0.0588,  0.0413, -0.0637,
#         -0.0379, -0.1206, -0.0460,  0.1248,  0.0963,  0.0185,  0.1117, -0.0684])), ('fc3.weight', tensor([[ 0.1085, -0.1530, -0.1083,  0.0474,  0.1055,  0.0016, -0.0237,  0.1219,
#          -0.0203, -0.0923,  0.0807,  0.0318, -0.1578, -0.0448, -0.1077,  0.0541,
#          -0.0703, -0.0038, -0.0702, -0.0299,  0.0227, -0.1663, -0.1658, -0.0224,
#           0.1121,  0.1170, -0.1423,  0.1700, -0.1271,  0.1588,  0.0396,  0.0104]])), ('fc3.bias', tensor([-0.1371]))])
# <class 'collections.OrderedDict'>
# odict_keys(['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias'])
# ['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias']
# <class 'str'>
# tensor([-0.0496, -0.0880, -0.1924, -0.6547, -0.4498, -0.4681, -0.0112,  0.2777,
#          0.5326, -0.0246, -0.3511, -0.2808,  0.3130, -0.3792,  0.0641, -0.2834,
#          0.1871,  0.6836, -0.3702, -0.2328, -0.5259,  0.3564, -0.1728,  0.6914,
#         -0.6369, -0.2857,  0.4633, -0.6449, -0.2866, -0.5386,  0.3787, -0.0430,
#         -0.5644, -0.6919, -0.1616, -0.1238, -0.4502,  0.6048, -0.3602,  0.2825,
#         -0.4983,  0.2452, -0.5587, -0.2200, -0.0042,  0.4363,  0.0134, -0.5673,
#         -0.1924, -0.5274, -0.1785,  0.4260, -0.3300, -0.3874,  0.5215, -0.2541,
#         -0.3085,  0.5492, -0.1846, -0.5105,  0.5818,  0.6412,  0.0354,  0.0159])
# None
# True
# dict_keys(['training', '_parameters', '_buffers', '_non_persistent_buffers_set', '_backward_hooks', '_is_full_backward_hook', '_forward_hooks', '_forward_pre_hooks', '_state_dict_hooks', '_load_state_dict_pre_hooks', '_modules'])
# '\nepoch_loss = []\nfor epoch in range(num_epochs):\n  \n  outputs = net(x_tensor)\n  loss = criterion(outputs, y_tensor)\n    \n  optimizer.zero_grad()\n  loss.backward()\n  optimizer.step()\n    \n  epoch_loss.append(loss.data.numpy().tolist())\n'

# %% [markdown]
# 学習の収束の図化

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(list(range(len(epoch_loss))), epoch_loss)
ax.set_xlabel('#epoch')
ax.set_ylabel('loss')
fig.show()

# %% [markdown]
# 予測

# %%
net.eval()

_x_new = np.linspace(0, 10, 1000)
x1_new = np.sin(_x_new)
x2_new = np.exp(_x_new / 5)
x_new = np.stack([x1_new, x2_new], axis=1)


x_new_tensor = torch.from_numpy(x_new).float()
with torch.no_grad():
    y_pred_tensor = net(x_new_tensor)

y_pred = y_pred_tensor.data.numpy()



fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.plot(_x_new, y_pred, c='orange')
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %% [markdown]
# [ ミニバッチ学習 ]

# %% [markdown]
# サンプルデータ

# %%
import numpy as np

np.random.seed(2020)
_x = np.random.uniform(0, 10, 100)
x1 = np.sin(_x)
x2 = np.exp(_x / 5)
x = np.stack([x1, x2], axis=1)
y = 3 * x1 + 2 * x2 + np.random.uniform(-1, 1, 100)

# %% [markdown]
# DataSetクラスの定義

# %%
import torch

class MakeDataset(torch.utils.data.Dataset):

    def __init__(self, x, y=None):
        self.x = x
        self.y = y

    def __len__(self):
        return self.x.shape[0]

    def __getitem__(self, i):
        x = torch.from_numpy(self.x[i]).float()
        if self.y is not None:
            y = torch.from_numpy(self.y[i]).float()
        
        if self.y is not None:
            return x, y
        else:
            return x

# %% [markdown]
# ニューラルネットワークの定義

# %%
import torch
import torch.nn.functional
import torch.utils.data


class Net(torch.nn.Module):

  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = torch.nn.Linear(2, 64)
    self.fc2 = torch.nn.Linear(64, 32)
    self.fc3 = torch.nn.Linear(32, 1)

  def forward(self, x):
    x = torch.nn.functional.relu(self.fc1(x))
    x = torch.nn.functional.relu(self.fc2(x))
    x = self.fc3(x)
    return x

# %% [markdown]
# ミニバッチ学習

# %%
num_epochs = 1000
batch_size = 64

# prepare dataset
dataset = MakeDataset(x, y.reshape(-1, 1))
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

# prepare model and training parameters
net = Net()
net.train()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()

# training
epoch_loss = []
for epoch in range(num_epochs):
    
    # use 'dataloader' to start batch learning
    running_loss = 0   # loss in this epoch
    for inputs, labels in dataloader:
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # add loss of this batch to loss of epoch
        running_loss += loss.data.numpy().tolist()
    
    epoch_loss.append(running_loss)

# %% [markdown]
# 予測

# %%
net.eval()

_x_new = np.linspace(0, 10, 1000)
x1_new = np.sin(_x_new)
x2_new = np.exp(_x_new / 5)
x_new = np.stack([x1_new, x2_new], axis=1)


test_dataset = MakeDataset(x_new)
dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=64)

y_pred = None
with torch.no_grad():
    for inputs in dataloader:
        outputs = net(inputs)
        if y_pred is None:
            y_pred = outputs.data.numpy()
        else:
            y_pred = np.concatenate([y_pred, outputs.data.numpy()])

y_pred = y_pred.reshape(-1)

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(_x, y)
ax.plot(_x_new, y_pred, c='orange')
ax.set_xlabel('_x')
ax.set_ylabel('y')
fig.show()

# %%
x_tensor
# Out:
# tensor([[-0.4241,  7.1890],
#         [ 0.6372,  5.7361],
#         [-0.9268,  2.7718],
#         [ 0.4107,  1.7223],
#         [-0.2256,  1.9618],
#         [ 0.8260,  1.5433],
#         [ 0.3680,  1.7384],
#         [-0.2874,  1.9870],
#         [ 0.7196,  5.6087],
#         [ 1.0000,  1.3681],
#         [ 0.9869,  1.3255],
#         [ 0.9602,  4.5456],
#         [ 0.8820,  4.3608],
#         [-0.4032,  2.0367],
#         [-0.2661,  1.9782],
#         [ 0.3754,  3.7947],
#         [ 0.8252,  1.5437],
#         [-0.6201,  3.0736],
#         [ 0.9464,  1.2819],
#         [-0.0557,  1.8955],
#         [-0.1072,  6.7290],
#         [ 0.9806,  1.3162],
#         [-0.5556,  3.1231],
#         [-0.3258,  7.0380],
#         [-0.9488,  2.7366],
#         [ 0.3834,  3.8012],
#         [ 0.3353,  1.0708],
#         [-0.9886,  2.4899],
#         [ 0.9999,  1.3657],
#         [-0.9988,  2.5911],
#         [ 0.9920,  1.4041],
#         [ 0.4459,  6.0045],
#         [-0.5583,  2.1102],
#         [-0.6094,  2.1370],
#         [ 0.7457,  5.5658],
#         [ 0.1765,  3.6405],
#         [-0.4337,  3.2121],
#         [ 0.3897,  3.8065],
#         [ 0.9786,  1.4270],
#         [ 0.8030,  5.4657],
#         [-0.9586,  2.4224],
#         [ 0.8957,  5.2748],
#         [ 0.9770,  4.6082],
#         [ 0.2259,  6.2926],
#         [ 0.6486,  1.1516],
#         [ 1.0000,  1.3666],
#         [ 0.0857,  3.5744],
#         [-0.6641,  3.0386],
#         [ 0.9399,  1.4679],
#         [-0.8979,  2.3427],
#         [-0.9123,  2.7922],
#         [ 0.4330,  1.7139],
#         [-0.2888,  3.3136],
#         [ 0.8075,  1.5532],
#         [ 0.1326,  1.8253],
#         [ 0.4653,  1.1016],
#         [-0.5972,  3.0914],
#         [ 0.0644,  6.5017],
#         [ 0.9845,  4.9831],
#         [ 0.6364,  4.0334],
#         [-0.9951,  2.5162],
#         [ 0.3346,  3.7617],
#         [ 0.9368,  4.4787],
#         [-0.8241,  2.8948],
#         [-0.9933,  2.6264],
#         [ 0.2886,  1.0603],
#         [ 0.4635,  5.9809],
#         [ 0.8955,  5.2755],
#         [ 0.8890,  4.3740],
#         [ 0.4258,  6.0315],
#         [ 0.7408,  1.5864],
#         [ 0.9739,  1.4332],
#         [-0.1411,  3.4155],
#         [ 0.1659,  1.0339],
#         [ 0.1478,  1.8197],
#         [ 0.3915,  3.8079],
#         [-0.1006,  6.7201],
#         [ 0.9529,  5.1162],
#         [ 0.7023,  1.1685],
#         [ 0.9749,  1.3090],
#         [-0.4949,  3.1680],
#         [ 0.9797,  1.4255],
#         [-0.4967,  7.3076],
#         [ 0.9222,  1.2646],
#         [ 0.8502,  5.3746],
#         [ 0.1398,  1.0285],
#         [ 0.6502,  5.7166],
#         [ 0.3901,  6.0788],
#         [-0.9758,  2.4557],
#         [-0.1012,  3.4431],
#         [-0.3570,  7.0848],
#         [-0.7387,  2.2135],
#         [-0.9713,  2.4460],
#         [ 0.7236,  1.5944],
#         [ 0.1073,  6.4460],
#         [ 0.4019,  1.7257],
#         [ 0.1013,  6.4537],
#         [-0.8364,  2.2852],
#         [ 0.9994,  1.3790],
#         [-0.9997,  2.5539]])
